# %% [markdown]
# # Jupyter Notebook: Parsing CSV file and Visualizing Data

# %% [markdown]
# In this notebook, we will load a CSV file, convert it to a pandas DataFrame, and then create a map visualizations using folium.

# %%
pip install pandas folium
# Out:
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (2.2.3)
# Requirement already satisfied: folium in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (0.17.0)
# Requirement already satisfied: numpy>=1.23.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/ceraven/Library/Python/3.11/lib/python/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas) (2024.2)
# Requirement already satisfied: branca>=0.6.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from folium) (0.8.0)
# Requirement already satisfied: jinja2>=2.9 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from folium) (3.1.4)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from folium) (2024.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jinja2>=2.9->folium) (2.1.5)
# Requirement already satisfied: six>=1.5 in /Users/ceraven/Library/Python/3.11/lib/python/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->folium) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->folium) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->folium) (2024.8.30)
#
# [notice] A new release of pip available: 22.3.1 -> 24.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import necessary libraries
import pandas as pd
import folium

# %% [markdown]
# ## Step 1: Load CSV File

# %%
# Load the CSV file into a DataFrame
file_path = "colorado_cultivations_full_list.csv"

df = pd.read_csv(file_path)

# Optional: Display the first few rows to check if the file is loaded correctly
df.head(15)
# Out:
#    License Number                    Facility Name                      DBA  \
# 0       403-01840                         1-11 LLC                     1:11
# 1       403-00164                 1022 S ROYER LLC                 Hightops
# 2       403-00687  11761013 COLORADO HOLDINGS LLC               A Cut Above
# 3       403-01932              132 ENTERPRISES LLC                    KLONE
# 4       403-01080             1395 SOUTH ACOMA LLC                      NaN
# 5       403-01998                        1CURE LLC                      NaN
# 6       403-01472        2222 E BOULDER STREET LLC                 HIGHTOPS
# 7       403-00980               4611 EXPANSION LLC                      NaN
# 8       403-01390            4747 PEARL STREET LLC  Great Ascent Botanicals
# 9       403-01401                         7415 LLC                      NaN
# 10      403-01613                         8058 LLC              Mighty Tree
# 11      403-00457       ABUNDANT HEALTH DENVER LLC       Herban Underground
# 12      403-02014                   ACES PLACE LLC                      NaN
# 13      403-01753         ADAMS GREEN CROSSING LLC                      NaN
# 14      403-01812         ADAMS GREEN CROSSING LLC     Adams Green Crossing
#
#                     Facility Type                               Street  \
# 0   Medical Marijuana Cultivation                  54414 County Road F
# 1   Medical Marijuana Cultivation              1022 South Royer Street
# 2   Medical Marijuana Cultivation                  3410 Astrozon Court
# 3   Medical Marijuana Cultivation      322 North Norfolk Street Unit I
# 4   Medical Marijuana Cultivation              1395 South Acoma Street
# 5   Medical Marijuana Cultivation                   7835 Maverick Lane
# 6               Optional Premises             2222 East Boulder Street
# 7   Medical Marijuana Cultivation                4655 East 46th Avenue
# 8   Medical Marijuana Cultivation            4747 Pearl Street Unit M1
# 9   Medical Marijuana Cultivation                        7415 Rex Road
# 10  Medical Marijuana Cultivation              4755 North Lipan Street
# 11  Medical Marijuana Cultivation          70 North Broadway, Suite 50
# 12  Medical Marijuana Cultivation                 14621 County Road 98
# 13  Medical Marijuana Cultivation  2727 Palmer Park Boulevard, Suite A
# 14  Medical Marijuana Cultivation      4595 East 46th Avenue, Unit 100
#
#                 City State  Zip Code Date Updated   Latitude   Longitude
# 0             Center    CO     81125   2024-09-03  37.820974 -106.012161
# 1   Colorado Springs    CO     80903   2024-09-03  38.819517 -104.815490
# 2   Colorado Springs    CO     80910   2024-09-03  38.790208 -104.767190
# 3             Aurora    CO     80011   2024-09-03  39.725483 -104.797924
# 4             Denver    CO     80223   2024-09-03  39.691360 -104.988803
# 5             Ordway    CO     81063   2024-09-03  38.388905 -104.676225
# 6   Colorado Springs    CO     80909   2024-09-03  38.838693 -104.787942
# 7             Denver    CO     80216   2024-09-03  39.780562 -104.932860
# 8            Boulder    CO     80301   2024-09-03  40.026155 -105.241834
# 9             Pueblo    CO     81005   2024-09-03  38.255533 -104.650620
# 10            Denver    CO     80211   2024-09-03  39.782501 -105.001764
# 11            Denver    CO     80203   2024-09-03  39.717834 -104.987427
# 12              Nunn    CO     80648   2024-09-03  40.696002 -104.775428
# 13  Colorado Springs    CO     80909   2024-09-03  38.853439 -104.777734
# 14            Denver    CO     80216   2024-09-03  39.780561 -104.933306

# %% [markdown]
# ## Step 2: Clean and Prepare the Data

# %%
# Check column names and data types
df.info()

# Clean any missing latitude or longitude data
df.dropna(subset=['Longitude', 'Latitude'], inplace=True)

# Optional: Check for missing values in other important columns
df.isnull().sum()

# Optional: Display the first few rows of cleaned data
df.head(15)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 824 entries, 0 to 823
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   License Number  824 non-null    object
#  1   Facility Name   824 non-null    object
#  2   DBA             507 non-null    object
#  3   Facility Type   824 non-null    object
#  4   Street          824 non-null    object
#  5   City            824 non-null    object
#  6   State           824 non-null    object
#  7   Zip Code        824 non-null    int64
#  8   Date Updated    824 non-null    object
#  9   Latitude        824 non-null    float64
#  10  Longitude       824 non-null    float64
# dtypes: float64(2), int64(1), object(8)
# memory usage: 70.9+ KB
#    License Number                    Facility Name                      DBA  \
# 0       403-01840                         1-11 LLC                     1:11
# 1       403-00164                 1022 S ROYER LLC                 Hightops
# 2       403-00687  11761013 COLORADO HOLDINGS LLC               A Cut Above
# 3       403-01932              132 ENTERPRISES LLC                    KLONE
# 4       403-01080             1395 SOUTH ACOMA LLC                      NaN
# 5       403-01998                        1CURE LLC                      NaN
# 6       403-01472        2222 E BOULDER STREET LLC                 HIGHTOPS
# 7       403-00980               4611 EXPANSION LLC                      NaN
# 8       403-01390            4747 PEARL STREET LLC  Great Ascent Botanicals
# 9       403-01401                         7415 LLC                      NaN
# 10      403-01613                         8058 LLC              Mighty Tree
# 11      403-00457       ABUNDANT HEALTH DENVER LLC       Herban Underground
# 12      403-02014                   ACES PLACE LLC                      NaN
# 13      403-01753         ADAMS GREEN CROSSING LLC                      NaN
# 14      403-01812         ADAMS GREEN CROSSING LLC     Adams Green Crossing
#
#                     Facility Type                               Street  \
# 0   Medical Marijuana Cultivation                  54414 County Road F
# 1   Medical Marijuana Cultivation              1022 South Royer Street
# 2   Medical Marijuana Cultivation                  3410 Astrozon Court
# 3   Medical Marijuana Cultivation      322 North Norfolk Street Unit I
# 4   Medical Marijuana Cultivation              1395 South Acoma Street
# 5   Medical Marijuana Cultivation                   7835 Maverick Lane
# 6               Optional Premises             2222 East Boulder Street
# 7   Medical Marijuana Cultivation                4655 East 46th Avenue
# 8   Medical Marijuana Cultivation            4747 Pearl Street Unit M1
# 9   Medical Marijuana Cultivation                        7415 Rex Road
# 10  Medical Marijuana Cultivation              4755 North Lipan Street
# 11  Medical Marijuana Cultivation          70 North Broadway, Suite 50
# 12  Medical Marijuana Cultivation                 14621 County Road 98
# 13  Medical Marijuana Cultivation  2727 Palmer Park Boulevard, Suite A
# 14  Medical Marijuana Cultivation      4595 East 46th Avenue, Unit 100
#
#                 City State  Zip Code Date Updated   Latitude   Longitude
# 0             Center    CO     81125   2024-09-03  37.820974 -106.012161
# 1   Colorado Springs    CO     80903   2024-09-03  38.819517 -104.815490
# 2   Colorado Springs    CO     80910   2024-09-03  38.790208 -104.767190
# 3             Aurora    CO     80011   2024-09-03  39.725483 -104.797924
# 4             Denver    CO     80223   2024-09-03  39.691360 -104.988803
# 5             Ordway    CO     81063   2024-09-03  38.388905 -104.676225
# 6   Colorado Springs    CO     80909   2024-09-03  38.838693 -104.787942
# 7             Denver    CO     80216   2024-09-03  39.780562 -104.932860
# 8            Boulder    CO     80301   2024-09-03  40.026155 -105.241834
# 9             Pueblo    CO     81005   2024-09-03  38.255533 -104.650620
# 10            Denver    CO     80211   2024-09-03  39.782501 -105.001764
# 11            Denver    CO     80203   2024-09-03  39.717834 -104.987427
# 12              Nunn    CO     80648   2024-09-03  40.696002 -104.775428
# 13  Colorado Springs    CO     80909   2024-09-03  38.853439 -104.777734
# 14            Denver    CO     80216   2024-09-03  39.780561 -104.933306

# %% [markdown]
# ## Step 3: Create a Searchable Map

# %%
# Initialize the map centered around Colorado
m = folium.Map(location=[39.5501, -105.7821], zoom_start=7)

# Add markers to the map for each food pantry
for idx, row in df.iterrows():
    popup_text = f"""
    <strong>{row['Facility Name']}</strong><br>
    <strong>{row['DBA']}</strong><br>
    Facility Type: {row['Facility Type']}<br>
    {row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip Code']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m)

# Save the map as an HTML file
m.save("colorado_cultivations_full_list_map.html")

# Display the map in the notebook
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_56fbc65aa0a076638397b130440446c1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_56fbc65aa0a076638397b130440446c1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_56fbc65aa0a076638397b130440446c1 = L.map(
#                 &quot;map_56fbc65aa0a076638397b130440446c1&quot;,
#                 {
#                     center: [39.5501, -105.7821],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_10c8c4e282b359c6765a5f262c1116fc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_10c8c4e282b359c6765a5f262c1116fc.addTo(map_56fbc65aa0a076638397b130440446c1);
#
#
#             var marker_a5ba2e3fb767ec331ba618e0a897a156 = L.marker(
#                 [37.820974, -106.012161],
#                 {}
#             ).addTo(map_56fbc65aa0a076638397b130440446c1);
#
#
#             var icon_bc88324c7e0cbe0f9a1413a3515247e9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a5ba2e3fb767ec331ba618e0a897a156.setIcon(icon_bc88324c7e0cbe0f9a1413a3515247e9);
#
#
#         var popup_aeca88e653fe0d7a4d1d8fd1fc5e79a1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d5a806054ec822ca263adc9b6159eb10 = $(`&lt;div id=&quot;html_d5a806054ec822ca263adc9b6159eb10&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;1-11 LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;1:11&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Cultivation&lt;br&gt;     54414 County Road F&lt;br&gt;     Center, CO 81125     &lt;/div&gt;`)[0];
#                 popup_aeca88e653fe0d7a4d1d8fd1fc5e79a1.setContent(html_d5a806054ec822ca263adc9b6159eb10);
#
#
#
#         marker_a5ba2e3fb767ec331ba618e0a897a156.bindPopup(popup_aeca88e653fe0d7a4d1d8fd1fc5e79a1)
#         ;
#
#
#
#
#             var marker_34048c3c50fc06d168789a3f851cdd3a = L.marker(
#                 [38.8195171, -104.8154896],
#                 {}
#             ).addTo(map_56fbc65aa0a076638397b130440446c1);
#
#
#             var icon_d9f650da366a062514b3a6e6fada16d0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_34048c3c50fc06d168789a3f851cdd3a.setIcon(icon_d9f650da366a062514b3a6e6fada16d0);
#
#
#         var popup_63e0fc823e93797984f6bf1719bd3748 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7282e0239e2fe4061430cc31097aab14 = $(`&lt;div id=&quot;html_7282e0239e2fe4061430cc31097aab14&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;1022 S ROYER LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Hightops&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Cultivation&lt;br&gt;     1022 South Royer Street&lt;br&gt;     Colorado Springs, CO 80903     &lt;/div&gt;`)[0];
#                 popup_63e0fc823e93797984f6bf1719bd3748.setContent(html_7282e0239e2fe4061430cc31097aab14);
#
#
#
#         marker_34048c3c50fc06d168789a3f851cdd3a.bindPopup(popup_63e0fc823e93797984f6bf1719bd3748)
#         ;
#
#
#
#
#             var marker_1fb7943eb59dbb3eed7f4ce6a30ab471 = L.marker(
#                 [38.7902083, -104.7671904],
#                 {}
#             ).addTo(map_56fbc65aa0a076638397b130440446c1);
#
#
#             var icon_24d3684c8638f0784ae2a806ca5a713d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1fb7943eb59dbb3eed7f4ce6a30ab471.setIcon(icon_24d3684c8638f0784ae2a806ca5a713d);
#
#
#         var popup_d4b69bbda15b554419867a301c7e89e6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b9faae5eac2c42075624c86a240228ca = $(`&lt;div id=&quot;html_b9faae5eac2c42075624c86a240228ca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;11761013 COLORADO HOLDINGS LLC &lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;A Cut Above&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Cultivation&lt;br&gt;     3410 Astrozon Court&lt;br&gt;     Colorado Springs, CO 80910     &lt;/div&gt;`)[0];

# %% [markdown]
# ## Step 4: Implement Search Functionality

# %%
# Example: Search for cultivations in a specific city
city_search = "Denver"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[39.5501, -105.7821], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Facility Name']}</strong><br>
    <strong>{row['DBA']}</strong><br>
    Facility Type: {row['Facility Type']}<br>
    {row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip Code']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_cultivations_map_denver.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1e70299800e6d1b6fb0510d324c6e945 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1e70299800e6d1b6fb0510d324c6e945&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1e70299800e6d1b6fb0510d324c6e945 = L.map(
#                 &quot;map_1e70299800e6d1b6fb0510d324c6e945&quot;,
#                 {
#                     center: [39.5501, -105.7821],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c7a3d6fa4fb3211f4817fbbba36cdbfa = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c7a3d6fa4fb3211f4817fbbba36cdbfa.addTo(map_1e70299800e6d1b6fb0510d324c6e945);
#
#
#             var marker_680d531d7804c9d362b3b4685599ec89 = L.marker(
#                 [39.6913598, -104.9888029],
#                 {}
#             ).addTo(map_1e70299800e6d1b6fb0510d324c6e945);
#
#
#             var icon_4a412ca72ccd828765efea538f2794ee = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_680d531d7804c9d362b3b4685599ec89.setIcon(icon_4a412ca72ccd828765efea538f2794ee);
#
#
#         var popup_7cf19d86768744c56367eb2430d5e958 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e072a0b968dc930fadee7482ac75604f = $(`&lt;div id=&quot;html_e072a0b968dc930fadee7482ac75604f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;1395 SOUTH ACOMA LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;nan&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Cultivation&lt;br&gt;     1395 South Acoma Street&lt;br&gt;     Denver, CO 80223     &lt;/div&gt;`)[0];
#                 popup_7cf19d86768744c56367eb2430d5e958.setContent(html_e072a0b968dc930fadee7482ac75604f);
#
#
#
#         marker_680d531d7804c9d362b3b4685599ec89.bindPopup(popup_7cf19d86768744c56367eb2430d5e958)
#         ;
#
#
#
#
#             var marker_0841ac4a29582e1944237f9f2ce0186c = L.marker(
#                 [39.7805618, -104.9328597],
#                 {}
#             ).addTo(map_1e70299800e6d1b6fb0510d324c6e945);
#
#
#             var icon_12f34f1887514c7f9c37a7e20dfd27df = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0841ac4a29582e1944237f9f2ce0186c.setIcon(icon_12f34f1887514c7f9c37a7e20dfd27df);
#
#
#         var popup_a91a07651aaa63e380772dfd5e207e56 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_27b60e816ca289919f4cccfe9bf6e8af = $(`&lt;div id=&quot;html_27b60e816ca289919f4cccfe9bf6e8af&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;4611 EXPANSION LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;nan&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Cultivation&lt;br&gt;     4655 East 46th Avenue&lt;br&gt;     Denver, CO 80216     &lt;/div&gt;`)[0];
#                 popup_a91a07651aaa63e380772dfd5e207e56.setContent(html_27b60e816ca289919f4cccfe9bf6e8af);
#
#
#
#         marker_0841ac4a29582e1944237f9f2ce0186c.bindPopup(popup_a91a07651aaa63e380772dfd5e207e56)
#         ;
#
#
#
#
#             var marker_6a06abffa068a972c0091c2628f3f339 = L.marker(
#                 [39.782501, -105.001764],
#                 {}
#             ).addTo(map_1e70299800e6d1b6fb0510d324c6e945);
#
#
#             var icon_00fd2e367af73a771e976c37b9d4b80c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6a06abffa068a972c0091c2628f3f339.setIcon(icon_00fd2e367af73a771e976c37b9d4b80c);
#
#
#         var popup_1ca2251bf323449360c697a6c97aaf7c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_46cd8e66e97570b0d6bcd25f1ad8e93e = $(`&lt;div id=&quot;html_46cd8e66e97570b0d6bcd25f1ad8e93e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;8058 LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Mighty Tree&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Cultivation&lt;br&gt;     4755 North Lipan Street&lt;br&gt;     Denver, CO 80211     &lt;/div&gt;`)[0];
#                 popup_1ca2251bf3234493

# %%
# Example: Search for cultivations in a specific city
city_search = "Colorado Springs"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[38.8591, -104.8135], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Facility Name']}</strong><br>
    <strong>{row['DBA']}</strong><br>
    Facility Type: {row['Facility Type']}<br>
    {row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip Code']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_cultivations_map_colorado_springs.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_464cfee26b875331e0fe1d3e5f36496d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_464cfee26b875331e0fe1d3e5f36496d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_464cfee26b875331e0fe1d3e5f36496d = L.map(
#                 &quot;map_464cfee26b875331e0fe1d3e5f36496d&quot;,
#                 {
#                     center: [38.8591, -104.8135],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6974fde6160fdb19be9e463d6e214d98 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_6974fde6160fdb19be9e463d6e214d98.addTo(map_464cfee26b875331e0fe1d3e5f36496d);
#
#
#             var marker_bd982b8fe23eb18c3330cc95fe1312aa = L.marker(
#                 [38.8195171, -104.8154896],
#                 {}
#             ).addTo(map_464cfee26b875331e0fe1d3e5f36496d);
#
#
#             var icon_7b97f8f04ecf7b7137b799e0b100f566 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_bd982b8fe23eb18c3330cc95fe1312aa.setIcon(icon_7b97f8f04ecf7b7137b799e0b100f566);
#
#
#         var popup_7ba360bef76b9fd38d502aba8b62f565 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a8da2c139eb2f25d8e6c499a8861092c = $(`&lt;div id=&quot;html_a8da2c139eb2f25d8e6c499a8861092c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;1022 S ROYER LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Hightops&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Cultivation&lt;br&gt;     1022 South Royer Street&lt;br&gt;     Colorado Springs, CO 80903     &lt;/div&gt;`)[0];
#                 popup_7ba360bef76b9fd38d502aba8b62f565.setContent(html_a8da2c139eb2f25d8e6c499a8861092c);
#
#
#
#         marker_bd982b8fe23eb18c3330cc95fe1312aa.bindPopup(popup_7ba360bef76b9fd38d502aba8b62f565)
#         ;
#
#
#
#
#             var marker_5d3d16ffd84409a26f6a4abe47d9749b = L.marker(
#                 [38.7902083, -104.7671904],
#                 {}
#             ).addTo(map_464cfee26b875331e0fe1d3e5f36496d);
#
#
#             var icon_fcf3fc86585f6ee9aa1d99649a78be13 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5d3d16ffd84409a26f6a4abe47d9749b.setIcon(icon_fcf3fc86585f6ee9aa1d99649a78be13);
#
#
#         var popup_ed937ddbb7abb4d5a8d41254f7109215 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b880b3a33db11befa2e817b18dc174f2 = $(`&lt;div id=&quot;html_b880b3a33db11befa2e817b18dc174f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;11761013 COLORADO HOLDINGS LLC &lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;A Cut Above&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Cultivation&lt;br&gt;     3410 Astrozon Court&lt;br&gt;     Colorado Springs, CO 80910     &lt;/div&gt;`)[0];
#                 popup_ed937ddbb7abb4d5a8d41254f7109215.setContent(html_b880b3a33db11befa2e817b18dc174f2);
#
#
#
#         marker_5d3d16ffd84409a26f6a4abe47d9749b.bindPopup(popup_ed937ddbb7abb4d5a8d41254f7109215)
#         ;
#
#
#
#
#             var marker_e4738e1d477bcf452c4626071483f206 = L.marker(
#                 [38.8386928, -104.7879422],
#                 {}
#             ).addTo(map_464cfee26b875331e0fe1d3e5f36496d);
#
#
#             var icon_18dd4aebeed28f0419781733d9fbf894 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e4738e1d477bcf452c4626071483f206.setIcon(icon_18dd4aebeed28f0419781733d9fbf894);
#
#
#         var popup_ee6d5f1e7a88776691488b791fbd7487 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8fcafb18d2edfb158d18e9b7ff499d44 = $(`&lt;div id=&quot;html_8fcafb18d2edfb158d18e9b7ff499d44&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;2222 E BOULDER STREET LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;HIGHTOPS&lt;/strong&gt;&lt;br&gt;     Facility Type: Optional Premises&lt;br&gt;     2222 East Boulder Street&lt;br&gt;     Colorado Springs, CO 80909     &l

# %%
# Example: Search for cultivations in a specific city
city_search = "Aurora"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[39.7108, -104.8125], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Facility Name']}</strong><br>
    <strong>{row['DBA']}</strong><br>
    Facility Type: {row['Facility Type']}<br>
    {row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip Code']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_cultivations_map_aurora.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2a416387516274ea92daf35d808b26ce {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2a416387516274ea92daf35d808b26ce&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2a416387516274ea92daf35d808b26ce = L.map(
#                 &quot;map_2a416387516274ea92daf35d808b26ce&quot;,
#                 {
#                     center: [39.7108, -104.8125],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_df76eda3771e68df66ec4ba0ded32960 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_df76eda3771e68df66ec4ba0ded32960.addTo(map_2a416387516274ea92daf35d808b26ce);
#
#
#             var marker_2cdf5bbcff051dfcf31006f72ae20812 = L.marker(
#                 [39.725483, -104.797924],
#                 {}
#             ).addTo(map_2a416387516274ea92daf35d808b26ce);
#
#
#             var icon_417b0e513834f8e40eaca7ee566eedf3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2cdf5bbcff051dfcf31006f72ae20812.setIcon(icon_417b0e513834f8e40eaca7ee566eedf3);
#
#
#         var popup_ff1daa7489c3cee2a3618b0fca18f2d9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d77aaea250e2ad672c129de36af8a9b8 = $(`&lt;div id=&quot;html_d77aaea250e2ad672c129de36af8a9b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;132 ENTERPRISES LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;KLONE&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Cultivation&lt;br&gt;     322 North Norfolk Street Unit I&lt;br&gt;     Aurora, CO 80011     &lt;/div&gt;`)[0];
#                 popup_ff1daa7489c3cee2a3618b0fca18f2d9.setContent(html_d77aaea250e2ad672c129de36af8a9b8);
#
#
#
#         marker_2cdf5bbcff051dfcf31006f72ae20812.bindPopup(popup_ff1daa7489c3cee2a3618b0fca18f2d9)
#         ;
#
#
#
#
#             var marker_637cb4698b9166206508d10190d67ab6 = L.marker(
#                 [39.7684311, -104.8147025],
#                 {}
#             ).addTo(map_2a416387516274ea92daf35d808b26ce);
#
#
#             var icon_30d7b8f25261c2a182760f4760aa811f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_637cb4698b9166206508d10190d67ab6.setIcon(icon_30d7b8f25261c2a182760f4760aa811f);
#
#
#         var popup_847c87fc3413277add9aa73e742f7faa = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_178902fba375b685f5e9bf2260500d4a = $(`&lt;div id=&quot;html_178902fba375b685f5e9bf2260500d4a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;BUD FOX ENTERPRISES LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;nan&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Cultivation&lt;br&gt;     14896 East 38th Avenue, Unit C&lt;br&gt;     Aurora, CO 80011     &lt;/div&gt;`)[0];
#                 popup_847c87fc3413277add9aa73e742f7faa.setContent(html_178902fba375b685f5e9bf2260500d4a);
#
#
#
#         marker_637cb4698b9166206508d10190d67ab6.bindPopup(popup_847c87fc3413277add9aa73e742f7faa)
#         ;
#
#
#
#
#             var marker_6daab95e09b5ba913fe0e42750dfea22 = L.marker(
#                 [39.7632007, -104.8495745],
#                 {}
#             ).addTo(map_2a416387516274ea92daf35d808b26ce);
#
#
#             var icon_2228bed639d8147f1098069c89e505ad = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6daab95e09b5ba913fe0e42750dfea22.setIcon(icon_2228bed639d8147f1098069c89e505ad);
#
#
#         var popup_3c0c2d23e3584ad3a90e57abba4a7f92 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_105753d624ab9b07f38a994baf3761e2 = $(`&lt;div id=&quot;html_105753d624ab9b07f38a994baf3761e2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;CANNA CLUB LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Best Buds&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Cultivation&lt;br&gt;     11900 East 33rd Avenue, Suite 2&lt;br&gt;     Aurora, CO 80010     &lt;/div&gt;`)[0];

# %%
# Example: Search for cultivations in a specific city
city_search = "Fort Collins"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[40.5853, -105.0844], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Facility Name']}</strong><br>
    <strong>{row['DBA']}</strong><br>
    Facility Type: {row['Facility Type']}<br>
    {row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip Code']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_cultivations_map_fort_collins.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_56bb00ac09449eb1263a2118c2c0c79f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_56bb00ac09449eb1263a2118c2c0c79f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_56bb00ac09449eb1263a2118c2c0c79f = L.map(
#                 &quot;map_56bb00ac09449eb1263a2118c2c0c79f&quot;,
#                 {
#                     center: [40.5853, -105.0844],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ed4ccee162dcaf8f3ff651a39d163cbf = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_ed4ccee162dcaf8f3ff651a39d163cbf.addTo(map_56bb00ac09449eb1263a2118c2c0c79f);
#
#
#             var marker_67a0f9ffd1e1c09df9d27159f93d8201 = L.marker(
#                 [40.5912784, -105.0547251],
#                 {}
#             ).addTo(map_56bb00ac09449eb1263a2118c2c0c79f);
#
#
#             var icon_057617997866f01e7e600acdc829f4b4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_67a0f9ffd1e1c09df9d27159f93d8201.setIcon(icon_057617997866f01e7e600acdc829f4b4);
#
#
#         var popup_ff71ecf4e211ebbb7093a12a04ae158b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9c2fb2577a8648c1964c5ecee43fa0b7 = $(`&lt;div id=&quot;html_9c2fb2577a8648c1964c5ecee43fa0b7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;FLOWER POWER BOTANICALS LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;nan&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Cultivation&lt;br&gt;     1308 - 1310 Duff Drive&lt;br&gt;     Fort Collins, CO 80524     &lt;/div&gt;`)[0];
#                 popup_ff71ecf4e211ebbb7093a12a04ae158b.setContent(html_9c2fb2577a8648c1964c5ecee43fa0b7);
#
#
#
#         marker_67a0f9ffd1e1c09df9d27159f93d8201.bindPopup(popup_ff71ecf4e211ebbb7093a12a04ae158b)
#         ;
#
#
#
#
#             var marker_75981bbc4341b171ff4db2ad7d0b9479 = L.marker(
#                 [40.494268, -105.0774983],
#                 {}
#             ).addTo(map_56bb00ac09449eb1263a2118c2c0c79f);
#
#
#             var icon_9774b6dbf0db290e58dc269c3720568a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_75981bbc4341b171ff4db2ad7d0b9479.setIcon(icon_9774b6dbf0db290e58dc269c3720568a);
#
#
#         var popup_26c6d189f1cd0dd1f373e7224c4ee729 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e9dd304b584564e7eef1f3097670c09d = $(`&lt;div id=&quot;html_e9dd304b584564e7eef1f3097670c09d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;KIND CARE OF COLORADO LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Kind Care of Colorado&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Cultivation&lt;br&gt;     6629 South College Avenue&lt;br&gt;     Fort Collins, CO 80525     &lt;/div&gt;`)[0];
#                 popup_26c6d189f1cd0dd1f373e7224c4ee729.setContent(html_e9dd304b584564e7eef1f3097670c09d);
#
#
#
#         marker_75981bbc4341b171ff4db2ad7d0b9479.bindPopup(popup_26c6d189f1cd0dd1f373e7224c4ee729)
#         ;
#
#
#
#
#             var marker_e8b5c877ea2403e73a8cf4af82a37219 = L.marker(
#                 [40.606051, -105.071691],
#                 {}
#             ).addTo(map_56bb00ac09449eb1263a2118c2c0c79f);
#
#
#             var icon_68e120393e5cdb336fc31e3f5273f9a2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e8b5c877ea2403e73a8cf4af82a37219.setIcon(icon_68e120393e5cdb336fc31e3f5273f9a2);
#
#
#         var popup_bb3561e80bedb870212ce6e8385f0803 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ac6e5cbbd4df02a7f72211eea7f25637 = $(`&lt;div id=&quot;html_ac6e5cbbd4df02a7f72211eea7f25637&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;NATURAL ALTERNATIVES FOR HEALTH CORP&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;nan&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Cultivation&lt;br&gt;     1420 Blue Spruce Drive, Unit G&amp;H&lt;br&gt;

# %%
# Example: Search for cultivations in a specific city
city_search = "Lakewood"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[39.7109, -105.0815], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Facility Name']}</strong><br>
    <strong>{row['DBA']}</strong><br>
    Facility Type: {row['Facility Type']}<br>
    {row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip Code']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_cultivations_map_lakewood.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1bd702ca206742fe385fbf3f51354c2f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1bd702ca206742fe385fbf3f51354c2f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1bd702ca206742fe385fbf3f51354c2f = L.map(
#                 &quot;map_1bd702ca206742fe385fbf3f51354c2f&quot;,
#                 {
#                     center: [39.7109, -105.0815],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1827d9d64a70dc8176f741d5d6768a6c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_1827d9d64a70dc8176f741d5d6768a6c.addTo(map_1bd702ca206742fe385fbf3f51354c2f);
#
#
#             var marker_c24df596b711c4203c2f76b98571904d = L.marker(
#                 [39.7106571, -105.1181927],
#                 {}
#             ).addTo(map_1bd702ca206742fe385fbf3f51354c2f);
#
#
#             var icon_28ebadf30aabd2365e7d66d029838b36 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c24df596b711c4203c2f76b98571904d.setIcon(icon_28ebadf30aabd2365e7d66d029838b36);
#
#
#         var popup_2118c593961dc3f26c30b91105b0f9fb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_77b9975d8413349601eb3933ccee24c5 = $(`&lt;div id=&quot;html_77b9975d8413349601eb3933ccee24c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;HEALING HOUSE LAKEWOOD LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Ascend Cannabis Co.&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Cultivation&lt;br&gt;     10712 West Alameda Avenue&lt;br&gt;     Lakewood, CO 80226     &lt;/div&gt;`)[0];
#                 popup_2118c593961dc3f26c30b91105b0f9fb.setContent(html_77b9975d8413349601eb3933ccee24c5);
#
#
#
#         marker_c24df596b711c4203c2f76b98571904d.bindPopup(popup_2118c593961dc3f26c30b91105b0f9fb)
#         ;
#
#
#
#
#             tile_layer_1827d9d64a70dc8176f741d5d6768a6c.addTo(map_1bd702ca206742fe385fbf3f51354c2f);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Example: Search for cultivations in a specific city
city_search = "Garden City"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[40.4233, -104.7112], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Facility Name']}</strong><br>
    <strong>{row['DBA']}</strong><br>
    Facility Type: {row['Facility Type']}<br>
    {row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip Code']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_cultivations_map_garden_city.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_73b348836210988e382bcabeb28fca57 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_73b348836210988e382bcabeb28fca57&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_73b348836210988e382bcabeb28fca57 = L.map(
#                 &quot;map_73b348836210988e382bcabeb28fca57&quot;,
#                 {
#                     center: [40.4233, -104.7112],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2390a85217bd52e77cefd08465e72bcd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_2390a85217bd52e77cefd08465e72bcd.addTo(map_73b348836210988e382bcabeb28fca57);
#
#
#             var marker_3f221dc949fb70ed5d74809df841c310 = L.marker(
#                 [40.3944806, -104.6866871],
#                 {}
#             ).addTo(map_73b348836210988e382bcabeb28fca57);
#
#
#             var icon_968c7aa49c92f070ccea7060ce2ad428 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3f221dc949fb70ed5d74809df841c310.setIcon(icon_968c7aa49c92f070ccea7060ce2ad428);
#
#
#         var popup_bab25acd50c4e76ace6ce7e865026367 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_753c7c07020fda8302fb6a2855ef0b0e = $(`&lt;div id=&quot;html_753c7c07020fda8302fb6a2855ef0b0e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;NATURES HERBS &amp; WELLNESS CENTER&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Nature&#x27;s Herbs &amp; Wellness Center&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Cultivation&lt;br&gt;     540 27th Street&lt;br&gt;     Garden City, CO 80631     &lt;/div&gt;`)[0];
#                 popup_bab25acd50c4e76ace6ce7e865026367.setContent(html_753c7c07020fda8302fb6a2855ef0b0e);
#
#
#
#         marker_3f221dc949fb70ed5d74809df841c310.bindPopup(popup_bab25acd50c4e76ace6ce7e865026367)
#         ;
#
#
#
#
#             var marker_59dd4037d286bf9e8bb60f07edbc578f = L.marker(
#                 [40.3967964, -104.6874197],
#                 {}
#             ).addTo(map_73b348836210988e382bcabeb28fca57);
#
#
#             var icon_cac109320b93816de848ac508a30dfa8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_59dd4037d286bf9e8bb60f07edbc578f.setIcon(icon_cac109320b93816de848ac508a30dfa8);
#
#
#         var popup_72a3cf816c89cfd3845ac8a42b016dc9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_836b0af9f62bb7f6beb24b979926538d = $(`&lt;div id=&quot;html_836b0af9f62bb7f6beb24b979926538d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;HIGH PLAINZ STRAINS II LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;nan&lt;/strong&gt;&lt;br&gt;     Facility Type: Retail Marijuana Cultivation Facility&lt;br&gt;     2506 6th Avenue&lt;br&gt;     Garden City, CO 80631     &lt;/div&gt;`)[0];
#                 popup_72a3cf816c89cfd3845ac8a42b016dc9.setContent(html_836b0af9f62bb7f6beb24b979926538d);
#
#
#
#         marker_59dd4037d286bf9e8bb60f07edbc578f.bindPopup(popup_72a3cf816c89cfd3845ac8a42b016dc9)
#         ;
#
#
#
#
#             var marker_626ad7754452ca730131de47ef498f70 = L.marker(
#                 [40.3944806, -104.6866871],
#                 {}
#             ).addTo(map_73b348836210988e382bcabeb28fca57);
#
#
#             var icon_fbf3d1e6e8518619532bd7de93a0ace5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_626ad7754452ca730131de47ef498f70.setIcon(icon_fbf3d1e6e8518619532bd7de93a0ace5);
#
#
#         var popup_3a051572a2cb4a2f4f81dc302a5f8f5a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9a3b5d8cb63438fb1cd06eac2d5e29b6 = $(`&lt;div id=&quot;html_9a3b5d8cb63438fb1cd06eac2d5e29b6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;NATURES HERBS &amp; WELLNESS CENTER&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Natures Herbs &amp; Wellness Center&lt;/strong&gt;&lt;br&gt;     Facility Type: Retail Marijuana Cultivation Facility&lt;b

# %%
# Example: Search for cultivations in a specific city
city_search = "Pueblo"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[38.2765, -104.6046], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Facility Name']}</strong><br>
    <strong>{row['DBA']}</strong><br>
    Facility Type: {row['Facility Type']}<br>
    {row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip Code']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_cultivations_map_pueblo.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_638c1e99da542b47133aded1d5691e85 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_638c1e99da542b47133aded1d5691e85&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_638c1e99da542b47133aded1d5691e85 = L.map(
#                 &quot;map_638c1e99da542b47133aded1d5691e85&quot;,
#                 {
#                     center: [38.2765, -104.6046],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_761653da0e62d6c5996681f7e3ab8c1d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_761653da0e62d6c5996681f7e3ab8c1d.addTo(map_638c1e99da542b47133aded1d5691e85);
#
#
#             var marker_0aa16dd8bc8f515d134b90cb2a0fb263 = L.marker(
#                 [38.255533, -104.65062],
#                 {}
#             ).addTo(map_638c1e99da542b47133aded1d5691e85);
#
#
#             var icon_e79b1f8fee92af3896a8a3b48691435d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0aa16dd8bc8f515d134b90cb2a0fb263.setIcon(icon_e79b1f8fee92af3896a8a3b48691435d);
#
#
#         var popup_b0f4a2277ca4c1036f2c4a00947e810f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f7c5ca9d973109bb0df9b95c0f00ac24 = $(`&lt;div id=&quot;html_f7c5ca9d973109bb0df9b95c0f00ac24&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;7415 LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;nan&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Cultivation&lt;br&gt;     7415 Rex Road&lt;br&gt;     Pueblo, CO 81005     &lt;/div&gt;`)[0];
#                 popup_b0f4a2277ca4c1036f2c4a00947e810f.setContent(html_f7c5ca9d973109bb0df9b95c0f00ac24);
#
#
#
#         marker_0aa16dd8bc8f515d134b90cb2a0fb263.bindPopup(popup_b0f4a2277ca4c1036f2c4a00947e810f)
#         ;
#
#
#
#
#             var marker_a02f036206f7cbdc917f6157aab9a9c2 = L.marker(
#                 [38.2499983, -104.6012742],
#                 {}
#             ).addTo(map_638c1e99da542b47133aded1d5691e85);
#
#
#             var icon_a2b6360d82ce716f42a1363cc56dcafe = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a02f036206f7cbdc917f6157aab9a9c2.setIcon(icon_a2b6360d82ce716f42a1363cc56dcafe);
#
#
#         var popup_6236edc8d6f582c4d8721b98789c8e52 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b5dbdc232953742275527cae78399e61 = $(`&lt;div id=&quot;html_b5dbdc232953742275527cae78399e61&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;AF INC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Apothecary Farms&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Cultivation&lt;br&gt;     1917 Santa Fe Drive&lt;br&gt;     Pueblo, CO 81006     &lt;/div&gt;`)[0];
#                 popup_6236edc8d6f582c4d8721b98789c8e52.setContent(html_b5dbdc232953742275527cae78399e61);
#
#
#
#         marker_a02f036206f7cbdc917f6157aab9a9c2.bindPopup(popup_6236edc8d6f582c4d8721b98789c8e52)
#         ;
#
#
#
#
#             var marker_fa3a59de5d4bd18376834e98a4e0947a = L.marker(
#                 [38.3260135, -104.705327],
#                 {}
#             ).addTo(map_638c1e99da542b47133aded1d5691e85);
#
#
#             var icon_5138890dc959859507fdc3a2e0ffee81 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_fa3a59de5d4bd18376834e98a4e0947a.setIcon(icon_5138890dc959859507fdc3a2e0ffee81);
#
#
#         var popup_01cde8832dc57f5a2bc5fdee163a8e3d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0189449dab13a560a28d0c01056cb7d2 = $(`&lt;div id=&quot;html_0189449dab13a560a28d0c01056cb7d2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;COLORADO DISTRIBUTING INC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;nan&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Cultivation&lt;br&gt;     893 East Enterprise Drive&lt;br&gt;     Pueblo West, CO 81007     &lt;/div&gt;`)[0];
#                 popup_01cde8832dc57f5a2bc5fdee1

# %%
# Example: Search for cultivations in a specific city
city_search = "Boulder"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[40.0150, -105.2705], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Facility Name']}</strong><br>
    <strong>{row['DBA']}</strong><br>
    Facility Type: {row['Facility Type']}<br>
    {row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip Code']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_cultivations_map_boulder.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cb6d56671fea28f75c77a456745912c0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cb6d56671fea28f75c77a456745912c0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cb6d56671fea28f75c77a456745912c0 = L.map(
#                 &quot;map_cb6d56671fea28f75c77a456745912c0&quot;,
#                 {
#                     center: [40.015, -105.2705],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bfdcb1277f78db422b88d83fa7b31510 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_bfdcb1277f78db422b88d83fa7b31510.addTo(map_cb6d56671fea28f75c77a456745912c0);
#
#
#             var marker_5e1b0cfd853d2b80483fa2c3c9bf1fc6 = L.marker(
#                 [40.0261546, -105.2418338],
#                 {}
#             ).addTo(map_cb6d56671fea28f75c77a456745912c0);
#
#
#             var icon_a04cc42b6045f8f926146bcc3ca1597f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5e1b0cfd853d2b80483fa2c3c9bf1fc6.setIcon(icon_a04cc42b6045f8f926146bcc3ca1597f);
#
#
#         var popup_02a27743eca1aae6b6e8024f3e4cc08e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_06623abf63de79821ef13156d27b90be = $(`&lt;div id=&quot;html_06623abf63de79821ef13156d27b90be&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;4747 PEARL STREET LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Great Ascent Botanicals&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Cultivation&lt;br&gt;     4747 Pearl Street Unit M1&lt;br&gt;     Boulder, CO 80301     &lt;/div&gt;`)[0];
#                 popup_02a27743eca1aae6b6e8024f3e4cc08e.setContent(html_06623abf63de79821ef13156d27b90be);
#
#
#
#         marker_5e1b0cfd853d2b80483fa2c3c9bf1fc6.bindPopup(popup_02a27743eca1aae6b6e8024f3e4cc08e)
#         ;
#
#
#
#
#             var marker_7a039f25e804c18d2ed83c8410b31b53 = L.marker(
#                 [40.0310008, -105.1799901],
#                 {}
#             ).addTo(map_cb6d56671fea28f75c77a456745912c0);
#
#
#             var icon_ad40680cb777cf8a0ffddda6ec495ea5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7a039f25e804c18d2ed83c8410b31b53.setIcon(icon_ad40680cb777cf8a0ffddda6ec495ea5);
#
#
#         var popup_9ea96d69c56745295306d19276932e95 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_56505782d699966cb0e57dfdea8987ad = $(`&lt;div id=&quot;html_56505782d699966cb0e57dfdea8987ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;EAH ENTERPRISES LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Vera Cultivation&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Cultivation&lt;br&gt;     3105 North 75th Street&lt;br&gt;     Boulder, CO 80301     &lt;/div&gt;`)[0];
#                 popup_9ea96d69c56745295306d19276932e95.setContent(html_56505782d699966cb0e57dfdea8987ad);
#
#
#
#         marker_7a039f25e804c18d2ed83c8410b31b53.bindPopup(popup_9ea96d69c56745295306d19276932e95)
#         ;
#
#
#
#
#             var marker_6d6d9994b1ee3beb2822a5799b5c62c6 = L.marker(
#                 [40.040917, -105.282079],
#                 {}
#             ).addTo(map_cb6d56671fea28f75c77a456745912c0);
#
#
#             var icon_e754dcd3f47bafc938c324616b4c976e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6d6d9994b1ee3beb2822a5799b5c62c6.setIcon(icon_e754dcd3f47bafc938c324616b4c976e);
#
#
#         var popup_2405fd19c6bc3f582e768e635a0f0c88 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4365a15e33190b5a88b0ac0139259c24 = $(`&lt;div id=&quot;html_4365a15e33190b5a88b0ac0139259c24&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;R &amp; B CONSULTING INC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Iion Cannabis&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Cultivation&lt;br&gt;     4727 North Broadway, Unit G&lt;br&gt;     Boulder, CO 80304

# %% [markdown]
# ## Step 5: Export Cleaned Data to CSV

# %%
# Export the cleaned DataFrame to a CSV file
df.to_csv("cleaned_colorado_cultivations_full_list_v2.csv", index=False)

# Confirm the export
print("Data exported to colorado_cultivations_full_list_v2.csv")
# Out:
# Data exported to colorado_cultivations_full_list_v2.csv
