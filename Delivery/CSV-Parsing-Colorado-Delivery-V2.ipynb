# %% [markdown]
# # Jupyter Notebook: Parsing CSV file and Visualizing Data

# %% [markdown]
# In this notebook, we will load a CSV file, convert it to a pandas DataFrame, and then create a map visualizations using folium.

# %%
pip install pandas folium
# Out:
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (2.2.3)
# Requirement already satisfied: folium in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (0.17.0)
# Requirement already satisfied: numpy>=1.23.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/ceraven/Library/Python/3.11/lib/python/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas) (2024.2)
# Requirement already satisfied: branca>=0.6.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from folium) (0.8.0)
# Requirement already satisfied: jinja2>=2.9 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from folium) (3.1.4)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from folium) (2024.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jinja2>=2.9->folium) (2.1.5)
# Requirement already satisfied: six>=1.5 in /Users/ceraven/Library/Python/3.11/lib/python/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->folium) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->folium) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->folium) (2024.8.30)
#
# [notice] A new release of pip available: 22.3.1 -> 24.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import necessary libraries
import pandas as pd
import folium

# %% [markdown]
# ## Step 1: Load CSV File

# %%
# Load the CSV file into a DataFrame
file_path = "colorado_delivery_full_list.csv"

df = pd.read_csv(file_path)

# Optional: Display the first few rows to check if the file is loaded correctly
df.head(15)
# Out:
#    License Number                         Facility Name  \
# 0       505-00018                       ABCDELIVERY LLC
# 1       505-00034  ALTERNATIVE MEDICINE ON THE MALL LLC
# 2       505-00040            GOGI CANNABIS DELIVERY LLC
# 3       505-00016                               LGK LLC
# 4       505-00004                     MAGNOLIA ROAD INC
# 5       505-00020                              SBUD LLC
# 6       505-00001                     THE DANDELION LLC
# 7      605R-00012                       ABCDELIVERY LLC
# 8      605R-00074  ALTERNATIVE MEDICINE ON THE MALL LLC
# 9      605R-00036      BLAZE TO GO DELIVERY SERVICE LLC
# 10     605R-00095          CANNABIS DEPOT DENVER NF LLC
# 11     605R-00025                               DKC LLC
# 12     605R-00092                   DOPE APOTHEOSIS INC
# 13     605R-00033                              E2T2 LLC
# 14     605R-00078                ELEVATION DELIVERY LLC
#
#                                DBA        Facility Type  \
# 0             Better Days Delivery  MMJ Delivery Permit
# 1               Native Roots Speer  MMJ Delivery Permit
# 2                             Gogi  MMJ Delivery Permit
# 3                Strawberry Fields  MMJ Delivery Permit
# 4   Magnolia Road Cannabis Company  MMJ Delivery Permit
# 5                        Star Buds  MMJ Delivery Permit
# 6                    The Dandelion  MMJ Delivery Permit
# 7             Better Days Delivery  RMJ Delivery Permit
# 8               Native Roots Speer  RMJ Delivery Permit
# 9                              NaN  RMJ Delivery Permit
# 10                             NaN  RMJ Delivery Permit
# 11                Denver Kush Club  RMJ Delivery Permit
# 12              Police and Thieves  RMJ Delivery Permit
# 13                Cookies Broadway  RMJ Delivery Permit
# 14                             NaN  RMJ Delivery Permit
#
#                                    Street     City State  Zip Code  \
# 0                    1965 Kingston Street   Aurora    CO     80010
# 1                  500 North Grant Street   Denver    CO     80203
# 2                        1520 Iris Street   Denver    CO     80215
# 3   3435 South Yosemite Street, Suite 200   Denver    CO     80231
# 4              1750 30th Street, Unit 84B  Boulder    CO     80301
# 5                  1640 East Evans Avenue   Denver    CO     80210
# 6                       845 Walnut Street  Boulder    CO     80302
# 7                    1965 Kingston Street   Aurora    CO     80010
# 8                  500 North Grant Street   Denver    CO     80203
# 9    1111 North Broadway Street  Unit 303   Denver    CO     80203
# 10            155 North Federal Boulevard   Denver    CO     80219
# 11                     2615 Welton Street   Denver    CO     80205
# 12                6302 East Colfax Avenue   Denver    CO     80220
# 13                    2057 South Broadway   Denver    CO     80210
# 14                2076 South Yates Street   Denver    CO     80219
#
#    Date Updated   Latitude   Longitude
# 0    2024-09-03  39.746871 -104.859028
# 1    2024-09-03  39.728988 -104.983607
# 2    2024-09-03  39.634736 -105.105979
# 3    2024-09-03  39.654761 -104.885102
# 4    2024-09-03  40.017474 -105.253867
# 5    2024-09-03  39.678404 -104.968238
# 6    2024-09-03  40.016122 -105.284040
# 7    2024-09-03  39.746871 -104.859028
# 8    2024-09-03  39.728988 -104.983607
# 9    2024-09-03  39.734011 -104.987338
# 10   2024-09-03  39.713346 -105.025007
# 11   2024-09-03  39.754327 -104.979034
# 12   2024-09-03  39.740064 -104.914879
# 13   2024-09-03  39.679292 -104.987982
# 14   2024-09-03  39.679732 -105.050827

# %% [markdown]
# ## Step 2: Clean and Prepare the Data

# %%
# Check column names and data types
df.info()

# Clean any missing latitude or longitude data
df.dropna(subset=['Longitude', 'Latitude'], inplace=True)

# Optional: Check for missing values in other important columns
df.isnull().sum()

# Optional: Display the first few rows of cleaned data
df.head(15)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   License Number  37 non-null     object
#  1   Facility Name   37 non-null     object
#  2   DBA             29 non-null     object
#  3   Facility Type   37 non-null     object
#  4   Street          37 non-null     object
#  5   City            37 non-null     object
#  6   State           37 non-null     object
#  7   Zip Code        37 non-null     int64
#  8   Date Updated    37 non-null     object
#  9   Latitude        37 non-null     float64
#  10  Longitude       37 non-null     float64
# dtypes: float64(2), int64(1), object(8)
# memory usage: 3.3+ KB
#    License Number                         Facility Name  \
# 0       505-00018                       ABCDELIVERY LLC
# 1       505-00034  ALTERNATIVE MEDICINE ON THE MALL LLC
# 2       505-00040            GOGI CANNABIS DELIVERY LLC
# 3       505-00016                               LGK LLC
# 4       505-00004                     MAGNOLIA ROAD INC
# 5       505-00020                              SBUD LLC
# 6       505-00001                     THE DANDELION LLC
# 7      605R-00012                       ABCDELIVERY LLC
# 8      605R-00074  ALTERNATIVE MEDICINE ON THE MALL LLC
# 9      605R-00036      BLAZE TO GO DELIVERY SERVICE LLC
# 10     605R-00095          CANNABIS DEPOT DENVER NF LLC
# 11     605R-00025                               DKC LLC
# 12     605R-00092                   DOPE APOTHEOSIS INC
# 13     605R-00033                              E2T2 LLC
# 14     605R-00078                ELEVATION DELIVERY LLC
#
#                                DBA        Facility Type  \
# 0             Better Days Delivery  MMJ Delivery Permit
# 1               Native Roots Speer  MMJ Delivery Permit
# 2                             Gogi  MMJ Delivery Permit
# 3                Strawberry Fields  MMJ Delivery Permit
# 4   Magnolia Road Cannabis Company  MMJ Delivery Permit
# 5                        Star Buds  MMJ Delivery Permit
# 6                    The Dandelion  MMJ Delivery Permit
# 7             Better Days Delivery  RMJ Delivery Permit
# 8               Native Roots Speer  RMJ Delivery Permit
# 9                              NaN  RMJ Delivery Permit
# 10                             NaN  RMJ Delivery Permit
# 11                Denver Kush Club  RMJ Delivery Permit
# 12              Police and Thieves  RMJ Delivery Permit
# 13                Cookies Broadway  RMJ Delivery Permit
# 14                             NaN  RMJ Delivery Permit
#
#                                    Street     City State  Zip Code  \
# 0                    1965 Kingston Street   Aurora    CO     80010
# 1                  500 North Grant Street   Denver    CO     80203
# 2                        1520 Iris Street   Denver    CO     80215
# 3   3435 South Yosemite Street, Suite 200   Denver    CO     80231
# 4              1750 30th Street, Unit 84B  Boulder    CO     80301
# 5                  1640 East Evans Avenue   Denver    CO     80210
# 6                       845 Walnut Street  Boulder    CO     80302
# 7                    1965 Kingston Street   Aurora    CO     80010
# 8                  500 North Grant Street   Denver    CO     80203
# 9    1111 North Broadway Street  Unit 303   Denver    CO     80203
# 10            155 North Federal Boulevard   Denver    CO     80219
# 11                     2615 Welton Street   Denver    CO     80205
# 12                6302 East Colfax Avenue   Denver    CO     80220
# 13                    2057 South Broadway   Denver    CO     80210
# 14                2076 South Yates Street   Denver    CO     80219
#
#    Date Updated   Latitude   Longitude
# 0    2024-09-03  39.746871 -104.859028
# 1    2024-09-03  39.728988 -104.983607
# 2    2024-09-03  39.634736 -105.105979
# 3    2024-09-03  39.654761 -104.885102
# 4    2024-09-03  40.017474 -105.253867
# 5    2024-09-03  39.678404 -104.968238
# 6    2024-09-03  40.016122 -105.284040
# 7    2024-09-03  39.746871 -104.859028
# 8    2024-09-03  39.728988 -104.983607
# 9    2024-09-03  39.734011 -104.987338
# 10   2024-09-03  39.713346 -105.025007
# 11   2024-09-03  39.754327 -104.979034
# 12   2024-09-03  39.740064 -104.914879
# 13   2024-09-03  39.679292 -104.987982
# 14   2024-09-03  39.679732 -105.050827

# %% [markdown]
# ## Step 3: Create a Searchable Map

# %%
# Initialize the map centered around Colorado
m = folium.Map(location=[39.5501, -105.7821], zoom_start=7)

# Add markers to the map for each food pantry
for idx, row in df.iterrows():
    popup_text = f"""
    <strong>{row['Facility Name']}</strong><br>
    <strong>{row['DBA']}</strong><br>
    Facility Type: {row['Facility Type']}<br>
    {row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip Code']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m)

# Save the map as an HTML file
m.save("colorado_delivery_full_list_map.html")

# Display the map in the notebook
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e9831a422d6cceb0705ac4aa683f38fd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e9831a422d6cceb0705ac4aa683f38fd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e9831a422d6cceb0705ac4aa683f38fd = L.map(
#                 &quot;map_e9831a422d6cceb0705ac4aa683f38fd&quot;,
#                 {
#                     center: [39.5501, -105.7821],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8ef6a722d501dbb9c4202eac671ae4a8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_8ef6a722d501dbb9c4202eac671ae4a8.addTo(map_e9831a422d6cceb0705ac4aa683f38fd);
#
#
#             var marker_7df56478cdaf3889e4089330c08515b3 = L.marker(
#                 [39.7468712, -104.8590276],
#                 {}
#             ).addTo(map_e9831a422d6cceb0705ac4aa683f38fd);
#
#
#             var icon_177039e9283f6fff18ead5fca3e46d84 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7df56478cdaf3889e4089330c08515b3.setIcon(icon_177039e9283f6fff18ead5fca3e46d84);
#
#
#         var popup_486f81ffa8242eb3b60093e9e4a3dd8f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_47ef34cffc3349be56b65fc6531ea269 = $(`&lt;div id=&quot;html_47ef34cffc3349be56b65fc6531ea269&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;ABCDELIVERY LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Better Days Delivery&lt;/strong&gt;&lt;br&gt;     Facility Type: MMJ Delivery Permit&lt;br&gt;     1965 Kingston Street&lt;br&gt;     Aurora, CO 80010     &lt;/div&gt;`)[0];
#                 popup_486f81ffa8242eb3b60093e9e4a3dd8f.setContent(html_47ef34cffc3349be56b65fc6531ea269);
#
#
#
#         marker_7df56478cdaf3889e4089330c08515b3.bindPopup(popup_486f81ffa8242eb3b60093e9e4a3dd8f)
#         ;
#
#
#
#
#             var marker_56e10681d6573656656ccc93c5b119c1 = L.marker(
#                 [39.7289875, -104.9836073],
#                 {}
#             ).addTo(map_e9831a422d6cceb0705ac4aa683f38fd);
#
#
#             var icon_07605b45bec01bab79e5f16be58babb0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_56e10681d6573656656ccc93c5b119c1.setIcon(icon_07605b45bec01bab79e5f16be58babb0);
#
#
#         var popup_4b14a900a181f6797dea1372aa5da4d8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_47d061ace5ccc7402cb851d5f0ae6a70 = $(`&lt;div id=&quot;html_47d061ace5ccc7402cb851d5f0ae6a70&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;ALTERNATIVE MEDICINE ON THE MALL LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Native Roots Speer&lt;/strong&gt;&lt;br&gt;     Facility Type: MMJ Delivery Permit&lt;br&gt;     500 North Grant Street&lt;br&gt;     Denver, CO 80203     &lt;/div&gt;`)[0];
#                 popup_4b14a900a181f6797dea1372aa5da4d8.setContent(html_47d061ace5ccc7402cb851d5f0ae6a70);
#
#
#
#         marker_56e10681d6573656656ccc93c5b119c1.bindPopup(popup_4b14a900a181f6797dea1372aa5da4d8)
#         ;
#
#
#
#
#             var marker_4d7fa4c910e1eef248c2f878b9f275b1 = L.marker(
#                 [39.6347356, -105.1059793],
#                 {}
#             ).addTo(map_e9831a422d6cceb0705ac4aa683f38fd);
#
#
#             var icon_7075d2b158105b5b3abf3d8af33e49c3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4d7fa4c910e1eef248c2f878b9f275b1.setIcon(icon_7075d2b158105b5b3abf3d8af33e49c3);
#
#
#         var popup_3469fa9f104ba7b5d3506ded0e283422 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8b48fa00552e19c58d2d933d03987ecc = $(`&lt;div id=&quot;html_8b48fa00552e19c58d2d933d03987ecc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;GOGI CANNABIS DELIVERY LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Gogi&lt;/strong&gt;&lt;br&gt;     Facility Type: MMJ Delivery Permit&lt;br&gt;     1520 Iris Street&lt;br&gt;     Denver, CO 80215     &lt;/div&gt;`)[0];
#                 pop

# %% [markdown]
# ## Step 4: Implement Search Functionality

# %%
# Example: Search for delivery in a specific city
city_search = "Denver"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[39.5501, -105.7821], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Facility Name']}</strong><br>
    <strong>{row['DBA']}</strong><br>
    Facility Type: {row['Facility Type']}<br>
    {row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip Code']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_delivery_map_denver.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_19c460f8de0e669c7763911b59929bb4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_19c460f8de0e669c7763911b59929bb4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_19c460f8de0e669c7763911b59929bb4 = L.map(
#                 &quot;map_19c460f8de0e669c7763911b59929bb4&quot;,
#                 {
#                     center: [39.5501, -105.7821],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d20529c084cf591f605494849d2f273a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d20529c084cf591f605494849d2f273a.addTo(map_19c460f8de0e669c7763911b59929bb4);
#
#
#             var marker_e41e2d7270d4094e732505d5dd003318 = L.marker(
#                 [39.7289875, -104.9836073],
#                 {}
#             ).addTo(map_19c460f8de0e669c7763911b59929bb4);
#
#
#             var icon_17cd72711a8811bc1ea8e1f867e84d59 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e41e2d7270d4094e732505d5dd003318.setIcon(icon_17cd72711a8811bc1ea8e1f867e84d59);
#
#
#         var popup_0e727c5e5d36192a57270ba048edeabd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_960fd5f1519abcde1abddfed403f6f15 = $(`&lt;div id=&quot;html_960fd5f1519abcde1abddfed403f6f15&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;ALTERNATIVE MEDICINE ON THE MALL LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Native Roots Speer&lt;/strong&gt;&lt;br&gt;     Facility Type: MMJ Delivery Permit&lt;br&gt;     500 North Grant Street&lt;br&gt;     Denver, CO 80203     &lt;/div&gt;`)[0];
#                 popup_0e727c5e5d36192a57270ba048edeabd.setContent(html_960fd5f1519abcde1abddfed403f6f15);
#
#
#
#         marker_e41e2d7270d4094e732505d5dd003318.bindPopup(popup_0e727c5e5d36192a57270ba048edeabd)
#         ;
#
#
#
#
#             var marker_f71d580a40624d3005d27672da5a6d99 = L.marker(
#                 [39.6347356, -105.1059793],
#                 {}
#             ).addTo(map_19c460f8de0e669c7763911b59929bb4);
#
#
#             var icon_9b87346eb0adb935ea6b3c34f3ded03b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f71d580a40624d3005d27672da5a6d99.setIcon(icon_9b87346eb0adb935ea6b3c34f3ded03b);
#
#
#         var popup_7b4945823d6ead88a4b816180a93a2f8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_24a8c0f15c0da80002e646a75a17804b = $(`&lt;div id=&quot;html_24a8c0f15c0da80002e646a75a17804b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;GOGI CANNABIS DELIVERY LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Gogi&lt;/strong&gt;&lt;br&gt;     Facility Type: MMJ Delivery Permit&lt;br&gt;     1520 Iris Street&lt;br&gt;     Denver, CO 80215     &lt;/div&gt;`)[0];
#                 popup_7b4945823d6ead88a4b816180a93a2f8.setContent(html_24a8c0f15c0da80002e646a75a17804b);
#
#
#
#         marker_f71d580a40624d3005d27672da5a6d99.bindPopup(popup_7b4945823d6ead88a4b816180a93a2f8)
#         ;
#
#
#
#
#             var marker_7ebcedc2a1d42a2d9a7ae2ff4dcc518f = L.marker(
#                 [39.6547608, -104.8851018],
#                 {}
#             ).addTo(map_19c460f8de0e669c7763911b59929bb4);
#
#
#             var icon_e72626e338866a5c7edfaa26facd8263 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7ebcedc2a1d42a2d9a7ae2ff4dcc518f.setIcon(icon_e72626e338866a5c7edfaa26facd8263);
#
#
#         var popup_593f13760efb0b979245c9c28fd88df4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b699eb84a3c3757f21acfe866edc2f2c = $(`&lt;div id=&quot;html_b699eb84a3c3757f21acfe866edc2f2c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;LGK LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Strawberry Fields&lt;/strong&gt;&lt;br&gt;     Facility Type: MMJ Delivery Permit&lt;br&gt;     3435 South Yosemite Street, Suite 200&lt;br&gt;     Denver, CO 80231     &lt;/div&gt;`)[0];

# %%
# Example: Search for delivery in a specific city
city_search = "Aurora"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[39.7108, -104.8125], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Facility Name']}</strong><br>
    <strong>{row['DBA']}</strong><br>
    Facility Type: {row['Facility Type']}<br>
    {row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip Code']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_delivery_map_aurora.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_12914c302843894189e40858f68c1465 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_12914c302843894189e40858f68c1465&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_12914c302843894189e40858f68c1465 = L.map(
#                 &quot;map_12914c302843894189e40858f68c1465&quot;,
#                 {
#                     center: [39.7108, -104.8125],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4c4aaab7417158c58c96c33a1568c5f0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_4c4aaab7417158c58c96c33a1568c5f0.addTo(map_12914c302843894189e40858f68c1465);
#
#
#             var marker_fbacbdbb9507dbe035ef319f6abde714 = L.marker(
#                 [39.7468712, -104.8590276],
#                 {}
#             ).addTo(map_12914c302843894189e40858f68c1465);
#
#
#             var icon_2713816edddb8a9aef4f16e439ba7628 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_fbacbdbb9507dbe035ef319f6abde714.setIcon(icon_2713816edddb8a9aef4f16e439ba7628);
#
#
#         var popup_75f08e6bf16727cf648e3d23ec8f83a3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_733b706b3bbdebf8dc9b4265343551e5 = $(`&lt;div id=&quot;html_733b706b3bbdebf8dc9b4265343551e5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;ABCDELIVERY LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Better Days Delivery&lt;/strong&gt;&lt;br&gt;     Facility Type: MMJ Delivery Permit&lt;br&gt;     1965 Kingston Street&lt;br&gt;     Aurora, CO 80010     &lt;/div&gt;`)[0];
#                 popup_75f08e6bf16727cf648e3d23ec8f83a3.setContent(html_733b706b3bbdebf8dc9b4265343551e5);
#
#
#
#         marker_fbacbdbb9507dbe035ef319f6abde714.bindPopup(popup_75f08e6bf16727cf648e3d23ec8f83a3)
#         ;
#
#
#
#
#             var marker_3c23e288e52b8ad96e873d2fbad49230 = L.marker(
#                 [39.7468712, -104.8590276],
#                 {}
#             ).addTo(map_12914c302843894189e40858f68c1465);
#
#
#             var icon_3aaebe35abbeab32396053038ee348e8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3c23e288e52b8ad96e873d2fbad49230.setIcon(icon_3aaebe35abbeab32396053038ee348e8);
#
#
#         var popup_b631d3e865eaa5039e967f2a3b175bf0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8fc87685782cfdc85d67e465af8bdf9b = $(`&lt;div id=&quot;html_8fc87685782cfdc85d67e465af8bdf9b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;ABCDELIVERY LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Better Days Delivery&lt;/strong&gt;&lt;br&gt;     Facility Type: RMJ Delivery Permit&lt;br&gt;     1965 Kingston Street&lt;br&gt;     Aurora, CO 80010     &lt;/div&gt;`)[0];
#                 popup_b631d3e865eaa5039e967f2a3b175bf0.setContent(html_8fc87685782cfdc85d67e465af8bdf9b);
#
#
#
#         marker_3c23e288e52b8ad96e873d2fbad49230.bindPopup(popup_b631d3e865eaa5039e967f2a3b175bf0)
#         ;
#
#
#
#
#             var marker_ca17394e13f00a68c797b3216f994e29 = L.marker(
#                 [39.667444, -104.8605731],
#                 {}
#             ).addTo(map_12914c302843894189e40858f68c1465);
#
#
#             var icon_1f2e8544ff2b6cd71608134524746b37 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ca17394e13f00a68c797b3216f994e29.setIcon(icon_1f2e8544ff2b6cd71608134524746b37);
#
#
#         var popup_b94603d7c36b9e7f854105b0622fce3e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_38fdc099821f36543715ad7630576f8f = $(`&lt;div id=&quot;html_38fdc099821f36543715ad7630576f8f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;HIGH COUNTRY SUPPLY LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Colorado Harvest Company&lt;/strong&gt;&lt;br&gt;     Facility Type: RMJ Delivery Permit&lt;br&gt;     11002 East Yale Avenue&lt;br&gt;     Aurora, CO 80010     &lt;/div&gt;`)[0];
#                 po

# %%
# Example: Search for delivery in a specific city
city_search = "Lakewood"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[39.7109, -105.0815], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Facility Name']}</strong><br>
    <strong>{row['DBA']}</strong><br>
    Facility Type: {row['Facility Type']}<br>
    {row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip Code']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_delivery_map_lakewood.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2c4d172f690116551c1f7d0daac29dd6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2c4d172f690116551c1f7d0daac29dd6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2c4d172f690116551c1f7d0daac29dd6 = L.map(
#                 &quot;map_2c4d172f690116551c1f7d0daac29dd6&quot;,
#                 {
#                     center: [39.7109, -105.0815],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c028e2c42e1cc3f846ba76d50584b7d9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c028e2c42e1cc3f846ba76d50584b7d9.addTo(map_2c4d172f690116551c1f7d0daac29dd6);
#
#
#             var marker_c799f7a3ce894300b6e0afbfca9cbd41 = L.marker(
#                 [39.7413599, -105.106391],
#                 {}
#             ).addTo(map_2c4d172f690116551c1f7d0daac29dd6);
#
#
#             var icon_8132b1574e23d159011dfe08f5a643f0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c799f7a3ce894300b6e0afbfca9cbd41.setIcon(icon_8132b1574e23d159011dfe08f5a643f0);
#
#
#         var popup_3c7ad733af0fa2d35ada71549f54f018 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0e83fd5db581daecc5d31e123c90caf7 = $(`&lt;div id=&quot;html_0e83fd5db581daecc5d31e123c90caf7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;GOGI CANNABIS DELIVERY LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Gogi&lt;/strong&gt;&lt;br&gt;     Facility Type: RMJ Delivery Permit&lt;br&gt;     1520 Iris Street&lt;br&gt;     Lakewood, CO 80215     &lt;/div&gt;`)[0];
#                 popup_3c7ad733af0fa2d35ada71549f54f018.setContent(html_0e83fd5db581daecc5d31e123c90caf7);
#
#
#
#         marker_c799f7a3ce894300b6e0afbfca9cbd41.bindPopup(popup_3c7ad733af0fa2d35ada71549f54f018)
#         ;
#
#
#
#
#             tile_layer_c028e2c42e1cc3f846ba76d50584b7d9.addTo(map_2c4d172f690116551c1f7d0daac29dd6);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Example: Search for delivery in a specific city
city_search = "Arvada"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[39.8028, -105.0875], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Facility Name']}</strong><br>
    <strong>{row['DBA']}</strong><br>
    Facility Type: {row['Facility Type']}<br>
    {row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip Code']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_delivery_map_arvada.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_96f29b6cff74f77ed5e9ecd131471996 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_96f29b6cff74f77ed5e9ecd131471996&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_96f29b6cff74f77ed5e9ecd131471996 = L.map(
#                 &quot;map_96f29b6cff74f77ed5e9ecd131471996&quot;,
#                 {
#                     center: [39.8028, -105.0875],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1fe8482654ce821bc840dc0c23d6f095 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_1fe8482654ce821bc840dc0c23d6f095.addTo(map_96f29b6cff74f77ed5e9ecd131471996);
#
#
#             var marker_0318fa3c7d23fa28fcff2dcc1a1a87c5 = L.marker(
#                 [39.65719, -104.782358],
#                 {}
#             ).addTo(map_96f29b6cff74f77ed5e9ecd131471996);
#
#
#             var icon_1b21b8760bf3b37be13cbe3313efea50 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0318fa3c7d23fa28fcff2dcc1a1a87c5.setIcon(icon_1b21b8760bf3b37be13cbe3313efea50);
#
#
#         var popup_62568c80fab120cb1be1743d652689cc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4dbf6b6890399ad23de4adcf17bf4614 = $(`&lt;div id=&quot;html_4dbf6b6890399ad23de4adcf17bf4614&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;WOOSIEGIRL LLC &lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Buzz Delivery &lt;/strong&gt;&lt;br&gt;     Facility Type: RMJ Delivery Permit&lt;br&gt;     8445 Eldora Way&lt;br&gt;     Arvada, CO 80007     &lt;/div&gt;`)[0];
#                 popup_62568c80fab120cb1be1743d652689cc.setContent(html_4dbf6b6890399ad23de4adcf17bf4614);
#
#
#
#         marker_0318fa3c7d23fa28fcff2dcc1a1a87c5.bindPopup(popup_62568c80fab120cb1be1743d652689cc)
#         ;
#
#
#
#
#             tile_layer_1fe8482654ce821bc840dc0c23d6f095.addTo(map_96f29b6cff74f77ed5e9ecd131471996);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Example: Search for delivery in a specific city
city_search = "Pueblo"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[38.2765, -104.6046], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Facility Name']}</strong><br>
    <strong>{row['DBA']}</strong><br>
    Facility Type: {row['Facility Type']}<br>
    {row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip Code']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_delivery_map_pueblo.html")

# Display the filtered map in the notebook
m_filtered

# %%
# Example: Search for delivery in a specific city
city_search = "Boulder"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[40.0150, -105.2705], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Facility Name']}</strong><br>
    <strong>{row['DBA']}</strong><br>
    Facility Type: {row['Facility Type']}<br>
    {row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip Code']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_delivery_map_boulder.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ad527610165be1192e1b5b5d506f6865 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ad527610165be1192e1b5b5d506f6865&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ad527610165be1192e1b5b5d506f6865 = L.map(
#                 &quot;map_ad527610165be1192e1b5b5d506f6865&quot;,
#                 {
#                     center: [40.015, -105.2705],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5da2d113699540872da4c15cf02c42a4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_5da2d113699540872da4c15cf02c42a4.addTo(map_ad527610165be1192e1b5b5d506f6865);
#
#
#             var marker_ae312afc4edbc8bbb1a45743728ed45a = L.marker(
#                 [40.0174738, -105.2538668],
#                 {}
#             ).addTo(map_ad527610165be1192e1b5b5d506f6865);
#
#
#             var icon_cad16425e8484218edbf76577af72b09 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ae312afc4edbc8bbb1a45743728ed45a.setIcon(icon_cad16425e8484218edbf76577af72b09);
#
#
#         var popup_5526fdcfd73cf6da9287d11296a30383 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e7c11e4a50894585680dcacfe45c8544 = $(`&lt;div id=&quot;html_e7c11e4a50894585680dcacfe45c8544&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;MAGNOLIA ROAD INC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Magnolia Road Cannabis Company&lt;/strong&gt;&lt;br&gt;     Facility Type: MMJ Delivery Permit&lt;br&gt;     1750 30th Street, Unit 84B&lt;br&gt;     Boulder, CO 80301     &lt;/div&gt;`)[0];
#                 popup_5526fdcfd73cf6da9287d11296a30383.setContent(html_e7c11e4a50894585680dcacfe45c8544);
#
#
#
#         marker_ae312afc4edbc8bbb1a45743728ed45a.bindPopup(popup_5526fdcfd73cf6da9287d11296a30383)
#         ;
#
#
#
#
#             var marker_a032c4abaa9eab8729d455259e364046 = L.marker(
#                 [40.0161223, -105.2840396],
#                 {}
#             ).addTo(map_ad527610165be1192e1b5b5d506f6865);
#
#
#             var icon_d64ad9483e39eaa1f07e5f48baf450fd = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a032c4abaa9eab8729d455259e364046.setIcon(icon_d64ad9483e39eaa1f07e5f48baf450fd);
#
#
#         var popup_5cb31d9031fdd4af5915c3d46ae2c2d2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fe354449dd10a99f720af51b15d4c19f = $(`&lt;div id=&quot;html_fe354449dd10a99f720af51b15d4c19f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;THE DANDELION LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;The Dandelion&lt;/strong&gt;&lt;br&gt;     Facility Type: MMJ Delivery Permit&lt;br&gt;     845 Walnut Street&lt;br&gt;     Boulder, CO 80302     &lt;/div&gt;`)[0];
#                 popup_5cb31d9031fdd4af5915c3d46ae2c2d2.setContent(html_fe354449dd10a99f720af51b15d4c19f);
#
#
#
#         marker_a032c4abaa9eab8729d455259e364046.bindPopup(popup_5cb31d9031fdd4af5915c3d46ae2c2d2)
#         ;
#
#
#
#
#             tile_layer_5da2d113699540872da4c15cf02c42a4.addTo(map_ad527610165be1192e1b5b5d506f6865);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Step 5: Export Cleaned Data to CSV

# %%
# Export the cleaned DataFrame to a CSV file
df.to_csv("cleaned_colorado_delivery_full_list_v2.csv", index=False)

# Confirm the export
print("Data exported to colorado_delivery_full_list_v2.csv")
# Out:
# Data exported to colorado_delivery_full_list_v2.csv
