# %% [markdown]
# # Jupyter Notebook: Parsing CSV file and Visualizing Data

# %% [markdown]
# In this notebook, we will load a CSV file, convert it to a pandas DataFrame, and then create a map visualizations using folium.

# %%
pip install pandas folium
# Out:
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (2.2.3)
# Requirement already satisfied: folium in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (0.17.0)
# Requirement already satisfied: numpy>=1.23.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/ceraven/Library/Python/3.11/lib/python/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas) (2024.2)
# Requirement already satisfied: branca>=0.6.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from folium) (0.8.0)
# Requirement already satisfied: jinja2>=2.9 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from folium) (3.1.4)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from folium) (2024.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jinja2>=2.9->folium) (2.1.5)
# Requirement already satisfied: six>=1.5 in /Users/ceraven/Library/Python/3.11/lib/python/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->folium) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->folium) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->folium) (2024.8.30)
#
# [notice] A new release of pip available: 22.3.1 -> 24.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import necessary libraries
import pandas as pd
import folium

# %% [markdown]
# ## Step 1: Load CSV File

# %%
# Load the CSV file into a DataFrame
file_path = "colorado_operators_full_list.csv"

df = pd.read_csv(file_path)

# Optional: Display the first few rows to check if the file is loaded correctly
df.head(15)
# Out:
#    License Number                      Facility Name                  DBA  \
# 0       407-00008                BEYOND BROADWAY LLC              LivWell
# 1       407-00016          CLEARWATER CONSULTING LLC                  NaN
# 2       407-00001                  LAMA HOLDINGS LLC  Lama Brand Cannabis
# 3       407-00018                    MIH MANAGER LLC                  NaN
# 4       407-00021                    NOBO DENVER LLC                  NaN
# 5       407-00020                    SILVERPEAK CORP                  NaN
# 6       407-00015          THE COMMISSION CARTEL LLC                  NaN
# 7      407R-00013                BEYOND BROADWAY LLC              LivWell
# 8      407R-00034                BUFFALO BIOTECH LLC     Dalwhinnie Farms
# 9      407R-00033              CCS OF BROOMFIELD LLC                  NaN
# 10     407R-00024          CLEARWATER CONSULTING LLC                  NaN
# 11     407R-00001                  LAMA HOLDINGS LLC  Lama Brand Cannabis
# 12     407R-00028             MAMMOTH MANAGEMENT LLC                  NaN
# 13     407R-00029                    MIH MANAGER LLC                  NaN
# 14     407R-00026  NATIONAL WAREHOUSE MANAGEMENT LLC                  NaN
#
#    Facility Type                            Street         City State  \
# 0   MMJ Operator  400 East 84th  Avenue, Suite W-5     Thornton    CO
# 1   MMJ Operator            27066 East Irish Drive       Aurora    CO
# 2   MMJ Operator               1015 McMurdo Circle  Castle Rock    CO
# 3   MMJ Operator      4880 Havana Street Suite 201       Denver    CO
# 4   MMJ Operator           1265 Yellow Pine Avenue      Boulder    CO
# 5   MMJ Operator               10192 Audrey Street    Firestone    CO
# 6   MMJ Operator     5475 Peoria Street Unit 4-109       Denver    CO
# 7   RMJ Operator  400 East 84th  Avenue, Suite W-5     Thornton    CO
# 8   RMJ Operator      1615 Platte Street Suite 200       Denver    CO
# 9   RMJ Operator           328 Caribou Pass Circle    Lafayette    CO
# 10  RMJ Operator            27066 East Irish Drive       Aurora    CO
# 11  RMJ Operator               1015 McMurdo Circle  Castle Rock    CO
# 12  RMJ Operator             9154 East 37th Avenue       Denver    CO
# 13  RMJ Operator      4880 Havana Street Suite 201       Denver    CO
# 14  RMJ Operator    1875 Lawrence Street Suite 730       Denver    CO
#
#     Zip Code Date Updated   Latitude   Longitude
# 0      80229   2024-09-03  39.849142 -104.982212
# 1      80016   2024-09-03  39.577544 -104.697290
# 2      80108   2024-09-03  39.377384 -104.815996
# 3      80239   2024-09-03  39.786288 -104.865664
# 4      80304   2024-09-03  40.059663 -105.281533
# 5      80504   2024-09-03  40.148588 -104.965605
# 6      80239   2024-09-03  39.795075 -104.847699
# 7      80229   2024-09-03  39.849142 -104.982212
# 8      80202   2024-09-03  39.757615 -105.008103
# 9      80026   2024-09-03  40.000930 -105.132333
# 10     80016   2024-09-03  39.577544 -104.697290
# 11     80108   2024-09-03  39.377384 -104.815996
# 12     80238   2024-09-03  39.767152 -104.880127
# 13     80239   2024-09-03  39.786288 -104.865664
# 14     80202   2024-09-03  39.751123 -104.993354

# %% [markdown]
# ## Step 2: Clean and Prepare the Data

# %%
# Check column names and data types
df.info()

# Clean any missing latitude or longitude data
df.dropna(subset=['Longitude', 'Latitude'], inplace=True)

# Optional: Check for missing values in other important columns
df.isnull().sum()

# Optional: Display the first few rows of cleaned data
df.head(15)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   License Number  19 non-null     object
#  1   Facility Name   19 non-null     object
#  2   DBA             6 non-null      object
#  3   Facility Type   19 non-null     object
#  4   Street          19 non-null     object
#  5   City            19 non-null     object
#  6   State           19 non-null     object
#  7   Zip Code        19 non-null     int64
#  8   Date Updated    19 non-null     object
#  9   Latitude        19 non-null     float64
#  10  Longitude       19 non-null     float64
# dtypes: float64(2), int64(1), object(8)
# memory usage: 1.8+ KB
#    License Number                      Facility Name                  DBA  \
# 0       407-00008                BEYOND BROADWAY LLC              LivWell
# 1       407-00016          CLEARWATER CONSULTING LLC                  NaN
# 2       407-00001                  LAMA HOLDINGS LLC  Lama Brand Cannabis
# 3       407-00018                    MIH MANAGER LLC                  NaN
# 4       407-00021                    NOBO DENVER LLC                  NaN
# 5       407-00020                    SILVERPEAK CORP                  NaN
# 6       407-00015          THE COMMISSION CARTEL LLC                  NaN
# 7      407R-00013                BEYOND BROADWAY LLC              LivWell
# 8      407R-00034                BUFFALO BIOTECH LLC     Dalwhinnie Farms
# 9      407R-00033              CCS OF BROOMFIELD LLC                  NaN
# 10     407R-00024          CLEARWATER CONSULTING LLC                  NaN
# 11     407R-00001                  LAMA HOLDINGS LLC  Lama Brand Cannabis
# 12     407R-00028             MAMMOTH MANAGEMENT LLC                  NaN
# 13     407R-00029                    MIH MANAGER LLC                  NaN
# 14     407R-00026  NATIONAL WAREHOUSE MANAGEMENT LLC                  NaN
#
#    Facility Type                            Street         City State  \
# 0   MMJ Operator  400 East 84th  Avenue, Suite W-5     Thornton    CO
# 1   MMJ Operator            27066 East Irish Drive       Aurora    CO
# 2   MMJ Operator               1015 McMurdo Circle  Castle Rock    CO
# 3   MMJ Operator      4880 Havana Street Suite 201       Denver    CO
# 4   MMJ Operator           1265 Yellow Pine Avenue      Boulder    CO
# 5   MMJ Operator               10192 Audrey Street    Firestone    CO
# 6   MMJ Operator     5475 Peoria Street Unit 4-109       Denver    CO
# 7   RMJ Operator  400 East 84th  Avenue, Suite W-5     Thornton    CO
# 8   RMJ Operator      1615 Platte Street Suite 200       Denver    CO
# 9   RMJ Operator           328 Caribou Pass Circle    Lafayette    CO
# 10  RMJ Operator            27066 East Irish Drive       Aurora    CO
# 11  RMJ Operator               1015 McMurdo Circle  Castle Rock    CO
# 12  RMJ Operator             9154 East 37th Avenue       Denver    CO
# 13  RMJ Operator      4880 Havana Street Suite 201       Denver    CO
# 14  RMJ Operator    1875 Lawrence Street Suite 730       Denver    CO
#
#     Zip Code Date Updated   Latitude   Longitude
# 0      80229   2024-09-03  39.849142 -104.982212
# 1      80016   2024-09-03  39.577544 -104.697290
# 2      80108   2024-09-03  39.377384 -104.815996
# 3      80239   2024-09-03  39.786288 -104.865664
# 4      80304   2024-09-03  40.059663 -105.281533
# 5      80504   2024-09-03  40.148588 -104.965605
# 6      80239   2024-09-03  39.795075 -104.847699
# 7      80229   2024-09-03  39.849142 -104.982212
# 8      80202   2024-09-03  39.757615 -105.008103
# 9      80026   2024-09-03  40.000930 -105.132333
# 10     80016   2024-09-03  39.577544 -104.697290
# 11     80108   2024-09-03  39.377384 -104.815996
# 12     80238   2024-09-03  39.767152 -104.880127
# 13     80239   2024-09-03  39.786288 -104.865664
# 14     80202   2024-09-03  39.751123 -104.993354

# %% [markdown]
# ## Step 3: Create a Searchable Map

# %%
# Initialize the map centered around Colorado
m = folium.Map(location=[39.5501, -105.7821], zoom_start=7)

# Add markers to the map for each food pantry
for idx, row in df.iterrows():
    popup_text = f"""
    <strong>{row['Facility Name']}</strong><br>
    <strong>{row['DBA']}</strong><br>
    Facility Type: {row['Facility Type']}<br>
    {row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip Code']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m)

# Save the map as an HTML file
m.save("colorado_operators_full_list_map.html")

# Display the map in the notebook
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e69bc834723d6740df7f1c68dd29818b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e69bc834723d6740df7f1c68dd29818b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e69bc834723d6740df7f1c68dd29818b = L.map(
#                 &quot;map_e69bc834723d6740df7f1c68dd29818b&quot;,
#                 {
#                     center: [39.5501, -105.7821],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_56a7e6dfc365c231da81d6126450bf02 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_56a7e6dfc365c231da81d6126450bf02.addTo(map_e69bc834723d6740df7f1c68dd29818b);
#
#
#             var marker_f199eb6e221018a56e5c8ab9487a9ee7 = L.marker(
#                 [39.849142, -104.9822123],
#                 {}
#             ).addTo(map_e69bc834723d6740df7f1c68dd29818b);
#
#
#             var icon_ce74444417ced15bdaff52150e73572a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f199eb6e221018a56e5c8ab9487a9ee7.setIcon(icon_ce74444417ced15bdaff52150e73572a);
#
#
#         var popup_f19c4b01e3e59f880865c0ac13eac823 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_87b12e37a3cca3f3c3e93e8959ad29f8 = $(`&lt;div id=&quot;html_87b12e37a3cca3f3c3e93e8959ad29f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;BEYOND BROADWAY LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;LivWell&lt;/strong&gt;&lt;br&gt;     Facility Type: MMJ Operator&lt;br&gt;     400 East 84th  Avenue, Suite W-5&lt;br&gt;     Thornton, CO 80229     &lt;/div&gt;`)[0];
#                 popup_f19c4b01e3e59f880865c0ac13eac823.setContent(html_87b12e37a3cca3f3c3e93e8959ad29f8);
#
#
#
#         marker_f199eb6e221018a56e5c8ab9487a9ee7.bindPopup(popup_f19c4b01e3e59f880865c0ac13eac823)
#         ;
#
#
#
#
#             var marker_8bfb0e2fa193905a9d5055acd56af6a7 = L.marker(
#                 [39.5775442, -104.6972905],
#                 {}
#             ).addTo(map_e69bc834723d6740df7f1c68dd29818b);
#
#
#             var icon_6d1cd482acac40eb740c4cce1d0fbdbf = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8bfb0e2fa193905a9d5055acd56af6a7.setIcon(icon_6d1cd482acac40eb740c4cce1d0fbdbf);
#
#
#         var popup_4c46a3fa3e8b01009fd03ae9a36908c1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d16beee9ae3c2bb376ef94d731716ca6 = $(`&lt;div id=&quot;html_d16beee9ae3c2bb376ef94d731716ca6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;CLEARWATER CONSULTING LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;nan&lt;/strong&gt;&lt;br&gt;     Facility Type: MMJ Operator&lt;br&gt;     27066 East Irish Drive&lt;br&gt;     Aurora, CO 80016     &lt;/div&gt;`)[0];
#                 popup_4c46a3fa3e8b01009fd03ae9a36908c1.setContent(html_d16beee9ae3c2bb376ef94d731716ca6);
#
#
#
#         marker_8bfb0e2fa193905a9d5055acd56af6a7.bindPopup(popup_4c46a3fa3e8b01009fd03ae9a36908c1)
#         ;
#
#
#
#
#             var marker_3534c11dd9626cabd9504a41ea596b0c = L.marker(
#                 [39.3773837, -104.8159957],
#                 {}
#             ).addTo(map_e69bc834723d6740df7f1c68dd29818b);
#
#
#             var icon_0f21979210ce0161236bf3fe58883bad = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3534c11dd9626cabd9504a41ea596b0c.setIcon(icon_0f21979210ce0161236bf3fe58883bad);
#
#
#         var popup_1e1ca2e47df7a54bcb245d2bb3748309 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_59fd4bbd5375d4f89dd8b6982f0b37b0 = $(`&lt;div id=&quot;html_59fd4bbd5375d4f89dd8b6982f0b37b0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;LAMA HOLDINGS LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Lama Brand Cannabis&lt;/strong&gt;&lt;br&gt;     Facility Type: MMJ Operator&lt;br&gt;     1015 McMurdo Circle&lt;br&gt;     Castle Rock, CO 80108     &lt;/div&gt;`)[0];
#                 popup_1e1ca2e47df7a54bcb245d2bb3

# %% [markdown]
# ## Step 4: Implement Search Functionality

# %%
# Example: Search for operators in a specific city
city_search = "Denver"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[39.5501, -105.7821], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Facility Name']}</strong><br>
    <strong>{row['DBA']}</strong><br>
    Facility Type: {row['Facility Type']}<br>
    {row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip Code']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_operators_map_denver.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_295ad6183f95f64305dec20f9ad4df76 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_295ad6183f95f64305dec20f9ad4df76&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_295ad6183f95f64305dec20f9ad4df76 = L.map(
#                 &quot;map_295ad6183f95f64305dec20f9ad4df76&quot;,
#                 {
#                     center: [39.5501, -105.7821],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d5fbaa8c9c822c371198d4f21974800e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d5fbaa8c9c822c371198d4f21974800e.addTo(map_295ad6183f95f64305dec20f9ad4df76);
#
#
#             var marker_0a2f3918defc84c711cbc458dc7d080b = L.marker(
#                 [39.7862876, -104.8656645],
#                 {}
#             ).addTo(map_295ad6183f95f64305dec20f9ad4df76);
#
#
#             var icon_95b8cb30b7720567f0e757d5094b4d3c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0a2f3918defc84c711cbc458dc7d080b.setIcon(icon_95b8cb30b7720567f0e757d5094b4d3c);
#
#
#         var popup_e21603e85a69960625a00287f7b1ce8b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_27ef8aa678241b1146bcb14d153c4324 = $(`&lt;div id=&quot;html_27ef8aa678241b1146bcb14d153c4324&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;MIH MANAGER LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;nan&lt;/strong&gt;&lt;br&gt;     Facility Type: MMJ Operator&lt;br&gt;     4880 Havana Street Suite 201&lt;br&gt;     Denver, CO 80239     &lt;/div&gt;`)[0];
#                 popup_e21603e85a69960625a00287f7b1ce8b.setContent(html_27ef8aa678241b1146bcb14d153c4324);
#
#
#
#         marker_0a2f3918defc84c711cbc458dc7d080b.bindPopup(popup_e21603e85a69960625a00287f7b1ce8b)
#         ;
#
#
#
#
#             var marker_7826d4761d52d583e809eaf762bcd6d0 = L.marker(
#                 [39.7950754, -104.8476993],
#                 {}
#             ).addTo(map_295ad6183f95f64305dec20f9ad4df76);
#
#
#             var icon_9bc12c9979df8b716b3c7d64ae2f4001 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7826d4761d52d583e809eaf762bcd6d0.setIcon(icon_9bc12c9979df8b716b3c7d64ae2f4001);
#
#
#         var popup_b922c8aafa75b257b1c2b7a9d87f8fe4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c0b96b1167d41b93e053af3dbfca10fb = $(`&lt;div id=&quot;html_c0b96b1167d41b93e053af3dbfca10fb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;THE COMMISSION CARTEL LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;nan&lt;/strong&gt;&lt;br&gt;     Facility Type: MMJ Operator&lt;br&gt;     5475 Peoria Street Unit 4-109&lt;br&gt;     Denver, CO 80239     &lt;/div&gt;`)[0];
#                 popup_b922c8aafa75b257b1c2b7a9d87f8fe4.setContent(html_c0b96b1167d41b93e053af3dbfca10fb);
#
#
#
#         marker_7826d4761d52d583e809eaf762bcd6d0.bindPopup(popup_b922c8aafa75b257b1c2b7a9d87f8fe4)
#         ;
#
#
#
#
#             var marker_d3c1da9e4988c3ce689ce34de3934fbd = L.marker(
#                 [39.7576154, -105.008103],
#                 {}
#             ).addTo(map_295ad6183f95f64305dec20f9ad4df76);
#
#
#             var icon_883b71cd237f13822bf8dd714aea6442 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d3c1da9e4988c3ce689ce34de3934fbd.setIcon(icon_883b71cd237f13822bf8dd714aea6442);
#
#
#         var popup_bf2a734af8f5ccb49235146d061665f6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bfb89d3ea6f92f538dc1d12d47394132 = $(`&lt;div id=&quot;html_bfb89d3ea6f92f538dc1d12d47394132&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;BUFFALO BIOTECH LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Dalwhinnie Farms&lt;/strong&gt;&lt;br&gt;     Facility Type: RMJ Operator&lt;br&gt;     1615 Platte Street Suite 200&lt;br&gt;     Denver, CO 80202     &lt;/div&gt;`)[0];
#                 popup_bf2a734af8f5ccb49235146d061665

# %%
# Example: Search for operators in a specific city
city_search = "Aurora"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[39.7108, -104.8125], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Facility Name']}</strong><br>
    <strong>{row['DBA']}</strong><br>
    Facility Type: {row['Facility Type']}<br>
    {row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip Code']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_operators_map_aurora.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_020273390c1bcf8f562a8d9bb6583814 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_020273390c1bcf8f562a8d9bb6583814&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_020273390c1bcf8f562a8d9bb6583814 = L.map(
#                 &quot;map_020273390c1bcf8f562a8d9bb6583814&quot;,
#                 {
#                     center: [39.7108, -104.8125],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9ba6b61cf7bfa9b4b7e0531d28e56ee9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_9ba6b61cf7bfa9b4b7e0531d28e56ee9.addTo(map_020273390c1bcf8f562a8d9bb6583814);
#
#
#             var marker_7c8453f2f415b48a82f96a304817081d = L.marker(
#                 [39.5775442, -104.6972905],
#                 {}
#             ).addTo(map_020273390c1bcf8f562a8d9bb6583814);
#
#
#             var icon_2b15f033f5e77bb4c211aa4569daf842 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7c8453f2f415b48a82f96a304817081d.setIcon(icon_2b15f033f5e77bb4c211aa4569daf842);
#
#
#         var popup_9140b813bac2641b47f1d9a7a0d28ed9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a1f95859370987687f9dd299772c8c46 = $(`&lt;div id=&quot;html_a1f95859370987687f9dd299772c8c46&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;CLEARWATER CONSULTING LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;nan&lt;/strong&gt;&lt;br&gt;     Facility Type: MMJ Operator&lt;br&gt;     27066 East Irish Drive&lt;br&gt;     Aurora, CO 80016     &lt;/div&gt;`)[0];
#                 popup_9140b813bac2641b47f1d9a7a0d28ed9.setContent(html_a1f95859370987687f9dd299772c8c46);
#
#
#
#         marker_7c8453f2f415b48a82f96a304817081d.bindPopup(popup_9140b813bac2641b47f1d9a7a0d28ed9)
#         ;
#
#
#
#
#             var marker_774068d81c1bd9bab289fc6338891743 = L.marker(
#                 [39.5775442, -104.6972905],
#                 {}
#             ).addTo(map_020273390c1bcf8f562a8d9bb6583814);
#
#
#             var icon_c32df5e234684008d5fea91aeb0729c9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_774068d81c1bd9bab289fc6338891743.setIcon(icon_c32df5e234684008d5fea91aeb0729c9);
#
#
#         var popup_6580cf4ba9fa40e8d323a631f5b6523c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_08a285bf41282cac71608dac8e8492a4 = $(`&lt;div id=&quot;html_08a285bf41282cac71608dac8e8492a4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;CLEARWATER CONSULTING LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;nan&lt;/strong&gt;&lt;br&gt;     Facility Type: RMJ Operator&lt;br&gt;     27066 East Irish Drive&lt;br&gt;     Aurora, CO 80016     &lt;/div&gt;`)[0];
#                 popup_6580cf4ba9fa40e8d323a631f5b6523c.setContent(html_08a285bf41282cac71608dac8e8492a4);
#
#
#
#         marker_774068d81c1bd9bab289fc6338891743.bindPopup(popup_6580cf4ba9fa40e8d323a631f5b6523c)
#         ;
#
#
#
#
#             tile_layer_9ba6b61cf7bfa9b4b7e0531d28e56ee9.addTo(map_020273390c1bcf8f562a8d9bb6583814);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Example: Search for operators in a specific city
city_search = "Boulder"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[40.0150, -105.2705], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Facility Name']}</strong><br>
    <strong>{row['DBA']}</strong><br>
    Facility Type: {row['Facility Type']}<br>
    {row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip Code']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_operators_map_boulder.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_445e194f731531bbac0ce2f8ef81cf5a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_445e194f731531bbac0ce2f8ef81cf5a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_445e194f731531bbac0ce2f8ef81cf5a = L.map(
#                 &quot;map_445e194f731531bbac0ce2f8ef81cf5a&quot;,
#                 {
#                     center: [40.015, -105.2705],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_92b37e0e02cf3529722aee2e9bea288b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_92b37e0e02cf3529722aee2e9bea288b.addTo(map_445e194f731531bbac0ce2f8ef81cf5a);
#
#
#             var marker_3eb9babf7d436a21edad3bec192a42b2 = L.marker(
#                 [40.059663, -105.2815328],
#                 {}
#             ).addTo(map_445e194f731531bbac0ce2f8ef81cf5a);
#
#
#             var icon_2f90445010159f7ce9058684b2e18682 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3eb9babf7d436a21edad3bec192a42b2.setIcon(icon_2f90445010159f7ce9058684b2e18682);
#
#
#         var popup_1804c7ca32e9061e6f878ffeaf366e56 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e7346f70d72b860fbd8c7eeb21b3e95e = $(`&lt;div id=&quot;html_e7346f70d72b860fbd8c7eeb21b3e95e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;NOBO DENVER LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;nan&lt;/strong&gt;&lt;br&gt;     Facility Type: MMJ Operator&lt;br&gt;     1265 Yellow Pine Avenue&lt;br&gt;     Boulder, CO 80304     &lt;/div&gt;`)[0];
#                 popup_1804c7ca32e9061e6f878ffeaf366e56.setContent(html_e7346f70d72b860fbd8c7eeb21b3e95e);
#
#
#
#         marker_3eb9babf7d436a21edad3bec192a42b2.bindPopup(popup_1804c7ca32e9061e6f878ffeaf366e56)
#         ;
#
#
#
#
#             var marker_262c363a62084102cfe1951710c76d14 = L.marker(
#                 [40.059663, -105.2815328],
#                 {}
#             ).addTo(map_445e194f731531bbac0ce2f8ef81cf5a);
#
#
#             var icon_c8f41b44ffd906de90ec4b949285422d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_262c363a62084102cfe1951710c76d14.setIcon(icon_c8f41b44ffd906de90ec4b949285422d);
#
#
#         var popup_6331d303689b86b849337d45b86a1078 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dba48f661d5187ebe81d7a82c85fd747 = $(`&lt;div id=&quot;html_dba48f661d5187ebe81d7a82c85fd747&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;NOBO DENVER LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;nan&lt;/strong&gt;&lt;br&gt;     Facility Type: RMJ Operator&lt;br&gt;     1265 Yellow Pine Avenue&lt;br&gt;     Boulder, CO 80304     &lt;/div&gt;`)[0];
#                 popup_6331d303689b86b849337d45b86a1078.setContent(html_dba48f661d5187ebe81d7a82c85fd747);
#
#
#
#         marker_262c363a62084102cfe1951710c76d14.bindPopup(popup_6331d303689b86b849337d45b86a1078)
#         ;
#
#
#
#
#             tile_layer_92b37e0e02cf3529722aee2e9bea288b.addTo(map_445e194f731531bbac0ce2f8ef81cf5a);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Step 5: Export Cleaned Data to CSV

# %%
# Export the cleaned DataFrame to a CSV file
df.to_csv("cleaned_colorado_operators_full_list_v2.csv", index=False)

# Confirm the export
print("Data exported to colorado_operators_full_list_v2.csv")
# Out:
# Data exported to colorado_operators_full_list_v2.csv
