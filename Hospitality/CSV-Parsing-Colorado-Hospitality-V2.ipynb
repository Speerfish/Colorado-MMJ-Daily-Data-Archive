# %% [markdown]
# # Jupyter Notebook: Parsing CSV file and Visualizing Data

# %% [markdown]
# In this notebook, we will load a CSV file, convert it to a pandas DataFrame, and then create a map visualizations using folium.

# %%
pip install pandas folium
# Out:
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (2.2.3)
# Requirement already satisfied: folium in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (0.17.0)
# Requirement already satisfied: numpy>=1.23.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/ceraven/Library/Python/3.11/lib/python/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas) (2024.2)
# Requirement already satisfied: branca>=0.6.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from folium) (0.8.0)
# Requirement already satisfied: jinja2>=2.9 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from folium) (3.1.4)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from folium) (2024.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jinja2>=2.9->folium) (2.1.5)
# Requirement already satisfied: six>=1.5 in /Users/ceraven/Library/Python/3.11/lib/python/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->folium) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->folium) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->folium) (2024.8.30)
#
# [notice] A new release of pip available: 22.3.1 -> 24.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import necessary libraries
import pandas as pd
import folium

# %% [markdown]
# ## Step 1: Load CSV File

# %%
# Load the CSV file into a DataFrame
file_path = "colorado_hospitality_full_list.csv"

df = pd.read_csv(file_path)

# Optional: Display the first few rows to check if the file is loaded correctly
df.head(15)
# Out:
#    License Number                       Facility Name  \
# 0      609H-00003                      1130 YUMA LLC
# 1      609H-00015                  AES ENTERPRISE LLC
# 2      609H-00010                     CCT DEN HLD LLC
# 3      609H-00013              CCT HOLDINGS LIMOS LLC
# 4      609H-00012              CCT HOLDINGS LIMOS LLC
# 5      609H-00016                        HASH CAB LLC
# 6      609H-00011                 KUSH & CANVASES LLC
# 7      609H-00008         TETRA HOSPITALITY GROUP LLC
# 8      609H-00006                  THE 420 DENVER INC
# 9     610HS-00006                AYAN ENTERPRISES LLC
# 10    610HS-00003                   HOPE HOLDINGS LTD
# 11    610HS-00010                            MAMA LLC
# 12    610HS-00011                     PR VENTURES INC
# 13    610HS-00009  PURE ELEVATIONS SPA AND GARDEN LLC
# 14    610HS-00008                         ROASTED LLC
#
#                          DBA                 Facility Type  \
# 0          The Coffee Joint           Hospitality Business
# 1            Canna CabanaBus          Hospitality Business
# 2       Puff, Pass And Paint          Hospitality Business
# 3    Colorado Cannabis Tours          Hospitality Business
# 4    Colorado Cannabis Tours          Hospitality Business
# 5                        NaN          Hospitality Business
# 6    The Cannabis Experience          Hospitality Business
# 7                      Tetra          Hospitality Business
# 8                        NaN          Hospitality Business
# 9         CIRRUS SOCIAL CLUB  Hospitality & Sales Business
# 10     JAD's Mile High Smoke  Hospitality & Sales Business
# 11                       NaN  Hospitality & Sales Business
# 12  Thunderbuzz Cannabis Bar  Hospitality & Sales Business
# 13                       NaN  Hospitality & Sales Business
# 14                       NaN  Hospitality & Sales Business
#
#                             Street      City State  Zip Code Date Updated  \
# 0                 1130 Yuma Court     Denver    CO     80204   2024-09-03
# 1             16343 Filmore Street  Thornton    CO     80602   2024-09-03
# 2       1904 South Cherokee Street    Denver    CO     80223   2024-09-03
# 3       1904 South Cherokee Street    Denver    CO     80223   2024-09-03
# 4      1904 South Cherokee Street     Denver    CO     80223   2024-09-03
# 5    6735 West 84th Circle Unit 72    Arvada    CO     80003   2024-09-03
# 6      3001 North Elizabeth Street    Denver    CO     80205   2024-09-03
# 7               3039 Walnut Street    Denver    CO     80205   2024-09-03
# 8   420 East 11th Avenue Suite 420    Denver    CO     80203   2024-09-03
# 9          3200 East Colfax Avenue    Denver    CO     80222   2024-09-03
# 10          7667 Washington Street    Denver    CO     80229   2024-09-03
# 11             3739 Wynkoop Street    Denver    CO     80216   2024-09-03
# 12       1196 South Santa Fe Drive    Denver    CO     80223   2024-09-03
# 13        185 South Santa Fe Drive    Denver    CO     80223   2024-09-03
# 14         217 Main Street Suite C  Antonito    CO     81120   2024-09-03
#
#      Latitude   Longitude
# 0   39.734233 -105.014378
# 1   39.923260 -104.953113
# 2   39.682013 -104.990887
# 3   39.682013 -104.990887
# 4   39.682013 -104.990887
# 5   39.849252 -105.072078
# 6   39.759475 -104.956117
# 7   39.763601 -104.980891
# 8   39.733450 -104.981439
# 9   39.740077 -104.949310
# 10  39.791049 -104.978271
# 11  39.772008 -104.975346
# 12  39.694970 -104.992030
# 13  39.714098 -104.998405
# 14  37.073189 -106.008955

# %% [markdown]
# ## Step 2: Clean and Prepare the Data

# %%
# Check column names and data types
df.info()

# Clean any missing latitude or longitude data
df.dropna(subset=['Longitude', 'Latitude'], inplace=True)

# Optional: Check for missing values in other important columns
df.isnull().sum()

# Optional: Display the first few rows of cleaned data
df.head(15)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   License Number  15 non-null     object
#  1   Facility Name   15 non-null     object
#  2   DBA             10 non-null     object
#  3   Facility Type   15 non-null     object
#  4   Street          15 non-null     object
#  5   City            15 non-null     object
#  6   State           15 non-null     object
#  7   Zip Code        15 non-null     int64
#  8   Date Updated    15 non-null     object
#  9   Latitude        15 non-null     float64
#  10  Longitude       15 non-null     float64
# dtypes: float64(2), int64(1), object(8)
# memory usage: 1.4+ KB
#    License Number                       Facility Name  \
# 0      609H-00003                      1130 YUMA LLC
# 1      609H-00015                  AES ENTERPRISE LLC
# 2      609H-00010                     CCT DEN HLD LLC
# 3      609H-00013              CCT HOLDINGS LIMOS LLC
# 4      609H-00012              CCT HOLDINGS LIMOS LLC
# 5      609H-00016                        HASH CAB LLC
# 6      609H-00011                 KUSH & CANVASES LLC
# 7      609H-00008         TETRA HOSPITALITY GROUP LLC
# 8      609H-00006                  THE 420 DENVER INC
# 9     610HS-00006                AYAN ENTERPRISES LLC
# 10    610HS-00003                   HOPE HOLDINGS LTD
# 11    610HS-00010                            MAMA LLC
# 12    610HS-00011                     PR VENTURES INC
# 13    610HS-00009  PURE ELEVATIONS SPA AND GARDEN LLC
# 14    610HS-00008                         ROASTED LLC
#
#                          DBA                 Facility Type  \
# 0          The Coffee Joint           Hospitality Business
# 1            Canna CabanaBus          Hospitality Business
# 2       Puff, Pass And Paint          Hospitality Business
# 3    Colorado Cannabis Tours          Hospitality Business
# 4    Colorado Cannabis Tours          Hospitality Business
# 5                        NaN          Hospitality Business
# 6    The Cannabis Experience          Hospitality Business
# 7                      Tetra          Hospitality Business
# 8                        NaN          Hospitality Business
# 9         CIRRUS SOCIAL CLUB  Hospitality & Sales Business
# 10     JAD's Mile High Smoke  Hospitality & Sales Business
# 11                       NaN  Hospitality & Sales Business
# 12  Thunderbuzz Cannabis Bar  Hospitality & Sales Business
# 13                       NaN  Hospitality & Sales Business
# 14                       NaN  Hospitality & Sales Business
#
#                             Street      City State  Zip Code Date Updated  \
# 0                 1130 Yuma Court     Denver    CO     80204   2024-09-03
# 1             16343 Filmore Street  Thornton    CO     80602   2024-09-03
# 2       1904 South Cherokee Street    Denver    CO     80223   2024-09-03
# 3       1904 South Cherokee Street    Denver    CO     80223   2024-09-03
# 4      1904 South Cherokee Street     Denver    CO     80223   2024-09-03
# 5    6735 West 84th Circle Unit 72    Arvada    CO     80003   2024-09-03
# 6      3001 North Elizabeth Street    Denver    CO     80205   2024-09-03
# 7               3039 Walnut Street    Denver    CO     80205   2024-09-03
# 8   420 East 11th Avenue Suite 420    Denver    CO     80203   2024-09-03
# 9          3200 East Colfax Avenue    Denver    CO     80222   2024-09-03
# 10          7667 Washington Street    Denver    CO     80229   2024-09-03
# 11             3739 Wynkoop Street    Denver    CO     80216   2024-09-03
# 12       1196 South Santa Fe Drive    Denver    CO     80223   2024-09-03
# 13        185 South Santa Fe Drive    Denver    CO     80223   2024-09-03
# 14         217 Main Street Suite C  Antonito    CO     81120   2024-09-03
#
#      Latitude   Longitude
# 0   39.734233 -105.014378
# 1   39.923260 -104.953113
# 2   39.682013 -104.990887
# 3   39.682013 -104.990887
# 4   39.682013 -104.990887
# 5   39.849252 -105.072078
# 6   39.759475 -104.956117
# 7   39.763601 -104.980891
# 8   39.733450 -104.981439
# 9   39.740077 -104.949310
# 10  39.791049 -104.978271
# 11  39.772008 -104.975346
# 12  39.694970 -104.992030
# 13  39.714098 -104.998405
# 14  37.073189 -106.008955

# %% [markdown]
# ## Step 3: Create a Searchable Map

# %%
# Initialize the map centered around Colorado
m = folium.Map(location=[39.5501, -105.7821], zoom_start=7)

# Add markers to the map for each food pantry
for idx, row in df.iterrows():
    popup_text = f"""
    <strong>{row['Facility Name']}</strong><br>
    <strong>{row['DBA']}</strong><br>
    Facility Type: {row['Facility Type']}<br>
    {row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip Code']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m)

# Save the map as an HTML file
m.save("colorado_hospitality_full_list_map.html")

# Display the map in the notebook
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5864b977bbb3c279a0f1e3a7099cad9e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5864b977bbb3c279a0f1e3a7099cad9e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5864b977bbb3c279a0f1e3a7099cad9e = L.map(
#                 &quot;map_5864b977bbb3c279a0f1e3a7099cad9e&quot;,
#                 {
#                     center: [39.5501, -105.7821],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_31592abff50a6a91faf28202a98d8f7f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_31592abff50a6a91faf28202a98d8f7f.addTo(map_5864b977bbb3c279a0f1e3a7099cad9e);
#
#
#             var marker_86b4198983e2066dd4d96abd9c4cae4e = L.marker(
#                 [39.7342327, -105.0143784],
#                 {}
#             ).addTo(map_5864b977bbb3c279a0f1e3a7099cad9e);
#
#
#             var icon_bfdec844a589601379d948dbec2adb1b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_86b4198983e2066dd4d96abd9c4cae4e.setIcon(icon_bfdec844a589601379d948dbec2adb1b);
#
#
#         var popup_81b16a68e8a29997a66bf96ee5601338 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_03769670e1baa28da8d5d4a4ac18baf8 = $(`&lt;div id=&quot;html_03769670e1baa28da8d5d4a4ac18baf8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;1130 YUMA LLC &lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;The Coffee Joint &lt;/strong&gt;&lt;br&gt;     Facility Type: Hospitality Business&lt;br&gt;     1130 Yuma Court &lt;br&gt;     Denver, CO 80204     &lt;/div&gt;`)[0];
#                 popup_81b16a68e8a29997a66bf96ee5601338.setContent(html_03769670e1baa28da8d5d4a4ac18baf8);
#
#
#
#         marker_86b4198983e2066dd4d96abd9c4cae4e.bindPopup(popup_81b16a68e8a29997a66bf96ee5601338)
#         ;
#
#
#
#
#             var marker_8fcde41aee8ca5f893dadad06ec58a1e = L.marker(
#                 [39.9232596, -104.9531126],
#                 {}
#             ).addTo(map_5864b977bbb3c279a0f1e3a7099cad9e);
#
#
#             var icon_13ffb85e6ff42cf24c3083e77f9f9d51 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8fcde41aee8ca5f893dadad06ec58a1e.setIcon(icon_13ffb85e6ff42cf24c3083e77f9f9d51);
#
#
#         var popup_ef563a4a57012790e5c82a0e730a78bd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_85fb9d134cd6fed8cde2545929155a0d = $(`&lt;div id=&quot;html_85fb9d134cd6fed8cde2545929155a0d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;AES ENTERPRISE LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Canna CabanaBus&lt;/strong&gt;&lt;br&gt;     Facility Type: Hospitality Business&lt;br&gt;     16343 Filmore Street&lt;br&gt;     Thornton, CO 80602     &lt;/div&gt;`)[0];
#                 popup_ef563a4a57012790e5c82a0e730a78bd.setContent(html_85fb9d134cd6fed8cde2545929155a0d);
#
#
#
#         marker_8fcde41aee8ca5f893dadad06ec58a1e.bindPopup(popup_ef563a4a57012790e5c82a0e730a78bd)
#         ;
#
#
#
#
#             var marker_4bff46dc25aaa3f4b94a5408bece827c = L.marker(
#                 [39.6820133, -104.9908875],
#                 {}
#             ).addTo(map_5864b977bbb3c279a0f1e3a7099cad9e);
#
#
#             var icon_2ad911b50916c1f95158ca25c1bb3816 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4bff46dc25aaa3f4b94a5408bece827c.setIcon(icon_2ad911b50916c1f95158ca25c1bb3816);
#
#
#         var popup_e1923fb0170b1713095ae0a24dcca601 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7f8350a2b3b663c66290cdb7a4d2eec2 = $(`&lt;div id=&quot;html_7f8350a2b3b663c66290cdb7a4d2eec2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;CCT DEN HLD LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Puff, Pass And Paint&lt;/strong&gt;&lt;br&gt;     Facility Type: Hospitality Business&lt;br&gt;     1904 South Cherokee Street&lt;br&gt;     Denver, CO 80223     &lt;/div&gt;`)[0];
#                 popup_e1923fb0

# %% [markdown]
# ## Step 4: Implement Search Functionality

# %%
# Example: Search for hospitality in a specific city
city_search = "Denver"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[39.5501, -105.7821], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Facility Name']}</strong><br>
    <strong>{row['DBA']}</strong><br>
    Facility Type: {row['Facility Type']}<br>
    {row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip Code']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_hospitality_map_denver.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_097925b7beb89f8bf97bb3c23e5d5cb4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_097925b7beb89f8bf97bb3c23e5d5cb4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_097925b7beb89f8bf97bb3c23e5d5cb4 = L.map(
#                 &quot;map_097925b7beb89f8bf97bb3c23e5d5cb4&quot;,
#                 {
#                     center: [39.5501, -105.7821],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d778c4a775faf4ee2dc93f3622a7d4e7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d778c4a775faf4ee2dc93f3622a7d4e7.addTo(map_097925b7beb89f8bf97bb3c23e5d5cb4);
#
#
#             var marker_6b417984a469d5083bec6a6c24b7e4e7 = L.marker(
#                 [39.7342327, -105.0143784],
#                 {}
#             ).addTo(map_097925b7beb89f8bf97bb3c23e5d5cb4);
#
#
#             var icon_2f4b517c9871f6255af7e58e838a9b1e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6b417984a469d5083bec6a6c24b7e4e7.setIcon(icon_2f4b517c9871f6255af7e58e838a9b1e);
#
#
#         var popup_7f850f2b54bd2d7560c3d84227ba9c33 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bcbd4000a36c4e048df2c8663862695b = $(`&lt;div id=&quot;html_bcbd4000a36c4e048df2c8663862695b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;1130 YUMA LLC &lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;The Coffee Joint &lt;/strong&gt;&lt;br&gt;     Facility Type: Hospitality Business&lt;br&gt;     1130 Yuma Court &lt;br&gt;     Denver, CO 80204     &lt;/div&gt;`)[0];
#                 popup_7f850f2b54bd2d7560c3d84227ba9c33.setContent(html_bcbd4000a36c4e048df2c8663862695b);
#
#
#
#         marker_6b417984a469d5083bec6a6c24b7e4e7.bindPopup(popup_7f850f2b54bd2d7560c3d84227ba9c33)
#         ;
#
#
#
#
#             var marker_3cd3c381b0b255432041d370d5927644 = L.marker(
#                 [39.6820133, -104.9908875],
#                 {}
#             ).addTo(map_097925b7beb89f8bf97bb3c23e5d5cb4);
#
#
#             var icon_42106d7204a68ffc6ea66eceb8f13b59 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3cd3c381b0b255432041d370d5927644.setIcon(icon_42106d7204a68ffc6ea66eceb8f13b59);
#
#
#         var popup_5373284fdf421627573d8ee17ee1e9d8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f6d4efe293641d18f1a05cdee6203373 = $(`&lt;div id=&quot;html_f6d4efe293641d18f1a05cdee6203373&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;CCT DEN HLD LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Puff, Pass And Paint&lt;/strong&gt;&lt;br&gt;     Facility Type: Hospitality Business&lt;br&gt;     1904 South Cherokee Street&lt;br&gt;     Denver, CO 80223     &lt;/div&gt;`)[0];
#                 popup_5373284fdf421627573d8ee17ee1e9d8.setContent(html_f6d4efe293641d18f1a05cdee6203373);
#
#
#
#         marker_3cd3c381b0b255432041d370d5927644.bindPopup(popup_5373284fdf421627573d8ee17ee1e9d8)
#         ;
#
#
#
#
#             var marker_e65c5d1ef1a75fe5dc396b11bbfeea05 = L.marker(
#                 [39.6820133, -104.9908875],
#                 {}
#             ).addTo(map_097925b7beb89f8bf97bb3c23e5d5cb4);
#
#
#             var icon_58a07e71281d11e066e61ddf8ed9dfbc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e65c5d1ef1a75fe5dc396b11bbfeea05.setIcon(icon_58a07e71281d11e066e61ddf8ed9dfbc);
#
#
#         var popup_7d65a28c41ff92bed4bf6f1fe9522fca = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8582403fc66cd06fbc994a7d1dd30c4c = $(`&lt;div id=&quot;html_8582403fc66cd06fbc994a7d1dd30c4c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;CCT HOLDINGS LIMOS LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Colorado Cannabis Tours&lt;/strong&gt;&lt;br&gt;     Facility Type: Hospitality Business&lt;br&gt;     1904 South Cherokee Street&lt;br&gt;     Denver, CO 80223     &lt;/div&gt;`)[0];

# %%
# Example: Search for hospitality in a specific city
city_search = "Arvada"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[39.8028, -105.0875], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Facility Name']}</strong><br>
    <strong>{row['DBA']}</strong><br>
    Facility Type: {row['Facility Type']}<br>
    {row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip Code']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_hospitality_map_arvada.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_46272b7b081f48e7e56e2cb09591c554 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_46272b7b081f48e7e56e2cb09591c554&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_46272b7b081f48e7e56e2cb09591c554 = L.map(
#                 &quot;map_46272b7b081f48e7e56e2cb09591c554&quot;,
#                 {
#                     center: [39.8028, -105.0875],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4ba7d0336ac4cbb7d25d45bdc7687d0d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_4ba7d0336ac4cbb7d25d45bdc7687d0d.addTo(map_46272b7b081f48e7e56e2cb09591c554);
#
#
#             var marker_62e7e136abaa2d49584bdebf69b2bbdb = L.marker(
#                 [39.8492523, -105.0720784],
#                 {}
#             ).addTo(map_46272b7b081f48e7e56e2cb09591c554);
#
#
#             var icon_172b19dd54446cb8adc8a4d683d70852 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_62e7e136abaa2d49584bdebf69b2bbdb.setIcon(icon_172b19dd54446cb8adc8a4d683d70852);
#
#
#         var popup_4c984b6a3dc1f936b9a356a5e139a68c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d909707d2e2575037e3f17c04ccad30b = $(`&lt;div id=&quot;html_d909707d2e2575037e3f17c04ccad30b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;HASH CAB LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;nan&lt;/strong&gt;&lt;br&gt;     Facility Type: Hospitality Business&lt;br&gt;     6735 West 84th Circle Unit 72&lt;br&gt;     Arvada, CO 80003     &lt;/div&gt;`)[0];
#                 popup_4c984b6a3dc1f936b9a356a5e139a68c.setContent(html_d909707d2e2575037e3f17c04ccad30b);
#
#
#
#         marker_62e7e136abaa2d49584bdebf69b2bbdb.bindPopup(popup_4c984b6a3dc1f936b9a356a5e139a68c)
#         ;
#
#
#
#
#             tile_layer_4ba7d0336ac4cbb7d25d45bdc7687d0d.addTo(map_46272b7b081f48e7e56e2cb09591c554);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Step 5: Export Cleaned Data to CSV

# %%
# Export the cleaned DataFrame to a CSV file
df.to_csv("cleaned_colorado_hospitality_full_list_v2.csv", index=False)

# Confirm the export
print("Data exported to colorado_hospitality_full_list_v2.csv")
# Out:
# Data exported to colorado_hospitality_full_list_v2.csv
