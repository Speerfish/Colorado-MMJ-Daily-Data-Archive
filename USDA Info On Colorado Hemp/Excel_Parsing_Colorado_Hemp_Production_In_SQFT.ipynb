# %% [markdown]
# # Jupyter Notebook: Parsing Excel file and Visualizing Data

# %% [markdown]
# In this notebook, we will load a Excel file, convert it to a pandas DataFrame, and then create visualizations using matplotlib.

# %%
pip install pandas matplotlib openpyxl
# Out:
# ...
#
# [notice] A new release of pip available: 22.3.1 -> 24.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Step 1: Load Excel File

# %%
# Load the Excel file into a Pandas DataFrame
file_path = 'Hemp_Production_In_SQFT.xlsx'

# Read the file into a dataframe
df = pd.read_excel(file_path, usecols=['Year', 'Data Item', 'Value'])

# Display the first few rows of the dataframe to check the data
df.head(15)
# Out:
#    Year                                          Data Item    Value
# 0  2023  HEMP, INDUSTRIAL, UNDER PROTECTION - SQ FT IN ...    31222
# 1  2022  HEMP, INDUSTRIAL, UNDER PROTECTION - SQ FT IN ...   148027
# 2  2021  HEMP, INDUSTRIAL, UNDER PROTECTION - SQ FT IN ...  1992395

# %% [markdown]
# ## Step 2: Clean and Prepare the Data

# %%
# Check for missing values
print(df.isnull().sum())

# Drop rows with missing values (if needed)
df.dropna(inplace=True)

# Ensure the 'Year' column is an integer and 'Value' is a float
df['Year'] = df['Year'].astype(int)
df['Value'] = df['Value'].astype(float)

# Display the cleaned data
df.head(15)
# Out:
# Year         0
# Data Item    0
# Value        0
# dtype: int64
#    Year                                          Data Item      Value
# 0  2023  HEMP, INDUSTRIAL, UNDER PROTECTION - SQ FT IN ...    31222.0
# 1  2022  HEMP, INDUSTRIAL, UNDER PROTECTION - SQ FT IN ...   148027.0
# 2  2021  HEMP, INDUSTRIAL, UNDER PROTECTION - SQ FT IN ...  1992395.0

# %% [markdown]
# ## Step 3: Plot Bar Graphs by Year

# %%
# Get the unique years
years = df['Year'].unique()

# Loop through each year and create individual bar graphs
for year in years:
    # Filter data for the current year
    year_data = df[df['Year'] == year]
    
    # Create a new figure for each year
    plt.figure(figsize=(12, 8))
    
    # Plot the bar graph for the current year
    plt.bar(year_data['Data Item'], year_data['Value'], color='green')
    
    # Add labels and title for the current year's plot
    plt.xlabel('Data Item')
    plt.ylabel('SQFT (Value)')
    plt.title(f'Hemp Production In SQFT in {year}')
    
    # Rotate the x-axis labels for better readability
    plt.xticks(rotation=45, ha='right')
    
    # Show the plot
    plt.tight_layout()
    plt.show()

plt.savefig('hemp_production_in_sqft.png', dpi=300)
