# %% [markdown]
# # Jupyter Notebook: Parsing CSV file and Visualizing Data

# %% [markdown]
# In this notebook, we will load a CSV file, convert it to a pandas DataFrame, and then create a map visualizations using folium.

# %%
pip install pandas folium
# Out:
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (2.2.3)
# Requirement already satisfied: folium in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (0.17.0)
# Requirement already satisfied: numpy>=1.23.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/ceraven/Library/Python/3.11/lib/python/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas) (2024.2)
# Requirement already satisfied: branca>=0.6.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from folium) (0.8.0)
# Requirement already satisfied: jinja2>=2.9 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from folium) (3.1.4)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from folium) (2024.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jinja2>=2.9->folium) (2.1.5)
# Requirement already satisfied: six>=1.5 in /Users/ceraven/Library/Python/3.11/lib/python/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->folium) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->folium) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->folium) (2024.8.30)
#
# [notice] A new release of pip available: 22.3.1 -> 24.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import necessary libraries
import pandas as pd
import folium

# %% [markdown]
# ## Step 1: Load CSV File

# %%
# Load the CSV file into a DataFrame
file_path = "colorado_product_manufacturers_full_list.csv"

df = pd.read_csv(file_path)

# Optional: Display the first few rows to check if the file is loaded correctly
df.head(15)
# Out:
#    License Number              Facility Name                            DBA  \
# 0       404-00341          2306 N POWERS LLC                       Hightops
# 1       404-00538                  81082 LLC  Colorado Cannabis Exchange II
# 2       404-00650             ACES PLACE LLC     Green Rooster Concentrates
# 3       404-00510   ADAMS GREEN CROSSING LLC                            NaN
# 4       404-00498                     AF INC            Apothecary Extracts
# 5       404-00629                     AF INC            Apothecary Extracts
# 6       404-00493              ALLGREENS LLC                            NaN
# 7       404-00472      AVICENNA PRODUCTS LLC         High Tech Concentrates
# 8       404-00454      AVICENNA PRODUCTS LLC         High Tech Concentrates
# 9       404-00621      AVICENNA PRODUCTS LLC         High Tech Concentrates
# 10      404-00501         BD EXTRACTIONS LLC                      Dabs Labs
# 11      404-00155        BEYOND BROADWAY LLC                      Infusiasm
# 12      404-00824  BIG MOUNTAIN ORGANICS LLC                        Floraco
# 13      404-00423                BIG TOP LLC                            NaN
# 14      404-00555            BK HOLDINGS LLC              The Herbal Center
#
#                      Facility Type  \
# 0   Medical Marijuana Products Mfg
# 1   Medical Marijuana Products Mfg
# 2   Medical Marijuana Products Mfg
# 3   Medical Marijuana Products Mfg
# 4   Medical Marijuana Products Mfg
# 5   Medical Marijuana Products Mfg
# 6   Medical Marijuana Products Mfg
# 7   Medical Marijuana Products Mfg
# 8   Medical Marijuana Products Mfg
# 9   Medical Marijuana Products Mfg
# 10  Medical Marijuana Products Mfg
# 11  Medical Marijuana Products Mfg
# 12  Medical Marijuana Products Mfg
# 13  Medical Marijuana Products Mfg
# 14  Medical Marijuana Products Mfg
#
#                                         Street              City State  \
# 0   2306 North Powers Frontage Road, Suite 100  Colorado Springs    CO
# 1                              123 Pine Street          Trinidad    CO
# 2                         14621 County Road 98              Nunn    CO
# 3          2727 Palmer Park Boulevard, Suite A  Colorado Springs    CO
# 4                             3049 Delta Drive  Colorado Springs    CO
# 5                           65 Precision Drive       Pueblo West    CO
# 6                      1235 South Huron Street            Denver    CO
# 7                      3950 North Grape Street            Denver    CO
# 8                    1822 South Bannock Street            Denver    CO
# 9      35715 US Highway 40 Building D Unit 106         Evergreen    CO
# 10                128 Maine Street, Building A  Log Lane Village    CO
# 11           5141 North National Western Drive            Denver    CO
# 12                   2901 North El Paso Street  Colorado Springs    CO
# 13                     1952 South Acoma Street            Denver    CO
# 14                      12001 East 37th Avenue            Denver    CO
#
#     Zip Code Date Updated   Latitude   Longitude
# 0      80915   2024-09-03  38.863467 -104.720079
# 1      81082   2024-09-03  37.173006 -104.509181
# 2      80648   2024-09-03  40.696002 -104.775428
# 3      80909   2024-09-03  38.853439 -104.777734
# 4      80910   2024-09-03  38.795160 -104.776840
# 5      81007   2024-09-03  38.335082 -104.727394
# 6      80223   2024-09-03  39.694207 -104.996932
# 7      80207   2024-09-03  39.772075 -104.924540
# 8      80223   2024-09-03  39.683521 -104.989639
# 9      80439   2024-09-03  39.741408 -105.431886
# 10     80705   2024-09-03  40.269166 -103.832020
# 11     80216   2024-09-03  39.788098 -104.968789
# 12     80907   2024-09-03  38.872356 -104.812599
# 13     80223   2024-09-03  39.680866 -104.988579
# 14     80239   2024-09-03  39.768162 -104.848436

# %% [markdown]
# ## Step 2: Clean and Prepare the Data

# %%
# Check column names and data types
df.info()

# Clean any missing latitude or longitude data
df.dropna(subset=['Longitude', 'Latitude'], inplace=True)

# Optional: Check for missing values in other important columns
df.isnull().sum()

# Optional: Display the first few rows of cleaned data
df.head(15)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 431 entries, 0 to 430
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   License Number  431 non-null    object
#  1   Facility Name   431 non-null    object
#  2   DBA             306 non-null    object
#  3   Facility Type   431 non-null    object
#  4   Street          431 non-null    object
#  5   City            431 non-null    object
#  6   State           431 non-null    object
#  7   Zip Code        431 non-null    int64
#  8   Date Updated    431 non-null    object
#  9   Latitude        431 non-null    float64
#  10  Longitude       431 non-null    float64
# dtypes: float64(2), int64(1), object(8)
# memory usage: 37.2+ KB
#    License Number              Facility Name                            DBA  \
# 0       404-00341          2306 N POWERS LLC                       Hightops
# 1       404-00538                  81082 LLC  Colorado Cannabis Exchange II
# 2       404-00650             ACES PLACE LLC     Green Rooster Concentrates
# 3       404-00510   ADAMS GREEN CROSSING LLC                            NaN
# 4       404-00498                     AF INC            Apothecary Extracts
# 5       404-00629                     AF INC            Apothecary Extracts
# 6       404-00493              ALLGREENS LLC                            NaN
# 7       404-00472      AVICENNA PRODUCTS LLC         High Tech Concentrates
# 8       404-00454      AVICENNA PRODUCTS LLC         High Tech Concentrates
# 9       404-00621      AVICENNA PRODUCTS LLC         High Tech Concentrates
# 10      404-00501         BD EXTRACTIONS LLC                      Dabs Labs
# 11      404-00155        BEYOND BROADWAY LLC                      Infusiasm
# 12      404-00824  BIG MOUNTAIN ORGANICS LLC                        Floraco
# 13      404-00423                BIG TOP LLC                            NaN
# 14      404-00555            BK HOLDINGS LLC              The Herbal Center
#
#                      Facility Type  \
# 0   Medical Marijuana Products Mfg
# 1   Medical Marijuana Products Mfg
# 2   Medical Marijuana Products Mfg
# 3   Medical Marijuana Products Mfg
# 4   Medical Marijuana Products Mfg
# 5   Medical Marijuana Products Mfg
# 6   Medical Marijuana Products Mfg
# 7   Medical Marijuana Products Mfg
# 8   Medical Marijuana Products Mfg
# 9   Medical Marijuana Products Mfg
# 10  Medical Marijuana Products Mfg
# 11  Medical Marijuana Products Mfg
# 12  Medical Marijuana Products Mfg
# 13  Medical Marijuana Products Mfg
# 14  Medical Marijuana Products Mfg
#
#                                         Street              City State  \
# 0   2306 North Powers Frontage Road, Suite 100  Colorado Springs    CO
# 1                              123 Pine Street          Trinidad    CO
# 2                         14621 County Road 98              Nunn    CO
# 3          2727 Palmer Park Boulevard, Suite A  Colorado Springs    CO
# 4                             3049 Delta Drive  Colorado Springs    CO
# 5                           65 Precision Drive       Pueblo West    CO
# 6                      1235 South Huron Street            Denver    CO
# 7                      3950 North Grape Street            Denver    CO
# 8                    1822 South Bannock Street            Denver    CO
# 9      35715 US Highway 40 Building D Unit 106         Evergreen    CO
# 10                128 Maine Street, Building A  Log Lane Village    CO
# 11           5141 North National Western Drive            Denver    CO
# 12                   2901 North El Paso Street  Colorado Springs    CO
# 13                     1952 South Acoma Street            Denver    CO
# 14                      12001 East 37th Avenue            Denver    CO
#
#     Zip Code Date Updated   Latitude   Longitude
# 0      80915   2024-09-03  38.863467 -104.720079
# 1      81082   2024-09-03  37.173006 -104.509181
# 2      80648   2024-09-03  40.696002 -104.775428
# 3      80909   2024-09-03  38.853439 -104.777734
# 4      80910   2024-09-03  38.795160 -104.776840
# 5      81007   2024-09-03  38.335082 -104.727394
# 6      80223   2024-09-03  39.694207 -104.996932
# 7      80207   2024-09-03  39.772075 -104.924540
# 8      80223   2024-09-03  39.683521 -104.989639
# 9      80439   2024-09-03  39.741408 -105.431886
# 10     80705   2024-09-03  40.269166 -103.832020
# 11     80216   2024-09-03  39.788098 -104.968789
# 12     80907   2024-09-03  38.872356 -104.812599
# 13     80223   2024-09-03  39.680866 -104.988579
# 14     80239   2024-09-03  39.768162 -104.848436

# %% [markdown]
# ## Step 3: Create a Searchable Map

# %%
# Initialize the map centered around Colorado
m = folium.Map(location=[39.5501, -105.7821], zoom_start=7)

# Add markers to the map for each food pantry
for idx, row in df.iterrows():
    popup_text = f"""
    <strong>{row['Facility Name']}</strong><br>
    <strong>{row['DBA']}</strong><br>
    Facility Type: {row['Facility Type']}<br>
    {row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip Code']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m)

# Save the map as an HTML file
m.save("colorado_product_manufacturers_full_list_map.html")

# Display the map in the notebook
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_57f287908814afb8f4fcbcd04b0f1b11 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_57f287908814afb8f4fcbcd04b0f1b11&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_57f287908814afb8f4fcbcd04b0f1b11 = L.map(
#                 &quot;map_57f287908814afb8f4fcbcd04b0f1b11&quot;,
#                 {
#                     center: [39.5501, -105.7821],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_565fd704a2ad8cf9f73f45a5919a7b40 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_565fd704a2ad8cf9f73f45a5919a7b40.addTo(map_57f287908814afb8f4fcbcd04b0f1b11);
#
#
#             var marker_db07ee1d37da42660a6c7a802d9c75b1 = L.marker(
#                 [38.863467, -104.720079],
#                 {}
#             ).addTo(map_57f287908814afb8f4fcbcd04b0f1b11);
#
#
#             var icon_79cec15ea9b7d1c00b6b8608ec18432f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_db07ee1d37da42660a6c7a802d9c75b1.setIcon(icon_79cec15ea9b7d1c00b6b8608ec18432f);
#
#
#         var popup_a585d77eff62fe22a0e842ed19b72571 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_17cc0c47b28722b715c51509028ccb8f = $(`&lt;div id=&quot;html_17cc0c47b28722b715c51509028ccb8f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;2306 N POWERS LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Hightops&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Products Mfg&lt;br&gt;     2306 North Powers Frontage Road, Suite 100&lt;br&gt;     Colorado Springs, CO 80915     &lt;/div&gt;`)[0];
#                 popup_a585d77eff62fe22a0e842ed19b72571.setContent(html_17cc0c47b28722b715c51509028ccb8f);
#
#
#
#         marker_db07ee1d37da42660a6c7a802d9c75b1.bindPopup(popup_a585d77eff62fe22a0e842ed19b72571)
#         ;
#
#
#
#
#             var marker_e88712629f4a696fb5e514bd2fccc13d = L.marker(
#                 [37.1730063, -104.509181],
#                 {}
#             ).addTo(map_57f287908814afb8f4fcbcd04b0f1b11);
#
#
#             var icon_eeda4b476640acfbb89689e42f386405 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e88712629f4a696fb5e514bd2fccc13d.setIcon(icon_eeda4b476640acfbb89689e42f386405);
#
#
#         var popup_a3e76ce10275928a18e6b15f8fcd485f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7d197f3b7096240b0d9796c2066b78d6 = $(`&lt;div id=&quot;html_7d197f3b7096240b0d9796c2066b78d6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;81082 LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Colorado Cannabis Exchange II&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Products Mfg&lt;br&gt;     123 Pine Street&lt;br&gt;     Trinidad, CO 81082     &lt;/div&gt;`)[0];
#                 popup_a3e76ce10275928a18e6b15f8fcd485f.setContent(html_7d197f3b7096240b0d9796c2066b78d6);
#
#
#
#         marker_e88712629f4a696fb5e514bd2fccc13d.bindPopup(popup_a3e76ce10275928a18e6b15f8fcd485f)
#         ;
#
#
#
#
#             var marker_d5b5171ea3dbf323c6a52accbdb213e5 = L.marker(
#                 [40.6960022, -104.775428],
#                 {}
#             ).addTo(map_57f287908814afb8f4fcbcd04b0f1b11);
#
#
#             var icon_d71384cd6d79b824111097ee371bdf29 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d5b5171ea3dbf323c6a52accbdb213e5.setIcon(icon_d71384cd6d79b824111097ee371bdf29);
#
#
#         var popup_33fe5e3030a4db9597cdd9ef86a7ed6f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_addf07ced8fc789fe6682c83f52a1875 = $(`&lt;div id=&quot;html_addf07ced8fc789fe6682c83f52a1875&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;ACES PLACE LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Green Rooster Concentrates&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Products Mfg&lt;br&gt;     14621 County Road 98&lt;br&gt;     Nunn, CO 80648

# %% [markdown]
# ## Step 4: Implement Search Functionality

# %%
# Example: Search for product manufacturers in a specific city
city_search = "Denver"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[39.5501, -105.7821], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Facility Name']}</strong><br>
    <strong>{row['DBA']}</strong><br>
    Facility Type: {row['Facility Type']}<br>
    {row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip Code']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_product_manufacturers_map_denver.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_95403fb546bbd8a4110d1912648ae16e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_95403fb546bbd8a4110d1912648ae16e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_95403fb546bbd8a4110d1912648ae16e = L.map(
#                 &quot;map_95403fb546bbd8a4110d1912648ae16e&quot;,
#                 {
#                     center: [39.5501, -105.7821],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ca18366f5df52abd5ca2f1eab6952521 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_ca18366f5df52abd5ca2f1eab6952521.addTo(map_95403fb546bbd8a4110d1912648ae16e);
#
#
#             var marker_a23b91fa46c8eeedcc367e365043c213 = L.marker(
#                 [39.6942073, -104.9969316],
#                 {}
#             ).addTo(map_95403fb546bbd8a4110d1912648ae16e);
#
#
#             var icon_deadee12f2201e15e6861c266eb5157a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a23b91fa46c8eeedcc367e365043c213.setIcon(icon_deadee12f2201e15e6861c266eb5157a);
#
#
#         var popup_6e2e641962beb783bdc421f78aa3c2fb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_46b00e828c074096cdb515697451bfdc = $(`&lt;div id=&quot;html_46b00e828c074096cdb515697451bfdc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;ALLGREENS LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;nan&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Products Mfg&lt;br&gt;     1235 South Huron Street&lt;br&gt;     Denver, CO 80223     &lt;/div&gt;`)[0];
#                 popup_6e2e641962beb783bdc421f78aa3c2fb.setContent(html_46b00e828c074096cdb515697451bfdc);
#
#
#
#         marker_a23b91fa46c8eeedcc367e365043c213.bindPopup(popup_6e2e641962beb783bdc421f78aa3c2fb)
#         ;
#
#
#
#
#             var marker_7bc0ac0cb14cd7e5f7645af0ad648437 = L.marker(
#                 [39.772075, -104.92454],
#                 {}
#             ).addTo(map_95403fb546bbd8a4110d1912648ae16e);
#
#
#             var icon_847342e0240d3cf73c518d823714275c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7bc0ac0cb14cd7e5f7645af0ad648437.setIcon(icon_847342e0240d3cf73c518d823714275c);
#
#
#         var popup_3259a89946dde5c3b2f74eadd221e0fd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_58966b38fb0055def16952d6c6dbc0da = $(`&lt;div id=&quot;html_58966b38fb0055def16952d6c6dbc0da&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;AVICENNA PRODUCTS LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;High Tech Concentrates&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Products Mfg&lt;br&gt;     3950 North Grape Street&lt;br&gt;     Denver, CO 80207     &lt;/div&gt;`)[0];
#                 popup_3259a89946dde5c3b2f74eadd221e0fd.setContent(html_58966b38fb0055def16952d6c6dbc0da);
#
#
#
#         marker_7bc0ac0cb14cd7e5f7645af0ad648437.bindPopup(popup_3259a89946dde5c3b2f74eadd221e0fd)
#         ;
#
#
#
#
#             var marker_130fe9887ca845a0008689a40f9989f9 = L.marker(
#                 [39.6835214, -104.9896395],
#                 {}
#             ).addTo(map_95403fb546bbd8a4110d1912648ae16e);
#
#
#             var icon_2710abf2670e46e7cf971d8d76532af4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_130fe9887ca845a0008689a40f9989f9.setIcon(icon_2710abf2670e46e7cf971d8d76532af4);
#
#
#         var popup_8a98f8711741488b351ebf1693b5d517 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f69378f963fbf90990dd396e6f3e4a4e = $(`&lt;div id=&quot;html_f69378f963fbf90990dd396e6f3e4a4e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;AVICENNA PRODUCTS LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;High Tech Concentrates&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Products Mfg&lt;br&gt;     1822 South Bannock Street&lt;br&gt;     Denver, CO 80223     &lt;/div&gt;

# %%
# Example: Search for product manufacturers in a specific city
city_search = "Colorado Springs"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[38.8591, -104.8135], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Facility Name']}</strong><br>
    <strong>{row['DBA']}</strong><br>
    Facility Type: {row['Facility Type']}<br>
    {row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip Code']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_product_manufacturers_map_colorado_springs.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4de8f368c4d3801bd81a611b7ce3daaa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4de8f368c4d3801bd81a611b7ce3daaa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4de8f368c4d3801bd81a611b7ce3daaa = L.map(
#                 &quot;map_4de8f368c4d3801bd81a611b7ce3daaa&quot;,
#                 {
#                     center: [38.8591, -104.8135],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d8915221146a8329674c9e8d8a539403 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d8915221146a8329674c9e8d8a539403.addTo(map_4de8f368c4d3801bd81a611b7ce3daaa);
#
#
#             var marker_3a2d2cfa626560e32ac3895de7f34c25 = L.marker(
#                 [38.863467, -104.720079],
#                 {}
#             ).addTo(map_4de8f368c4d3801bd81a611b7ce3daaa);
#
#
#             var icon_4272baedf459930da5d84e274a7ab30d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3a2d2cfa626560e32ac3895de7f34c25.setIcon(icon_4272baedf459930da5d84e274a7ab30d);
#
#
#         var popup_bc45cbd784bcacfa011f45f59e4ea1c6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8ecb32bd4ecf191c969e30524a067495 = $(`&lt;div id=&quot;html_8ecb32bd4ecf191c969e30524a067495&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;2306 N POWERS LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Hightops&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Products Mfg&lt;br&gt;     2306 North Powers Frontage Road, Suite 100&lt;br&gt;     Colorado Springs, CO 80915     &lt;/div&gt;`)[0];
#                 popup_bc45cbd784bcacfa011f45f59e4ea1c6.setContent(html_8ecb32bd4ecf191c969e30524a067495);
#
#
#
#         marker_3a2d2cfa626560e32ac3895de7f34c25.bindPopup(popup_bc45cbd784bcacfa011f45f59e4ea1c6)
#         ;
#
#
#
#
#             var marker_8e1a26f76d47e39bfd5656359afbb093 = L.marker(
#                 [38.8534388, -104.7777338],
#                 {}
#             ).addTo(map_4de8f368c4d3801bd81a611b7ce3daaa);
#
#
#             var icon_c7b1a9720582000ddf10562cad779f99 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8e1a26f76d47e39bfd5656359afbb093.setIcon(icon_c7b1a9720582000ddf10562cad779f99);
#
#
#         var popup_8303fac28adc63bf559b3c023a698fa2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2f4ee95c29a73da34c70ae4a2d9a926a = $(`&lt;div id=&quot;html_2f4ee95c29a73da34c70ae4a2d9a926a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;ADAMS GREEN CROSSING LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;nan&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Products Mfg&lt;br&gt;     2727 Palmer Park Boulevard, Suite A&lt;br&gt;     Colorado Springs, CO 80909     &lt;/div&gt;`)[0];
#                 popup_8303fac28adc63bf559b3c023a698fa2.setContent(html_2f4ee95c29a73da34c70ae4a2d9a926a);
#
#
#
#         marker_8e1a26f76d47e39bfd5656359afbb093.bindPopup(popup_8303fac28adc63bf559b3c023a698fa2)
#         ;
#
#
#
#
#             var marker_cbb2f6e45427533338525a53d6cce78d = L.marker(
#                 [38.7951601, -104.77684],
#                 {}
#             ).addTo(map_4de8f368c4d3801bd81a611b7ce3daaa);
#
#
#             var icon_d80255e184cce1efb583c28e964209a0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_cbb2f6e45427533338525a53d6cce78d.setIcon(icon_d80255e184cce1efb583c28e964209a0);
#
#
#         var popup_fcc46c2449d750ce6256ee122591c8f9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_883b211816c74930f41f8a2d69282a7e = $(`&lt;div id=&quot;html_883b211816c74930f41f8a2d69282a7e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;AF INC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Apothecary Extracts&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Products Mfg&lt;br&gt;     3049 Delta Drive&lt;br&gt;     Colorado Springs,

# %%
# Example: Search for product manufacturers in a specific city
city_search = "Aurora"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[39.7108, -104.8125], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Facility Name']}</strong><br>
    <strong>{row['DBA']}</strong><br>
    Facility Type: {row['Facility Type']}<br>
    {row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip Code']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_product_manufacturers_map_aurora.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7c62a76068c7e484dc7043eaa22038e7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7c62a76068c7e484dc7043eaa22038e7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7c62a76068c7e484dc7043eaa22038e7 = L.map(
#                 &quot;map_7c62a76068c7e484dc7043eaa22038e7&quot;,
#                 {
#                     center: [39.7108, -104.8125],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_88fcf25579c50fd088b1f7506a0c876f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_88fcf25579c50fd088b1f7506a0c876f.addTo(map_7c62a76068c7e484dc7043eaa22038e7);
#
#
#             var marker_8cebfd68efe48608c1af67288c1b9294 = L.marker(
#                 [39.7684311, -104.8147025],
#                 {}
#             ).addTo(map_7c62a76068c7e484dc7043eaa22038e7);
#
#
#             var icon_f888215be91560844a3e5665a7168926 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8cebfd68efe48608c1af67288c1b9294.setIcon(icon_f888215be91560844a3e5665a7168926);
#
#
#         var popup_f067d625dbed1fcf8c7db89df86edc4c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_236cc75f419ad5ab7ee5cdc321512379 = $(`&lt;div id=&quot;html_236cc75f419ad5ab7ee5cdc321512379&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;BUD FOX ENTERPRISES LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Bud Fox Enterprises&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Products Mfg&lt;br&gt;     14896 East 38th Avenue&lt;br&gt;     Aurora, CO 80011     &lt;/div&gt;`)[0];
#                 popup_f067d625dbed1fcf8c7db89df86edc4c.setContent(html_236cc75f419ad5ab7ee5cdc321512379);
#
#
#
#         marker_8cebfd68efe48608c1af67288c1b9294.bindPopup(popup_f067d625dbed1fcf8c7db89df86edc4c)
#         ;
#
#
#
#
#             var marker_48b29e4fec09233f89a1fc72d1c21112 = L.marker(
#                 [39.7632007, -104.8495745],
#                 {}
#             ).addTo(map_7c62a76068c7e484dc7043eaa22038e7);
#
#
#             var icon_5550715840df31bad5f74dda0787c283 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_48b29e4fec09233f89a1fc72d1c21112.setIcon(icon_5550715840df31bad5f74dda0787c283);
#
#
#         var popup_1787517d432f6d55249d24cf47e72f10 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_245107c3c4a29aac65e3b93d7d849eab = $(`&lt;div id=&quot;html_245107c3c4a29aac65e3b93d7d849eab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;CANNA CLUB LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Best Buds&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Products Mfg&lt;br&gt;     11900 East 33rd Avenue, Suite 2&lt;br&gt;     Aurora, CO 80010     &lt;/div&gt;`)[0];
#                 popup_1787517d432f6d55249d24cf47e72f10.setContent(html_245107c3c4a29aac65e3b93d7d849eab);
#
#
#
#         marker_48b29e4fec09233f89a1fc72d1c21112.bindPopup(popup_1787517d432f6d55249d24cf47e72f10)
#         ;
#
#
#
#
#             var marker_34d74a4dc2def8102367e9ae289d83da = L.marker(
#                 [39.7039672, -104.7828795],
#                 {}
#             ).addTo(map_7c62a76068c7e484dc7043eaa22038e7);
#
#
#             var icon_1fafbbc9eaa00169392a7a7d3164b666 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_34d74a4dc2def8102367e9ae289d83da.setIcon(icon_1fafbbc9eaa00169392a7a7d3164b666);
#
#
#         var popup_548a1eb05166825baa1db70fa5e60752 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6770e90fa148fb9e19e11724a2c701c3 = $(`&lt;div id=&quot;html_6770e90fa148fb9e19e11724a2c701c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;DUTCH BOTANICALS LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;nan&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Products Mfg&lt;br&gt;     17600 East Exposition Drive, Unit C-2&lt;br&gt;     Aurora, CO 80017     &lt;

# %%
# Example: Search for product manufacturers in a specific city
city_search = "Fort Collins"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[40.5853, -105.0844], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Facility Name']}</strong><br>
    <strong>{row['DBA']}</strong><br>
    Facility Type: {row['Facility Type']}<br>
    {row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip Code']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_product_manufacturers_map_fort_collins.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e5a500d8ef3f2a41d4049294abe25168 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e5a500d8ef3f2a41d4049294abe25168&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e5a500d8ef3f2a41d4049294abe25168 = L.map(
#                 &quot;map_e5a500d8ef3f2a41d4049294abe25168&quot;,
#                 {
#                     center: [40.5853, -105.0844],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f73dc7db71939827ac022ff3cf689ab9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f73dc7db71939827ac022ff3cf689ab9.addTo(map_e5a500d8ef3f2a41d4049294abe25168);
#
#
#             var marker_99f75fe3ac2c83a9b833ed62f17f23ec = L.marker(
#                 [40.6032491, -105.0719132],
#                 {}
#             ).addTo(map_e5a500d8ef3f2a41d4049294abe25168);
#
#
#             var icon_5873df1f5b9270bd43a0b2bbbcca183a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_99f75fe3ac2c83a9b833ed62f17f23ec.setIcon(icon_5873df1f5b9270bd43a0b2bbbcca183a);
#
#
#         var popup_1eccb43f9ac52e6a47e43ac85b42d698 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d7121eb82afc5411c13f7dc3b6306ecb = $(`&lt;div id=&quot;html_d7121eb82afc5411c13f7dc3b6306ecb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;CIELO VERDE LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Outer Other &lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Products Mfg&lt;br&gt;     1225 Blue Spruce Drive Unit P&lt;br&gt;     Fort Collins, CO 80524     &lt;/div&gt;`)[0];
#                 popup_1eccb43f9ac52e6a47e43ac85b42d698.setContent(html_d7121eb82afc5411c13f7dc3b6306ecb);
#
#
#
#         marker_99f75fe3ac2c83a9b833ed62f17f23ec.bindPopup(popup_1eccb43f9ac52e6a47e43ac85b42d698)
#         ;
#
#
#
#
#             var marker_9c807e5075c41746731138a61329d639 = L.marker(
#                 [40.5080946, -105.0772071],
#                 {}
#             ).addTo(map_e5a500d8ef3f2a41d4049294abe25168);
#
#
#             var icon_4227812510f983193f26d10826b8d999 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9c807e5075c41746731138a61329d639.setIcon(icon_4227812510f983193f26d10826b8d999);
#
#
#         var popup_2a32674324e8f5c6d6e431f8616e45e3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c33ad2f92de982cf533e7e956fe81eff = $(`&lt;div id=&quot;html_c33ad2f92de982cf533e7e956fe81eff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;PO TECH-CO LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;nan&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Products Mfg&lt;br&gt;     5724 South College Avenue&lt;br&gt;     Fort Collins, CO 80525     &lt;/div&gt;`)[0];
#                 popup_2a32674324e8f5c6d6e431f8616e45e3.setContent(html_c33ad2f92de982cf533e7e956fe81eff);
#
#
#
#         marker_9c807e5075c41746731138a61329d639.bindPopup(popup_2a32674324e8f5c6d6e431f8616e45e3)
#         ;
#
#
#
#
#             var marker_44aff1343928ca95c101bed97b642dca = L.marker(
#                 [40.6032491, -105.0719132],
#                 {}
#             ).addTo(map_e5a500d8ef3f2a41d4049294abe25168);
#
#
#             var icon_d9ac82488f3ac74fb0ca8651883615fa = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_44aff1343928ca95c101bed97b642dca.setIcon(icon_d9ac82488f3ac74fb0ca8651883615fa);
#
#
#         var popup_184b812131580adf4a1539be43a1b61a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_53763d300c63c13c081e8b531fe6e2ed = $(`&lt;div id=&quot;html_53763d300c63c13c081e8b531fe6e2ed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;CIELO VERDE LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Outer Other&lt;/strong&gt;&lt;br&gt;     Facility Type: Retail Marijuana Products Mfg&lt;br&gt;     1225 Blue Spruce Drive, Unit P&lt;br&gt;     Fort Collins, CO 80524     &lt;/div&gt

# %%
# Example: Search for product manufacturers in a specific city
city_search = "Garden City"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[40.4233, -104.7112], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Facility Name']}</strong><br>
    <strong>{row['DBA']}</strong><br>
    Facility Type: {row['Facility Type']}<br>
    {row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip Code']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_product_manufacturers_map_garden_city.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_992e4a2e8a9f1313a061befff6a57341 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_992e4a2e8a9f1313a061befff6a57341&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_992e4a2e8a9f1313a061befff6a57341 = L.map(
#                 &quot;map_992e4a2e8a9f1313a061befff6a57341&quot;,
#                 {
#                     center: [40.4233, -104.7112],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fd8300e267ab0691ac6c4944b38f9f35 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_fd8300e267ab0691ac6c4944b38f9f35.addTo(map_992e4a2e8a9f1313a061befff6a57341);
#
#
#             var marker_4ab250c3fcd286cdb87514614971eeca = L.marker(
#                 [40.3944806, -104.6866871],
#                 {}
#             ).addTo(map_992e4a2e8a9f1313a061befff6a57341);
#
#
#             var icon_2f8b86ef5dbef80bd10811bf47b2c2de = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4ab250c3fcd286cdb87514614971eeca.setIcon(icon_2f8b86ef5dbef80bd10811bf47b2c2de);
#
#
#         var popup_48549728601a0c48fd74421c3589affd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_52f995f162604fdcde7081721457d2ea = $(`&lt;div id=&quot;html_52f995f162604fdcde7081721457d2ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;NATURES KITCHEN LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;nan&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Products Mfg&lt;br&gt;     540 27th Street&lt;br&gt;     Garden City, CO 80631     &lt;/div&gt;`)[0];
#                 popup_48549728601a0c48fd74421c3589affd.setContent(html_52f995f162604fdcde7081721457d2ea);
#
#
#
#         marker_4ab250c3fcd286cdb87514614971eeca.bindPopup(popup_48549728601a0c48fd74421c3589affd)
#         ;
#
#
#
#
#             var marker_4c74f151d9f749a835d8b60fe7da2fda = L.marker(
#                 [40.3944806, -104.6866871],
#                 {}
#             ).addTo(map_992e4a2e8a9f1313a061befff6a57341);
#
#
#             var icon_93dc70431acc80ac9e0d5cbccd6cabcf = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4c74f151d9f749a835d8b60fe7da2fda.setIcon(icon_93dc70431acc80ac9e0d5cbccd6cabcf);
#
#
#         var popup_a3696635803ac7662e05d6e965b1f2cf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1f31bb28fd6e3db8a89732d3ba6614a7 = $(`&lt;div id=&quot;html_1f31bb28fd6e3db8a89732d3ba6614a7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;NATURES KITCHEN LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;nan&lt;/strong&gt;&lt;br&gt;     Facility Type: Retail Marijuana Products Mfg&lt;br&gt;     540 27th Street&lt;br&gt;     Garden City, CO 80631     &lt;/div&gt;`)[0];
#                 popup_a3696635803ac7662e05d6e965b1f2cf.setContent(html_1f31bb28fd6e3db8a89732d3ba6614a7);
#
#
#
#         marker_4c74f151d9f749a835d8b60fe7da2fda.bindPopup(popup_a3696635803ac7662e05d6e965b1f2cf)
#         ;
#
#
#
#
#             tile_layer_fd8300e267ab0691ac6c4944b38f9f35.addTo(map_992e4a2e8a9f1313a061befff6a57341);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Example: Search for product manufacturers in a specific city
city_search = "Pueblo"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[38.2765, -104.6046], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Facility Name']}</strong><br>
    <strong>{row['DBA']}</strong><br>
    Facility Type: {row['Facility Type']}<br>
    {row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip Code']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_product_manufacturers_map_pueblo.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bfa352da49b35ced4da09bf579def990 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bfa352da49b35ced4da09bf579def990&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bfa352da49b35ced4da09bf579def990 = L.map(
#                 &quot;map_bfa352da49b35ced4da09bf579def990&quot;,
#                 {
#                     center: [38.2765, -104.6046],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1a30cd2f349c8b4955932e80ca9523b8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_1a30cd2f349c8b4955932e80ca9523b8.addTo(map_bfa352da49b35ced4da09bf579def990);
#
#
#             var marker_d32e690df7eec08ef5c7838b5f1420da = L.marker(
#                 [38.335082, -104.727394],
#                 {}
#             ).addTo(map_bfa352da49b35ced4da09bf579def990);
#
#
#             var icon_72a09f59bf4cb41679e1671abbeb08b9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d32e690df7eec08ef5c7838b5f1420da.setIcon(icon_72a09f59bf4cb41679e1671abbeb08b9);
#
#
#         var popup_5b6971059f7b6106bd1c10052e235673 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6c574ccf65c140be4f4db496b40461b2 = $(`&lt;div id=&quot;html_6c574ccf65c140be4f4db496b40461b2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;AF INC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Apothecary Extracts&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Products Mfg&lt;br&gt;     65 Precision Drive&lt;br&gt;     Pueblo West, CO 81007     &lt;/div&gt;`)[0];
#                 popup_5b6971059f7b6106bd1c10052e235673.setContent(html_6c574ccf65c140be4f4db496b40461b2);
#
#
#
#         marker_d32e690df7eec08ef5c7838b5f1420da.bindPopup(popup_5b6971059f7b6106bd1c10052e235673)
#         ;
#
#
#
#
#             var marker_8049489b58322aed51a427a3c542fd7f = L.marker(
#                 [38.320934, -104.704879],
#                 {}
#             ).addTo(map_bfa352da49b35ced4da09bf579def990);
#
#
#             var icon_00eb0e6c29d51bf65d1830f7d5d47ec9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8049489b58322aed51a427a3c542fd7f.setIcon(icon_00eb0e6c29d51bf65d1830f7d5d47ec9);
#
#
#         var popup_5e9d3319da1d6d87c93bd7b55b136803 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5afeab51c9aa6e2d64fd0b470524606c = $(`&lt;div id=&quot;html_5afeab51c9aa6e2d64fd0b470524606c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;COLD BAKED LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Concentrate Distribution Center&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Products Mfg&lt;br&gt;     920 East Spaulding Avenue&lt;br&gt;     Pueblo West, CO 81007     &lt;/div&gt;`)[0];
#                 popup_5e9d3319da1d6d87c93bd7b55b136803.setContent(html_5afeab51c9aa6e2d64fd0b470524606c);
#
#
#
#         marker_8049489b58322aed51a427a3c542fd7f.bindPopup(popup_5e9d3319da1d6d87c93bd7b55b136803)
#         ;
#
#
#
#
#             var marker_8c53f86d21774c0480e1c15a5ed96965 = L.marker(
#                 [38.3260135, -104.705327],
#                 {}
#             ).addTo(map_bfa352da49b35ced4da09bf579def990);
#
#
#             var icon_fc95ff6320efc792ea78e4d77d22891a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8c53f86d21774c0480e1c15a5ed96965.setIcon(icon_fc95ff6320efc792ea78e4d77d22891a);
#
#
#         var popup_97b38461350ba7241caad3f41938df57 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_04c4e4eac8a5cd5c722e864759c8a6f7 = $(`&lt;div id=&quot;html_04c4e4eac8a5cd5c722e864759c8a6f7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;COLORADO DISTRIBUTING INC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Apex Extracts&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Products Mfg&lt;br&gt;     893 East Enterprise Drive&lt;br&gt;     Pueblo West, CO 81007

# %%
# Example: Search for product manufacturers in a specific city
city_search = "Boulder"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[40.0150, -105.2705], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Facility Name']}</strong><br>
    <strong>{row['DBA']}</strong><br>
    Facility Type: {row['Facility Type']}<br>
    {row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip Code']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_product_manufacturers_map_boulder.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d98818e2d63e23d81bfb1d14ed1e634b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d98818e2d63e23d81bfb1d14ed1e634b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d98818e2d63e23d81bfb1d14ed1e634b = L.map(
#                 &quot;map_d98818e2d63e23d81bfb1d14ed1e634b&quot;,
#                 {
#                     center: [40.015, -105.2705],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_37615898f0a54ee6d0cb66abf7d93412 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_37615898f0a54ee6d0cb66abf7d93412.addTo(map_d98818e2d63e23d81bfb1d14ed1e634b);
#
#
#             var marker_f49cb69cb5b5b1e6d67f5ad79890650e = L.marker(
#                 [40.014776, -105.223357],
#                 {}
#             ).addTo(map_d98818e2d63e23d81bfb1d14ed1e634b);
#
#
#             var icon_282568322905d8e776d96c7d93689263 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f49cb69cb5b5b1e6d67f5ad79890650e.setIcon(icon_282568322905d8e776d96c7d93689263);
#
#
#         var popup_bf40da22a6f87970a7a32c4d951a5d97 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_78592cc870d873238197017f55998df4 = $(`&lt;div id=&quot;html_78592cc870d873238197017f55998df4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;BOULDER MANUFACTURING LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;nan&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Products Mfg&lt;br&gt;     5575 Arapahoe Avenue, Units B &amp; C, &lt;br&gt;     Boulder, CO 80303     &lt;/div&gt;`)[0];
#                 popup_bf40da22a6f87970a7a32c4d951a5d97.setContent(html_78592cc870d873238197017f55998df4);
#
#
#
#         marker_f49cb69cb5b5b1e6d67f5ad79890650e.bindPopup(popup_bf40da22a6f87970a7a32c4d951a5d97)
#         ;
#
#
#
#
#             var marker_2fcf29e33d91d684d43c993ecf462bb2 = L.marker(
#                 [40.0871197, -105.2337414],
#                 {}
#             ).addTo(map_d98818e2d63e23d81bfb1d14ed1e634b);
#
#
#             var icon_640442f762c19c597498186cbbf0153f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2fcf29e33d91d684d43c993ecf462bb2.setIcon(icon_640442f762c19c597498186cbbf0153f);
#
#
#         var popup_83bfdec61e4c9ac569eaa9286754fc8b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b5508972e25011d536a0e83e03b9c7fb = $(`&lt;div id=&quot;html_b5508972e25011d536a0e83e03b9c7fb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;BOULDER SWEET GRASS LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Sweet Mary Jane&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Products Mfg&lt;br&gt;     1700 North 55th Street, Unit C&lt;br&gt;     Boulder, CO 80301     &lt;/div&gt;`)[0];
#                 popup_83bfdec61e4c9ac569eaa9286754fc8b.setContent(html_b5508972e25011d536a0e83e03b9c7fb);
#
#
#
#         marker_2fcf29e33d91d684d43c993ecf462bb2.bindPopup(popup_83bfdec61e4c9ac569eaa9286754fc8b)
#         ;
#
#
#
#
#             var marker_ae0d1bb1de0954e4f66dc787aeb93c3d = L.marker(
#                 [40.015524, -105.2092685],
#                 {}
#             ).addTo(map_d98818e2d63e23d81bfb1d14ed1e634b);
#
#
#             var icon_330c3e9b1fe33e8fbaa995a9904be9b6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ae0d1bb1de0954e4f66dc787aeb93c3d.setIcon(icon_330c3e9b1fe33e8fbaa995a9904be9b6);
#
#
#         var popup_170d317c6d1fbb681904d9b20c089313 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_03593a8c2db8ac1060cdaf34434743e4 = $(`&lt;div id=&quot;html_03593a8c2db8ac1060cdaf34434743e4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;CANNXTRACTS LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;nan&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Products Mfg&lt;br&gt;     6185 Arapahoe Road Unit D&lt;br&gt;     Boulder, CO 80303     &lt;/

# %% [markdown]
# ## Step 5: Export Cleaned Data to CSV

# %%
# Export the cleaned DataFrame to a CSV file
df.to_csv("cleaned_colorado_product_manufacturers_full_list_v2.csv", index=False)

# Confirm the export
print("Data exported to colorado_product_manufacturers_full_list_v2.csv")
# Out:
# Data exported to colorado_product_manufacturers_full_list_v2.csv
