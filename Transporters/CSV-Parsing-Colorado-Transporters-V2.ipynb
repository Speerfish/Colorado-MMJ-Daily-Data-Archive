# %% [markdown]
# # Jupyter Notebook: Parsing CSV file and Visualizing Data

# %% [markdown]
# In this notebook, we will load a CSV file, convert it to a pandas DataFrame, and then create a map visualizations using folium.

# %%
pip install pandas folium
# Out:
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (2.2.3)
# Requirement already satisfied: folium in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (0.17.0)
# Requirement already satisfied: numpy>=1.23.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/ceraven/Library/Python/3.11/lib/python/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas) (2024.2)
# Requirement already satisfied: branca>=0.6.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from folium) (0.8.0)
# Requirement already satisfied: jinja2>=2.9 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from folium) (3.1.4)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from folium) (2024.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jinja2>=2.9->folium) (2.1.5)
# Requirement already satisfied: six>=1.5 in /Users/ceraven/Library/Python/3.11/lib/python/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->folium) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->folium) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->folium) (2024.8.30)
#
# [notice] A new release of pip available: 22.3.1 -> 24.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import necessary libraries
import pandas as pd
import folium

# %% [markdown]
# ## Step 1: Load CSV File

# %%
# Load the CSV file into a DataFrame
file_path = "colorado_transporters_full_list.csv"

df = pd.read_csv(file_path)

# Optional: Display the first few rows to check if the file is loaded correctly
df.head(15)
# Out:
#    License Number                              Facility Name  \
# 0     406NP-00011                            ABCDELIVERY LLC
# 1       406-00012                 GOGI CANNABIS DELIVERY LLC
# 2       406-00005                     GPS TRANSPORTATION LLC
# 3     406NP-00013                             GREEN BIRD LLC
# 4       406-00007  INDYSPENSABLE WHOLESALE DISTRIBUTORS CORP
# 5       406-00008           SPECIALTY TRANSPORT SERVICES LLC
# 6     406NP-00006                        SUN-UP DELIVERY LLC
# 7    406RNP-00015                            ABCDELIVERY LLC
# 8    406RNP-00028           BLAZE TO GO DELIVERY SERVICE LLC
# 9    406RNP-00027                         CANNA-COURIERS LLC
# 10   406RNP-00047                     ELEVATION DELIVERY LLC
# 11   406RNP-00029                             GO HARVEST LLC
# 12     406R-00022                 GOGI CANNABIS DELIVERY LLC
# 13     406R-00008                     GPS TRANSPORTATION LLC
# 14   406RNP-00032                             HIGH POINT LTD
#
#                             DBA        Facility Type  \
# 0          Better Days Delivery  MMJ Transporter- NP
# 1                          GOGI      MMJ Transporter
# 2          Green Parcel Service      MMJ Transporter
# 3                    GREEN BIRD  MMJ Transporter- NP
# 4              IDY Distributors      MMJ Transporter
# 5   Cannabis Transport Services      MMJ Transporter
# 6               Sun-Up Delivery  MMJ Transporter- NP
# 7          Better Days Delivery  RMJ Transporter- NP
# 8                           NaN  RMJ Transporter- NP
# 9                CANNA-COURIERS  RMJ Transporter- NP
# 10                          NaN  RMJ Transporter- NP
# 11                          NaN  RMJ Transporter- NP
# 12                         GOGI      RMJ Transporter
# 13         Green Parcel Service      RMJ Transporter
# 14                          NaN  RMJ Transporter- NP
#
#                                   Street      City State  Zip Code  \
# 0                   1965 Kingston Street    Aurora    CO     80010
# 1                       1520 Iris Street  Lakewood    CO     80215
# 2                2186 South Jason Street    Denver    CO     80223
# 3            6757 East Exposition Avenue    Denver    CO     80224
# 4            1332 South Cherokee Street     Denver    CO     80223
# 5      4335 Race Street, Suite 100 & 101    Denver    CO     80216
# 6                   33861 Skyline Drive     Golden    CO     80403
# 7                   1965 Kingston Street    Aurora    CO     80010
# 8   1111 North Broadway Street  Unit 303    Denver    CO     80203
# 9                     824 Pintail Avenue  Brighton    CO     80601
# 10              2076 South Yates Street    Denver     CO     80219
# 11           1178 South Kalamath Street     Denver    CO     80223
# 12                      1520 Iris Street  Lakewood    CO     80215
# 13               2186 South Jason Street    Denver    CO     80223
# 14                 18275 East 52nd Place    Denver    CO     80249
#
#    Date Updated   Latitude   Longitude
# 0    2024-09-03  39.746871 -104.859028
# 1    2024-09-03  39.741360 -105.106391
# 2    2024-09-03  39.676977 -104.999353
# 3    2024-09-03  39.703873 -104.909228
# 4    2024-09-03  39.692251 -104.990901
# 5    2024-09-03  39.777011 -104.963810
# 6    2024-09-03  39.882640 -105.386030
# 7    2024-09-03  39.746871 -104.859028
# 8    2024-09-03  39.734011 -104.987338
# 9    2024-09-03  39.973165 -104.833862
# 10   2024-09-03  39.679732 -105.050827
# 11   2024-09-03  39.695339 -105.000219
# 12   2024-09-03  39.741360 -105.106391
# 13   2024-09-03  39.676977 -104.999353
# 14   2024-09-03  39.791982 -104.775223

# %% [markdown]
# ## Step 2: Clean and Prepare the Data

# %%
# Check column names and data types
df.info()

# Clean any missing latitude or longitude data
df.dropna(subset=['Longitude', 'Latitude'], inplace=True)

# Optional: Check for missing values in other important columns
df.isnull().sum()

# Optional: Display the first few rows of cleaned data
df.head(15)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   License Number  24 non-null     object
#  1   Facility Name   24 non-null     object
#  2   DBA             18 non-null     object
#  3   Facility Type   24 non-null     object
#  4   Street          24 non-null     object
#  5   City            24 non-null     object
#  6   State           24 non-null     object
#  7   Zip Code        24 non-null     int64
#  8   Date Updated    24 non-null     object
#  9   Latitude        24 non-null     float64
#  10  Longitude       24 non-null     float64
# dtypes: float64(2), int64(1), object(8)
# memory usage: 2.2+ KB
#    License Number                              Facility Name  \
# 0     406NP-00011                            ABCDELIVERY LLC
# 1       406-00012                 GOGI CANNABIS DELIVERY LLC
# 2       406-00005                     GPS TRANSPORTATION LLC
# 3     406NP-00013                             GREEN BIRD LLC
# 4       406-00007  INDYSPENSABLE WHOLESALE DISTRIBUTORS CORP
# 5       406-00008           SPECIALTY TRANSPORT SERVICES LLC
# 6     406NP-00006                        SUN-UP DELIVERY LLC
# 7    406RNP-00015                            ABCDELIVERY LLC
# 8    406RNP-00028           BLAZE TO GO DELIVERY SERVICE LLC
# 9    406RNP-00027                         CANNA-COURIERS LLC
# 10   406RNP-00047                     ELEVATION DELIVERY LLC
# 11   406RNP-00029                             GO HARVEST LLC
# 12     406R-00022                 GOGI CANNABIS DELIVERY LLC
# 13     406R-00008                     GPS TRANSPORTATION LLC
# 14   406RNP-00032                             HIGH POINT LTD
#
#                             DBA        Facility Type  \
# 0          Better Days Delivery  MMJ Transporter- NP
# 1                          GOGI      MMJ Transporter
# 2          Green Parcel Service      MMJ Transporter
# 3                    GREEN BIRD  MMJ Transporter- NP
# 4              IDY Distributors      MMJ Transporter
# 5   Cannabis Transport Services      MMJ Transporter
# 6               Sun-Up Delivery  MMJ Transporter- NP
# 7          Better Days Delivery  RMJ Transporter- NP
# 8                           NaN  RMJ Transporter- NP
# 9                CANNA-COURIERS  RMJ Transporter- NP
# 10                          NaN  RMJ Transporter- NP
# 11                          NaN  RMJ Transporter- NP
# 12                         GOGI      RMJ Transporter
# 13         Green Parcel Service      RMJ Transporter
# 14                          NaN  RMJ Transporter- NP
#
#                                   Street      City State  Zip Code  \
# 0                   1965 Kingston Street    Aurora    CO     80010
# 1                       1520 Iris Street  Lakewood    CO     80215
# 2                2186 South Jason Street    Denver    CO     80223
# 3            6757 East Exposition Avenue    Denver    CO     80224
# 4            1332 South Cherokee Street     Denver    CO     80223
# 5      4335 Race Street, Suite 100 & 101    Denver    CO     80216
# 6                   33861 Skyline Drive     Golden    CO     80403
# 7                   1965 Kingston Street    Aurora    CO     80010
# 8   1111 North Broadway Street  Unit 303    Denver    CO     80203
# 9                     824 Pintail Avenue  Brighton    CO     80601
# 10              2076 South Yates Street    Denver     CO     80219
# 11           1178 South Kalamath Street     Denver    CO     80223
# 12                      1520 Iris Street  Lakewood    CO     80215
# 13               2186 South Jason Street    Denver    CO     80223
# 14                 18275 East 52nd Place    Denver    CO     80249
#
#    Date Updated   Latitude   Longitude
# 0    2024-09-03  39.746871 -104.859028
# 1    2024-09-03  39.741360 -105.106391
# 2    2024-09-03  39.676977 -104.999353
# 3    2024-09-03  39.703873 -104.909228
# 4    2024-09-03  39.692251 -104.990901
# 5    2024-09-03  39.777011 -104.963810
# 6    2024-09-03  39.882640 -105.386030
# 7    2024-09-03  39.746871 -104.859028
# 8    2024-09-03  39.734011 -104.987338
# 9    2024-09-03  39.973165 -104.833862
# 10   2024-09-03  39.679732 -105.050827
# 11   2024-09-03  39.695339 -105.000219
# 12   2024-09-03  39.741360 -105.106391
# 13   2024-09-03  39.676977 -104.999353
# 14   2024-09-03  39.791982 -104.775223

# %% [markdown]
# ## Step 3: Create a Searchable Map

# %%
# Initialize the map centered around Colorado
m = folium.Map(location=[39.5501, -105.7821], zoom_start=7)

# Add markers to the map for each food pantry
for idx, row in df.iterrows():
    popup_text = f"""
    <strong>{row['Facility Name']}</strong><br>
    <strong>{row['DBA']}</strong><br>
    Facility Type: {row['Facility Type']}<br>
    {row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip Code']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m)

# Save the map as an HTML file
m.save("colorado_transporters_full_list_map.html")

# Display the map in the notebook
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5b53266adebd2802ee1f3ab1624e04da {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5b53266adebd2802ee1f3ab1624e04da&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5b53266adebd2802ee1f3ab1624e04da = L.map(
#                 &quot;map_5b53266adebd2802ee1f3ab1624e04da&quot;,
#                 {
#                     center: [39.5501, -105.7821],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2f8e804daf9741c6abeaa9e30a369329 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_2f8e804daf9741c6abeaa9e30a369329.addTo(map_5b53266adebd2802ee1f3ab1624e04da);
#
#
#             var marker_4f5933aab58da1c14b5beae20b13c7da = L.marker(
#                 [39.7468712, -104.8590276],
#                 {}
#             ).addTo(map_5b53266adebd2802ee1f3ab1624e04da);
#
#
#             var icon_5f6c8964945e7e13819a2bdb1eb4fb9b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4f5933aab58da1c14b5beae20b13c7da.setIcon(icon_5f6c8964945e7e13819a2bdb1eb4fb9b);
#
#
#         var popup_d1c687d7c98c59ae05a0affcf4696c21 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e8ffea3b47784d2788be112ebe5ef841 = $(`&lt;div id=&quot;html_e8ffea3b47784d2788be112ebe5ef841&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;ABCDELIVERY LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Better Days Delivery&lt;/strong&gt;&lt;br&gt;     Facility Type: MMJ Transporter- NP&lt;br&gt;     1965 Kingston Street&lt;br&gt;     Aurora, CO 80010     &lt;/div&gt;`)[0];
#                 popup_d1c687d7c98c59ae05a0affcf4696c21.setContent(html_e8ffea3b47784d2788be112ebe5ef841);
#
#
#
#         marker_4f5933aab58da1c14b5beae20b13c7da.bindPopup(popup_d1c687d7c98c59ae05a0affcf4696c21)
#         ;
#
#
#
#
#             var marker_7e55c35f5f13f0ae9a9e49dc45a59b25 = L.marker(
#                 [39.7413599, -105.106391],
#                 {}
#             ).addTo(map_5b53266adebd2802ee1f3ab1624e04da);
#
#
#             var icon_ebc936d8c42a412cee0a25edcb0f7fb8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7e55c35f5f13f0ae9a9e49dc45a59b25.setIcon(icon_ebc936d8c42a412cee0a25edcb0f7fb8);
#
#
#         var popup_932ad8a6b84f3bc0a89f12cbb4cbe728 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d24b7cee72fa49d08fafb73cd7e23013 = $(`&lt;div id=&quot;html_d24b7cee72fa49d08fafb73cd7e23013&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;GOGI CANNABIS DELIVERY LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;GOGI&lt;/strong&gt;&lt;br&gt;     Facility Type: MMJ Transporter&lt;br&gt;     1520 Iris Street&lt;br&gt;     Lakewood, CO 80215     &lt;/div&gt;`)[0];
#                 popup_932ad8a6b84f3bc0a89f12cbb4cbe728.setContent(html_d24b7cee72fa49d08fafb73cd7e23013);
#
#
#
#         marker_7e55c35f5f13f0ae9a9e49dc45a59b25.bindPopup(popup_932ad8a6b84f3bc0a89f12cbb4cbe728)
#         ;
#
#
#
#
#             var marker_4efea8525447de232be40568a7b2d614 = L.marker(
#                 [39.6769774, -104.9993532],
#                 {}
#             ).addTo(map_5b53266adebd2802ee1f3ab1624e04da);
#
#
#             var icon_30bffd6ee9c0d6d2094b767bcd217f69 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4efea8525447de232be40568a7b2d614.setIcon(icon_30bffd6ee9c0d6d2094b767bcd217f69);
#
#
#         var popup_1bbf5cb6721130bb089f444ac4524b27 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c819ca2c4fc034f91d3ed3e987fc1041 = $(`&lt;div id=&quot;html_c819ca2c4fc034f91d3ed3e987fc1041&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;GPS TRANSPORTATION LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Green Parcel Service&lt;/strong&gt;&lt;br&gt;     Facility Type: MMJ Transporter&lt;br&gt;     2186 South Jason Street&lt;br&gt;     Denver, CO 80223     &lt;/div&gt;`)[0];
#                 popup_1bbf5cb6721130b

# %% [markdown]
# ## Step 4: Implement Search Functionality

# %%
# Example: Search for transporters in a specific city
city_search = "Denver"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[39.5501, -105.7821], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Facility Name']}</strong><br>
    <strong>{row['DBA']}</strong><br>
    Facility Type: {row['Facility Type']}<br>
    {row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip Code']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_transporters_map_denver.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8321a573c9882959c6ccccab726e4c7c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8321a573c9882959c6ccccab726e4c7c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8321a573c9882959c6ccccab726e4c7c = L.map(
#                 &quot;map_8321a573c9882959c6ccccab726e4c7c&quot;,
#                 {
#                     center: [39.5501, -105.7821],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_217d03df3900690aa4a4e1070f3e93f3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_217d03df3900690aa4a4e1070f3e93f3.addTo(map_8321a573c9882959c6ccccab726e4c7c);
#
#
#             var marker_e49cb52d615705faa84fa464eed9ca7a = L.marker(
#                 [39.6769774, -104.9993532],
#                 {}
#             ).addTo(map_8321a573c9882959c6ccccab726e4c7c);
#
#
#             var icon_0f6f181d5330e95e615e837a9f5fe57b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e49cb52d615705faa84fa464eed9ca7a.setIcon(icon_0f6f181d5330e95e615e837a9f5fe57b);
#
#
#         var popup_cc083e7564881e3f0e0d092eb3cf021a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7f54c30c80e55bc262ec885ded22cc40 = $(`&lt;div id=&quot;html_7f54c30c80e55bc262ec885ded22cc40&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;GPS TRANSPORTATION LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Green Parcel Service&lt;/strong&gt;&lt;br&gt;     Facility Type: MMJ Transporter&lt;br&gt;     2186 South Jason Street&lt;br&gt;     Denver, CO 80223     &lt;/div&gt;`)[0];
#                 popup_cc083e7564881e3f0e0d092eb3cf021a.setContent(html_7f54c30c80e55bc262ec885ded22cc40);
#
#
#
#         marker_e49cb52d615705faa84fa464eed9ca7a.bindPopup(popup_cc083e7564881e3f0e0d092eb3cf021a)
#         ;
#
#
#
#
#             var marker_cde0646bbd116ebcf178e223f7e6baca = L.marker(
#                 [39.7038731, -104.9092277],
#                 {}
#             ).addTo(map_8321a573c9882959c6ccccab726e4c7c);
#
#
#             var icon_c081211427dbb78a0cbce448cea4eff7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_cde0646bbd116ebcf178e223f7e6baca.setIcon(icon_c081211427dbb78a0cbce448cea4eff7);
#
#
#         var popup_cc564bf526e566dc7a616e8c165efce5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_49a4f845d3d16296b356f237fac14266 = $(`&lt;div id=&quot;html_49a4f845d3d16296b356f237fac14266&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;GREEN BIRD LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;GREEN BIRD&lt;/strong&gt;&lt;br&gt;     Facility Type: MMJ Transporter- NP&lt;br&gt;     6757 East Exposition Avenue&lt;br&gt;     Denver, CO 80224     &lt;/div&gt;`)[0];
#                 popup_cc564bf526e566dc7a616e8c165efce5.setContent(html_49a4f845d3d16296b356f237fac14266);
#
#
#
#         marker_cde0646bbd116ebcf178e223f7e6baca.bindPopup(popup_cc564bf526e566dc7a616e8c165efce5)
#         ;
#
#
#
#
#             var marker_bd296629af944c53cc69895557270c79 = L.marker(
#                 [39.6922509, -104.9909014],
#                 {}
#             ).addTo(map_8321a573c9882959c6ccccab726e4c7c);
#
#
#             var icon_3ed3d49b3ff144bf0a0149069f5e575e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_bd296629af944c53cc69895557270c79.setIcon(icon_3ed3d49b3ff144bf0a0149069f5e575e);
#
#
#         var popup_f29ae77f96a93a09d313a492d43b3d2e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_75701a1b828ef2a3af7150c7545893ac = $(`&lt;div id=&quot;html_75701a1b828ef2a3af7150c7545893ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;INDYSPENSABLE WHOLESALE DISTRIBUTORS CORP&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;IDY Distributors&lt;/strong&gt;&lt;br&gt;     Facility Type: MMJ Transporter&lt;br&gt;     1332 South Cherokee Street &lt;br&gt;     Denver, CO 80223     &lt;/div&gt;`)[0];

# %%
# Example: Search for transporters in a specific city
city_search = "Colorado Springs"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[38.8591, -104.8135], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Facility Name']}</strong><br>
    <strong>{row['DBA']}</strong><br>
    Facility Type: {row['Facility Type']}<br>
    {row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip Code']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_transporters_map_colorado_springs.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_986a550b27e5e98070bd1d165a1c068e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_986a550b27e5e98070bd1d165a1c068e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_986a550b27e5e98070bd1d165a1c068e = L.map(
#                 &quot;map_986a550b27e5e98070bd1d165a1c068e&quot;,
#                 {
#                     center: [38.8591, -104.8135],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_02310d9fae0f55a38ef018bcbeb06fe8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_02310d9fae0f55a38ef018bcbeb06fe8.addTo(map_986a550b27e5e98070bd1d165a1c068e);
#
#
#             var marker_b143fcfe179bd379610831d889d757f0 = L.marker(
#                 [39.012754, -104.748178],
#                 {}
#             ).addTo(map_986a550b27e5e98070bd1d165a1c068e);
#
#
#             var icon_c782576b01f02cbbbabb461335ac9238 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b143fcfe179bd379610831d889d757f0.setIcon(icon_c782576b01f02cbbbabb461335ac9238);
#
#
#         var popup_b2083eafafd9be8ac9c7fe8b3e7d850c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f4f88358f9ae55741395b293c610246b = $(`&lt;div id=&quot;html_f4f88358f9ae55741395b293c610246b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;MIKELL GROUP LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Emerald Transport&lt;/strong&gt;&lt;br&gt;     Facility Type: RMJ Transporter- NP&lt;br&gt;     8872 Falcon Nest Court&lt;br&gt;     Colorado Springs, CO 80908     &lt;/div&gt;`)[0];
#                 popup_b2083eafafd9be8ac9c7fe8b3e7d850c.setContent(html_f4f88358f9ae55741395b293c610246b);
#
#
#
#         marker_b143fcfe179bd379610831d889d757f0.bindPopup(popup_b2083eafafd9be8ac9c7fe8b3e7d850c)
#         ;
#
#
#
#
#             tile_layer_02310d9fae0f55a38ef018bcbeb06fe8.addTo(map_986a550b27e5e98070bd1d165a1c068e);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Example: Search for transporters in a specific city
city_search = "Aurora"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[39.7108, -104.8125], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Facility Name']}</strong><br>
    <strong>{row['DBA']}</strong><br>
    Facility Type: {row['Facility Type']}<br>
    {row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip Code']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_transporters_map_aurora.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a3d21ded04c69186589525f741ac2801 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a3d21ded04c69186589525f741ac2801&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a3d21ded04c69186589525f741ac2801 = L.map(
#                 &quot;map_a3d21ded04c69186589525f741ac2801&quot;,
#                 {
#                     center: [39.7108, -104.8125],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3fce42f8a50910fb8f6e9f598602300d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_3fce42f8a50910fb8f6e9f598602300d.addTo(map_a3d21ded04c69186589525f741ac2801);
#
#
#             var marker_ea115926abdcab26411272d597ceabbd = L.marker(
#                 [39.7468712, -104.8590276],
#                 {}
#             ).addTo(map_a3d21ded04c69186589525f741ac2801);
#
#
#             var icon_dcb3ddb635bba02922bb7e2bbaa3106b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ea115926abdcab26411272d597ceabbd.setIcon(icon_dcb3ddb635bba02922bb7e2bbaa3106b);
#
#
#         var popup_8f52ef1b9364fe916740832a37e16d0f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0afb86a989c49d3036f59bb92dbd2f5a = $(`&lt;div id=&quot;html_0afb86a989c49d3036f59bb92dbd2f5a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;ABCDELIVERY LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Better Days Delivery&lt;/strong&gt;&lt;br&gt;     Facility Type: MMJ Transporter- NP&lt;br&gt;     1965 Kingston Street&lt;br&gt;     Aurora, CO 80010     &lt;/div&gt;`)[0];
#                 popup_8f52ef1b9364fe916740832a37e16d0f.setContent(html_0afb86a989c49d3036f59bb92dbd2f5a);
#
#
#
#         marker_ea115926abdcab26411272d597ceabbd.bindPopup(popup_8f52ef1b9364fe916740832a37e16d0f)
#         ;
#
#
#
#
#             var marker_2f5adb6a1ac5ad58cc691ca782342e0d = L.marker(
#                 [39.7468712, -104.8590276],
#                 {}
#             ).addTo(map_a3d21ded04c69186589525f741ac2801);
#
#
#             var icon_652e8f82f6cc210773c591cb9ab5e796 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2f5adb6a1ac5ad58cc691ca782342e0d.setIcon(icon_652e8f82f6cc210773c591cb9ab5e796);
#
#
#         var popup_50f4eacb0a069357bb4c944d7b23abd0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_843a9fd27fe810a7332f006f9277a7b9 = $(`&lt;div id=&quot;html_843a9fd27fe810a7332f006f9277a7b9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;ABCDELIVERY LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Better Days Delivery&lt;/strong&gt;&lt;br&gt;     Facility Type: RMJ Transporter- NP&lt;br&gt;     1965 Kingston Street&lt;br&gt;     Aurora, CO 80010     &lt;/div&gt;`)[0];
#                 popup_50f4eacb0a069357bb4c944d7b23abd0.setContent(html_843a9fd27fe810a7332f006f9277a7b9);
#
#
#
#         marker_2f5adb6a1ac5ad58cc691ca782342e0d.bindPopup(popup_50f4eacb0a069357bb4c944d7b23abd0)
#         ;
#
#
#
#
#             var marker_fa290ba83d8d50ab9a761817f1a42685 = L.marker(
#                 [39.639036, -104.755332],
#                 {}
#             ).addTo(map_a3d21ded04c69186589525f741ac2801);
#
#
#             var icon_5c4a64affef5dec1512bac20fd984f38 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_fa290ba83d8d50ab9a761817f1a42685.setIcon(icon_5c4a64affef5dec1512bac20fd984f38);
#
#
#         var popup_dfbf526c23492d063cbc060181de382b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e134659ea235ed1a0ab0df373fff355b = $(`&lt;div id=&quot;html_e134659ea235ed1a0ab0df373fff355b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;SHW LOGISTICS LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;High Demand Delivery&lt;/strong&gt;&lt;br&gt;     Facility Type: RMJ Transporter- NP&lt;br&gt;     4275 South Hailfax Way&lt;br&gt;     Aurora, CO 80013     &lt;/div&gt;`)[0];
#                 popup_dfbf526

# %%
# Example: Search for transporters in a specific city
city_search = "Lakewood"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[39.7109, -105.0815], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Facility Name']}</strong><br>
    <strong>{row['DBA']}</strong><br>
    Facility Type: {row['Facility Type']}<br>
    {row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip Code']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_transporters_map_lakewood.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a1901da94b6884ec40e7cf04fb82c8a8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a1901da94b6884ec40e7cf04fb82c8a8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a1901da94b6884ec40e7cf04fb82c8a8 = L.map(
#                 &quot;map_a1901da94b6884ec40e7cf04fb82c8a8&quot;,
#                 {
#                     center: [39.7109, -105.0815],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_646cd0aa092eb0862012245c5d530e1a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_646cd0aa092eb0862012245c5d530e1a.addTo(map_a1901da94b6884ec40e7cf04fb82c8a8);
#
#
#             var marker_dae1e603fe4e463ec94cd427d52e2f55 = L.marker(
#                 [39.7413599, -105.106391],
#                 {}
#             ).addTo(map_a1901da94b6884ec40e7cf04fb82c8a8);
#
#
#             var icon_9be21704cfa1b25e0b392b41826ef33b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_dae1e603fe4e463ec94cd427d52e2f55.setIcon(icon_9be21704cfa1b25e0b392b41826ef33b);
#
#
#         var popup_907c4fea781ee6665f262d5c9bab0353 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_35ea4ea8a2542790c57b621113fba05f = $(`&lt;div id=&quot;html_35ea4ea8a2542790c57b621113fba05f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;GOGI CANNABIS DELIVERY LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;GOGI&lt;/strong&gt;&lt;br&gt;     Facility Type: MMJ Transporter&lt;br&gt;     1520 Iris Street&lt;br&gt;     Lakewood, CO 80215     &lt;/div&gt;`)[0];
#                 popup_907c4fea781ee6665f262d5c9bab0353.setContent(html_35ea4ea8a2542790c57b621113fba05f);
#
#
#
#         marker_dae1e603fe4e463ec94cd427d52e2f55.bindPopup(popup_907c4fea781ee6665f262d5c9bab0353)
#         ;
#
#
#
#
#             var marker_9a46c2d507a85d5192077a33c321928b = L.marker(
#                 [39.7413599, -105.106391],
#                 {}
#             ).addTo(map_a1901da94b6884ec40e7cf04fb82c8a8);
#
#
#             var icon_adf43252a06e8164fde2f19f927e8096 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9a46c2d507a85d5192077a33c321928b.setIcon(icon_adf43252a06e8164fde2f19f927e8096);
#
#
#         var popup_b92bbdbd0a8642477eb6489980af347e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_672620458dc20e53820399451580cc9d = $(`&lt;div id=&quot;html_672620458dc20e53820399451580cc9d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;GOGI CANNABIS DELIVERY LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;GOGI&lt;/strong&gt;&lt;br&gt;     Facility Type: RMJ Transporter&lt;br&gt;     1520 Iris Street&lt;br&gt;     Lakewood, CO 80215     &lt;/div&gt;`)[0];
#                 popup_b92bbdbd0a8642477eb6489980af347e.setContent(html_672620458dc20e53820399451580cc9d);
#
#
#
#         marker_9a46c2d507a85d5192077a33c321928b.bindPopup(popup_b92bbdbd0a8642477eb6489980af347e)
#         ;
#
#
#
#
#             tile_layer_646cd0aa092eb0862012245c5d530e1a.addTo(map_a1901da94b6884ec40e7cf04fb82c8a8);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Example: Search for transporters in a specific city
city_search = "Arvada"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[39.8028, -105.0875], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Facility Name']}</strong><br>
    <strong>{row['DBA']}</strong><br>
    Facility Type: {row['Facility Type']}<br>
    {row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip Code']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_transporters_map_arvada.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_660f7e50f15d00e2a760a2cbdef701cc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_660f7e50f15d00e2a760a2cbdef701cc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_660f7e50f15d00e2a760a2cbdef701cc = L.map(
#                 &quot;map_660f7e50f15d00e2a760a2cbdef701cc&quot;,
#                 {
#                     center: [39.8028, -105.0875],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_05d1b324076f980b021f0e59077b44c3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_05d1b324076f980b021f0e59077b44c3.addTo(map_660f7e50f15d00e2a760a2cbdef701cc);
#
#
#             var marker_11a16dcd899c95ce09f564897818fab4 = L.marker(
#                 [39.65719, -104.782358],
#                 {}
#             ).addTo(map_660f7e50f15d00e2a760a2cbdef701cc);
#
#
#             var icon_e2c2ef5a9549e495dad6889dd987ef11 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_11a16dcd899c95ce09f564897818fab4.setIcon(icon_e2c2ef5a9549e495dad6889dd987ef11);
#
#
#         var popup_25b5bbb95fcbd5664f22109392c09d1b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_af4fa592fc471d46eaf68a3417d14023 = $(`&lt;div id=&quot;html_af4fa592fc471d46eaf68a3417d14023&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;WOOSIEGIRL LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Buzz Delivery&lt;/strong&gt;&lt;br&gt;     Facility Type: RMJ Transporter- NP&lt;br&gt;     8445 Eldora Way&lt;br&gt;     Arvada , CO 80007     &lt;/div&gt;`)[0];
#                 popup_25b5bbb95fcbd5664f22109392c09d1b.setContent(html_af4fa592fc471d46eaf68a3417d14023);
#
#
#
#         marker_11a16dcd899c95ce09f564897818fab4.bindPopup(popup_25b5bbb95fcbd5664f22109392c09d1b)
#         ;
#
#
#
#
#             tile_layer_05d1b324076f980b021f0e59077b44c3.addTo(map_660f7e50f15d00e2a760a2cbdef701cc);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Step 5: Export Cleaned Data to CSV

# %%
# Export the cleaned DataFrame to a CSV file
df.to_csv("cleaned_colorado_transporters_full_list_v2.csv", index=False)

# Confirm the export
print("Data exported to colorado_transporters_full_list_v2.csv")
# Out:
# Data exported to colorado_transporters_full_list_v2.csv
