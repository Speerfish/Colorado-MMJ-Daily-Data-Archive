# %% [markdown]
# # Jupyter Notebook: Parsing CSV file and Visualizing Data

# %% [markdown]
# In this notebook, we will load a CSV file, convert it to a pandas DataFrame, and then create a map visualizations using folium.

# %%
pip install pandas folium
# Out:
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (2.2.3)
# Requirement already satisfied: folium in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (0.17.0)
# Requirement already satisfied: numpy>=1.23.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/ceraven/Library/Python/3.11/lib/python/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas) (2024.2)
# Requirement already satisfied: branca>=0.6.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from folium) (0.8.0)
# Requirement already satisfied: jinja2>=2.9 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from folium) (3.1.4)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from folium) (2024.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jinja2>=2.9->folium) (2.1.5)
# Requirement already satisfied: six>=1.5 in /Users/ceraven/Library/Python/3.11/lib/python/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->folium) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->folium) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->folium) (2024.8.30)
#
# [notice] A new release of pip available: 22.3.1 -> 24.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import necessary libraries
import pandas as pd
import folium

# %% [markdown]
# ## Step 1: Load CSV File

# %%
# Load the CSV file into a DataFrame
file_path = "colorado_dispensaries_full_list_v2.csv"

df = pd.read_csv(file_path)

# Optional: Display the first few rows to check if the file is loaded correctly
df.head(15)
# Out:
#    License Number                    Facility Name  \
# 0       402-01197                         1-11 LLC
# 1       402-00116                 1022 S ROYER LLC
# 2       402-00455   11761013 COLORADO HOLDINGS LLC
# 3       402-00017            1617 WAZEE STREET LLC
# 4       402-00248                2306 N POWERS LLC
# 5       402-00618                      4 ROSES LLC
# 6       402-00656            543 BRYANT STREET LLC
# 7       402-01020                         8058 LLC
# 8       402-01371          A AND M ENTERPRISES LLC
# 9       402-00306       ABUNDANT HEALTH DENVER LLC
# 10      402-00869  ACADEMY OF THE HEALING ARTS LLC
# 11      402-00929                   ACES PLACE LLC
# 12      402-01097         ADAMS GREEN CROSSING LLC
# 13      402-01145         ADAMS GREEN CROSSING LLC
# 14      402-01119                           AF INC
#
#                             DBA            Facility Type  \
# 0                    one:eleven  Medical Marijuana Store
# 1                      Hightops  Medical Marijuana Store
# 2                   A Cut Above  Medical Marijuana Store
# 3          LoDo Wellness Center  Medical Marijuana Store
# 4                      Hightops  Medical Marijuana Store
# 5                      Bleezies  Medical Marijuana Store
# 6                      Snaxland  Medical Marijuana Store
# 7                   Mighty Tree  Medical Marijuana Store
# 8               Backstage Grass  Medical Marijuana Store
# 9            Herban Underground  Medical Marijuana Store
# 10  High Valley Healing Alamosa  Medical Marijuana Store
# 11                          NaN  Medical Marijuana Store
# 12                          NaN  Medical Marijuana Store
# 13                          NaN  Medical Marijuana Store
# 14             Apothecary Farms  Medical Marijuana Store
#
#                                         Street              City State  \
# 0                             17034 Highway 17            Moffat    CO
# 1                      1022 South Royer Street  Colorado Springs    CO
# 2                          1911 South Broadway            Denver    CO
# 3                    1617 Wazee Street, Unit B            Denver    CO
# 4   2306 North Powers Frontage Road, Suite 100  Colorado Springs    CO
# 5                     3234 North Nevada Avenue  Colorado Springs    CO
# 6                            543 Bryant Street            Denver    CO
# 7                      4755 North Lipan Street            Denver    CO
# 8                          117 Greydene Avenue        Canon City    CO
# 9                  70 North Broadway, Suite 50            Denver    CO
# 10              0711 West Highway 160, Suite B           Alamosa    CO
# 11                  1101 Academy Court, Unit 4      Fort Collins    CO
# 12                   3640 West Colorado Avenue  Colorado Springs    CO
# 13         2727 Palmer Park Boulevard, Suite A  Colorado Springs    CO
# 14                            3049 Delta Drive  Colorado Springs    CO
#
#     Zip Code Date Updated   Latitude   Longitude
# 0      81143   2024-09-03  37.992955 -105.907324
# 1      80903   2024-09-03  38.819517 -104.815490
# 2      80210   2024-09-03  39.681864 -104.987676
# 3      80202   2024-09-03  39.751655 -104.999706
# 4      80915   2024-09-03  38.863467 -104.720079
# 5      80907   2024-09-03  38.878155 -104.818384
# 6      80204   2024-09-03  39.724321 -105.018772
# 7      80211   2024-09-03  39.782501 -105.001764
# 8      81212   2024-09-03  38.447405 -105.210971
# 9      80203   2024-09-03  39.717834 -104.987427
# 10     81101   2024-09-03  37.467184 -105.867273
# 11     80524   2024-09-03  40.573840 -105.047385
# 12     80904   2024-09-03  38.856554 -104.882175
# 13     80909   2024-09-03  38.853439 -104.777734
# 14     80910   2024-09-03  38.795160 -104.776840

# %% [markdown]
# ## Step 2: Clean and Prepare the Data

# %%
# Check column names and data types
df.info()

# Clean any missing latitude or longitude data
df.dropna(subset=['Longitude', 'Latitude'], inplace=True)

# Optional: Check for missing values in other important columns
df.isnull().sum()

# Optional: Display the first few rows of cleaned data
df.head(15)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 998 entries, 0 to 997
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   License Number  998 non-null    object
#  1   Facility Name   998 non-null    object
#  2   DBA             840 non-null    object
#  3   Facility Type   998 non-null    object
#  4   Street          998 non-null    object
#  5   City            998 non-null    object
#  6   State           998 non-null    object
#  7   Zip Code        998 non-null    int64
#  8   Date Updated    998 non-null    object
#  9   Latitude        998 non-null    float64
#  10  Longitude       998 non-null    float64
# dtypes: float64(2), int64(1), object(8)
# memory usage: 85.9+ KB
#    License Number                    Facility Name  \
# 0       402-01197                         1-11 LLC
# 1       402-00116                 1022 S ROYER LLC
# 2       402-00455   11761013 COLORADO HOLDINGS LLC
# 3       402-00017            1617 WAZEE STREET LLC
# 4       402-00248                2306 N POWERS LLC
# 5       402-00618                      4 ROSES LLC
# 6       402-00656            543 BRYANT STREET LLC
# 7       402-01020                         8058 LLC
# 8       402-01371          A AND M ENTERPRISES LLC
# 9       402-00306       ABUNDANT HEALTH DENVER LLC
# 10      402-00869  ACADEMY OF THE HEALING ARTS LLC
# 11      402-00929                   ACES PLACE LLC
# 12      402-01097         ADAMS GREEN CROSSING LLC
# 13      402-01145         ADAMS GREEN CROSSING LLC
# 14      402-01119                           AF INC
#
#                             DBA            Facility Type  \
# 0                    one:eleven  Medical Marijuana Store
# 1                      Hightops  Medical Marijuana Store
# 2                   A Cut Above  Medical Marijuana Store
# 3          LoDo Wellness Center  Medical Marijuana Store
# 4                      Hightops  Medical Marijuana Store
# 5                      Bleezies  Medical Marijuana Store
# 6                      Snaxland  Medical Marijuana Store
# 7                   Mighty Tree  Medical Marijuana Store
# 8               Backstage Grass  Medical Marijuana Store
# 9            Herban Underground  Medical Marijuana Store
# 10  High Valley Healing Alamosa  Medical Marijuana Store
# 11                          NaN  Medical Marijuana Store
# 12                          NaN  Medical Marijuana Store
# 13                          NaN  Medical Marijuana Store
# 14             Apothecary Farms  Medical Marijuana Store
#
#                                         Street              City State  \
# 0                             17034 Highway 17            Moffat    CO
# 1                      1022 South Royer Street  Colorado Springs    CO
# 2                          1911 South Broadway            Denver    CO
# 3                    1617 Wazee Street, Unit B            Denver    CO
# 4   2306 North Powers Frontage Road, Suite 100  Colorado Springs    CO
# 5                     3234 North Nevada Avenue  Colorado Springs    CO
# 6                            543 Bryant Street            Denver    CO
# 7                      4755 North Lipan Street            Denver    CO
# 8                          117 Greydene Avenue        Canon City    CO
# 9                  70 North Broadway, Suite 50            Denver    CO
# 10              0711 West Highway 160, Suite B           Alamosa    CO
# 11                  1101 Academy Court, Unit 4      Fort Collins    CO
# 12                   3640 West Colorado Avenue  Colorado Springs    CO
# 13         2727 Palmer Park Boulevard, Suite A  Colorado Springs    CO
# 14                            3049 Delta Drive  Colorado Springs    CO
#
#     Zip Code Date Updated   Latitude   Longitude
# 0      81143   2024-09-03  37.992955 -105.907324
# 1      80903   2024-09-03  38.819517 -104.815490
# 2      80210   2024-09-03  39.681864 -104.987676
# 3      80202   2024-09-03  39.751655 -104.999706
# 4      80915   2024-09-03  38.863467 -104.720079
# 5      80907   2024-09-03  38.878155 -104.818384
# 6      80204   2024-09-03  39.724321 -105.018772
# 7      80211   2024-09-03  39.782501 -105.001764
# 8      81212   2024-09-03  38.447405 -105.210971
# 9      80203   2024-09-03  39.717834 -104.987427
# 10     81101   2024-09-03  37.467184 -105.867273
# 11     80524   2024-09-03  40.573840 -105.047385
# 12     80904   2024-09-03  38.856554 -104.882175
# 13     80909   2024-09-03  38.853439 -104.777734
# 14     80910   2024-09-03  38.795160 -104.776840

# %% [markdown]
# ## Step 3: Create a Searchable Map

# %%
# Initialize the map centered around Colorado
m = folium.Map(location=[39.5501, -105.7821], zoom_start=7)

# Add markers to the map for each food pantry
for idx, row in df.iterrows():
    popup_text = f"""
    <strong>{row['Facility Name']}</strong><br>
    <strong>{row['DBA']}</strong><br>
    Facility Type: {row['Facility Type']}<br>
    {row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip Code']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m)

# Save the map as an HTML file
m.save("colorado_dispensaries_full_list_map.html")

# Display the map in the notebook
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a5cc33e4f6f45e841a10a040fa1c2b65 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a5cc33e4f6f45e841a10a040fa1c2b65&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a5cc33e4f6f45e841a10a040fa1c2b65 = L.map(
#                 &quot;map_a5cc33e4f6f45e841a10a040fa1c2b65&quot;,
#                 {
#                     center: [39.5501, -105.7821],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_266276f0a8173cbd216aa68733eb1d31 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_266276f0a8173cbd216aa68733eb1d31.addTo(map_a5cc33e4f6f45e841a10a040fa1c2b65);
#
#
#             var marker_757fea3bec763f2700db5aeb37500659 = L.marker(
#                 [37.992955, -105.907324],
#                 {}
#             ).addTo(map_a5cc33e4f6f45e841a10a040fa1c2b65);
#
#
#             var icon_bbd1f213273ba20e0f8c7ca8deeab095 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_757fea3bec763f2700db5aeb37500659.setIcon(icon_bbd1f213273ba20e0f8c7ca8deeab095);
#
#
#         var popup_0da948fa2b0bfdb0d7f4ea370b6e9951 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7d0cd312c5edb47fac05379e2e36764a = $(`&lt;div id=&quot;html_7d0cd312c5edb47fac05379e2e36764a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;1-11 LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;one:eleven&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Store&lt;br&gt;     17034 Highway 17&lt;br&gt;     Moffat, CO 81143     &lt;/div&gt;`)[0];
#                 popup_0da948fa2b0bfdb0d7f4ea370b6e9951.setContent(html_7d0cd312c5edb47fac05379e2e36764a);
#
#
#
#         marker_757fea3bec763f2700db5aeb37500659.bindPopup(popup_0da948fa2b0bfdb0d7f4ea370b6e9951)
#         ;
#
#
#
#
#             var marker_9ebe72d93602e8405430e46abfba2cc5 = L.marker(
#                 [38.8195171, -104.8154896],
#                 {}
#             ).addTo(map_a5cc33e4f6f45e841a10a040fa1c2b65);
#
#
#             var icon_340ad766a9a16ccc0b0e8342aa4002ba = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9ebe72d93602e8405430e46abfba2cc5.setIcon(icon_340ad766a9a16ccc0b0e8342aa4002ba);
#
#
#         var popup_f0928f5c613872321fe0c04ccfbf6bfb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f7886149ed48b189a800e8bd78cec17c = $(`&lt;div id=&quot;html_f7886149ed48b189a800e8bd78cec17c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;1022 S ROYER LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Hightops&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Store&lt;br&gt;     1022 South Royer Street&lt;br&gt;     Colorado Springs, CO 80903     &lt;/div&gt;`)[0];
#                 popup_f0928f5c613872321fe0c04ccfbf6bfb.setContent(html_f7886149ed48b189a800e8bd78cec17c);
#
#
#
#         marker_9ebe72d93602e8405430e46abfba2cc5.bindPopup(popup_f0928f5c613872321fe0c04ccfbf6bfb)
#         ;
#
#
#
#
#             var marker_979725ba8b7afc7de1694231423fd61d = L.marker(
#                 [39.6818644, -104.987676],
#                 {}
#             ).addTo(map_a5cc33e4f6f45e841a10a040fa1c2b65);
#
#
#             var icon_2413f93989c766b50d03015ec4c8f2e1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_979725ba8b7afc7de1694231423fd61d.setIcon(icon_2413f93989c766b50d03015ec4c8f2e1);
#
#
#         var popup_d0ad081a9539235a0f9b41378078b130 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_193e9d9fc0d48faa9a1fa934ac11f79e = $(`&lt;div id=&quot;html_193e9d9fc0d48faa9a1fa934ac11f79e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;11761013 COLORADO HOLDINGS LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;A Cut Above&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Store&lt;br&gt;     1911 South Broadway&lt;br&gt;     Denver, CO 80210     &lt;/div&gt;`)[0];
#                 popup_d0ad081a953923

# %% [markdown]
# ## Step 4: Implement Search Functionality

# %%
# Example: Search for dispensaries in a specific city
city_search = "Denver"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[39.5501, -105.7821], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Facility Name']}</strong><br>
    <strong>{row['DBA']}</strong><br>
    Facility Type: {row['Facility Type']}<br>
    {row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip Code']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_dispensaries_map_denver.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_49463b4fb4a4593199399947d171779f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_49463b4fb4a4593199399947d171779f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_49463b4fb4a4593199399947d171779f = L.map(
#                 &quot;map_49463b4fb4a4593199399947d171779f&quot;,
#                 {
#                     center: [39.5501, -105.7821],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3b604cd3f912d5a8272815790db9d579 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_3b604cd3f912d5a8272815790db9d579.addTo(map_49463b4fb4a4593199399947d171779f);
#
#
#             var marker_d32139593b48659ac34d152ddfe58af2 = L.marker(
#                 [39.6818644, -104.987676],
#                 {}
#             ).addTo(map_49463b4fb4a4593199399947d171779f);
#
#
#             var icon_923d927176ad18dddc9042a62cb26341 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d32139593b48659ac34d152ddfe58af2.setIcon(icon_923d927176ad18dddc9042a62cb26341);
#
#
#         var popup_4b73ed9848abfeeb3de438f74053f9e5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1bcda614b49a663a3c86e91ad66edf7f = $(`&lt;div id=&quot;html_1bcda614b49a663a3c86e91ad66edf7f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;11761013 COLORADO HOLDINGS LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;A Cut Above&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Store&lt;br&gt;     1911 South Broadway&lt;br&gt;     Denver, CO 80210     &lt;/div&gt;`)[0];
#                 popup_4b73ed9848abfeeb3de438f74053f9e5.setContent(html_1bcda614b49a663a3c86e91ad66edf7f);
#
#
#
#         marker_d32139593b48659ac34d152ddfe58af2.bindPopup(popup_4b73ed9848abfeeb3de438f74053f9e5)
#         ;
#
#
#
#
#             var marker_64c0377e432904c852410cf3e5281a09 = L.marker(
#                 [39.7516552, -104.9997063],
#                 {}
#             ).addTo(map_49463b4fb4a4593199399947d171779f);
#
#
#             var icon_26733410738aa73349245db0bbb74121 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_64c0377e432904c852410cf3e5281a09.setIcon(icon_26733410738aa73349245db0bbb74121);
#
#
#         var popup_dfdb52931b2609e76472f7b74ea3b093 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ac61e8a0eb904deacd3100d88983170c = $(`&lt;div id=&quot;html_ac61e8a0eb904deacd3100d88983170c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;1617 WAZEE STREET LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;LoDo Wellness Center&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Store&lt;br&gt;     1617 Wazee Street, Unit B&lt;br&gt;     Denver, CO 80202     &lt;/div&gt;`)[0];
#                 popup_dfdb52931b2609e76472f7b74ea3b093.setContent(html_ac61e8a0eb904deacd3100d88983170c);
#
#
#
#         marker_64c0377e432904c852410cf3e5281a09.bindPopup(popup_dfdb52931b2609e76472f7b74ea3b093)
#         ;
#
#
#
#
#             var marker_e612b7b47aeb272dd444ebd8f74250ee = L.marker(
#                 [39.7243206, -105.0187723],
#                 {}
#             ).addTo(map_49463b4fb4a4593199399947d171779f);
#
#
#             var icon_242ffd2eb3f0617df0cc47584d8228b3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e612b7b47aeb272dd444ebd8f74250ee.setIcon(icon_242ffd2eb3f0617df0cc47584d8228b3);
#
#
#         var popup_92702215dfb663a7275b015e16b09c0a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_56f5e32f87df9ae3b7f82307a754dbad = $(`&lt;div id=&quot;html_56f5e32f87df9ae3b7f82307a754dbad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;543 BRYANT STREET LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Snaxland&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Store&lt;br&gt;     543 Bryant Street&lt;br&gt;     Denver, CO 80204     &lt;/div&gt;`)[0];

# %%
# Example: Search for dispensaries in a specific city
city_search = "Colorado Springs"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[38.8591, -104.8135], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Facility Name']}</strong><br>
    <strong>{row['DBA']}</strong><br>
    Facility Type: {row['Facility Type']}<br>
    {row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip Code']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_dispensaries_map_colorado_springs.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3511de9e559e2252939fe2964bc94469 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3511de9e559e2252939fe2964bc94469&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3511de9e559e2252939fe2964bc94469 = L.map(
#                 &quot;map_3511de9e559e2252939fe2964bc94469&quot;,
#                 {
#                     center: [38.8591, -104.8135],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_13697c158ca90421510bca033f7e3cdb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_13697c158ca90421510bca033f7e3cdb.addTo(map_3511de9e559e2252939fe2964bc94469);
#
#
#             var marker_1d37d13d27c250c48df6b67d9c9f6801 = L.marker(
#                 [38.8195171, -104.8154896],
#                 {}
#             ).addTo(map_3511de9e559e2252939fe2964bc94469);
#
#
#             var icon_383ee95247b1be6e0cc72da8810937cc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1d37d13d27c250c48df6b67d9c9f6801.setIcon(icon_383ee95247b1be6e0cc72da8810937cc);
#
#
#         var popup_20de7fff92158f359ac1a6e3feea8f56 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a3e2d4ad6fa9e873571407dfe5a37265 = $(`&lt;div id=&quot;html_a3e2d4ad6fa9e873571407dfe5a37265&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;1022 S ROYER LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Hightops&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Store&lt;br&gt;     1022 South Royer Street&lt;br&gt;     Colorado Springs, CO 80903     &lt;/div&gt;`)[0];
#                 popup_20de7fff92158f359ac1a6e3feea8f56.setContent(html_a3e2d4ad6fa9e873571407dfe5a37265);
#
#
#
#         marker_1d37d13d27c250c48df6b67d9c9f6801.bindPopup(popup_20de7fff92158f359ac1a6e3feea8f56)
#         ;
#
#
#
#
#             var marker_d0a78e81bdf494651ef6ee83d119fbbd = L.marker(
#                 [38.863467, -104.720079],
#                 {}
#             ).addTo(map_3511de9e559e2252939fe2964bc94469);
#
#
#             var icon_74b98a3805fa27e711ac9dab49489f08 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d0a78e81bdf494651ef6ee83d119fbbd.setIcon(icon_74b98a3805fa27e711ac9dab49489f08);
#
#
#         var popup_29b0ecddb79678a68a90f0421050dac5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3cc4138bd055515c17231ee9e43566df = $(`&lt;div id=&quot;html_3cc4138bd055515c17231ee9e43566df&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;2306 N POWERS LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Hightops&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Store&lt;br&gt;     2306 North Powers Frontage Road, Suite 100&lt;br&gt;     Colorado Springs, CO 80915     &lt;/div&gt;`)[0];
#                 popup_29b0ecddb79678a68a90f0421050dac5.setContent(html_3cc4138bd055515c17231ee9e43566df);
#
#
#
#         marker_d0a78e81bdf494651ef6ee83d119fbbd.bindPopup(popup_29b0ecddb79678a68a90f0421050dac5)
#         ;
#
#
#
#
#             var marker_dc193f3274191b6446f510b711103356 = L.marker(
#                 [38.8781548, -104.8183845],
#                 {}
#             ).addTo(map_3511de9e559e2252939fe2964bc94469);
#
#
#             var icon_8610128384fffeb9e834b6608cfa56ea = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_dc193f3274191b6446f510b711103356.setIcon(icon_8610128384fffeb9e834b6608cfa56ea);
#
#
#         var popup_e76b19e87ddce9e09bdc4e84a41441a6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0e1643583abc211cf70e84939ba5cdc6 = $(`&lt;div id=&quot;html_0e1643583abc211cf70e84939ba5cdc6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;4 ROSES LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Bleezies&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Store&lt;br&gt;     3234 North Nevada Avenue&lt;br&gt;     Colorado Springs, CO 80907     &lt;/div&gt;`)[0];

# %%
# Example: Search for dispensaries in a specific city
city_search = "Aurora"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[39.7108, -104.8125], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Facility Name']}</strong><br>
    <strong>{row['DBA']}</strong><br>
    Facility Type: {row['Facility Type']}<br>
    {row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip Code']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_dispensaries_map_aurora.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f4bd9045d4c65f49a049cc5346257f8c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f4bd9045d4c65f49a049cc5346257f8c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f4bd9045d4c65f49a049cc5346257f8c = L.map(
#                 &quot;map_f4bd9045d4c65f49a049cc5346257f8c&quot;,
#                 {
#                     center: [39.7108, -104.8125],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d7e133590420bdb3bd817dd4d682d54d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d7e133590420bdb3bd817dd4d682d54d.addTo(map_f4bd9045d4c65f49a049cc5346257f8c);
#
#
#             var marker_207caede85e89a6cdee74ce88e335175 = L.marker(
#                 [39.7250311, -104.8124222],
#                 {}
#             ).addTo(map_f4bd9045d4c65f49a049cc5346257f8c);
#
#
#             var icon_2bed87136132b2e9bac05dcf03ab5969 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_207caede85e89a6cdee74ce88e335175.setIcon(icon_2bed87136132b2e9bac05dcf03ab5969);
#
#
#         var popup_a3a8e5d9c2341df3e79e7915cd48c90e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c6578f9030090d116e76cde6ac3a82dc = $(`&lt;div id=&quot;html_c6578f9030090d116e76cde6ac3a82dc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;BROW ACQUISITIONS AURORA LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Xclusive Cannabis&lt;/strong&gt;&lt;br&gt;     Facility Type: Retail Marijuana Store&lt;br&gt;     15200 East 6th Avenue Unit 1&lt;br&gt;     Aurora, CO 80011     &lt;/div&gt;`)[0];
#                 popup_a3a8e5d9c2341df3e79e7915cd48c90e.setContent(html_c6578f9030090d116e76cde6ac3a82dc);
#
#
#
#         marker_207caede85e89a6cdee74ce88e335175.bindPopup(popup_a3a8e5d9c2341df3e79e7915cd48c90e)
#         ;
#
#
#
#
#             var marker_c989bcec1cbd516467e8066fc0a13cef = L.marker(
#                 [39.7632007, -104.8495745],
#                 {}
#             ).addTo(map_f4bd9045d4c65f49a049cc5346257f8c);
#
#
#             var icon_2e4c0df643735f869fba2fd703f4efb9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c989bcec1cbd516467e8066fc0a13cef.setIcon(icon_2e4c0df643735f869fba2fd703f4efb9);
#
#
#         var popup_6380803ab5fba5fc6f5b466f9aa8b824 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7dfbb43db7017d48e8f15d67b6ac573c = $(`&lt;div id=&quot;html_7dfbb43db7017d48e8f15d67b6ac573c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;CANNA CLUB LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Best Buds&lt;/strong&gt;&lt;br&gt;     Facility Type: Retail Marijuana Store&lt;br&gt;     11900 East 33rd Avenue, Suite 1&lt;br&gt;     Aurora, CO 80010     &lt;/div&gt;`)[0];
#                 popup_6380803ab5fba5fc6f5b466f9aa8b824.setContent(html_7dfbb43db7017d48e8f15d67b6ac573c);
#
#
#
#         marker_c989bcec1cbd516467e8066fc0a13cef.bindPopup(popup_6380803ab5fba5fc6f5b466f9aa8b824)
#         ;
#
#
#
#
#             var marker_817ca26436c7f57a1a15e2d4a6164987 = L.marker(
#                 [39.7234623, -104.8660225],
#                 {}
#             ).addTo(map_f4bd9045d4c65f49a049cc5346257f8c);
#
#
#             var icon_c0dc8942f4599bebfa0716e10418de5a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_817ca26436c7f57a1a15e2d4a6164987.setIcon(icon_c0dc8942f4599bebfa0716e10418de5a);
#
#
#         var popup_42da4ea3e5f7299fe37061e530828240 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8920643d6f3063928a2d908cab6e5fd1 = $(`&lt;div id=&quot;html_8920643d6f3063928a2d908cab6e5fd1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;DOUBLE BROW LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Emerald Fields&lt;/strong&gt;&lt;br&gt;     Facility Type: Retail Marijuana Store&lt;br&gt;     503 Havana Street&lt;br&gt;     Aurora, CO 80010     &lt;/div&gt;`)[0];

# %%
# Example: Search for dispensaries in a specific city
city_search = "Fort Collins"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[40.5853, -105.0844], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Facility Name']}</strong><br>
    <strong>{row['DBA']}</strong><br>
    Facility Type: {row['Facility Type']}<br>
    {row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip Code']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_dispensaries_map_fort_collins.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4dd56f1a5611eb3cf3d8e92f7f872aae {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4dd56f1a5611eb3cf3d8e92f7f872aae&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4dd56f1a5611eb3cf3d8e92f7f872aae = L.map(
#                 &quot;map_4dd56f1a5611eb3cf3d8e92f7f872aae&quot;,
#                 {
#                     center: [40.5853, -105.0844],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_07ced950e66e8704bfbc02a9713868d1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_07ced950e66e8704bfbc02a9713868d1.addTo(map_4dd56f1a5611eb3cf3d8e92f7f872aae);
#
#
#             var marker_c2ee203cc4eb386eb16cb8ea84b14e85 = L.marker(
#                 [40.5738399, -105.0473852],
#                 {}
#             ).addTo(map_4dd56f1a5611eb3cf3d8e92f7f872aae);
#
#
#             var icon_474a4e1a473f8eb23effed9f61dc0ea5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c2ee203cc4eb386eb16cb8ea84b14e85.setIcon(icon_474a4e1a473f8eb23effed9f61dc0ea5);
#
#
#         var popup_6c0687e144c447577d9c47435bb4e53e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b0733b65bfa29509409fe583f04045b3 = $(`&lt;div id=&quot;html_b0733b65bfa29509409fe583f04045b3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;ACES PLACE LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;nan&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Store&lt;br&gt;     1101 Academy Court, Unit 4&lt;br&gt;     Fort Collins, CO 80524     &lt;/div&gt;`)[0];
#                 popup_6c0687e144c447577d9c47435bb4e53e.setContent(html_b0733b65bfa29509409fe583f04045b3);
#
#
#
#         marker_c2ee203cc4eb386eb16cb8ea84b14e85.bindPopup(popup_6c0687e144c447577d9c47435bb4e53e)
#         ;
#
#
#
#
#             var marker_797bdaa5fcc56503b695b4cfd7bb1bc8 = L.marker(
#                 [40.577109, -105.003324],
#                 {}
#             ).addTo(map_4dd56f1a5611eb3cf3d8e92f7f872aae);
#
#
#             var icon_c02b99f3ab5890572f26be6182aed600 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_797bdaa5fcc56503b695b4cfd7bb1bc8.setIcon(icon_c02b99f3ab5890572f26be6182aed600);
#
#
#         var popup_e94cd14a4a727a8cde4f62d65878f557 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e4f6149bdbd251ab97c6a10630c37ea4 = $(`&lt;div id=&quot;html_e4f6149bdbd251ab97c6a10630c37ea4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;CHOICE ORGANICS INC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Green Dragon&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Store&lt;br&gt;     813 Smithfield Drive, Units A &amp; B&lt;br&gt;     Fort Collins, CO 80524     &lt;/div&gt;`)[0];
#                 popup_e94cd14a4a727a8cde4f62d65878f557.setContent(html_e4f6149bdbd251ab97c6a10630c37ea4);
#
#
#
#         marker_797bdaa5fcc56503b695b4cfd7bb1bc8.bindPopup(popup_e94cd14a4a727a8cde4f62d65878f557)
#         ;
#
#
#
#
#             var marker_d8c8c62418d2f2de33d02e2ca37c5c61 = L.marker(
#                 [40.5763751, -105.0767149],
#                 {}
#             ).addTo(map_4dd56f1a5611eb3cf3d8e92f7f872aae);
#
#
#             var icon_68975955560bb41f08a11bdf8bf77153 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d8c8c62418d2f2de33d02e2ca37c5c61.setIcon(icon_68975955560bb41f08a11bdf8bf77153);
#
#
#         var popup_72b2e102ccbcce57c16603759709b528 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2f0b69da0fe68b10a04c407c2131b644 = $(`&lt;div id=&quot;html_2f0b69da0fe68b10a04c407c2131b644&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;DP RETAIL 100 LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Green Dragon&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Store&lt;br&gt;     804 South College Avenue&lt;br&gt;     Fort Collins, CO 80524     &lt;/div&gt;`)[0];

# %%
# Example: Search for dispensaries in a specific city
city_search = "Lakewood"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[39.7109, -105.0815], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Facility Name']}</strong><br>
    <strong>{row['DBA']}</strong><br>
    Facility Type: {row['Facility Type']}<br>
    {row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip Code']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_dispensaries_map_lakewood.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b96bd42d4ff985919c9c623d12e1871d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b96bd42d4ff985919c9c623d12e1871d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b96bd42d4ff985919c9c623d12e1871d = L.map(
#                 &quot;map_b96bd42d4ff985919c9c623d12e1871d&quot;,
#                 {
#                     center: [39.7109, -105.0815],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_986051ba9625f11c97623e5adc618bb9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_986051ba9625f11c97623e5adc618bb9.addTo(map_b96bd42d4ff985919c9c623d12e1871d);
#
#
#             var marker_c8d5319c984e4b2dc71b0ec38dbdab1e = L.marker(
#                 [39.7403205, -105.1162959],
#                 {}
#             ).addTo(map_b96bd42d4ff985919c9c623d12e1871d);
#
#
#             var icon_2e45926c4edff99ab1fd90a7a2d03cfb = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c8d5319c984e4b2dc71b0ec38dbdab1e.setIcon(icon_2e45926c4edff99ab1fd90a7a2d03cfb);
#
#
#         var popup_b6c6d1d82a6e75ed5f4536df3154f685 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4e335a019b9ceb05a06459bdc9500b0c = $(`&lt;div id=&quot;html_4e335a019b9ceb05a06459bdc9500b0c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;CPM LAKEWOOD LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Ajoya Medical Cannabis&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Store&lt;br&gt;     10590 West Colfax Avenue&lt;br&gt;     Lakewood, CO 80215     &lt;/div&gt;`)[0];
#                 popup_b6c6d1d82a6e75ed5f4536df3154f685.setContent(html_4e335a019b9ceb05a06459bdc9500b0c);
#
#
#
#         marker_c8d5319c984e4b2dc71b0ec38dbdab1e.bindPopup(popup_b6c6d1d82a6e75ed5f4536df3154f685)
#         ;
#
#
#
#
#             var marker_63e4e8d450b75a86adf0d84896902a7f = L.marker(
#                 [39.682017, -105.1293189],
#                 {}
#             ).addTo(map_b96bd42d4ff985919c9c623d12e1871d);
#
#
#             var icon_b0319b28e788f029f4acb1f66cd0f547 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_63e4e8d450b75a86adf0d84896902a7f.setIcon(icon_b0319b28e788f029f4acb1f66cd0f547);
#
#
#         var popup_1883d831b77519c6e27f102106eccd90 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_265cdbf06af8f757f0f0888293f5ea79 = $(`&lt;div id=&quot;html_265cdbf06af8f757f0f0888293f5ea79&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;D &amp; D CONSULTING INC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Kaya Cannabis&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Store&lt;br&gt;     12018 West Jewell Avenue, Unit B &amp; C&lt;br&gt;     Lakewood, CO 80228     &lt;/div&gt;`)[0];
#                 popup_1883d831b77519c6e27f102106eccd90.setContent(html_265cdbf06af8f757f0f0888293f5ea79);
#
#
#
#         marker_63e4e8d450b75a86adf0d84896902a7f.bindPopup(popup_1883d831b77519c6e27f102106eccd90)
#         ;
#
#
#
#
#             var marker_e4aa223d035523e06ce24d53e7530067 = L.marker(
#                 [39.7403904, -105.0910718],
#                 {}
#             ).addTo(map_b96bd42d4ff985919c9c623d12e1871d);
#
#
#             var icon_5eae6cee5c2b8a910cafe5fd687d7042 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e4aa223d035523e06ce24d53e7530067.setIcon(icon_5eae6cee5c2b8a910cafe5fd687d7042);
#
#
#         var popup_00b9713ecebae4df32a722a8af6855b0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_84a9b090813a8436bce88e96736c70f6 = $(`&lt;div id=&quot;html_84a9b090813a8436bce88e96736c70f6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;DENVER COMPASSIONATE CAREGIVERS INC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Rocky Mountain High&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Store&lt;br&gt;     8420 West Colfax Avenue&lt;br&gt;     Lakew

# %%
# Example: Search for dispensaries in a specific city
city_search = "Arvada"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[39.8028, -105.0875], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Facility Name']}</strong><br>
    <strong>{row['DBA']}</strong><br>
    Facility Type: {row['Facility Type']}<br>
    {row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip Code']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_dispensaries_map_arvada.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_66616c185863003e57a97d7b13d1f961 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_66616c185863003e57a97d7b13d1f961&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_66616c185863003e57a97d7b13d1f961 = L.map(
#                 &quot;map_66616c185863003e57a97d7b13d1f961&quot;,
#                 {
#                     center: [39.8028, -105.0875],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e1ba4055408c88ec03ba44d87cfa46cc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e1ba4055408c88ec03ba44d87cfa46cc.addTo(map_66616c185863003e57a97d7b13d1f961);
#
#
#             var marker_582ca3910e824bb02e5daa48046506b1 = L.marker(
#                 [39.799578, -105.0531965],
#                 {}
#             ).addTo(map_66616c185863003e57a97d7b13d1f961);
#
#
#             var icon_585fd9c457be3c42ee48f50ab23166a1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_582ca3910e824bb02e5daa48046506b1.setIcon(icon_585fd9c457be3c42ee48f50ab23166a1);
#
#
#         var popup_392b745c16c5e0a0e1e905b211aa3294 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3d8117421eadf0bfc13ed39be50706ed = $(`&lt;div id=&quot;html_3d8117421eadf0bfc13ed39be50706ed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;YUMA WAY LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Berkeley Dispensary&lt;/strong&gt;&lt;br&gt;     Facility Type: Retail Marijuana Store&lt;br&gt;     5398 Sheridan Boulevard&lt;br&gt;     Arvada, CO 80002     &lt;/div&gt;`)[0];
#                 popup_392b745c16c5e0a0e1e905b211aa3294.setContent(html_3d8117421eadf0bfc13ed39be50706ed);
#
#
#
#         marker_582ca3910e824bb02e5daa48046506b1.bindPopup(popup_392b745c16c5e0a0e1e905b211aa3294)
#         ;
#
#
#
#
#             tile_layer_e1ba4055408c88ec03ba44d87cfa46cc.addTo(map_66616c185863003e57a97d7b13d1f961);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Example: Search for dispensaries in a specific city
city_search = "Garden City"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[40.4233, -104.7112], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Facility Name']}</strong><br>
    <strong>{row['DBA']}</strong><br>
    Facility Type: {row['Facility Type']}<br>
    {row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip Code']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_dispensaries_map_garden_city.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8f1a54e6b3f0958dee186a961aa3bf4d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8f1a54e6b3f0958dee186a961aa3bf4d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8f1a54e6b3f0958dee186a961aa3bf4d = L.map(
#                 &quot;map_8f1a54e6b3f0958dee186a961aa3bf4d&quot;,
#                 {
#                     center: [40.4233, -104.7112],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6bdfa09a84af0deedf306f1ac6bd7bc9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_6bdfa09a84af0deedf306f1ac6bd7bc9.addTo(map_8f1a54e6b3f0958dee186a961aa3bf4d);
#
#
#             var marker_5f25dac532c2c648a5c654adaf3fd358 = L.marker(
#                 [40.393964, -104.6918421],
#                 {}
#             ).addTo(map_8f1a54e6b3f0958dee186a961aa3bf4d);
#
#
#             var icon_1bcf2a1be5d68df357b4a2756c488642 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5f25dac532c2c648a5c654adaf3fd358.setIcon(icon_1bcf2a1be5d68df357b4a2756c488642);
#
#
#         var popup_8f1cfd73ec67ac14d0aabf9af755c838 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ee1ede90b27a23ab61493a6d05a6d751 = $(`&lt;div id=&quot;html_ee1ede90b27a23ab61493a6d05a6d751&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;LIVWELL I LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;LivWell&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Store&lt;br&gt;     2647 8th Avenue, Unit B&lt;br&gt;     Garden City, CO 80631     &lt;/div&gt;`)[0];
#                 popup_8f1cfd73ec67ac14d0aabf9af755c838.setContent(html_ee1ede90b27a23ab61493a6d05a6d751);
#
#
#
#         marker_5f25dac532c2c648a5c654adaf3fd358.bindPopup(popup_8f1cfd73ec67ac14d0aabf9af755c838)
#         ;
#
#
#
#
#             var marker_00a05b159c9212e373c89b30ba4c69db = L.marker(
#                 [40.3944806, -104.6866871],
#                 {}
#             ).addTo(map_8f1a54e6b3f0958dee186a961aa3bf4d);
#
#
#             var icon_3028f740b7002d3f350fc93e163b445f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_00a05b159c9212e373c89b30ba4c69db.setIcon(icon_3028f740b7002d3f350fc93e163b445f);
#
#
#         var popup_16e8ca03f6ad41df24b76a59e30cb14b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0b708bc64421899257e241b131be68a1 = $(`&lt;div id=&quot;html_0b708bc64421899257e241b131be68a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;NATURES HERBS &amp; WELLNESS CENTER&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Nature&#x27;s Herbs &amp; Wellness Center&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Store&lt;br&gt;     540 27th Street&lt;br&gt;     Garden City, CO 80631     &lt;/div&gt;`)[0];
#                 popup_16e8ca03f6ad41df24b76a59e30cb14b.setContent(html_0b708bc64421899257e241b131be68a1);
#
#
#
#         marker_00a05b159c9212e373c89b30ba4c69db.bindPopup(popup_16e8ca03f6ad41df24b76a59e30cb14b)
#         ;
#
#
#
#
#             var marker_745230f73e8e6bd12b48b3ee43718a9c = L.marker(
#                 [40.3971411, -104.691015],
#                 {}
#             ).addTo(map_8f1a54e6b3f0958dee186a961aa3bf4d);
#
#
#             var icon_7f1ab1f674a35630f54b551d580f6cdf = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_745230f73e8e6bd12b48b3ee43718a9c.setIcon(icon_7f1ab1f674a35630f54b551d580f6cdf);
#
#
#         var popup_5375246d25b08e8d1d98500a07688cd4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c49761c2045693114915ebf93b4159d0 = $(`&lt;div id=&quot;html_c49761c2045693114915ebf93b4159d0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;SMOKE HOLDCO LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Star Buds&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Store&lt;br&gt;     2502 8th Avenue&lt;br&gt;     Garden City, CO 80631     &lt;/div&gt;`)[0

# %%
# Example: Search for dispensaries in a specific city
city_search = "Pueblo"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[38.2765, -104.6046], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Facility Name']}</strong><br>
    <strong>{row['DBA']}</strong><br>
    Facility Type: {row['Facility Type']}<br>
    {row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip Code']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_dispensaries_map_pueblo.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1bb0208252e0e6b1d4e8465612290fba {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1bb0208252e0e6b1d4e8465612290fba&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1bb0208252e0e6b1d4e8465612290fba = L.map(
#                 &quot;map_1bb0208252e0e6b1d4e8465612290fba&quot;,
#                 {
#                     center: [38.2765, -104.6046],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6aa9890ac53656c56f14a89341210842 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_6aa9890ac53656c56f14a89341210842.addTo(map_1bb0208252e0e6b1d4e8465612290fba);
#
#
#             var marker_36949f1c9bc11ec22fafe931545437dd = L.marker(
#                 [38.2499983, -104.6012742],
#                 {}
#             ).addTo(map_1bb0208252e0e6b1d4e8465612290fba);
#
#
#             var icon_535ce562639a4cb08c09812a2c223ebb = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_36949f1c9bc11ec22fafe931545437dd.setIcon(icon_535ce562639a4cb08c09812a2c223ebb);
#
#
#         var popup_13ff3344e41b4e05fc3d11001d615bcf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_89232be6acca7d3bc9c999b0cecc9340 = $(`&lt;div id=&quot;html_89232be6acca7d3bc9c999b0cecc9340&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;AF INC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Apothecary Farms&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Store&lt;br&gt;     1917 Santa Fe Drive&lt;br&gt;     Pueblo, CO 81006     &lt;/div&gt;`)[0];
#                 popup_13ff3344e41b4e05fc3d11001d615bcf.setContent(html_89232be6acca7d3bc9c999b0cecc9340);
#
#
#
#         marker_36949f1c9bc11ec22fafe931545437dd.bindPopup(popup_13ff3344e41b4e05fc3d11001d615bcf)
#         ;
#
#
#
#
#             var marker_94e545e99f7eeb9ef4a1906f13df4d47 = L.marker(
#                 [38.3260135, -104.705327],
#                 {}
#             ).addTo(map_1bb0208252e0e6b1d4e8465612290fba);
#
#
#             var icon_b7ba610749b4cae3f9594002b42add45 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_94e545e99f7eeb9ef4a1906f13df4d47.setIcon(icon_b7ba610749b4cae3f9594002b42add45);
#
#
#         var popup_c84dbea6684444754134d19fed15d8c3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f6fdf1f5c8338a70acc62aba6d1162c9 = $(`&lt;div id=&quot;html_f6fdf1f5c8338a70acc62aba6d1162c9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;COLORADO DISTRIBUTING INC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;The Dispo&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Store&lt;br&gt;     893 East Enterprise Drive&lt;br&gt;     Pueblo West, CO 81007     &lt;/div&gt;`)[0];
#                 popup_c84dbea6684444754134d19fed15d8c3.setContent(html_f6fdf1f5c8338a70acc62aba6d1162c9);
#
#
#
#         marker_94e545e99f7eeb9ef4a1906f13df4d47.bindPopup(popup_c84dbea6684444754134d19fed15d8c3)
#         ;
#
#
#
#
#             var marker_16603e6931770c1e135ff371fd8eb337 = L.marker(
#                 [38.323527, -104.703985],
#                 {}
#             ).addTo(map_1bb0208252e0e6b1d4e8465612290fba);
#
#
#             var icon_2d8d4c80e9fed02f63f7555ecfeb5ba4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_16603e6931770c1e135ff371fd8eb337.setIcon(icon_2d8d4c80e9fed02f63f7555ecfeb5ba4);
#
#
#         var popup_6fc936336afeb0f85709bb75a1ecb6af = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_da9cf98e411ab92569aa335bf3be5df1 = $(`&lt;div id=&quot;html_da9cf98e411ab92569aa335bf3be5df1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;DENCO LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;nan&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Store&lt;br&gt;     922 East Kimble Drive&lt;br&gt;     Pueblo West, CO 81007     &lt;/div&gt;`)[0];
#                 popup_6fc936336afeb0f85709bb

# %%
# Example: Search for dispensaries in a specific city
city_search = "Boulder"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[40.0150, -105.2705], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Facility Name']}</strong><br>
    <strong>{row['DBA']}</strong><br>
    Facility Type: {row['Facility Type']}<br>
    {row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip Code']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_dispensaries_map_boulder.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e2d2c69363138aeb2691a48bf556c092 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e2d2c69363138aeb2691a48bf556c092&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e2d2c69363138aeb2691a48bf556c092 = L.map(
#                 &quot;map_e2d2c69363138aeb2691a48bf556c092&quot;,
#                 {
#                     center: [40.015, -105.2705],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1f0edb171a97e7211b5a30de7163331e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_1f0edb171a97e7211b5a30de7163331e.addTo(map_e2d2c69363138aeb2691a48bf556c092);
#
#
#             var marker_a945d7a2ff61032ad523373b2b083d2b = L.marker(
#                 [40.0141938, -105.227272],
#                 {}
#             ).addTo(map_e2d2c69363138aeb2691a48bf556c092);
#
#
#             var icon_2e19c6d958018d5eba5fab047a800136 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a945d7a2ff61032ad523373b2b083d2b.setIcon(icon_2e19c6d958018d5eba5fab047a800136);
#
#
#         var popup_cedb4b88514ebec2afa390f6ce519649 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8a23a8dddcf25d8c20ecc77e79b71f78 = $(`&lt;div id=&quot;html_8a23a8dddcf25d8c20ecc77e79b71f78&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;B WELL LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Boulder Built&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Store&lt;br&gt;     5420 Arapahoe Avenue, Suite F&lt;br&gt;     Boulder, CO 80303     &lt;/div&gt;`)[0];
#                 popup_cedb4b88514ebec2afa390f6ce519649.setContent(html_8a23a8dddcf25d8c20ecc77e79b71f78);
#
#
#
#         marker_a945d7a2ff61032ad523373b2b083d2b.bindPopup(popup_cedb4b88514ebec2afa390f6ce519649)
#         ;
#
#
#
#
#             var marker_52e57153ff4dc490c4d7ca3703d4283a = L.marker(
#                 [40.0190262, -105.275154],
#                 {}
#             ).addTo(map_e2d2c69363138aeb2691a48bf556c092);
#
#
#             var icon_6ef12865443f576757a10a798038387c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_52e57153ff4dc490c4d7ca3703d4283a.setIcon(icon_6ef12865443f576757a10a798038387c);
#
#
#         var popup_bfd9ef34bca200ec18b6cd2431686e6a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_950dda1919176bb6160c27e04b89fb05 = $(`&lt;div id=&quot;html_950dda1919176bb6160c27e04b89fb05&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;BIG RIVER BEND LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;The Trust Cannabis Company&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Store&lt;br&gt;     1537 Pearl Street, Suite B&lt;br&gt;     Boulder, CO 80302     &lt;/div&gt;`)[0];
#                 popup_bfd9ef34bca200ec18b6cd2431686e6a.setContent(html_950dda1919176bb6160c27e04b89fb05);
#
#
#
#         marker_52e57153ff4dc490c4d7ca3703d4283a.bindPopup(popup_bfd9ef34bca200ec18b6cd2431686e6a)
#         ;
#
#
#
#
#             var marker_a01a3d83341e934396d94bf522ddc6a1 = L.marker(
#                 [40.0146775, -105.2129051],
#                 {}
#             ).addTo(map_e2d2c69363138aeb2691a48bf556c092);
#
#
#             var icon_4e994ce19adef07677e711f5346475b8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a01a3d83341e934396d94bf522ddc6a1.setIcon(icon_4e994ce19adef07677e711f5346475b8);
#
#
#         var popup_39299a0097efcbf5e463ae05a2e8a372 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_75eb70161248767a1184d93a2011b3a3 = $(`&lt;div id=&quot;html_75eb70161248767a1184d93a2011b3a3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;BOULDER SNAX INC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Snaxland&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Store&lt;br&gt;     7464 Arapahoe Avenue, Unit A9&lt;br&gt;     Boulder, CO 80303     &lt;/div&gt;`)[0];

# %%
# Example: Search for dispensaries in a specific city
city_search = "Grand Junction"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[39.0714, -108.5497], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Facility Name']}</strong><br>
    <strong>{row['DBA']}</strong><br>
    Facility Type: {row['Facility Type']}<br>
    {row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip Code']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_dispensaries_map_grand_junction.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0b3f1dd5aa2891f3cb80fa909d48ce86 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0b3f1dd5aa2891f3cb80fa909d48ce86&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0b3f1dd5aa2891f3cb80fa909d48ce86 = L.map(
#                 &quot;map_0b3f1dd5aa2891f3cb80fa909d48ce86&quot;,
#                 {
#                     center: [39.0714, -108.5497],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a12fbf07d018e0bcc996de1df629ca8c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a12fbf07d018e0bcc996de1df629ca8c.addTo(map_0b3f1dd5aa2891f3cb80fa909d48ce86);
#
#
#             var marker_3ec6c97c586fe58a623b1a53116694c9 = L.marker(
#                 [39.104372, -108.550183],
#                 {}
#             ).addTo(map_0b3f1dd5aa2891f3cb80fa909d48ce86);
#
#
#             var icon_97dc5e3535089b9ecdb9a0cd6a1ed318 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3ec6c97c586fe58a623b1a53116694c9.setIcon(icon_97dc5e3535089b9ecdb9a0cd6a1ed318);
#
#
#         var popup_dc01b6f8a7dc12e7f6a5d7f1116d40a1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1acc071e8d9f361c99d679f295c53ec2 = $(`&lt;div id=&quot;html_1acc071e8d9f361c99d679f295c53ec2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;RJJ GRAND JUNCTION LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Native Roots Grand Junction&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Store&lt;br&gt;     683 Horizon Drive Unit 110&lt;br&gt;     Grand Junction, CO 81506     &lt;/div&gt;`)[0];
#                 popup_dc01b6f8a7dc12e7f6a5d7f1116d40a1.setContent(html_1acc071e8d9f361c99d679f295c53ec2);
#
#
#
#         marker_3ec6c97c586fe58a623b1a53116694c9.bindPopup(popup_dc01b6f8a7dc12e7f6a5d7f1116d40a1)
#         ;
#
#
#
#
#             var marker_f9512fd6e5208617527207e8c7fb9d78 = L.marker(
#                 [39.1152039, -108.5326489],
#                 {}
#             ).addTo(map_0b3f1dd5aa2891f3cb80fa909d48ce86);
#
#
#             var icon_b55e9618452ba4613dd7d0f1799bee90 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f9512fd6e5208617527207e8c7fb9d78.setIcon(icon_b55e9618452ba4613dd7d0f1799bee90);
#
#
#         var popup_5635797fc7c340bd1ff80fa543149e80 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_39481fce9192784d789a78c0ebd00968 = $(`&lt;div id=&quot;html_39481fce9192784d789a78c0ebd00968&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;CAMCAP LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Grand Junction Greenery&lt;/strong&gt;&lt;br&gt;     Facility Type: Retail Marijuana Store&lt;br&gt;     762 Horizon Drive&lt;br&gt;     Grand Junction, CO 81506     &lt;/div&gt;`)[0];
#                 popup_5635797fc7c340bd1ff80fa543149e80.setContent(html_39481fce9192784d789a78c0ebd00968);
#
#
#
#         marker_f9512fd6e5208617527207e8c7fb9d78.bindPopup(popup_5635797fc7c340bd1ff80fa543149e80)
#         ;
#
#
#
#
#             var marker_e0c7ea174a78d03f2362187e92a64872 = L.marker(
#                 [39.041449, -108.547977],
#                 {}
#             ).addTo(map_0b3f1dd5aa2891f3cb80fa909d48ce86);
#
#
#             var icon_feba75c4823190cd3459ceb47e90b863 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e0c7ea174a78d03f2362187e92a64872.setIcon(icon_feba75c4823190cd3459ceb47e90b863);
#
#
#         var popup_fd1a98db36db30a43e520eb738905c94 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a632ac0a977a14fea03203ccb12b111c = $(`&lt;div id=&quot;html_a632ac0a977a14fea03203ccb12b111c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;CANNA CARE LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;nan&lt;/strong&gt;&lt;br&gt;     Facility Type: Retail Marijuana Store&lt;br&gt;     2730 South Highway 50&lt;br&gt;     Grand Junction, CO 81503     &lt;/div&gt;`)[0];

# %% [markdown]
# ## Step 5: Export Cleaned Data to CSV

# %%
# Export the cleaned DataFrame to a CSV file
df.to_csv("cleaned_colorado_dispensaries_full_list_v2.csv", index=False)

# Confirm the export
print("Data exported to colorado_dispensaries_full_list_v2.csv")
# Out:
# Data exported to colorado_dispensaries_full_list_v2.csv
