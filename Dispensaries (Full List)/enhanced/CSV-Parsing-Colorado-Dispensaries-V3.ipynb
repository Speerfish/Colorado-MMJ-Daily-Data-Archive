# %% [markdown]
# # Jupyter Notebook: Parsing CSV file and Visualizing Data

# %% [markdown]
# In this notebook, we will load a CSV file, convert it to a pandas DataFrame, and then create a map visualizations using folium.

# %%
pip install pandas folium
# Out:
# Requirement already satisfied: pandas in /opt/homebrew/lib/python3.11/site-packages (2.2.3)
# Requirement already satisfied: folium in /opt/homebrew/lib/python3.11/site-packages (0.17.0)
# Requirement already satisfied: numpy>=1.23.2 in /opt/homebrew/lib/python3.11/site-packages (from pandas) (2.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/ceraven/Library/Python/3.11/lib/python/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/lib/python3.11/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/homebrew/lib/python3.11/site-packages (from pandas) (2024.2)
# Requirement already satisfied: branca>=0.6.0 in /opt/homebrew/lib/python3.11/site-packages (from folium) (0.8.0)
# Requirement already satisfied: jinja2>=2.9 in /opt/homebrew/lib/python3.11/site-packages (from folium) (3.1.4)
# Requirement already satisfied: requests in /opt/homebrew/lib/python3.11/site-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in /opt/homebrew/lib/python3.11/site-packages (from folium) (2024.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/lib/python3.11/site-packages (from jinja2>=2.9->folium) (3.0.1)
# Requirement already satisfied: six>=1.5 in /Users/ceraven/Library/Python/3.11/lib/python/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/lib/python3.11/site-packages (from requests->folium) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/lib/python3.11/site-packages (from requests->folium) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/lib/python3.11/site-packages (from requests->folium) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/lib/python3.11/site-packages (from requests->folium) (2024.8.30)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import necessary libraries
import pandas as pd
import folium

# %% [markdown]
# ## Step 1: Load CSV File

# %%
# Load the CSV file into a DataFrame
file_path = "enriched_colorado_dispensaries_v3a.csv"

df = pd.read_csv(file_path)

# Optional: Display the first few rows to check if the file is loaded correctly
df.head(15)
# Out:
#    License Number                   Facility Name  \
# 0       402-01197                        1-11 LLC
# 1      402R-00581                        1-11 LLC
# 2       402-00116                1022 S ROYER LLC
# 3      402R-00739                       10232 LLC
# 4       402-00455  11761013 COLORADO HOLDINGS LLC
# 5      402R-00587  11761013 COLORADO HOLDINGS LLC
# 6      402R-01041         1310 FACTORY CIRCLE LLC
# 7       402-00017           1617 WAZEE STREET LLC
# 8      402R-00081           1617 WAZEE STREET LLC
# 9       402-00248               2306 N POWERS LLC
# 10      402-00618                     4 ROSES LLC
# 11     402R-00698              417 COMMERCIAL LLC
# 12     402R-00438                  505 CENTER LLC
# 13     402R-01024              5403 QUEBEC ST LLC
# 14      402-00656           543 BRYANT STREET LLC
#
#                                                 DBA            Facility Type  \
# 0                                        one:eleven  Medical Marijuana Store
# 1                                        one:eleven   Retail Marijuana Store
# 2                                          Hightops  Medical Marijuana Store
# 3                                        Provisions   Retail Marijuana Store
# 4                                       A Cut Above  Medical Marijuana Store
# 5                                       A Cut Above   Retail Marijuana Store
# 6   Nature's Herbs & Wellness Center of Fort Lupton   Retail Marijuana Store
# 7                              LoDo Wellness Center  Medical Marijuana Store
# 8                              LODO WELLNESS CENTER   Retail Marijuana Store
# 9                                          Hightops  Medical Marijuana Store
# 10                                         Bleezies  Medical Marijuana Store
# 11                                         THE BUZZ   Retail Marijuana Store
# 12                        Pure Marijuana Dispensary   Retail Marijuana Store
# 13                                              NaN   Retail Marijuana Store
# 14                                         Snaxland  Medical Marijuana Store
#
#                                         Street              City State  \
# 0                             17034 Highway 17            Moffat    CO
# 1                             17034 Highway 17            Moffat    CO
# 2                      1022 South Royer Street  Colorado Springs    CO
# 3                          10232 Interstate 25        Walsenburg    CO
# 4                          1911 South Broadway            Denver    CO
# 5                          1911 South Broadway            Denver    CO
# 6                   1310 Factory Circle Unit A       Fort Lupton    CO
# 7                    1617 Wazee Street, Unit B            Denver    CO
# 8                    1617 Wazee Street, Unit B            Denver    CO
# 9   2306 North Powers Frontage Road, Suite 100  Colorado Springs    CO
# 10                    3234 North Nevada Avenue  Colorado Springs    CO
# 11                 417 North Commercial Street          Trinidad    CO
# 12                        505 West 40th Avenue            Denver    CO
# 13                          5403 Quebec Street     Commerce City    CO
# 14                           543 Bryant Street            Denver    CO
#
#     Zip Code   Latitude   Longitude  Phone-Number  \
# 0      81143  37.992955 -105.907324  719-937-7716
# 1      81143  37.992955 -105.907324  719-754-1975
# 2      80903  38.819517 -104.815490  719-597-9333
# 3      81089  37.650447 -104.786115  719-738-2062
# 4      80210  39.681864 -104.987676  720-536-8965
# 5      80210  39.681864 -104.987676  720-536-8965
# 6      80621  40.093006 -104.814095  720-712-6044
# 7      80202  39.751655 -104.999706  303-534-5020
# 8      80202  39.751655 -104.999706  303-534-5020
# 9      80915  38.863467 -104.720079  719-597-9333
# 10     80907  38.878155 -104.818384  719-698-6119
# 11     81082  37.171396 -104.506981  719-422-8261
# 12     80216  39.771809 -104.993852  303-733-9956
# 13     80022  39.837693 -104.903175      Unlisted
# 14     80204  39.724321 -105.018772  303-872-3959
#
#                                               Website
# 0                  https://www.1-eleven.com/our-story
# 1                  https://www.1-eleven.com/our-story
# 2                  https://hightopscannabis.com/menu/
# 3        https://provisionsdispensary.com/contact-us/
# 4   https://weedmaps.com/dispensaries/a-cut-above-...
# 5                   https://acadispensary.com/denver/
# 6   https://www.allbud.com/dispensaries/colorado/g...
# 7   https://www.denverdispensaries.net/place/lodo-...
# 8   https://www.denverdispensaries.net/place/lodo-...
# 9   https://weedmaps.com/dispensaries/high-tops-po...
# 10         https://bleeziescolorado.wm.store/discover
# 11         https://thebuzzdispo.com/about-us-and-info
# 12                               https://puremmj.com/
# 13                                           Unlisted
# 14                  https://snaxland.com/pages/denver

# %% [markdown]
# ## Step 2: Clean and Prepare the Data

# %%
# Check column names and data types
df.info()

# Clean any missing latitude or longitude data
df.dropna(subset=['Longitude', 'Latitude'], inplace=True)

# Optional: Check for missing values in other important columns
df.isnull().sum()

# Optional: Display the first few rows of cleaned data
df.head(15)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 998 entries, 0 to 997
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   License Number  998 non-null    object
#  1   Facility Name   998 non-null    object
#  2   DBA             841 non-null    object
#  3   Facility Type   998 non-null    object
#  4   Street          998 non-null    object
#  5   City            998 non-null    object
#  6   State           998 non-null    object
#  7   Zip Code        998 non-null    int64
#  8   Latitude        998 non-null    float64
#  9   Longitude       998 non-null    float64
#  10  Phone-Number    998 non-null    object
#  11  Website         998 non-null    object
# dtypes: float64(2), int64(1), object(9)
# memory usage: 93.7+ KB
#    License Number                   Facility Name  \
# 0       402-01197                        1-11 LLC
# 1      402R-00581                        1-11 LLC
# 2       402-00116                1022 S ROYER LLC
# 3      402R-00739                       10232 LLC
# 4       402-00455  11761013 COLORADO HOLDINGS LLC
# 5      402R-00587  11761013 COLORADO HOLDINGS LLC
# 6      402R-01041         1310 FACTORY CIRCLE LLC
# 7       402-00017           1617 WAZEE STREET LLC
# 8      402R-00081           1617 WAZEE STREET LLC
# 9       402-00248               2306 N POWERS LLC
# 10      402-00618                     4 ROSES LLC
# 11     402R-00698              417 COMMERCIAL LLC
# 12     402R-00438                  505 CENTER LLC
# 13     402R-01024              5403 QUEBEC ST LLC
# 14      402-00656           543 BRYANT STREET LLC
#
#                                                 DBA            Facility Type  \
# 0                                        one:eleven  Medical Marijuana Store
# 1                                        one:eleven   Retail Marijuana Store
# 2                                          Hightops  Medical Marijuana Store
# 3                                        Provisions   Retail Marijuana Store
# 4                                       A Cut Above  Medical Marijuana Store
# 5                                       A Cut Above   Retail Marijuana Store
# 6   Nature's Herbs & Wellness Center of Fort Lupton   Retail Marijuana Store
# 7                              LoDo Wellness Center  Medical Marijuana Store
# 8                              LODO WELLNESS CENTER   Retail Marijuana Store
# 9                                          Hightops  Medical Marijuana Store
# 10                                         Bleezies  Medical Marijuana Store
# 11                                         THE BUZZ   Retail Marijuana Store
# 12                        Pure Marijuana Dispensary   Retail Marijuana Store
# 13                                              NaN   Retail Marijuana Store
# 14                                         Snaxland  Medical Marijuana Store
#
#                                         Street              City State  \
# 0                             17034 Highway 17            Moffat    CO
# 1                             17034 Highway 17            Moffat    CO
# 2                      1022 South Royer Street  Colorado Springs    CO
# 3                          10232 Interstate 25        Walsenburg    CO
# 4                          1911 South Broadway            Denver    CO
# 5                          1911 South Broadway            Denver    CO
# 6                   1310 Factory Circle Unit A       Fort Lupton    CO
# 7                    1617 Wazee Street, Unit B            Denver    CO
# 8                    1617 Wazee Street, Unit B            Denver    CO
# 9   2306 North Powers Frontage Road, Suite 100  Colorado Springs    CO
# 10                    3234 North Nevada Avenue  Colorado Springs    CO
# 11                 417 North Commercial Street          Trinidad    CO
# 12                        505 West 40th Avenue            Denver    CO
# 13                          5403 Quebec Street     Commerce City    CO
# 14                           543 Bryant Street            Denver    CO
#
#     Zip Code   Latitude   Longitude  Phone-Number  \
# 0      81143  37.992955 -105.907324  719-937-7716
# 1      81143  37.992955 -105.907324  719-754-1975
# 2      80903  38.819517 -104.815490  719-597-9333
# 3      81089  37.650447 -104.786115  719-738-2062
# 4      80210  39.681864 -104.987676  720-536-8965
# 5      80210  39.681864 -104.987676  720-536-8965
# 6      80621  40.093006 -104.814095  720-712-6044
# 7      80202  39.751655 -104.999706  303-534-5020
# 8      80202  39.751655 -104.999706  303-534-5020
# 9      80915  38.863467 -104.720079  719-597-9333
# 10     80907  38.878155 -104.818384  719-698-6119
# 11     81082  37.171396 -104.506981  719-422-8261
# 12     80216  39.771809 -104.993852  303-733-9956
# 13     80022  39.837693 -104.903175      Unlisted
# 14     80204  39.724321 -105.018772  303-872-3959
#
#                                               Website
# 0                  https://www.1-eleven.com/our-story
# 1                  https://www.1-eleven.com/our-story
# 2                  https://hightopscannabis.com/menu/
# 3        https://provisionsdispensary.com/contact-us/
# 4   https://weedmaps.com/dispensaries/a-cut-above-...
# 5                   https://acadispensary.com/denver/
# 6   https://www.allbud.com/dispensaries/colorado/g...
# 7   https://www.denverdispensaries.net/place/lodo-...
# 8   https://www.denverdispensaries.net/place/lodo-...
# 9   https://weedmaps.com/dispensaries/high-tops-po...
# 10         https://bleeziescolorado.wm.store/discover
# 11         https://thebuzzdispo.com/about-us-and-info
# 12                               https://puremmj.com/
# 13                                           Unlisted
# 14                  https://snaxland.com/pages/denver

# %% [markdown]
# ## Step 3: Create a Searchable Map

# %%
# Initialize the map centered around Colorado
m = folium.Map(location=[39.5501, -105.7821], zoom_start=7)

# Add markers to the map for each food pantry
for idx, row in df.iterrows():
    popup_text = f"""
    <strong>{row['Facility Name']}</strong><br>
    <strong>DBA:<br>{row['DBA']}</strong><br>
    <b>Facility Type:</b><br>{row['Facility Type']}<br>
    <b>Address:</b><br>{row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip Code']}<br>
    <b>Phone:</b><br><a href="tel:{row['Phone-Number']}">{row['Phone-Number']}</a><br>
    <b>Website:</b><br><a href="{row['Website']}">{row['Facility Name']}</a><br>
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m)

# Save the map as an HTML file
m.save("colorado_dispensaries_full_list_map_v2.html")

# Display the map in the notebook
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b9e4d650b5ed81f05f0127fccfb481dc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b9e4d650b5ed81f05f0127fccfb481dc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b9e4d650b5ed81f05f0127fccfb481dc = L.map(
#                 &quot;map_b9e4d650b5ed81f05f0127fccfb481dc&quot;,
#                 {
#                     center: [39.5501, -105.7821],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1e1861d90b6d832b396220d1f441c8f5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_1e1861d90b6d832b396220d1f441c8f5.addTo(map_b9e4d650b5ed81f05f0127fccfb481dc);
#
#
#             var marker_7a50270f7d7c3ea8c846ab2d8fa69563 = L.marker(
#                 [37.992955, -105.907324],
#                 {}
#             ).addTo(map_b9e4d650b5ed81f05f0127fccfb481dc);
#
#
#             var icon_31234e71528653cde7b89d0e849e239d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7a50270f7d7c3ea8c846ab2d8fa69563.setIcon(icon_31234e71528653cde7b89d0e849e239d);
#
#
#         var popup_a68c637dcff8b7466db9c6886bc03055 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_970863c8d52196154e00fd7c3aaeac2d = $(`&lt;div id=&quot;html_970863c8d52196154e00fd7c3aaeac2d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;1-11 LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;DBA:&lt;br&gt;one:eleven&lt;/strong&gt;&lt;br&gt;     &lt;b&gt;Facility Type:&lt;/b&gt;&lt;br&gt;Medical Marijuana Store&lt;br&gt;     &lt;b&gt;Address:&lt;/b&gt;&lt;br&gt;17034 Highway 17&lt;br&gt;     Moffat, CO 81143&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:719-937-7716&quot;&gt;719-937-7716&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;https://www.1-eleven.com/our-story&quot;&gt;1-11 LLC&lt;/a&gt;&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_a68c637dcff8b7466db9c6886bc03055.setContent(html_970863c8d52196154e00fd7c3aaeac2d);
#
#
#
#         marker_7a50270f7d7c3ea8c846ab2d8fa69563.bindPopup(popup_a68c637dcff8b7466db9c6886bc03055)
#         ;
#
#
#
#
#             var marker_9179fd734b60c2bf3db635bc30269b12 = L.marker(
#                 [37.992955, -105.907324],
#                 {}
#             ).addTo(map_b9e4d650b5ed81f05f0127fccfb481dc);
#
#
#             var icon_324ebe6ddccd6bc5ef43e31fad0a0d31 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9179fd734b60c2bf3db635bc30269b12.setIcon(icon_324ebe6ddccd6bc5ef43e31fad0a0d31);
#
#
#         var popup_765ff053a6b301039c29d7601d009bb5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1ea213ed262a3c8d2bce0f5486e793e5 = $(`&lt;div id=&quot;html_1ea213ed262a3c8d2bce0f5486e793e5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;1-11 LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;DBA:&lt;br&gt;one:eleven&lt;/strong&gt;&lt;br&gt;     &lt;b&gt;Facility Type:&lt;/b&gt;&lt;br&gt;Retail Marijuana Store&lt;br&gt;     &lt;b&gt;Address:&lt;/b&gt;&lt;br&gt;17034 Highway 17&lt;br&gt;     Moffat, CO 81143&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:719-754-1975&quot;&gt;719-754-1975&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;https://www.1-eleven.com/our-story&quot;&gt;1-11 LLC&lt;/a&gt;&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_765ff053a6b301039c29d7601d009bb5.setContent(html_1ea213ed262a3c8d2bce0f5486e793e5);
#
#
#
#         marker_9179fd734b60c2bf3db635bc30269b12.bindPopup(popup_765ff053a6b301039c29d7601d009bb5)
#         ;
#
#
#
#
#             var marker_845f2cfc246116977b12cdb48b70eed9 = L.marker(
#                 [38.8195171, -104.8154896],
#                 {}
#             ).addTo(map_b9e4d650b5ed81f05f0127fccfb481dc);
#
#
#             var icon_5e642e8d525f6f9fa25c5a0274036a38 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_845f2cfc246116977b12cdb48b70eed9.setIcon(icon_5e64

# %% [markdown]
# ## Step 4: Implement Search Functionality

# %%
# Example: Search for dispensaries in a specific city
city_search = "Denver"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[39.5501, -105.7821], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Facility Name']}</strong><br>
    <strong>DBA:<br>{row['DBA']}</strong><br>
    <b>Facility Type:</b><br>{row['Facility Type']}<br>
    <b>Address:</b><br>{row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip Code']}<br>
    <b>Phone:</b><br><a href="tel:{row['Phone-Number']}">{row['Phone-Number']}</a><br>
    <b>Website:</b><br><a href="{row['Website']}">{row['Facility Name']}</a><br>
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_dispensaries_map_denver_v2.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5e2aede639a07190b76db0fbb1b6a0f1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5e2aede639a07190b76db0fbb1b6a0f1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5e2aede639a07190b76db0fbb1b6a0f1 = L.map(
#                 &quot;map_5e2aede639a07190b76db0fbb1b6a0f1&quot;,
#                 {
#                     center: [39.5501, -105.7821],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f516597e44dc0b3a9d3f023d44027638 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f516597e44dc0b3a9d3f023d44027638.addTo(map_5e2aede639a07190b76db0fbb1b6a0f1);
#
#
#             var marker_4d788b1c945f194cb93200125f2150c5 = L.marker(
#                 [39.6818644, -104.987676],
#                 {}
#             ).addTo(map_5e2aede639a07190b76db0fbb1b6a0f1);
#
#
#             var icon_c4e17a91f3b7d2d710d4a7ad8b47de1d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4d788b1c945f194cb93200125f2150c5.setIcon(icon_c4e17a91f3b7d2d710d4a7ad8b47de1d);
#
#
#         var popup_65bc48067487b07fabacac6ad4462184 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9f35658650605cc1820bd088f2ad78c8 = $(`&lt;div id=&quot;html_9f35658650605cc1820bd088f2ad78c8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;11761013 COLORADO HOLDINGS LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;DBA:&lt;br&gt;A Cut Above&lt;/strong&gt;&lt;br&gt;     &lt;b&gt;Facility Type:&lt;/b&gt;&lt;br&gt;Medical Marijuana Store&lt;br&gt;     &lt;b&gt;Address:&lt;/b&gt;&lt;br&gt;1911 South Broadway&lt;br&gt;     Denver, CO 80210&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:720-536-8965&quot;&gt;720-536-8965&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;https://weedmaps.com/dispensaries/a-cut-above-denver?page=3&quot;&gt;11761013 COLORADO HOLDINGS LLC&lt;/a&gt;&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_65bc48067487b07fabacac6ad4462184.setContent(html_9f35658650605cc1820bd088f2ad78c8);
#
#
#
#         marker_4d788b1c945f194cb93200125f2150c5.bindPopup(popup_65bc48067487b07fabacac6ad4462184)
#         ;
#
#
#
#
#             var marker_fb5fe6f39bae73191247e35939edc40a = L.marker(
#                 [39.6818644, -104.987676],
#                 {}
#             ).addTo(map_5e2aede639a07190b76db0fbb1b6a0f1);
#
#
#             var icon_ae274b72a037a8f47d6e07c764b31181 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_fb5fe6f39bae73191247e35939edc40a.setIcon(icon_ae274b72a037a8f47d6e07c764b31181);
#
#
#         var popup_59063abb7edd95a6711830e5df8d5487 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_37a88b985dac3f93cce1819786a4ef1f = $(`&lt;div id=&quot;html_37a88b985dac3f93cce1819786a4ef1f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;11761013 COLORADO HOLDINGS LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;DBA:&lt;br&gt;A Cut Above&lt;/strong&gt;&lt;br&gt;     &lt;b&gt;Facility Type:&lt;/b&gt;&lt;br&gt;Retail Marijuana Store&lt;br&gt;     &lt;b&gt;Address:&lt;/b&gt;&lt;br&gt;1911 South Broadway&lt;br&gt;     Denver, CO 80210&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:720-536-8965&quot;&gt;720-536-8965&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;https://acadispensary.com/denver/&quot;&gt;11761013 COLORADO HOLDINGS LLC&lt;/a&gt;&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_59063abb7edd95a6711830e5df8d5487.setContent(html_37a88b985dac3f93cce1819786a4ef1f);
#
#
#
#         marker_fb5fe6f39bae73191247e35939edc40a.bindPopup(popup_59063abb7edd95a6711830e5df8d5487)
#         ;
#
#
#
#
#             var marker_84c0398453cada2e346c33da5df3d17f = L.marker(
#                 [39.7516552, -104.9997063],
#                 {}
#             ).addTo(map_5e2aede639a07190b76db0fbb1b6a0f1);
#
#
#             var icon_b7805df40b31d50d2cef06bdfbff236b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot

# %%
# Example: Search for dispensaries in a specific city
city_search = "Colorado Springs"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[38.8591, -104.8135], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Facility Name']}</strong><br>
    <strong>DBA:<br>{row['DBA']}</strong><br>
    <b>Facility Type:</b><br>{row['Facility Type']}<br>
    <b>Address:</b><br>{row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip Code']}<br>
    <b>Phone:</b><br><a href="tel:{row['Phone-Number']}">{row['Phone-Number']}</a><br>
    <b>Website:</b><br><a href="{row['Website']}">{row['Facility Name']}</a><br>
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_dispensaries_map_colorado_springs_v2.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d26382b606347fcd4e7ce448f1323020 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d26382b606347fcd4e7ce448f1323020&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d26382b606347fcd4e7ce448f1323020 = L.map(
#                 &quot;map_d26382b606347fcd4e7ce448f1323020&quot;,
#                 {
#                     center: [38.8591, -104.8135],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_55782013b8e872d7111d563ddce37cee = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_55782013b8e872d7111d563ddce37cee.addTo(map_d26382b606347fcd4e7ce448f1323020);
#
#
#             var marker_036a15687e8fd3a3265fab1883a2b4d2 = L.marker(
#                 [38.8195171, -104.8154896],
#                 {}
#             ).addTo(map_d26382b606347fcd4e7ce448f1323020);
#
#
#             var icon_3ae0eba85404323684d309faeeda7604 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_036a15687e8fd3a3265fab1883a2b4d2.setIcon(icon_3ae0eba85404323684d309faeeda7604);
#
#
#         var popup_bfd1384ef2ab56729629bd0f4a902450 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1e6b25902e0d572c2aa7393ef2bdcefe = $(`&lt;div id=&quot;html_1e6b25902e0d572c2aa7393ef2bdcefe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;1022 S ROYER LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;DBA:&lt;br&gt;Hightops&lt;/strong&gt;&lt;br&gt;     &lt;b&gt;Facility Type:&lt;/b&gt;&lt;br&gt;Medical Marijuana Store&lt;br&gt;     &lt;b&gt;Address:&lt;/b&gt;&lt;br&gt;1022 South Royer Street&lt;br&gt;     Colorado Springs, CO 80903&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:719-597-9333&quot;&gt;719-597-9333&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;https://hightopscannabis.com/menu/&quot;&gt;1022 S ROYER LLC&lt;/a&gt;&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_bfd1384ef2ab56729629bd0f4a902450.setContent(html_1e6b25902e0d572c2aa7393ef2bdcefe);
#
#
#
#         marker_036a15687e8fd3a3265fab1883a2b4d2.bindPopup(popup_bfd1384ef2ab56729629bd0f4a902450)
#         ;
#
#
#
#
#             var marker_05e130ab47805d22c1e2ee25fbd10c46 = L.marker(
#                 [38.863467, -104.720079],
#                 {}
#             ).addTo(map_d26382b606347fcd4e7ce448f1323020);
#
#
#             var icon_fdbd71d8e9af0d0045051fb60cfddd69 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_05e130ab47805d22c1e2ee25fbd10c46.setIcon(icon_fdbd71d8e9af0d0045051fb60cfddd69);
#
#
#         var popup_e46ec83ed3a1f9a606e2d465c6cfea0c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_38a26d01223eb1bb469bae6aea335085 = $(`&lt;div id=&quot;html_38a26d01223eb1bb469bae6aea335085&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;2306 N POWERS LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;DBA:&lt;br&gt;Hightops&lt;/strong&gt;&lt;br&gt;     &lt;b&gt;Facility Type:&lt;/b&gt;&lt;br&gt;Medical Marijuana Store&lt;br&gt;     &lt;b&gt;Address:&lt;/b&gt;&lt;br&gt;2306 North Powers Frontage Road, Suite 100&lt;br&gt;     Colorado Springs, CO 80915&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:719-597-9333&quot;&gt;719-597-9333&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;https://weedmaps.com/dispensaries/high-tops-powers&quot;&gt;2306 N POWERS LLC&lt;/a&gt;&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_e46ec83ed3a1f9a606e2d465c6cfea0c.setContent(html_38a26d01223eb1bb469bae6aea335085);
#
#
#
#         marker_05e130ab47805d22c1e2ee25fbd10c46.bindPopup(popup_e46ec83ed3a1f9a606e2d465c6cfea0c)
#         ;
#
#
#
#
#             var marker_61d49c5748dd244196bbf1680380d74b = L.marker(
#                 [38.8781548, -104.8183845],
#                 {}
#             ).addTo(map_d26382b606347fcd4e7ce448f1323020);
#
#
#             var icon_d3cb0ca0bbea9285402e032c979b0802 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot

# %%
# Example: Search for dispensaries in a specific city
city_search = "Aurora"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[39.7108, -104.8125], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Facility Name']}</strong><br>
    <strong>DBA:<br>{row['DBA']}</strong><br>
    <b>Facility Type:</b><br>{row['Facility Type']}<br>
    <b>Address:</b><br>{row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip Code']}<br>
    <b>Phone:</b><br><a href="tel:{row['Phone-Number']}">{row['Phone-Number']}</a><br>
    <b>Website:</b><br><a href="{row['Website']}">{row['Facility Name']}</a><br>
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_dispensaries_map_aurora_v2.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_78d941e3b678ccc1365bb361ce89eac4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_78d941e3b678ccc1365bb361ce89eac4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_78d941e3b678ccc1365bb361ce89eac4 = L.map(
#                 &quot;map_78d941e3b678ccc1365bb361ce89eac4&quot;,
#                 {
#                     center: [39.7108, -104.8125],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_76d9b9673b6e9262d4a84b0634f43a0d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_76d9b9673b6e9262d4a84b0634f43a0d.addTo(map_78d941e3b678ccc1365bb361ce89eac4);
#
#
#             var marker_b4bf8d7f58ed92a5c736ba0334f430b2 = L.marker(
#                 [39.7250311, -104.8124222],
#                 {}
#             ).addTo(map_78d941e3b678ccc1365bb361ce89eac4);
#
#
#             var icon_35d11496b43e32a321e71042cfa188e4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b4bf8d7f58ed92a5c736ba0334f430b2.setIcon(icon_35d11496b43e32a321e71042cfa188e4);
#
#
#         var popup_f0b2dd3c4e3377a1f5a2d8c1f38363b1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0a498e3228543726304495205204c4f8 = $(`&lt;div id=&quot;html_0a498e3228543726304495205204c4f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;BROW ACQUISITIONS AURORA LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;DBA:&lt;br&gt;Xclusive Cannabis&lt;/strong&gt;&lt;br&gt;     &lt;b&gt;Facility Type:&lt;/b&gt;&lt;br&gt;Retail Marijuana Store&lt;br&gt;     &lt;b&gt;Address:&lt;/b&gt;&lt;br&gt;15200 East 6th Avenue Unit 1&lt;br&gt;     Aurora, CO 80011&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:720-738-4200&quot;&gt;720-738-4200&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;https://xclusivecannabis.com/&quot;&gt;BROW ACQUISITIONS AURORA LLC&lt;/a&gt;&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_f0b2dd3c4e3377a1f5a2d8c1f38363b1.setContent(html_0a498e3228543726304495205204c4f8);
#
#
#
#         marker_b4bf8d7f58ed92a5c736ba0334f430b2.bindPopup(popup_f0b2dd3c4e3377a1f5a2d8c1f38363b1)
#         ;
#
#
#
#
#             var marker_4a02470b6ca1d2de74ab91c61bcb8789 = L.marker(
#                 [39.7632007, -104.8495745],
#                 {}
#             ).addTo(map_78d941e3b678ccc1365bb361ce89eac4);
#
#
#             var icon_15aadab2220b3a9a920c223f6c329cd2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4a02470b6ca1d2de74ab91c61bcb8789.setIcon(icon_15aadab2220b3a9a920c223f6c329cd2);
#
#
#         var popup_b9f750436d765c772e6bf4b56cccf69c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b0f95eee69ba98591d8d8efdbb39ea3d = $(`&lt;div id=&quot;html_b0f95eee69ba98591d8d8efdbb39ea3d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;CANNA CLUB LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;DBA:&lt;br&gt;Best Buds&lt;/strong&gt;&lt;br&gt;     &lt;b&gt;Facility Type:&lt;/b&gt;&lt;br&gt;Retail Marijuana Store&lt;br&gt;     &lt;b&gt;Address:&lt;/b&gt;&lt;br&gt;11900 East 33rd Avenue, Suite 1&lt;br&gt;     Aurora, CO 80010&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:720-679-9779&quot;&gt;720-679-9779&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;https://weedmaps.com/dispensaries/best-buds-aurora-dia&quot;&gt;CANNA CLUB LLC&lt;/a&gt;&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_b9f750436d765c772e6bf4b56cccf69c.setContent(html_b0f95eee69ba98591d8d8efdbb39ea3d);
#
#
#
#         marker_4a02470b6ca1d2de74ab91c61bcb8789.bindPopup(popup_b9f750436d765c772e6bf4b56cccf69c)
#         ;
#
#
#
#
#             var marker_9852d837f855eca35e581c4e65b0e574 = L.marker(
#                 [39.7234623, -104.8660225],
#                 {}
#             ).addTo(map_78d941e3b678ccc1365bb361ce89eac4);
#
#
#             var icon_ae6b2ef7bdbdbf067f5ba7a72ff8b653 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quo

# %%
# Example: Search for dispensaries in a specific city
city_search = "Fort Collins"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[40.5853, -105.0844], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Facility Name']}</strong><br>
    <strong>DBA:<br>{row['DBA']}</strong><br>
    <b>Facility Type:</b><br>{row['Facility Type']}<br>
    <b>Address:</b><br>{row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip Code']}<br>
    <b>Phone:</b><br><a href="tel:{row['Phone-Number']}">{row['Phone-Number']}</a><br>
    <b>Website:</b><br><a href="{row['Website']}">{row['Facility Name']}</a><br>
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_dispensaries_map_fort_collins_v2.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f4d5bbe1049fac1568d0c35f54f1af2f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f4d5bbe1049fac1568d0c35f54f1af2f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f4d5bbe1049fac1568d0c35f54f1af2f = L.map(
#                 &quot;map_f4d5bbe1049fac1568d0c35f54f1af2f&quot;,
#                 {
#                     center: [40.5853, -105.0844],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_84ad3ef04a3ab7c240758550c6d99838 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_84ad3ef04a3ab7c240758550c6d99838.addTo(map_f4d5bbe1049fac1568d0c35f54f1af2f);
#
#
#             var marker_a7dfb12c010c5bb614f2fbe22ff51750 = L.marker(
#                 [40.5738399, -105.0473852],
#                 {}
#             ).addTo(map_f4d5bbe1049fac1568d0c35f54f1af2f);
#
#
#             var icon_16157ac41df28e9c379a1cd03ded4a32 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a7dfb12c010c5bb614f2fbe22ff51750.setIcon(icon_16157ac41df28e9c379a1cd03ded4a32);
#
#
#         var popup_ff2b1d49d9e38fcc9632bc793219efec = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a2a959d224eb16d9cc501f2a0b90f82f = $(`&lt;div id=&quot;html_a2a959d224eb16d9cc501f2a0b90f82f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;ACES PLACE LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;DBA:&lt;br&gt;nan&lt;/strong&gt;&lt;br&gt;     &lt;b&gt;Facility Type:&lt;/b&gt;&lt;br&gt;Medical Marijuana Store&lt;br&gt;     &lt;b&gt;Address:&lt;/b&gt;&lt;br&gt;1101 Academy Court, Unit 4&lt;br&gt;     Fort Collins, CO 80524&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:970-472-5107&quot;&gt;970-472-5107&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;https://www.acesplacefoco.com/home&quot;&gt;ACES PLACE LLC&lt;/a&gt;&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_ff2b1d49d9e38fcc9632bc793219efec.setContent(html_a2a959d224eb16d9cc501f2a0b90f82f);
#
#
#
#         marker_a7dfb12c010c5bb614f2fbe22ff51750.bindPopup(popup_ff2b1d49d9e38fcc9632bc793219efec)
#         ;
#
#
#
#
#             var marker_95796410fdf7e66b96814a765f7fb2d6 = L.marker(
#                 [40.5738399, -105.0473852],
#                 {}
#             ).addTo(map_f4d5bbe1049fac1568d0c35f54f1af2f);
#
#
#             var icon_201b274ec47f299ab513b92b2e6aaa90 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_95796410fdf7e66b96814a765f7fb2d6.setIcon(icon_201b274ec47f299ab513b92b2e6aaa90);
#
#
#         var popup_282922564b0f0b7839712473db6ac758 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bea82d5dbd2ff85a13c66a7050f4577f = $(`&lt;div id=&quot;html_bea82d5dbd2ff85a13c66a7050f4577f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;ACES PLACE LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;DBA:&lt;br&gt;nan&lt;/strong&gt;&lt;br&gt;     &lt;b&gt;Facility Type:&lt;/b&gt;&lt;br&gt;Retail Marijuana Store&lt;br&gt;     &lt;b&gt;Address:&lt;/b&gt;&lt;br&gt;1101 Academy Court, Unit 4&lt;br&gt;     Fort Collins, CO 80524&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:970-472-5107&quot;&gt;970-472-5107&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;https://www.acesplacefoco.com/home&quot;&gt;ACES PLACE LLC&lt;/a&gt;&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_282922564b0f0b7839712473db6ac758.setContent(html_bea82d5dbd2ff85a13c66a7050f4577f);
#
#
#
#         marker_95796410fdf7e66b96814a765f7fb2d6.bindPopup(popup_282922564b0f0b7839712473db6ac758)
#         ;
#
#
#
#
#             var marker_66d682e927af5f97dbf147bb8efd7876 = L.marker(
#                 [40.577109, -105.003324],
#                 {}
#             ).addTo(map_f4d5bbe1049fac1568d0c35f54f1af2f);
#
#
#             var icon_60a54ae4c7f7d92875fa256e843d2585 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_66d682

# %%
# Example: Search for dispensaries in a specific city
city_search = "Lakewood"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[39.7109, -105.0815], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Facility Name']}</strong><br>
    <strong>DBA:<br>{row['DBA']}</strong><br>
    <b>Facility Type:</b><br>{row['Facility Type']}<br>
    <b>Address:</b><br>{row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip Code']}<br>
    <b>Phone:</b><br><a href="tel:{row['Phone-Number']}">{row['Phone-Number']}</a><br>
    <b>Website:</b><br><a href="{row['Website']}">{row['Facility Name']}</a><br>
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_dispensaries_map_lakewood_v2.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_379b64226432731002424ef3dbee209f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_379b64226432731002424ef3dbee209f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_379b64226432731002424ef3dbee209f = L.map(
#                 &quot;map_379b64226432731002424ef3dbee209f&quot;,
#                 {
#                     center: [39.7109, -105.0815],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3ed6f2169e83c1c25cddbf54f40af210 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_3ed6f2169e83c1c25cddbf54f40af210.addTo(map_379b64226432731002424ef3dbee209f);
#
#
#             var marker_cfbad291f7f4306a14e5a39445e893d1 = L.marker(
#                 [39.7403205, -105.1162959],
#                 {}
#             ).addTo(map_379b64226432731002424ef3dbee209f);
#
#
#             var icon_71805f42863c4c48a4fe5d30515b65b7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_cfbad291f7f4306a14e5a39445e893d1.setIcon(icon_71805f42863c4c48a4fe5d30515b65b7);
#
#
#         var popup_e573aafa315719d1ce6c1c491856b332 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c5d39b926ff4eb1641a31925a8a2329b = $(`&lt;div id=&quot;html_c5d39b926ff4eb1641a31925a8a2329b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;CPM LAKEWOOD LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;DBA:&lt;br&gt;Ajoya Medical Cannabis&lt;/strong&gt;&lt;br&gt;     &lt;b&gt;Facility Type:&lt;/b&gt;&lt;br&gt;Medical Marijuana Store&lt;br&gt;     &lt;b&gt;Address:&lt;/b&gt;&lt;br&gt;10590 West Colfax Avenue&lt;br&gt;     Lakewood, CO 80215&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:303-232-3620&quot;&gt;303-232-3620&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;https://ajoyalife.com/dispensary-locations/lakewood&quot;&gt;CPM LAKEWOOD LLC&lt;/a&gt;&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_e573aafa315719d1ce6c1c491856b332.setContent(html_c5d39b926ff4eb1641a31925a8a2329b);
#
#
#
#         marker_cfbad291f7f4306a14e5a39445e893d1.bindPopup(popup_e573aafa315719d1ce6c1c491856b332)
#         ;
#
#
#
#
#             var marker_a9d2588c877677f091afe4e7fed80162 = L.marker(
#                 [39.7403205, -105.1162959],
#                 {}
#             ).addTo(map_379b64226432731002424ef3dbee209f);
#
#
#             var icon_55b99e33443b3bebc85a49f59f44c1ee = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a9d2588c877677f091afe4e7fed80162.setIcon(icon_55b99e33443b3bebc85a49f59f44c1ee);
#
#
#         var popup_1340de39f072b2fedb0aed0794f705b4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a5caa19c786395c16cc722e43c67b99c = $(`&lt;div id=&quot;html_a5caa19c786395c16cc722e43c67b99c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;CPM Lakewood LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;DBA:&lt;br&gt;Ajoya Medical Cannabis&lt;/strong&gt;&lt;br&gt;     &lt;b&gt;Facility Type:&lt;/b&gt;&lt;br&gt;Retail Marijuana Store&lt;br&gt;     &lt;b&gt;Address:&lt;/b&gt;&lt;br&gt;10590 West Colfax Avenue&lt;br&gt;     Lakewood, CO 80215&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:303-232-3620&quot;&gt;303-232-3620&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;https://ajoyalife.com/dispensary-locations/lakewood&quot;&gt;CPM Lakewood LLC&lt;/a&gt;&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_1340de39f072b2fedb0aed0794f705b4.setContent(html_a5caa19c786395c16cc722e43c67b99c);
#
#
#
#         marker_a9d2588c877677f091afe4e7fed80162.bindPopup(popup_1340de39f072b2fedb0aed0794f705b4)
#         ;
#
#
#
#
#             var marker_78350f6d978507c09257eac1e14a5656 = L.marker(
#                 [39.682017, -105.1293189],
#                 {}
#             ).addTo(map_379b64226432731002424ef3dbee209f);
#
#
#             var icon_33bbdfce5b5e0ba09f6798aed5ac43ee = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&q

# %%
# Example: Search for dispensaries in a specific city
city_search = "Arvada"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[39.8028, -105.0875], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Facility Name']}</strong><br>
    <strong>DBA:<br>{row['DBA']}</strong><br>
    <b>Facility Type:</b><br>{row['Facility Type']}<br>
    <b>Address:</b><br>{row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip Code']}<br>
    <b>Phone:</b><br><a href="tel:{row['Phone-Number']}">{row['Phone-Number']}</a><br>
    <b>Website:</b><br><a href="{row['Website']}">{row['Facility Name']}</a><br>
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_dispensaries_map_arvada_v2.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b83f671e233f1eb68208d9328c99102f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b83f671e233f1eb68208d9328c99102f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b83f671e233f1eb68208d9328c99102f = L.map(
#                 &quot;map_b83f671e233f1eb68208d9328c99102f&quot;,
#                 {
#                     center: [39.8028, -105.0875],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_62b01257febed09d096a716b8e1128c8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_62b01257febed09d096a716b8e1128c8.addTo(map_b83f671e233f1eb68208d9328c99102f);
#
#
#             var marker_72d2b83cb5634245b1f5444ae8a7dca1 = L.marker(
#                 [39.799578, -105.0531965],
#                 {}
#             ).addTo(map_b83f671e233f1eb68208d9328c99102f);
#
#
#             var icon_71a8debdea52a547887152d0f8ba55bd = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_72d2b83cb5634245b1f5444ae8a7dca1.setIcon(icon_71a8debdea52a547887152d0f8ba55bd);
#
#
#         var popup_beafb2bc9ffc84f15aeeb79e0e1e24b2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_80bd1995d9f77d5e212c034e2311f4ce = $(`&lt;div id=&quot;html_80bd1995d9f77d5e212c034e2311f4ce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;YUMA WAY LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;DBA:&lt;br&gt;Berkeley Dispensary&lt;/strong&gt;&lt;br&gt;     &lt;b&gt;Facility Type:&lt;/b&gt;&lt;br&gt;Retail Marijuana Store&lt;br&gt;     &lt;b&gt;Address:&lt;/b&gt;&lt;br&gt;5398 Sheridan Boulevard&lt;br&gt;     Arvada, CO 80002&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:720-310-8057&quot;&gt;720-310-8057&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;https://www.leafly.com/dispensary-info/berkeley-dispensary&quot;&gt;YUMA WAY LLC&lt;/a&gt;&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_beafb2bc9ffc84f15aeeb79e0e1e24b2.setContent(html_80bd1995d9f77d5e212c034e2311f4ce);
#
#
#
#         marker_72d2b83cb5634245b1f5444ae8a7dca1.bindPopup(popup_beafb2bc9ffc84f15aeeb79e0e1e24b2)
#         ;
#
#
#
#
#             tile_layer_62b01257febed09d096a716b8e1128c8.addTo(map_b83f671e233f1eb68208d9328c99102f);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Example: Search for dispensaries in a specific city
city_search = "Garden City"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[40.4233, -104.7112], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Facility Name']}</strong><br>
    <strong>DBA:<br>{row['DBA']}</strong><br>
    <b>Facility Type:</b><br>{row['Facility Type']}<br>
    <b>Address:</b><br>{row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip Code']}<br>
    <b>Phone:</b><br><a href="tel:{row['Phone-Number']}">{row['Phone-Number']}</a><br>
    <b>Website:</b><br><a href="{row['Website']}">{row['Facility Name']}</a><br>
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_dispensaries_map_garden_city_v2.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f67d3f9b572c3c70577d506f049c1062 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f67d3f9b572c3c70577d506f049c1062&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f67d3f9b572c3c70577d506f049c1062 = L.map(
#                 &quot;map_f67d3f9b572c3c70577d506f049c1062&quot;,
#                 {
#                     center: [40.4233, -104.7112],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8f04632f304b5b6100efcf7320d4824f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_8f04632f304b5b6100efcf7320d4824f.addTo(map_f67d3f9b572c3c70577d506f049c1062);
#
#
#             var marker_58d9cd4cc0e0b96be9917251cf1bcdea = L.marker(
#                 [40.3967964, -104.6874197],
#                 {}
#             ).addTo(map_f67d3f9b572c3c70577d506f049c1062);
#
#
#             var icon_8f91ecd46d213b4e4e207218a3e5045e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_58d9cd4cc0e0b96be9917251cf1bcdea.setIcon(icon_8f91ecd46d213b4e4e207218a3e5045e);
#
#
#         var popup_1704a7427af9d963326cb13adeb3f037 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f032fddddc010400af12f1e421c93371 = $(`&lt;div id=&quot;html_f032fddddc010400af12f1e421c93371&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;HIGH PLAINZ STRAINS II LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;DBA:&lt;br&gt;nan&lt;/strong&gt;&lt;br&gt;     &lt;b&gt;Facility Type:&lt;/b&gt;&lt;br&gt;Retail Marijuana Store&lt;br&gt;     &lt;b&gt;Address:&lt;/b&gt;&lt;br&gt;2506 6th Avenue&lt;br&gt;     Garden City, CO 80631&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:970-352-4119&quot;&gt;970-352-4119&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;https://highplainz.com/our-locations/garden-city/&quot;&gt;HIGH PLAINZ STRAINS II LLC&lt;/a&gt;&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_1704a7427af9d963326cb13adeb3f037.setContent(html_f032fddddc010400af12f1e421c93371);
#
#
#
#         marker_58d9cd4cc0e0b96be9917251cf1bcdea.bindPopup(popup_1704a7427af9d963326cb13adeb3f037)
#         ;
#
#
#
#
#             var marker_23696b36899c5a681fb30ef0043db0a8 = L.marker(
#                 [40.393964, -104.6918421],
#                 {}
#             ).addTo(map_f67d3f9b572c3c70577d506f049c1062);
#
#
#             var icon_6b0bda88430281a67a87b66f32b77814 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_23696b36899c5a681fb30ef0043db0a8.setIcon(icon_6b0bda88430281a67a87b66f32b77814);
#
#
#         var popup_fc74e58a47b1172fa28e8a81a23fa791 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c3169de01019230260cf999653ea0451 = $(`&lt;div id=&quot;html_c3169de01019230260cf999653ea0451&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;LIVWELL I LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;DBA:&lt;br&gt;LivWell&lt;/strong&gt;&lt;br&gt;     &lt;b&gt;Facility Type:&lt;/b&gt;&lt;br&gt;Medical Marijuana Store&lt;br&gt;     &lt;b&gt;Address:&lt;/b&gt;&lt;br&gt;2647 8th Avenue, Unit B&lt;br&gt;     Garden City, CO 80631&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:970-616-6007&quot;&gt;970-616-6007&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;https://livwell.com/locations/colorado/garden-city&quot;&gt;LIVWELL I LLC&lt;/a&gt;&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_fc74e58a47b1172fa28e8a81a23fa791.setContent(html_c3169de01019230260cf999653ea0451);
#
#
#
#         marker_23696b36899c5a681fb30ef0043db0a8.bindPopup(popup_fc74e58a47b1172fa28e8a81a23fa791)
#         ;
#
#
#
#
#             var marker_0db257dbe29ee38d2554b58345fbb0f3 = L.marker(
#                 [40.393964, -104.6918421],
#                 {}
#             ).addTo(map_f67d3f9b572c3c70577d506f049c1062);
#
#
#             var icon_970e4ec744fde974f256af9d66b7c991 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}

# %%
# Example: Search for dispensaries in a specific city
city_search = "Pueblo"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[38.2765, -104.6046], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Facility Name']}</strong><br>
    <strong>DBA:<br>{row['DBA']}</strong><br>
    <b>Facility Type:</b><br>{row['Facility Type']}<br>
    <b>Address:</b><br>{row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip Code']}<br>
    <b>Phone:</b><br><a href="tel:{row['Phone-Number']}">{row['Phone-Number']}</a><br>
    <b>Website:</b><br><a href="{row['Website']}">{row['Facility Name']}</a><br>
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_dispensaries_map_pueblo_v2.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_afaa6139919cd8b22c03dc8d25f8c8a4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_afaa6139919cd8b22c03dc8d25f8c8a4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_afaa6139919cd8b22c03dc8d25f8c8a4 = L.map(
#                 &quot;map_afaa6139919cd8b22c03dc8d25f8c8a4&quot;,
#                 {
#                     center: [38.2765, -104.6046],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1a032e9e932e0e12502e291cf21a9203 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_1a032e9e932e0e12502e291cf21a9203.addTo(map_afaa6139919cd8b22c03dc8d25f8c8a4);
#
#
#             var marker_08b8a9046daefebe5796d2f88779a3e2 = L.marker(
#                 [38.2499983, -104.6012742],
#                 {}
#             ).addTo(map_afaa6139919cd8b22c03dc8d25f8c8a4);
#
#
#             var icon_6300084ab6a41b9816258def9a576623 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_08b8a9046daefebe5796d2f88779a3e2.setIcon(icon_6300084ab6a41b9816258def9a576623);
#
#
#         var popup_27d77a44d320ddd0460e28afc3097745 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_aeac5b3fcf3cc160ebe9351c8c4b0991 = $(`&lt;div id=&quot;html_aeac5b3fcf3cc160ebe9351c8c4b0991&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;AF INC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;DBA:&lt;br&gt;Apothecary Farms&lt;/strong&gt;&lt;br&gt;     &lt;b&gt;Facility Type:&lt;/b&gt;&lt;br&gt;Medical Marijuana Store&lt;br&gt;     &lt;b&gt;Address:&lt;/b&gt;&lt;br&gt;1917 Santa Fe Drive&lt;br&gt;     Pueblo, CO 81006&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:405-698-0990&quot;&gt;405-698-0990&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;https://apothecaryfarms.com/&quot;&gt;AF INC&lt;/a&gt;&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_27d77a44d320ddd0460e28afc3097745.setContent(html_aeac5b3fcf3cc160ebe9351c8c4b0991);
#
#
#
#         marker_08b8a9046daefebe5796d2f88779a3e2.bindPopup(popup_27d77a44d320ddd0460e28afc3097745)
#         ;
#
#
#
#
#             var marker_0232d7ac2bc65730a05bcc1928cc198e = L.marker(
#                 [38.326155, -104.702136],
#                 {}
#             ).addTo(map_afaa6139919cd8b22c03dc8d25f8c8a4);
#
#
#             var icon_3172621972c877ac20562dbf982212b5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0232d7ac2bc65730a05bcc1928cc198e.setIcon(icon_3172621972c877ac20562dbf982212b5);
#
#
#         var popup_2363d7a5cd115fc35b25dfa4164e100b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_68d9ca2ae70239c8f0754c4da07bc0ff = $(`&lt;div id=&quot;html_68d9ca2ae70239c8f0754c4da07bc0ff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;AF INC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;DBA:&lt;br&gt;nan&lt;/strong&gt;&lt;br&gt;     &lt;b&gt;Facility Type:&lt;/b&gt;&lt;br&gt;Retail Marijuana Store&lt;br&gt;     &lt;b&gt;Address:&lt;/b&gt;&lt;br&gt;922 East Hailey Lane Unit B&lt;br&gt;     Pueblo West, CO 81007&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:719-647-8924&quot;&gt;719-647-8924&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;https://apothecaryfarms.com/contact/apothecary-farms-pueblo-west/&quot;&gt;AF INC&lt;/a&gt;&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_2363d7a5cd115fc35b25dfa4164e100b.setContent(html_68d9ca2ae70239c8f0754c4da07bc0ff);
#
#
#
#         marker_0232d7ac2bc65730a05bcc1928cc198e.bindPopup(popup_2363d7a5cd115fc35b25dfa4164e100b)
#         ;
#
#
#
#
#             var marker_3d1094746151a09d11fedef02ab559cc = L.marker(
#                 [38.2499983, -104.6012742],
#                 {}
#             ).addTo(map_afaa6139919cd8b22c03dc8d25f8c8a4);
#
#
#             var icon_69d83bb2dee947c87eab9750891b5f34 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3d1094746151a

# %%
# Example: Search for dispensaries in a specific city
city_search = "Boulder"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[40.0150, -105.2705], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Facility Name']}</strong><br>
    <strong>DBA:<br>{row['DBA']}</strong><br>
    <b>Facility Type:</b><br>{row['Facility Type']}<br>
    <b>Address:</b><br>{row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip Code']}<br>
    <b>Phone:</b><br><a href="tel:{row['Phone-Number']}">{row['Phone-Number']}</a><br>
    <b>Website:</b><br><a href="{row['Website']}">{row['Facility Name']}</a><br>
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_dispensaries_map_boulder_v2.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c20204bc9521b1ab6adfbb45aa21b555 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c20204bc9521b1ab6adfbb45aa21b555&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c20204bc9521b1ab6adfbb45aa21b555 = L.map(
#                 &quot;map_c20204bc9521b1ab6adfbb45aa21b555&quot;,
#                 {
#                     center: [40.015, -105.2705],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_75358dc4509fecddfdf261c7cc16ea00 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_75358dc4509fecddfdf261c7cc16ea00.addTo(map_c20204bc9521b1ab6adfbb45aa21b555);
#
#
#             var marker_e95462f1257927d55561867b6c5f8c72 = L.marker(
#                 [40.0258738, -105.2848987],
#                 {}
#             ).addTo(map_c20204bc9521b1ab6adfbb45aa21b555);
#
#
#             var icon_e77caabb5c18a1372945e1facc00d129 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e95462f1257927d55561867b6c5f8c72.setIcon(icon_e77caabb5c18a1372945e1facc00d129);
#
#
#         var popup_42a9d32fd9a939a5a3c487373b6adc5c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5a182a2f87324cd3a3614dedf7028f0c = $(`&lt;div id=&quot;html_5a182a2f87324cd3a3614dedf7028f0c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;A&amp;A INVESTMENTS LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;DBA:&lt;br&gt;Eclipse Cannabis Company&lt;/strong&gt;&lt;br&gt;     &lt;b&gt;Facility Type:&lt;/b&gt;&lt;br&gt;Retail Marijuana Store&lt;br&gt;     &lt;b&gt;Address:&lt;/b&gt;&lt;br&gt;933 Alpine Avenue Suite 2&lt;br&gt;     Boulder, CO 80304&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:720-420-0782&quot;&gt;720-420-0782&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;https://eclipsecannabis.com/&quot;&gt;A&amp;A INVESTMENTS LLC&lt;/a&gt;&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_42a9d32fd9a939a5a3c487373b6adc5c.setContent(html_5a182a2f87324cd3a3614dedf7028f0c);
#
#
#
#         marker_e95462f1257927d55561867b6c5f8c72.bindPopup(popup_42a9d32fd9a939a5a3c487373b6adc5c)
#         ;
#
#
#
#
#             var marker_bfd633e7f4ea7b3d9fcbdf4a45afb75b = L.marker(
#                 [40.0323665, -105.2597227],
#                 {}
#             ).addTo(map_c20204bc9521b1ab6adfbb45aa21b555);
#
#
#             var icon_ad710f161c12697407cbf30249f3f506 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_bfd633e7f4ea7b3d9fcbdf4a45afb75b.setIcon(icon_ad710f161c12697407cbf30249f3f506);
#
#
#         var popup_482b9775974c279aaa71ca1e1d6f7014 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_efba284e012dfc063d504d7f22315431 = $(`&lt;div id=&quot;html_efba284e012dfc063d504d7f22315431&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;ALPINE RAVEN INC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;DBA:&lt;br&gt;Maikoh Holistics&lt;/strong&gt;&lt;br&gt;     &lt;b&gt;Facility Type:&lt;/b&gt;&lt;br&gt;Retail Marijuana Store&lt;br&gt;     &lt;b&gt;Address:&lt;/b&gt;&lt;br&gt;2750 Glenwood Drive, Suite 8&lt;br&gt;     Boulder, CO 80304&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:720-476-6805&quot;&gt;720-476-6805&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;https://www.maikohholistics.com/&quot;&gt;ALPINE RAVEN INC&lt;/a&gt;&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_482b9775974c279aaa71ca1e1d6f7014.setContent(html_efba284e012dfc063d504d7f22315431);
#
#
#
#         marker_bfd633e7f4ea7b3d9fcbdf4a45afb75b.bindPopup(popup_482b9775974c279aaa71ca1e1d6f7014)
#         ;
#
#
#
#
#             var marker_eef6557f561abacb3a63ccc87e0e1536 = L.marker(
#                 [40.0141938, -105.227272],
#                 {}
#             ).addTo(map_c20204bc9521b1ab6adfbb45aa21b555);
#
#
#             var icon_bd1bb3e74d8450f2b71e1b8b490f8777 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}

# %%
# Example: Search for dispensaries in a specific city
city_search = "Grand Junction"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[39.0714, -108.5497], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Facility Name']}</strong><br>
    <strong>DBA:<br>{row['DBA']}</strong><br>
    <b>Facility Type:</b><br>{row['Facility Type']}<br>
    <b>Address:</b><br>{row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip Code']}<br>
    <b>Phone:</b><br><a href="tel:{row['Phone-Number']}">{row['Phone-Number']}</a><br>
    <b>Website:</b><br><a href="{row['Website']}">{row['Facility Name']}</a><br>
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_dispensaries_map_grand_junction_v2.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_09bf31b93d02ba5afe3c57187ec975e4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_09bf31b93d02ba5afe3c57187ec975e4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_09bf31b93d02ba5afe3c57187ec975e4 = L.map(
#                 &quot;map_09bf31b93d02ba5afe3c57187ec975e4&quot;,
#                 {
#                     center: [39.0714, -108.5497],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3e7782779282a3fe0585f9e0da2d0265 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_3e7782779282a3fe0585f9e0da2d0265.addTo(map_09bf31b93d02ba5afe3c57187ec975e4);
#
#
#             var marker_dde8e156de4d1b15fcf3b3eb0a6f88ed = L.marker(
#                 [39.1152039, -108.5326489],
#                 {}
#             ).addTo(map_09bf31b93d02ba5afe3c57187ec975e4);
#
#
#             var icon_451d755ddb17bb1d8cc8a6fbcc710c35 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_dde8e156de4d1b15fcf3b3eb0a6f88ed.setIcon(icon_451d755ddb17bb1d8cc8a6fbcc710c35);
#
#
#         var popup_a751224cccb563f7548f532b6a11e6f6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1c66d31e4101e6eca0aa95a6c597aa5b = $(`&lt;div id=&quot;html_1c66d31e4101e6eca0aa95a6c597aa5b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;CAMCAP LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;DBA:&lt;br&gt;Grand Junction Greenery&lt;/strong&gt;&lt;br&gt;     &lt;b&gt;Facility Type:&lt;/b&gt;&lt;br&gt;Retail Marijuana Store&lt;br&gt;     &lt;b&gt;Address:&lt;/b&gt;&lt;br&gt;762 Horizon Drive&lt;br&gt;     Grand Junction, CO 81506&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:970-424-5888&quot;&gt;970-424-5888&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;https://grandjunctiongreenery.com/marijuana-dispensary-durango/&quot;&gt;CAMCAP LLC&lt;/a&gt;&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_a751224cccb563f7548f532b6a11e6f6.setContent(html_1c66d31e4101e6eca0aa95a6c597aa5b);
#
#
#
#         marker_dde8e156de4d1b15fcf3b3eb0a6f88ed.bindPopup(popup_a751224cccb563f7548f532b6a11e6f6)
#         ;
#
#
#
#
#             var marker_da9d6cabf82316d07619ec6777199dd1 = L.marker(
#                 [39.041449, -108.547977],
#                 {}
#             ).addTo(map_09bf31b93d02ba5afe3c57187ec975e4);
#
#
#             var icon_7ac24d62fc9e04193c0e3abc8fbdbba5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_da9d6cabf82316d07619ec6777199dd1.setIcon(icon_7ac24d62fc9e04193c0e3abc8fbdbba5);
#
#
#         var popup_60472a2557667bdd3e8720018bfef9d1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ebd98d9eafce927b0daf25b6d55a6074 = $(`&lt;div id=&quot;html_ebd98d9eafce927b0daf25b6d55a6074&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;CANNA CARE LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;DBA:&lt;br&gt;nan&lt;/strong&gt;&lt;br&gt;     &lt;b&gt;Facility Type:&lt;/b&gt;&lt;br&gt;Retail Marijuana Store&lt;br&gt;     &lt;b&gt;Address:&lt;/b&gt;&lt;br&gt;2730 South Highway 50&lt;br&gt;     Grand Junction, CO 81503&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:970-248-5874&quot;&gt;970-248-5874&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;https://www.cannacaregj.com/&quot;&gt;CANNA CARE LLC&lt;/a&gt;&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_60472a2557667bdd3e8720018bfef9d1.setContent(html_ebd98d9eafce927b0daf25b6d55a6074);
#
#
#
#         marker_da9d6cabf82316d07619ec6777199dd1.bindPopup(popup_60472a2557667bdd3e8720018bfef9d1)
#         ;
#
#
#
#
#             var marker_7faef269b2017ad99cc8153a484fe1a1 = L.marker(
#                 [39.0555307, -108.5582239],
#                 {}
#             ).addTo(map_09bf31b93d02ba5afe3c57187ec975e4);
#
#
#             var icon_5cba8411dd19d31b1b7e3cbe01cc4077 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );

# %% [markdown]
# ## Step 5: Export Cleaned Data to CSV

# %%
# Export the cleaned DataFrame to a CSV file
df.to_csv("cleaned_colorado_dispensaries_full_list_v3.csv", index=False)

# Confirm the export
print("Data exported to colorado_dispensaries_full_list_v3.csv")
# Out:
# Data exported to colorado_dispensaries_full_list_v3.csv
