# %% [markdown]
# # Jupyter Notebook: Parsing CSV file and Visualizing Data

# %% [markdown]
# In this notebook, we will load a CSV file, convert it to a pandas DataFrame, and then create a map visualizations using folium.

# %%
pip install pandas folium
# Out:
# Requirement already satisfied: pandas in /opt/homebrew/lib/python3.11/site-packages (2.2.3)
# Requirement already satisfied: folium in /opt/homebrew/lib/python3.11/site-packages (0.17.0)
# Requirement already satisfied: numpy>=1.23.2 in /opt/homebrew/lib/python3.11/site-packages (from pandas) (2.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/ceraven/Library/Python/3.11/lib/python/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/lib/python3.11/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/homebrew/lib/python3.11/site-packages (from pandas) (2024.2)
# Requirement already satisfied: branca>=0.6.0 in /opt/homebrew/lib/python3.11/site-packages (from folium) (0.8.0)
# Requirement already satisfied: jinja2>=2.9 in /opt/homebrew/lib/python3.11/site-packages (from folium) (3.1.4)
# Requirement already satisfied: requests in /opt/homebrew/lib/python3.11/site-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in /opt/homebrew/lib/python3.11/site-packages (from folium) (2024.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/lib/python3.11/site-packages (from jinja2>=2.9->folium) (3.0.1)
# Requirement already satisfied: six>=1.5 in /Users/ceraven/Library/Python/3.11/lib/python/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/lib/python3.11/site-packages (from requests->folium) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/lib/python3.11/site-packages (from requests->folium) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/lib/python3.11/site-packages (from requests->folium) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/lib/python3.11/site-packages (from requests->folium) (2024.8.30)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import necessary libraries
import pandas as pd
import folium

# %% [markdown]
# ## Step 1: Load CSV File

# %%
# Load the CSV file into a DataFrame
file_path = "enriched_colorado_dispensaries_v3a.csv"

df = pd.read_csv(file_path)

# Optional: Display the first few rows to check if the file is loaded correctly
df.head(15)
# Out:
#    License Number                   Facility Name  \
# 0       402-01197                        1-11 LLC
# 1      402R-00581                        1-11 LLC
# 2       402-00116                1022 S ROYER LLC
# 3      402R-00739                       10232 LLC
# 4       402-00455  11761013 COLORADO HOLDINGS LLC
# 5      402R-00587  11761013 COLORADO HOLDINGS LLC
# 6      402R-01041         1310 FACTORY CIRCLE LLC
# 7       402-00017           1617 WAZEE STREET LLC
# 8      402R-00081           1617 WAZEE STREET LLC
# 9       402-00248               2306 N POWERS LLC
# 10      402-00618                     4 ROSES LLC
# 11     402R-00698              417 COMMERCIAL LLC
# 12     402R-00438                  505 CENTER LLC
# 13     402R-01024              5403 QUEBEC ST LLC
# 14      402-00656           543 BRYANT STREET LLC
#
#                                                 DBA            Facility Type  \
# 0                                        one:eleven  Medical Marijuana Store
# 1                                        one:eleven   Retail Marijuana Store
# 2                                          Hightops  Medical Marijuana Store
# 3                                        Provisions   Retail Marijuana Store
# 4                                       A Cut Above  Medical Marijuana Store
# 5                                       A Cut Above   Retail Marijuana Store
# 6   Nature's Herbs & Wellness Center of Fort Lupton   Retail Marijuana Store
# 7                              LoDo Wellness Center  Medical Marijuana Store
# 8                              LODO WELLNESS CENTER   Retail Marijuana Store
# 9                                          Hightops  Medical Marijuana Store
# 10                                         Bleezies  Medical Marijuana Store
# 11                                         THE BUZZ   Retail Marijuana Store
# 12                        Pure Marijuana Dispensary   Retail Marijuana Store
# 13                                              NaN   Retail Marijuana Store
# 14                                         Snaxland  Medical Marijuana Store
#
#                                         Street              City State  \
# 0                             17034 Highway 17            Moffat    CO
# 1                             17034 Highway 17            Moffat    CO
# 2                      1022 South Royer Street  Colorado Springs    CO
# 3                          10232 Interstate 25        Walsenburg    CO
# 4                          1911 South Broadway            Denver    CO
# 5                          1911 South Broadway            Denver    CO
# 6                   1310 Factory Circle Unit A       Fort Lupton    CO
# 7                    1617 Wazee Street, Unit B            Denver    CO
# 8                    1617 Wazee Street, Unit B            Denver    CO
# 9   2306 North Powers Frontage Road, Suite 100  Colorado Springs    CO
# 10                    3234 North Nevada Avenue  Colorado Springs    CO
# 11                 417 North Commercial Street          Trinidad    CO
# 12                        505 West 40th Avenue            Denver    CO
# 13                          5403 Quebec Street     Commerce City    CO
# 14                           543 Bryant Street            Denver    CO
#
#     Zip Code   Latitude   Longitude  Phone-Number  \
# 0      81143  37.992955 -105.907324  719-937-7716
# 1      81143  37.992955 -105.907324  719-754-1975
# 2      80903  38.819517 -104.815490  719-597-9333
# 3      81089  37.650447 -104.786115  719-738-2062
# 4      80210  39.681864 -104.987676  720-536-8965
# 5      80210  39.681864 -104.987676  720-536-8965
# 6      80621  40.093006 -104.814095  720-712-6044
# 7      80202  39.751655 -104.999706  303-534-5020
# 8      80202  39.751655 -104.999706  303-534-5020
# 9      80915  38.863467 -104.720079  719-597-9333
# 10     80907  38.878155 -104.818384  719-698-6119
# 11     81082  37.171396 -104.506981  719-422-8261
# 12     80216  39.771809 -104.993852  303-733-9956
# 13     80022  39.837693 -104.903175      Unlisted
# 14     80204  39.724321 -105.018772  303-872-3959
#
#                                               Website
# 0                  https://www.1-eleven.com/our-story
# 1                  https://www.1-eleven.com/our-story
# 2                  https://hightopscannabis.com/menu/
# 3        https://provisionsdispensary.com/contact-us/
# 4   https://weedmaps.com/dispensaries/a-cut-above-...
# 5                   https://acadispensary.com/denver/
# 6   https://www.allbud.com/dispensaries/colorado/g...
# 7   https://www.denverdispensaries.net/place/lodo-...
# 8   https://www.denverdispensaries.net/place/lodo-...
# 9   https://weedmaps.com/dispensaries/high-tops-po...
# 10         https://bleeziescolorado.wm.store/discover
# 11         https://thebuzzdispo.com/about-us-and-info
# 12                               https://puremmj.com/
# 13                                           Unlisted
# 14                  https://snaxland.com/pages/denver

# %% [markdown]
# ## Step 2: Clean and Prepare the Data

# %%
# Check column names and data types
df.info()

# Clean any missing latitude or longitude data
df.dropna(subset=['Longitude', 'Latitude'], inplace=True)

# Optional: Check for missing values in other important columns
df.isnull().sum()

# Optional: Display the first few rows of cleaned data
df.head(15)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 998 entries, 0 to 997
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   License Number  998 non-null    object
#  1   Facility Name   998 non-null    object
#  2   DBA             841 non-null    object
#  3   Facility Type   998 non-null    object
#  4   Street          998 non-null    object
#  5   City            998 non-null    object
#  6   State           998 non-null    object
#  7   Zip Code        998 non-null    int64
#  8   Latitude        998 non-null    float64
#  9   Longitude       998 non-null    float64
#  10  Phone-Number    998 non-null    object
#  11  Website         998 non-null    object
# dtypes: float64(2), int64(1), object(9)
# memory usage: 93.7+ KB
#    License Number                   Facility Name  \
# 0       402-01197                        1-11 LLC
# 1      402R-00581                        1-11 LLC
# 2       402-00116                1022 S ROYER LLC
# 3      402R-00739                       10232 LLC
# 4       402-00455  11761013 COLORADO HOLDINGS LLC
# 5      402R-00587  11761013 COLORADO HOLDINGS LLC
# 6      402R-01041         1310 FACTORY CIRCLE LLC
# 7       402-00017           1617 WAZEE STREET LLC
# 8      402R-00081           1617 WAZEE STREET LLC
# 9       402-00248               2306 N POWERS LLC
# 10      402-00618                     4 ROSES LLC
# 11     402R-00698              417 COMMERCIAL LLC
# 12     402R-00438                  505 CENTER LLC
# 13     402R-01024              5403 QUEBEC ST LLC
# 14      402-00656           543 BRYANT STREET LLC
#
#                                                 DBA            Facility Type  \
# 0                                        one:eleven  Medical Marijuana Store
# 1                                        one:eleven   Retail Marijuana Store
# 2                                          Hightops  Medical Marijuana Store
# 3                                        Provisions   Retail Marijuana Store
# 4                                       A Cut Above  Medical Marijuana Store
# 5                                       A Cut Above   Retail Marijuana Store
# 6   Nature's Herbs & Wellness Center of Fort Lupton   Retail Marijuana Store
# 7                              LoDo Wellness Center  Medical Marijuana Store
# 8                              LODO WELLNESS CENTER   Retail Marijuana Store
# 9                                          Hightops  Medical Marijuana Store
# 10                                         Bleezies  Medical Marijuana Store
# 11                                         THE BUZZ   Retail Marijuana Store
# 12                        Pure Marijuana Dispensary   Retail Marijuana Store
# 13                                              NaN   Retail Marijuana Store
# 14                                         Snaxland  Medical Marijuana Store
#
#                                         Street              City State  \
# 0                             17034 Highway 17            Moffat    CO
# 1                             17034 Highway 17            Moffat    CO
# 2                      1022 South Royer Street  Colorado Springs    CO
# 3                          10232 Interstate 25        Walsenburg    CO
# 4                          1911 South Broadway            Denver    CO
# 5                          1911 South Broadway            Denver    CO
# 6                   1310 Factory Circle Unit A       Fort Lupton    CO
# 7                    1617 Wazee Street, Unit B            Denver    CO
# 8                    1617 Wazee Street, Unit B            Denver    CO
# 9   2306 North Powers Frontage Road, Suite 100  Colorado Springs    CO
# 10                    3234 North Nevada Avenue  Colorado Springs    CO
# 11                 417 North Commercial Street          Trinidad    CO
# 12                        505 West 40th Avenue            Denver    CO
# 13                          5403 Quebec Street     Commerce City    CO
# 14                           543 Bryant Street            Denver    CO
#
#     Zip Code   Latitude   Longitude  Phone-Number  \
# 0      81143  37.992955 -105.907324  719-937-7716
# 1      81143  37.992955 -105.907324  719-754-1975
# 2      80903  38.819517 -104.815490  719-597-9333
# 3      81089  37.650447 -104.786115  719-738-2062
# 4      80210  39.681864 -104.987676  720-536-8965
# 5      80210  39.681864 -104.987676  720-536-8965
# 6      80621  40.093006 -104.814095  720-712-6044
# 7      80202  39.751655 -104.999706  303-534-5020
# 8      80202  39.751655 -104.999706  303-534-5020
# 9      80915  38.863467 -104.720079  719-597-9333
# 10     80907  38.878155 -104.818384  719-698-6119
# 11     81082  37.171396 -104.506981  719-422-8261
# 12     80216  39.771809 -104.993852  303-733-9956
# 13     80022  39.837693 -104.903175      Unlisted
# 14     80204  39.724321 -105.018772  303-872-3959
#
#                                               Website
# 0                  https://www.1-eleven.com/our-story
# 1                  https://www.1-eleven.com/our-story
# 2                  https://hightopscannabis.com/menu/
# 3        https://provisionsdispensary.com/contact-us/
# 4   https://weedmaps.com/dispensaries/a-cut-above-...
# 5                   https://acadispensary.com/denver/
# 6   https://www.allbud.com/dispensaries/colorado/g...
# 7   https://www.denverdispensaries.net/place/lodo-...
# 8   https://www.denverdispensaries.net/place/lodo-...
# 9   https://weedmaps.com/dispensaries/high-tops-po...
# 10         https://bleeziescolorado.wm.store/discover
# 11         https://thebuzzdispo.com/about-us-and-info
# 12                               https://puremmj.com/
# 13                                           Unlisted
# 14                  https://snaxland.com/pages/denver

# %% [markdown]
# ## Step 3: Create a Searchable Map

# %%
# Initialize the map centered around Colorado
m = folium.Map(location=[39.5501, -105.7821], zoom_start=7)

# Add markers to the map for each food pantry
for idx, row in df.iterrows():
    popup_text = f"""
    <strong>{row['Facility Name']}</strong><br>
    <strong>{row['DBA']}</strong><br>
    Facility Type: {row['Facility Type']}<br>
    {row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip Code']}<br>
    Phone: {row['Phone-Number']}<br>
    Website: <a href="{row['Website']}">{row['Facility Name']}</a><br>
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m)

# Save the map as an HTML file
m.save("colorado_dispensaries_full_list_map_v2.html")

# Display the map in the notebook
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_98c33981911646c383469ba209b9b1e7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_98c33981911646c383469ba209b9b1e7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_98c33981911646c383469ba209b9b1e7 = L.map(
#                 &quot;map_98c33981911646c383469ba209b9b1e7&quot;,
#                 {
#                     center: [39.5501, -105.7821],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cd7b26f38bca2570aee0b27a61d41654 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_cd7b26f38bca2570aee0b27a61d41654.addTo(map_98c33981911646c383469ba209b9b1e7);
#
#
#             var marker_3bb54e8d1cd3bc56093ccb432a63d879 = L.marker(
#                 [37.992955, -105.907324],
#                 {}
#             ).addTo(map_98c33981911646c383469ba209b9b1e7);
#
#
#             var icon_825c66bf017824106e1ad8375b57a4f6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3bb54e8d1cd3bc56093ccb432a63d879.setIcon(icon_825c66bf017824106e1ad8375b57a4f6);
#
#
#         var popup_fb1652c7ac0b00df24cbd747869bab07 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6702452217485b150c08440350fbabf3 = $(`&lt;div id=&quot;html_6702452217485b150c08440350fbabf3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;1-11 LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;one:eleven&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Store&lt;br&gt;     17034 Highway 17&lt;br&gt;     Moffat, CO 81143&lt;br&gt;     Phone: 719-937-7716&lt;br&gt;     Website: &lt;a href=&quot;https://www.1-eleven.com/our-story&quot;&gt;1-11 LLC&lt;/a&gt;&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_fb1652c7ac0b00df24cbd747869bab07.setContent(html_6702452217485b150c08440350fbabf3);
#
#
#
#         marker_3bb54e8d1cd3bc56093ccb432a63d879.bindPopup(popup_fb1652c7ac0b00df24cbd747869bab07)
#         ;
#
#
#
#
#             var marker_ca2d7d5226046258ea7f3a4af78950f4 = L.marker(
#                 [37.992955, -105.907324],
#                 {}
#             ).addTo(map_98c33981911646c383469ba209b9b1e7);
#
#
#             var icon_93128cd2bf8e2ce1aa3409ec395914c3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ca2d7d5226046258ea7f3a4af78950f4.setIcon(icon_93128cd2bf8e2ce1aa3409ec395914c3);
#
#
#         var popup_f87113948177f3dcb29685c92141396d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7ab6de0f74de9472d6262f334c913e90 = $(`&lt;div id=&quot;html_7ab6de0f74de9472d6262f334c913e90&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;1-11 LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;one:eleven&lt;/strong&gt;&lt;br&gt;     Facility Type: Retail Marijuana Store&lt;br&gt;     17034 Highway 17&lt;br&gt;     Moffat, CO 81143&lt;br&gt;     Phone: 719-754-1975&lt;br&gt;     Website: &lt;a href=&quot;https://www.1-eleven.com/our-story&quot;&gt;1-11 LLC&lt;/a&gt;&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_f87113948177f3dcb29685c92141396d.setContent(html_7ab6de0f74de9472d6262f334c913e90);
#
#
#
#         marker_ca2d7d5226046258ea7f3a4af78950f4.bindPopup(popup_f87113948177f3dcb29685c92141396d)
#         ;
#
#
#
#
#             var marker_65cdcd51cdb9239cd63bdc10d0fb457f = L.marker(
#                 [38.8195171, -104.8154896],
#                 {}
#             ).addTo(map_98c33981911646c383469ba209b9b1e7);
#
#
#             var icon_399e096415396f15e304423fc0b50d9a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_65cdcd51cdb9239cd63bdc10d0fb457f.setIcon(icon_399e096415396f15e304423fc0b50d9a);
#
#
#         var popup_2d10d34c64921126dfff38d3fe98dd4c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_867be7ee521da235b199c310d3c09963 = $(`&lt;div id=&quot;html_867be7ee521da235b199c310d3c09963&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;1022 S RO

# %% [markdown]
# ## Step 4: Implement Search Functionality

# %%
# Example: Search for dispensaries in a specific city
city_search = "Denver"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[39.5501, -105.7821], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Facility Name']}</strong><br>
    <strong>{row['DBA']}</strong><br>
    Facility Type: {row['Facility Type']}<br>
    {row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip Code']}<br>
    Phone: {row['Phone-Number']}<br>
    Website: <a href="{row['Website']}">{row['Facility Name']}</a><br>
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_dispensaries_map_denver_v2.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a5daf9dea66d993dff8fcdca64d4e3ec {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a5daf9dea66d993dff8fcdca64d4e3ec&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a5daf9dea66d993dff8fcdca64d4e3ec = L.map(
#                 &quot;map_a5daf9dea66d993dff8fcdca64d4e3ec&quot;,
#                 {
#                     center: [39.5501, -105.7821],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fac83beb40f752abe254706b7bd2d239 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_fac83beb40f752abe254706b7bd2d239.addTo(map_a5daf9dea66d993dff8fcdca64d4e3ec);
#
#
#             var marker_f2e072c59ae1e3e08773b4ae1580e07c = L.marker(
#                 [39.6818644, -104.987676],
#                 {}
#             ).addTo(map_a5daf9dea66d993dff8fcdca64d4e3ec);
#
#
#             var icon_6529c9ff93cba52faa62ea923866c5b2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f2e072c59ae1e3e08773b4ae1580e07c.setIcon(icon_6529c9ff93cba52faa62ea923866c5b2);
#
#
#         var popup_3a4d26a0fb689820a0737aa5895b92f4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a9767ae856e47d54b72484d80c1e5165 = $(`&lt;div id=&quot;html_a9767ae856e47d54b72484d80c1e5165&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;11761013 COLORADO HOLDINGS LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;A Cut Above&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Store&lt;br&gt;     1911 South Broadway&lt;br&gt;     Denver, CO 80210&lt;br&gt;     Phone: 720-536-8965&lt;br&gt;     Website: &lt;a href=&quot;https://weedmaps.com/dispensaries/a-cut-above-denver?page=3&quot;&gt;11761013 COLORADO HOLDINGS LLC&lt;/a&gt;&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_3a4d26a0fb689820a0737aa5895b92f4.setContent(html_a9767ae856e47d54b72484d80c1e5165);
#
#
#
#         marker_f2e072c59ae1e3e08773b4ae1580e07c.bindPopup(popup_3a4d26a0fb689820a0737aa5895b92f4)
#         ;
#
#
#
#
#             var marker_9d7fb554b55a1b050ff3c7eb4ab265d2 = L.marker(
#                 [39.6818644, -104.987676],
#                 {}
#             ).addTo(map_a5daf9dea66d993dff8fcdca64d4e3ec);
#
#
#             var icon_827d5e18bbd0709a9987d3bdc9edb1b3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9d7fb554b55a1b050ff3c7eb4ab265d2.setIcon(icon_827d5e18bbd0709a9987d3bdc9edb1b3);
#
#
#         var popup_9b18d51188bd5075fbe73e62526985ed = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_48918b9e2b6a96e05d2170a2bcd0ff66 = $(`&lt;div id=&quot;html_48918b9e2b6a96e05d2170a2bcd0ff66&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;11761013 COLORADO HOLDINGS LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;A Cut Above&lt;/strong&gt;&lt;br&gt;     Facility Type: Retail Marijuana Store&lt;br&gt;     1911 South Broadway&lt;br&gt;     Denver, CO 80210&lt;br&gt;     Phone: 720-536-8965&lt;br&gt;     Website: &lt;a href=&quot;https://acadispensary.com/denver/&quot;&gt;11761013 COLORADO HOLDINGS LLC&lt;/a&gt;&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_9b18d51188bd5075fbe73e62526985ed.setContent(html_48918b9e2b6a96e05d2170a2bcd0ff66);
#
#
#
#         marker_9d7fb554b55a1b050ff3c7eb4ab265d2.bindPopup(popup_9b18d51188bd5075fbe73e62526985ed)
#         ;
#
#
#
#
#             var marker_090843286359ebd3ec71fb2466c4cc67 = L.marker(
#                 [39.7516552, -104.9997063],
#                 {}
#             ).addTo(map_a5daf9dea66d993dff8fcdca64d4e3ec);
#
#
#             var icon_3964fa5ef8f8cb9ccad63a4107e886ad = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_090843286359ebd3ec71fb2466c4cc67.setIcon(icon_3964fa5ef8f8cb9ccad63a4107e886ad);
#
#
#         var popup_7c08991509a66dde6c53cb24b2073525 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_84b3015856baa65afc89fc3c0e1568e8 = $(`&lt;div id=&quot;ht

# %%
# Example: Search for dispensaries in a specific city
city_search = "Colorado Springs"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[38.8591, -104.8135], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Facility Name']}</strong><br>
    <strong>{row['DBA']}</strong><br>
    Facility Type: {row['Facility Type']}<br>
    {row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip Code']}<br>
    Phone: {row['Phone-Number']}<br>
    Website: <a href="{row['Website']}">{row['Facility Name']}</a><br>
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_dispensaries_map_colorado_springs_v2.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ddbb6c9858dfb6e6f621a317b7709cf7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ddbb6c9858dfb6e6f621a317b7709cf7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ddbb6c9858dfb6e6f621a317b7709cf7 = L.map(
#                 &quot;map_ddbb6c9858dfb6e6f621a317b7709cf7&quot;,
#                 {
#                     center: [38.8591, -104.8135],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9a483464b285b2443e2a554f7553868d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_9a483464b285b2443e2a554f7553868d.addTo(map_ddbb6c9858dfb6e6f621a317b7709cf7);
#
#
#             var marker_efba49c61e86241f7d75c64b79ef113e = L.marker(
#                 [38.8195171, -104.8154896],
#                 {}
#             ).addTo(map_ddbb6c9858dfb6e6f621a317b7709cf7);
#
#
#             var icon_4b5a06af22deeb54c930ffd7d902d7d2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_efba49c61e86241f7d75c64b79ef113e.setIcon(icon_4b5a06af22deeb54c930ffd7d902d7d2);
#
#
#         var popup_64d0f78e5906db89a86021dc66711f38 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0a1e0d85b7a9a1c10244f98f89988e7b = $(`&lt;div id=&quot;html_0a1e0d85b7a9a1c10244f98f89988e7b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;1022 S ROYER LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Hightops&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Store&lt;br&gt;     1022 South Royer Street&lt;br&gt;     Colorado Springs, CO 80903&lt;br&gt;     Phone: 719-597-9333&lt;br&gt;     Website: &lt;a href=&quot;https://hightopscannabis.com/menu/&quot;&gt;1022 S ROYER LLC&lt;/a&gt;&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_64d0f78e5906db89a86021dc66711f38.setContent(html_0a1e0d85b7a9a1c10244f98f89988e7b);
#
#
#
#         marker_efba49c61e86241f7d75c64b79ef113e.bindPopup(popup_64d0f78e5906db89a86021dc66711f38)
#         ;
#
#
#
#
#             var marker_34b67865e5356f9c464cb5ee17e5bb30 = L.marker(
#                 [38.863467, -104.720079],
#                 {}
#             ).addTo(map_ddbb6c9858dfb6e6f621a317b7709cf7);
#
#
#             var icon_c3f857ec982d625ed24db97a8bcecf48 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_34b67865e5356f9c464cb5ee17e5bb30.setIcon(icon_c3f857ec982d625ed24db97a8bcecf48);
#
#
#         var popup_05466bd0b2fb18afc39e28dbe580937d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bdcf5a8e129fc16a6f9b13827d0c0534 = $(`&lt;div id=&quot;html_bdcf5a8e129fc16a6f9b13827d0c0534&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;2306 N POWERS LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Hightops&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Store&lt;br&gt;     2306 North Powers Frontage Road, Suite 100&lt;br&gt;     Colorado Springs, CO 80915&lt;br&gt;     Phone: 719-597-9333&lt;br&gt;     Website: &lt;a href=&quot;https://weedmaps.com/dispensaries/high-tops-powers&quot;&gt;2306 N POWERS LLC&lt;/a&gt;&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_05466bd0b2fb18afc39e28dbe580937d.setContent(html_bdcf5a8e129fc16a6f9b13827d0c0534);
#
#
#
#         marker_34b67865e5356f9c464cb5ee17e5bb30.bindPopup(popup_05466bd0b2fb18afc39e28dbe580937d)
#         ;
#
#
#
#
#             var marker_75f2ee039c343854012a4ba082ac95ac = L.marker(
#                 [38.8781548, -104.8183845],
#                 {}
#             ).addTo(map_ddbb6c9858dfb6e6f621a317b7709cf7);
#
#
#             var icon_2471100a8647080560c776349250fc54 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_75f2ee039c343854012a4ba082ac95ac.setIcon(icon_2471100a8647080560c776349250fc54);
#
#
#         var popup_c01098743c8f659567b3bb048156383f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f4e5507e9b6e3bbed376d272daecbd5d = $(`&lt;div id=&quot;html_f4e5507e9b6e3bbed

# %%
# Example: Search for dispensaries in a specific city
city_search = "Aurora"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[39.7108, -104.8125], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Facility Name']}</strong><br>
    <strong>{row['DBA']}</strong><br>
    Facility Type: {row['Facility Type']}<br>
    {row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip Code']}<br>
    Phone: {row['Phone-Number']}<br>
    Website: <a href="{row['Website']}">{row['Facility Name']}</a><br>
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_dispensaries_map_aurora_v2.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5b51c8f50a6d5f86a4472b634bcac9f3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5b51c8f50a6d5f86a4472b634bcac9f3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5b51c8f50a6d5f86a4472b634bcac9f3 = L.map(
#                 &quot;map_5b51c8f50a6d5f86a4472b634bcac9f3&quot;,
#                 {
#                     center: [39.7108, -104.8125],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_784a76ffd7ea5d31ada4f3dca1f2533d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_784a76ffd7ea5d31ada4f3dca1f2533d.addTo(map_5b51c8f50a6d5f86a4472b634bcac9f3);
#
#
#             var marker_54dbc6e6901974c5ad9d1606c57e5172 = L.marker(
#                 [39.7250311, -104.8124222],
#                 {}
#             ).addTo(map_5b51c8f50a6d5f86a4472b634bcac9f3);
#
#
#             var icon_3e65a535053f930bbb1cfeb2218bfc41 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_54dbc6e6901974c5ad9d1606c57e5172.setIcon(icon_3e65a535053f930bbb1cfeb2218bfc41);
#
#
#         var popup_ca56e203e0ba6920f1bfa1ee93a77366 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_194daba1499d5af62017440e3b930ebc = $(`&lt;div id=&quot;html_194daba1499d5af62017440e3b930ebc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;BROW ACQUISITIONS AURORA LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Xclusive Cannabis&lt;/strong&gt;&lt;br&gt;     Facility Type: Retail Marijuana Store&lt;br&gt;     15200 East 6th Avenue Unit 1&lt;br&gt;     Aurora, CO 80011&lt;br&gt;     Phone: 720-738-4200&lt;br&gt;     Website: &lt;a href=&quot;https://xclusivecannabis.com/&quot;&gt;BROW ACQUISITIONS AURORA LLC&lt;/a&gt;&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_ca56e203e0ba6920f1bfa1ee93a77366.setContent(html_194daba1499d5af62017440e3b930ebc);
#
#
#
#         marker_54dbc6e6901974c5ad9d1606c57e5172.bindPopup(popup_ca56e203e0ba6920f1bfa1ee93a77366)
#         ;
#
#
#
#
#             var marker_043210a6a642a9161bbcd8cdd2e085a4 = L.marker(
#                 [39.7632007, -104.8495745],
#                 {}
#             ).addTo(map_5b51c8f50a6d5f86a4472b634bcac9f3);
#
#
#             var icon_e56bd3deb1365ddf549a0eb3a1a03fc6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_043210a6a642a9161bbcd8cdd2e085a4.setIcon(icon_e56bd3deb1365ddf549a0eb3a1a03fc6);
#
#
#         var popup_95c7508729c4990c8ccf8ce69761a8ec = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_489e98d21e8c9ea8e32fb688075a7688 = $(`&lt;div id=&quot;html_489e98d21e8c9ea8e32fb688075a7688&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;CANNA CLUB LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Best Buds&lt;/strong&gt;&lt;br&gt;     Facility Type: Retail Marijuana Store&lt;br&gt;     11900 East 33rd Avenue, Suite 1&lt;br&gt;     Aurora, CO 80010&lt;br&gt;     Phone: 720-679-9779&lt;br&gt;     Website: &lt;a href=&quot;https://weedmaps.com/dispensaries/best-buds-aurora-dia&quot;&gt;CANNA CLUB LLC&lt;/a&gt;&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_95c7508729c4990c8ccf8ce69761a8ec.setContent(html_489e98d21e8c9ea8e32fb688075a7688);
#
#
#
#         marker_043210a6a642a9161bbcd8cdd2e085a4.bindPopup(popup_95c7508729c4990c8ccf8ce69761a8ec)
#         ;
#
#
#
#
#             var marker_6b875c0cb0f91d0579042522a1940653 = L.marker(
#                 [39.7234623, -104.8660225],
#                 {}
#             ).addTo(map_5b51c8f50a6d5f86a4472b634bcac9f3);
#
#
#             var icon_b336b68bdeacbce80f13e73ed3aa754f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6b875c0cb0f91d0579042522a1940653.setIcon(icon_b336b68bdeacbce80f13e73ed3aa754f);
#
#
#         var popup_ce8e6e67daa73646c61bdbb4da359ed2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7a4da73512482cbe23ff940ebee7ccbe = $(`&lt;div id=&quot;html_7a4da73512482cbe

# %%
# Example: Search for dispensaries in a specific city
city_search = "Fort Collins"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[40.5853, -105.0844], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Facility Name']}</strong><br>
    <strong>{row['DBA']}</strong><br>
    Facility Type: {row['Facility Type']}<br>
    {row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip Code']}<br>
    Phone: {row['Phone-Number']}<br>
    Website: <a href="{row['Website']}">{row['Facility Name']}</a><br>
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_dispensaries_map_fort_collins_v2.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_77742d68881758f43ea789032ae0c0ac {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_77742d68881758f43ea789032ae0c0ac&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_77742d68881758f43ea789032ae0c0ac = L.map(
#                 &quot;map_77742d68881758f43ea789032ae0c0ac&quot;,
#                 {
#                     center: [40.5853, -105.0844],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a5e69c1cfdf33960a726f9f47f279812 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a5e69c1cfdf33960a726f9f47f279812.addTo(map_77742d68881758f43ea789032ae0c0ac);
#
#
#             var marker_120863485abd88ab8d74bcd809c821a0 = L.marker(
#                 [40.5738399, -105.0473852],
#                 {}
#             ).addTo(map_77742d68881758f43ea789032ae0c0ac);
#
#
#             var icon_7f849b96e698dbcb0e6b3187ca5f6628 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_120863485abd88ab8d74bcd809c821a0.setIcon(icon_7f849b96e698dbcb0e6b3187ca5f6628);
#
#
#         var popup_f53e3e6d552989ac9ae71cedb474b19e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2d2dd40880d354cdcff8fa670ad2d4e2 = $(`&lt;div id=&quot;html_2d2dd40880d354cdcff8fa670ad2d4e2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;ACES PLACE LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;nan&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Store&lt;br&gt;     1101 Academy Court, Unit 4&lt;br&gt;     Fort Collins, CO 80524&lt;br&gt;     Phone: 970-472-5107&lt;br&gt;     Website: &lt;a href=&quot;https://www.acesplacefoco.com/home&quot;&gt;ACES PLACE LLC&lt;/a&gt;&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_f53e3e6d552989ac9ae71cedb474b19e.setContent(html_2d2dd40880d354cdcff8fa670ad2d4e2);
#
#
#
#         marker_120863485abd88ab8d74bcd809c821a0.bindPopup(popup_f53e3e6d552989ac9ae71cedb474b19e)
#         ;
#
#
#
#
#             var marker_c8739a9f49bc6e6438b03e7a0ece3750 = L.marker(
#                 [40.5738399, -105.0473852],
#                 {}
#             ).addTo(map_77742d68881758f43ea789032ae0c0ac);
#
#
#             var icon_e3d63e33e7b553c81e7ca688663c384f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c8739a9f49bc6e6438b03e7a0ece3750.setIcon(icon_e3d63e33e7b553c81e7ca688663c384f);
#
#
#         var popup_57b7d50d6cda12217dfde3934a21684f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_40a81af7dd4c58e8e15f8e31dec2d576 = $(`&lt;div id=&quot;html_40a81af7dd4c58e8e15f8e31dec2d576&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;ACES PLACE LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;nan&lt;/strong&gt;&lt;br&gt;     Facility Type: Retail Marijuana Store&lt;br&gt;     1101 Academy Court, Unit 4&lt;br&gt;     Fort Collins, CO 80524&lt;br&gt;     Phone: 970-472-5107&lt;br&gt;     Website: &lt;a href=&quot;https://www.acesplacefoco.com/home&quot;&gt;ACES PLACE LLC&lt;/a&gt;&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_57b7d50d6cda12217dfde3934a21684f.setContent(html_40a81af7dd4c58e8e15f8e31dec2d576);
#
#
#
#         marker_c8739a9f49bc6e6438b03e7a0ece3750.bindPopup(popup_57b7d50d6cda12217dfde3934a21684f)
#         ;
#
#
#
#
#             var marker_ca5a10b20e3b110a0e59afd31dd50a0e = L.marker(
#                 [40.577109, -105.003324],
#                 {}
#             ).addTo(map_77742d68881758f43ea789032ae0c0ac);
#
#
#             var icon_5ac0fc42174bd4723f45fc7118aff95c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ca5a10b20e3b110a0e59afd31dd50a0e.setIcon(icon_5ac0fc42174bd4723f45fc7118aff95c);
#
#
#         var popup_100123069792aa518c22899dcd979988 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_17376888d516fa0afe15d1c5b0bcfc5d = $(`&lt;div id=&quot;html_17376888d516fa0afe15d1c5b0bcfc5d&quot; style=&quot;width: 100.0%; height: 1

# %%
# Example: Search for dispensaries in a specific city
city_search = "Lakewood"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[39.7109, -105.0815], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Facility Name']}</strong><br>
    <strong>{row['DBA']}</strong><br>
    Facility Type: {row['Facility Type']}<br>
    {row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip Code']}<br>
    Phone: {row['Phone-Number']}<br>
    Website: <a href="{row['Website']}">{row['Facility Name']}</a><br>
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_dispensaries_map_lakewood_v2.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_92b7fa7e2c3d33de23f9358a24e7f922 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_92b7fa7e2c3d33de23f9358a24e7f922&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_92b7fa7e2c3d33de23f9358a24e7f922 = L.map(
#                 &quot;map_92b7fa7e2c3d33de23f9358a24e7f922&quot;,
#                 {
#                     center: [39.7109, -105.0815],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b53de938c7d8e30d9907cec83362eb70 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b53de938c7d8e30d9907cec83362eb70.addTo(map_92b7fa7e2c3d33de23f9358a24e7f922);
#
#
#             var marker_51c75e7ef3d5e3278986f8dc8552fdf0 = L.marker(
#                 [39.7403205, -105.1162959],
#                 {}
#             ).addTo(map_92b7fa7e2c3d33de23f9358a24e7f922);
#
#
#             var icon_566eacdadf588b14b4394de58c9e9f90 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_51c75e7ef3d5e3278986f8dc8552fdf0.setIcon(icon_566eacdadf588b14b4394de58c9e9f90);
#
#
#         var popup_a961d91d21b79318784a31a1e7f50931 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f31e3f394de2e190990ad6f8c33798a8 = $(`&lt;div id=&quot;html_f31e3f394de2e190990ad6f8c33798a8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;CPM LAKEWOOD LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Ajoya Medical Cannabis&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Store&lt;br&gt;     10590 West Colfax Avenue&lt;br&gt;     Lakewood, CO 80215&lt;br&gt;     Phone: 303-232-3620&lt;br&gt;     Website: &lt;a href=&quot;https://ajoyalife.com/dispensary-locations/lakewood&quot;&gt;CPM LAKEWOOD LLC&lt;/a&gt;&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_a961d91d21b79318784a31a1e7f50931.setContent(html_f31e3f394de2e190990ad6f8c33798a8);
#
#
#
#         marker_51c75e7ef3d5e3278986f8dc8552fdf0.bindPopup(popup_a961d91d21b79318784a31a1e7f50931)
#         ;
#
#
#
#
#             var marker_16e553ed0472e68eb63e214ba5aa14db = L.marker(
#                 [39.7403205, -105.1162959],
#                 {}
#             ).addTo(map_92b7fa7e2c3d33de23f9358a24e7f922);
#
#
#             var icon_fedca06d2e885e6bf0f0b4acdf537a5e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_16e553ed0472e68eb63e214ba5aa14db.setIcon(icon_fedca06d2e885e6bf0f0b4acdf537a5e);
#
#
#         var popup_21e89d1fe0dbb1f06d256f73174d0e59 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e2ffe2cade1709f8abb4ca27f3f7ef02 = $(`&lt;div id=&quot;html_e2ffe2cade1709f8abb4ca27f3f7ef02&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;CPM Lakewood LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Ajoya Medical Cannabis&lt;/strong&gt;&lt;br&gt;     Facility Type: Retail Marijuana Store&lt;br&gt;     10590 West Colfax Avenue&lt;br&gt;     Lakewood, CO 80215&lt;br&gt;     Phone: 303-232-3620&lt;br&gt;     Website: &lt;a href=&quot;https://ajoyalife.com/dispensary-locations/lakewood&quot;&gt;CPM Lakewood LLC&lt;/a&gt;&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_21e89d1fe0dbb1f06d256f73174d0e59.setContent(html_e2ffe2cade1709f8abb4ca27f3f7ef02);
#
#
#
#         marker_16e553ed0472e68eb63e214ba5aa14db.bindPopup(popup_21e89d1fe0dbb1f06d256f73174d0e59)
#         ;
#
#
#
#
#             var marker_3252755bcb5770e7894952208ca44fbc = L.marker(
#                 [39.682017, -105.1293189],
#                 {}
#             ).addTo(map_92b7fa7e2c3d33de23f9358a24e7f922);
#
#
#             var icon_25ab773a9cc03dfb76ee40beace0067e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3252755bcb5770e7894952208ca44fbc.setIcon(icon_25ab773a9cc03dfb76ee40beace0067e);
#
#
#         var popup_82a84f5a4a8ae420b76ab0552c091982 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_30f1878fa2d80502a3f383a67899ff47 = $(`&lt;div id=&quot;html_30f187

# %%
# Example: Search for dispensaries in a specific city
city_search = "Arvada"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[39.8028, -105.0875], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Facility Name']}</strong><br>
    <strong>{row['DBA']}</strong><br>
    Facility Type: {row['Facility Type']}<br>
    {row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip Code']}<br>
    Phone: {row['Phone-Number']}<br>
    Website: <a href="{row['Website']}">{row['Facility Name']}</a><br>
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_dispensaries_map_arvada_v2.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9101a3adbac73d5e9b6878e753d44a08 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9101a3adbac73d5e9b6878e753d44a08&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9101a3adbac73d5e9b6878e753d44a08 = L.map(
#                 &quot;map_9101a3adbac73d5e9b6878e753d44a08&quot;,
#                 {
#                     center: [39.8028, -105.0875],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3878d86d68a0ab7c626f1f9d0b850320 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_3878d86d68a0ab7c626f1f9d0b850320.addTo(map_9101a3adbac73d5e9b6878e753d44a08);
#
#
#             var marker_c0060f71b830b68de3081f75d71ac63e = L.marker(
#                 [39.799578, -105.0531965],
#                 {}
#             ).addTo(map_9101a3adbac73d5e9b6878e753d44a08);
#
#
#             var icon_e5e695017e9b57ca14fb682b5a4e932a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c0060f71b830b68de3081f75d71ac63e.setIcon(icon_e5e695017e9b57ca14fb682b5a4e932a);
#
#
#         var popup_d45fed795f36b7b6cf50fde0557268c0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_51b44b0d3c7dca080f4d633f49ab7cc1 = $(`&lt;div id=&quot;html_51b44b0d3c7dca080f4d633f49ab7cc1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;YUMA WAY LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Berkeley Dispensary&lt;/strong&gt;&lt;br&gt;     Facility Type: Retail Marijuana Store&lt;br&gt;     5398 Sheridan Boulevard&lt;br&gt;     Arvada, CO 80002&lt;br&gt;     Phone: 720-310-8057&lt;br&gt;     Website: &lt;a href=&quot;https://www.leafly.com/dispensary-info/berkeley-dispensary&quot;&gt;YUMA WAY LLC&lt;/a&gt;&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_d45fed795f36b7b6cf50fde0557268c0.setContent(html_51b44b0d3c7dca080f4d633f49ab7cc1);
#
#
#
#         marker_c0060f71b830b68de3081f75d71ac63e.bindPopup(popup_d45fed795f36b7b6cf50fde0557268c0)
#         ;
#
#
#
#
#             tile_layer_3878d86d68a0ab7c626f1f9d0b850320.addTo(map_9101a3adbac73d5e9b6878e753d44a08);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Example: Search for dispensaries in a specific city
city_search = "Garden City"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[40.4233, -104.7112], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Facility Name']}</strong><br>
    <strong>{row['DBA']}</strong><br>
    Facility Type: {row['Facility Type']}<br>
    {row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip Code']}<br>
    Phone: {row['Phone-Number']}<br>
    Website: <a href="{row['Website']}">{row['Facility Name']}</a><br>
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_dispensaries_map_garden_city_v2.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_304e189d85e4d88407aec9f7b4cb8556 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_304e189d85e4d88407aec9f7b4cb8556&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_304e189d85e4d88407aec9f7b4cb8556 = L.map(
#                 &quot;map_304e189d85e4d88407aec9f7b4cb8556&quot;,
#                 {
#                     center: [40.4233, -104.7112],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f7b5bde4642cd02057be0a4e384c478a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f7b5bde4642cd02057be0a4e384c478a.addTo(map_304e189d85e4d88407aec9f7b4cb8556);
#
#
#             var marker_19e5a42c4a0167de163625b4f04d75b2 = L.marker(
#                 [40.3967964, -104.6874197],
#                 {}
#             ).addTo(map_304e189d85e4d88407aec9f7b4cb8556);
#
#
#             var icon_94b0618b63d9a1ee2a06a55198580793 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_19e5a42c4a0167de163625b4f04d75b2.setIcon(icon_94b0618b63d9a1ee2a06a55198580793);
#
#
#         var popup_692153546bafff0948a6d14e34e413a6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b5dd733d659a3d9d6cbb43154f053463 = $(`&lt;div id=&quot;html_b5dd733d659a3d9d6cbb43154f053463&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;HIGH PLAINZ STRAINS II LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;nan&lt;/strong&gt;&lt;br&gt;     Facility Type: Retail Marijuana Store&lt;br&gt;     2506 6th Avenue&lt;br&gt;     Garden City, CO 80631&lt;br&gt;     Phone: 970-352-4119&lt;br&gt;     Website: &lt;a href=&quot;https://highplainz.com/our-locations/garden-city/&quot;&gt;HIGH PLAINZ STRAINS II LLC&lt;/a&gt;&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_692153546bafff0948a6d14e34e413a6.setContent(html_b5dd733d659a3d9d6cbb43154f053463);
#
#
#
#         marker_19e5a42c4a0167de163625b4f04d75b2.bindPopup(popup_692153546bafff0948a6d14e34e413a6)
#         ;
#
#
#
#
#             var marker_6a957c204fedfd090cddf36ad14f6fa5 = L.marker(
#                 [40.393964, -104.6918421],
#                 {}
#             ).addTo(map_304e189d85e4d88407aec9f7b4cb8556);
#
#
#             var icon_dfd9bf1f7747b387c19d714cd4e6dbb6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6a957c204fedfd090cddf36ad14f6fa5.setIcon(icon_dfd9bf1f7747b387c19d714cd4e6dbb6);
#
#
#         var popup_f700d7834df6c130393f8950b01e1293 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a07ab39f3c5338f16d601156152c4a94 = $(`&lt;div id=&quot;html_a07ab39f3c5338f16d601156152c4a94&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;LIVWELL I LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;LivWell&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Store&lt;br&gt;     2647 8th Avenue, Unit B&lt;br&gt;     Garden City, CO 80631&lt;br&gt;     Phone: 970-616-6007&lt;br&gt;     Website: &lt;a href=&quot;https://livwell.com/locations/colorado/garden-city&quot;&gt;LIVWELL I LLC&lt;/a&gt;&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_f700d7834df6c130393f8950b01e1293.setContent(html_a07ab39f3c5338f16d601156152c4a94);
#
#
#
#         marker_6a957c204fedfd090cddf36ad14f6fa5.bindPopup(popup_f700d7834df6c130393f8950b01e1293)
#         ;
#
#
#
#
#             var marker_9110a93cfb369ff4b8c8b5f5b22f2f53 = L.marker(
#                 [40.393964, -104.6918421],
#                 {}
#             ).addTo(map_304e189d85e4d88407aec9f7b4cb8556);
#
#
#             var icon_a34897d7f465512fac4394b8ad150000 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9110a93cfb369ff4b8c8b5f5b22f2f53.setIcon(icon_a34897d7f465512fac4394b8ad150000);
#
#
#         var popup_4b0b22368dbf5ed55c5660ce30e0f76f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9c7e92f606a7deeda7ccb9c226082084 = $(`&lt;div id=&quot;html_9c7e92f606a7deeda7ccb9c226082084&q

# %%
# Example: Search for dispensaries in a specific city
city_search = "Pueblo"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[38.2765, -104.6046], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Facility Name']}</strong><br>
    <strong>{row['DBA']}</strong><br>
    Facility Type: {row['Facility Type']}<br>
    {row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip Code']}<br>
    Phone: {row['Phone-Number']}<br>
    Website: <a href="{row['Website']}">{row['Facility Name']}</a><br>
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_dispensaries_map_pueblo_v2.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_847830cda51b0e33301b183678627619 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_847830cda51b0e33301b183678627619&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_847830cda51b0e33301b183678627619 = L.map(
#                 &quot;map_847830cda51b0e33301b183678627619&quot;,
#                 {
#                     center: [38.2765, -104.6046],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d0d1d25791eafc39bec14e52e1fe6b93 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d0d1d25791eafc39bec14e52e1fe6b93.addTo(map_847830cda51b0e33301b183678627619);
#
#
#             var marker_c63e55f8a6a6d5b37dd6b0873d5bec60 = L.marker(
#                 [38.2499983, -104.6012742],
#                 {}
#             ).addTo(map_847830cda51b0e33301b183678627619);
#
#
#             var icon_4926f20228671113eabf6772c7f49aaf = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c63e55f8a6a6d5b37dd6b0873d5bec60.setIcon(icon_4926f20228671113eabf6772c7f49aaf);
#
#
#         var popup_fc4579c8495659808a086ad50bc1c0b6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0ce739dd320b82c29476c593f881679f = $(`&lt;div id=&quot;html_0ce739dd320b82c29476c593f881679f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;AF INC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Apothecary Farms&lt;/strong&gt;&lt;br&gt;     Facility Type: Medical Marijuana Store&lt;br&gt;     1917 Santa Fe Drive&lt;br&gt;     Pueblo, CO 81006&lt;br&gt;     Phone: 405-698-0990&lt;br&gt;     Website: &lt;a href=&quot;https://apothecaryfarms.com/&quot;&gt;AF INC&lt;/a&gt;&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_fc4579c8495659808a086ad50bc1c0b6.setContent(html_0ce739dd320b82c29476c593f881679f);
#
#
#
#         marker_c63e55f8a6a6d5b37dd6b0873d5bec60.bindPopup(popup_fc4579c8495659808a086ad50bc1c0b6)
#         ;
#
#
#
#
#             var marker_b9efe994bb055486ba706ea070fb8f4e = L.marker(
#                 [38.326155, -104.702136],
#                 {}
#             ).addTo(map_847830cda51b0e33301b183678627619);
#
#
#             var icon_3e986bb5a58e2440fe6f64408a1bc081 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b9efe994bb055486ba706ea070fb8f4e.setIcon(icon_3e986bb5a58e2440fe6f64408a1bc081);
#
#
#         var popup_22a3fa4af986c790e1711e50d6b7dfcb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1ce27645b975f3819bca45aaeaf288b9 = $(`&lt;div id=&quot;html_1ce27645b975f3819bca45aaeaf288b9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;AF INC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;nan&lt;/strong&gt;&lt;br&gt;     Facility Type: Retail Marijuana Store&lt;br&gt;     922 East Hailey Lane Unit B&lt;br&gt;     Pueblo West, CO 81007&lt;br&gt;     Phone: 719-647-8924&lt;br&gt;     Website: &lt;a href=&quot;https://apothecaryfarms.com/contact/apothecary-farms-pueblo-west/&quot;&gt;AF INC&lt;/a&gt;&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_22a3fa4af986c790e1711e50d6b7dfcb.setContent(html_1ce27645b975f3819bca45aaeaf288b9);
#
#
#
#         marker_b9efe994bb055486ba706ea070fb8f4e.bindPopup(popup_22a3fa4af986c790e1711e50d6b7dfcb)
#         ;
#
#
#
#
#             var marker_aa0493db50187e8641eda6126341d203 = L.marker(
#                 [38.2499983, -104.6012742],
#                 {}
#             ).addTo(map_847830cda51b0e33301b183678627619);
#
#
#             var icon_a01281caf7a3988efaefab11a41617cd = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_aa0493db50187e8641eda6126341d203.setIcon(icon_a01281caf7a3988efaefab11a41617cd);
#
#
#         var popup_de3efb1b8ee7c4aa8418cf6925897fe9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ce6a30b3ffbed6d8eb5ccaa812ec3245 = $(`&lt;div id=&quot;html_ce6a30b3ffbed6d8eb5ccaa812ec3245&quot; style=&quot;width: 100.0%; height: 100.0%;&

# %%
# Example: Search for dispensaries in a specific city
city_search = "Boulder"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[40.0150, -105.2705], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Facility Name']}</strong><br>
    <strong>{row['DBA']}</strong><br>
    Facility Type: {row['Facility Type']}<br>
    {row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip Code']}<br>
    Phone: {row['Phone-Number']}<br>
    Website: <a href="{row['Website']}">{row['Facility Name']}</a><br>
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_dispensaries_map_boulder_v2.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e3ca754559c5ee1e150b66816750e31a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e3ca754559c5ee1e150b66816750e31a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e3ca754559c5ee1e150b66816750e31a = L.map(
#                 &quot;map_e3ca754559c5ee1e150b66816750e31a&quot;,
#                 {
#                     center: [40.015, -105.2705],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_763541b4faede58046a5055a2190cb0a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_763541b4faede58046a5055a2190cb0a.addTo(map_e3ca754559c5ee1e150b66816750e31a);
#
#
#             var marker_e9a3ba3b7a9ea46fe65571aa0c2aa10a = L.marker(
#                 [40.0258738, -105.2848987],
#                 {}
#             ).addTo(map_e3ca754559c5ee1e150b66816750e31a);
#
#
#             var icon_df9022cdd807ea251a0cf21985985d5d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e9a3ba3b7a9ea46fe65571aa0c2aa10a.setIcon(icon_df9022cdd807ea251a0cf21985985d5d);
#
#
#         var popup_1565631a76662e9b79099d180d45351b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_efd73b4816dda511ca5b6684a0563668 = $(`&lt;div id=&quot;html_efd73b4816dda511ca5b6684a0563668&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;A&amp;A INVESTMENTS LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Eclipse Cannabis Company&lt;/strong&gt;&lt;br&gt;     Facility Type: Retail Marijuana Store&lt;br&gt;     933 Alpine Avenue Suite 2&lt;br&gt;     Boulder, CO 80304&lt;br&gt;     Phone: 720-420-0782&lt;br&gt;     Website: &lt;a href=&quot;https://eclipsecannabis.com/&quot;&gt;A&amp;A INVESTMENTS LLC&lt;/a&gt;&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_1565631a76662e9b79099d180d45351b.setContent(html_efd73b4816dda511ca5b6684a0563668);
#
#
#
#         marker_e9a3ba3b7a9ea46fe65571aa0c2aa10a.bindPopup(popup_1565631a76662e9b79099d180d45351b)
#         ;
#
#
#
#
#             var marker_fc7f21cda6e282d43c30c5e9a71681c2 = L.marker(
#                 [40.0323665, -105.2597227],
#                 {}
#             ).addTo(map_e3ca754559c5ee1e150b66816750e31a);
#
#
#             var icon_f9f700ba8e3cfc3bc1e6978d439b870f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_fc7f21cda6e282d43c30c5e9a71681c2.setIcon(icon_f9f700ba8e3cfc3bc1e6978d439b870f);
#
#
#         var popup_ac9c4826d8e3d153b5e6ffb381f993a5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_418ff783902a237473ff1ab9a5916eed = $(`&lt;div id=&quot;html_418ff783902a237473ff1ab9a5916eed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;ALPINE RAVEN INC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Maikoh Holistics&lt;/strong&gt;&lt;br&gt;     Facility Type: Retail Marijuana Store&lt;br&gt;     2750 Glenwood Drive, Suite 8&lt;br&gt;     Boulder, CO 80304&lt;br&gt;     Phone: 720-476-6805&lt;br&gt;     Website: &lt;a href=&quot;https://www.maikohholistics.com/&quot;&gt;ALPINE RAVEN INC&lt;/a&gt;&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_ac9c4826d8e3d153b5e6ffb381f993a5.setContent(html_418ff783902a237473ff1ab9a5916eed);
#
#
#
#         marker_fc7f21cda6e282d43c30c5e9a71681c2.bindPopup(popup_ac9c4826d8e3d153b5e6ffb381f993a5)
#         ;
#
#
#
#
#             var marker_e0810e79c2b2788f0e17ee84074acd3d = L.marker(
#                 [40.0141938, -105.227272],
#                 {}
#             ).addTo(map_e3ca754559c5ee1e150b66816750e31a);
#
#
#             var icon_760dd8f9b744e12ed4599f078e7093dc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e0810e79c2b2788f0e17ee84074acd3d.setIcon(icon_760dd8f9b744e12ed4599f078e7093dc);
#
#
#         var popup_d5d0bbc5f9cf7d58baabf46ef352990b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e853589de18590c6a048a48f43cc489f = $(`&lt;div id=&quot;html_e853589de18590c6a048a48f43cc489f&quot

# %%
# Example: Search for dispensaries in a specific city
city_search = "Grand Junction"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[39.0714, -108.5497], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Facility Name']}</strong><br>
    <strong>{row['DBA']}</strong><br>
    Facility Type: {row['Facility Type']}<br>
    {row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip Code']}<br>
    Phone: {row['Phone-Number']}<br>
    Website: <a href="{row['Website']}">{row['Facility Name']}</a><br>
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_dispensaries_map_grand_junction_v2.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6150121a5c2da023e8a4ad60a81f28f5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6150121a5c2da023e8a4ad60a81f28f5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6150121a5c2da023e8a4ad60a81f28f5 = L.map(
#                 &quot;map_6150121a5c2da023e8a4ad60a81f28f5&quot;,
#                 {
#                     center: [39.0714, -108.5497],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f26a1b28c16288fef2db47341118904b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f26a1b28c16288fef2db47341118904b.addTo(map_6150121a5c2da023e8a4ad60a81f28f5);
#
#
#             var marker_73b864a3084e4b5cd9fb33073a4d01ab = L.marker(
#                 [39.1152039, -108.5326489],
#                 {}
#             ).addTo(map_6150121a5c2da023e8a4ad60a81f28f5);
#
#
#             var icon_6d2e07455040dca11780a9be8843b836 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_73b864a3084e4b5cd9fb33073a4d01ab.setIcon(icon_6d2e07455040dca11780a9be8843b836);
#
#
#         var popup_75a494650f29f6d383ce0552b40df753 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_efb58de9050762acfca87b00b1bc284d = $(`&lt;div id=&quot;html_efb58de9050762acfca87b00b1bc284d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;CAMCAP LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Grand Junction Greenery&lt;/strong&gt;&lt;br&gt;     Facility Type: Retail Marijuana Store&lt;br&gt;     762 Horizon Drive&lt;br&gt;     Grand Junction, CO 81506&lt;br&gt;     Phone: 970-424-5888&lt;br&gt;     Website: &lt;a href=&quot;https://grandjunctiongreenery.com/marijuana-dispensary-durango/&quot;&gt;CAMCAP LLC&lt;/a&gt;&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_75a494650f29f6d383ce0552b40df753.setContent(html_efb58de9050762acfca87b00b1bc284d);
#
#
#
#         marker_73b864a3084e4b5cd9fb33073a4d01ab.bindPopup(popup_75a494650f29f6d383ce0552b40df753)
#         ;
#
#
#
#
#             var marker_f081d7d103a6e58968fc3c407b2a2040 = L.marker(
#                 [39.041449, -108.547977],
#                 {}
#             ).addTo(map_6150121a5c2da023e8a4ad60a81f28f5);
#
#
#             var icon_783bd770422e8447d353dd7b8440f37c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f081d7d103a6e58968fc3c407b2a2040.setIcon(icon_783bd770422e8447d353dd7b8440f37c);
#
#
#         var popup_95146b12215c92363a2f3e908cded5a0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a17f9b13a2dfc40753855322d387740b = $(`&lt;div id=&quot;html_a17f9b13a2dfc40753855322d387740b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;CANNA CARE LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;nan&lt;/strong&gt;&lt;br&gt;     Facility Type: Retail Marijuana Store&lt;br&gt;     2730 South Highway 50&lt;br&gt;     Grand Junction, CO 81503&lt;br&gt;     Phone: 970-248-5874&lt;br&gt;     Website: &lt;a href=&quot;https://www.cannacaregj.com/&quot;&gt;CANNA CARE LLC&lt;/a&gt;&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_95146b12215c92363a2f3e908cded5a0.setContent(html_a17f9b13a2dfc40753855322d387740b);
#
#
#
#         marker_f081d7d103a6e58968fc3c407b2a2040.bindPopup(popup_95146b12215c92363a2f3e908cded5a0)
#         ;
#
#
#
#
#             var marker_4f7da0124bfe68152d99675edcd77e78 = L.marker(
#                 [39.0555307, -108.5582239],
#                 {}
#             ).addTo(map_6150121a5c2da023e8a4ad60a81f28f5);
#
#
#             var icon_fe39966a73d7ec3b311b9fe32ad53a0c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4f7da0124bfe68152d99675edcd77e78.setIcon(icon_fe39966a73d7ec3b311b9fe32ad53a0c);
#
#
#         var popup_9af048ce6e5fa29d0137e9fa38c6030a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_54b3dae6e81438445277284c8337d0fe = $(`&lt;div id=&quot;html_54b3dae6e81438445277284c8337d0fe&quot; style=&quot;

# %% [markdown]
# ## Step 5: Export Cleaned Data to CSV

# %%
# Export the cleaned DataFrame to a CSV file
df.to_csv("cleaned_colorado_dispensaries_full_list_v3.csv", index=False)

# Confirm the export
print("Data exported to colorado_dispensaries_full_list_v3.csv")
# Out:
# Data exported to colorado_dispensaries_full_list_v3.csv
