# %% [markdown]
# # Jupyter Notebook: Parsing CSV file and Visualizing Data

# %% [markdown]
# In this notebook, we will load a CSV file, convert it to a pandas DataFrame, and then create a map visualizations using folium.

# %%
pip install pandas folium
# Out:
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (2.2.3)
# Requirement already satisfied: folium in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (0.17.0)
# Requirement already satisfied: numpy>=1.23.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/ceraven/Library/Python/3.11/lib/python/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas) (2024.2)
# Requirement already satisfied: branca>=0.6.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from folium) (0.8.0)
# Requirement already satisfied: jinja2>=2.9 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from folium) (3.1.4)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from folium) (2024.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jinja2>=2.9->folium) (2.1.5)
# Requirement already satisfied: six>=1.5 in /Users/ceraven/Library/Python/3.11/lib/python/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->folium) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->folium) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->folium) (2024.8.30)
#
# [notice] A new release of pip available: 22.3.1 -> 24.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import necessary libraries
import pandas as pd
import folium

# %% [markdown]
# ## Step 1: Load CSV File

# %%
# Load the CSV file into a DataFrame
file_path = "colorado_dispensaries_v2.csv"

df = pd.read_csv(file_path)

# Optional: Display the first few rows to check if the file is loaded correctly
df.head(15)
# Out:
#                                      Name                   Street  \
# 0                             Ace’s Place   1101 Academy Ct Unit 4
# 1                     Acme Healing Center     1644 County Road 203
# 2                     Affinity Dispensary        7739 E Colfax Ave
# 3                                   Ajoya       11950 W Colfax Ave
# 4                                   Ajoya  1100 W Dillon Rd Unit 3
# 5                    Alpenglow Botanicals      765 W Anemone Trail
# 6                 Altitude the Dispensary         6858 E Evans Ave
# 7    Altitude Organic Cannabis Dispensary  817 Little Beaver Trail
# 8               Altitude Organic Medicine        3840 N Nevada Ave
# 9               Altitude Organic Medicine        2354 E Platte Ave
# 10              Altitude Organic Medicine           523 S Tejon St
# 11              Altitude Organic Medicine      6755 N Academy Blvd
# 12  The Annie’s - a Strainwise Dispensary            135 Nevada St
# 13                       Apothecary Farms            3049 Delta Dr
# 14                       Apothecary Farms          2251 S Broadway
#
#                 City State    Zip          Type   Latitude   Longitude
# 0       Fort Collins    CO  80524   Undisclosed  40.573840 -105.047385
# 1            Durango    CO  81301   Undisclosed  37.321993 -107.851729
# 2             Denver    CO  80220   Undisclosed  39.740236 -104.898262
# 3           Lakewood    CO  80215   Undisclosed  39.740056 -105.132353
# 4         Louisville    CO  80027   Undisclosed  39.961557 -105.166179
# 5            Dillion    CO  80435  Recreational  39.589598 -106.008068
# 6             Denver    CO  80224   Undisclosed  39.678374 -104.908792
# 7             Dillon    CO  80435  Recreational  39.630299 -106.059890
# 8   Colorado Springs    CO  80907       Medical  38.888000 -104.819109
# 9   Colorado Springs    CO  80909       Medical  38.837698 -104.784484
# 10  Colorado Springs    CO  80903   Undisclosed  38.826478 -104.823799
# 11  Colorado Springs    CO  80918   Undisclosed  38.929185 -104.793010
# 12        Black Hawk    CO  80452   Undisclosed  39.799123 -105.513133
# 13  Colorado Springs    CO  80910       Medical  38.795160 -104.776840
# 14            Denver    CO  80210   Undisclosed  39.675782 -104.987681

# %% [markdown]
# ## Step 2: Clean and Prepare the Data

# %%
# Check column names and data types
df.info()

# Clean any missing latitude or longitude data
df.dropna(subset=['Longitude', 'Latitude'], inplace=True)

# Optional: Check for missing values in other important columns
df.isnull().sum()

# Optional: Display the first few rows of cleaned data
df.head(15)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550 entries, 0 to 549
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       550 non-null    object
#  1   Street     550 non-null    object
#  2   City       550 non-null    object
#  3   State      550 non-null    object
#  4   Zip        550 non-null    int64
#  5   Type       550 non-null    object
#  6   Latitude   550 non-null    float64
#  7   Longitude  550 non-null    float64
# dtypes: float64(2), int64(1), object(5)
# memory usage: 34.5+ KB
#                                      Name                   Street  \
# 0                             Ace’s Place   1101 Academy Ct Unit 4
# 1                     Acme Healing Center     1644 County Road 203
# 2                     Affinity Dispensary        7739 E Colfax Ave
# 3                                   Ajoya       11950 W Colfax Ave
# 4                                   Ajoya  1100 W Dillon Rd Unit 3
# 5                    Alpenglow Botanicals      765 W Anemone Trail
# 6                 Altitude the Dispensary         6858 E Evans Ave
# 7    Altitude Organic Cannabis Dispensary  817 Little Beaver Trail
# 8               Altitude Organic Medicine        3840 N Nevada Ave
# 9               Altitude Organic Medicine        2354 E Platte Ave
# 10              Altitude Organic Medicine           523 S Tejon St
# 11              Altitude Organic Medicine      6755 N Academy Blvd
# 12  The Annie’s - a Strainwise Dispensary            135 Nevada St
# 13                       Apothecary Farms            3049 Delta Dr
# 14                       Apothecary Farms          2251 S Broadway
#
#                 City State    Zip          Type   Latitude   Longitude
# 0       Fort Collins    CO  80524   Undisclosed  40.573840 -105.047385
# 1            Durango    CO  81301   Undisclosed  37.321993 -107.851729
# 2             Denver    CO  80220   Undisclosed  39.740236 -104.898262
# 3           Lakewood    CO  80215   Undisclosed  39.740056 -105.132353
# 4         Louisville    CO  80027   Undisclosed  39.961557 -105.166179
# 5            Dillion    CO  80435  Recreational  39.589598 -106.008068
# 6             Denver    CO  80224   Undisclosed  39.678374 -104.908792
# 7             Dillon    CO  80435  Recreational  39.630299 -106.059890
# 8   Colorado Springs    CO  80907       Medical  38.888000 -104.819109
# 9   Colorado Springs    CO  80909       Medical  38.837698 -104.784484
# 10  Colorado Springs    CO  80903   Undisclosed  38.826478 -104.823799
# 11  Colorado Springs    CO  80918   Undisclosed  38.929185 -104.793010
# 12        Black Hawk    CO  80452   Undisclosed  39.799123 -105.513133
# 13  Colorado Springs    CO  80910       Medical  38.795160 -104.776840
# 14            Denver    CO  80210   Undisclosed  39.675782 -104.987681

# %% [markdown]
# ## Step 3: Create a Searchable Map

# %%
# Initialize the map centered around Colorado
m = folium.Map(location=[39.5501, -105.7821], zoom_start=7)

# Add markers to the map for each food pantry
for idx, row in df.iterrows():
    popup_text = f"""
    <strong>{row['Name']}</strong><br>
    {row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip']}<br>
    Type: {row['Type']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m)

# Save the map as an HTML file
m.save("colorado_dispensaries_map.html")

# Display the map in the notebook
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_edcd2f224eef43d023a99ff40555739b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_edcd2f224eef43d023a99ff40555739b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_edcd2f224eef43d023a99ff40555739b = L.map(
#                 &quot;map_edcd2f224eef43d023a99ff40555739b&quot;,
#                 {
#                     center: [39.5501, -105.7821],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_45432bb05a4a0132dc53e54eb04da48f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_45432bb05a4a0132dc53e54eb04da48f.addTo(map_edcd2f224eef43d023a99ff40555739b);
#
#
#             var marker_6e167d8d890a388a1b8f454642dcc7d4 = L.marker(
#                 [40.5738399, -105.0473852],
#                 {}
#             ).addTo(map_edcd2f224eef43d023a99ff40555739b);
#
#
#             var icon_989e23141220546d028d049cbffd4929 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6e167d8d890a388a1b8f454642dcc7d4.setIcon(icon_989e23141220546d028d049cbffd4929);
#
#
#         var popup_79294eb2a49e584ea67711011447d515 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_af95b882aea106efe4da7de1fb7e5667 = $(`&lt;div id=&quot;html_af95b882aea106efe4da7de1fb7e5667&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;Ace’s Place&lt;/strong&gt;&lt;br&gt;     1101 Academy Ct Unit 4&lt;br&gt;     Fort Collins, CO 80524&lt;br&gt;     Type: Undisclosed     &lt;/div&gt;`)[0];
#                 popup_79294eb2a49e584ea67711011447d515.setContent(html_af95b882aea106efe4da7de1fb7e5667);
#
#
#
#         marker_6e167d8d890a388a1b8f454642dcc7d4.bindPopup(popup_79294eb2a49e584ea67711011447d515)
#         ;
#
#
#
#
#             var marker_c84a7a47e647012511c2883c5df5c3ce = L.marker(
#                 [37.3219931, -107.8517289],
#                 {}
#             ).addTo(map_edcd2f224eef43d023a99ff40555739b);
#
#
#             var icon_3ea45716e93066b34352ab5c8fb4bce7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c84a7a47e647012511c2883c5df5c3ce.setIcon(icon_3ea45716e93066b34352ab5c8fb4bce7);
#
#
#         var popup_1760b80c6a835ba9d75cbd91207944c9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8d4bb3620aa5f7213fb919da2d329dca = $(`&lt;div id=&quot;html_8d4bb3620aa5f7213fb919da2d329dca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;Acme Healing Center&lt;/strong&gt;&lt;br&gt;     1644 County Road 203&lt;br&gt;     Durango, CO 81301&lt;br&gt;     Type: Undisclosed     &lt;/div&gt;`)[0];
#                 popup_1760b80c6a835ba9d75cbd91207944c9.setContent(html_8d4bb3620aa5f7213fb919da2d329dca);
#
#
#
#         marker_c84a7a47e647012511c2883c5df5c3ce.bindPopup(popup_1760b80c6a835ba9d75cbd91207944c9)
#         ;
#
#
#
#
#             var marker_3ee9a68a9a48b242cf145dd2b77309de = L.marker(
#                 [39.7402361, -104.8982617],
#                 {}
#             ).addTo(map_edcd2f224eef43d023a99ff40555739b);
#
#
#             var icon_45ac1b13852399fd159953bc6fe733f3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3ee9a68a9a48b242cf145dd2b77309de.setIcon(icon_45ac1b13852399fd159953bc6fe733f3);
#
#
#         var popup_e6abeb6984331bf2e239567cf0fd1c6d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a169af660061893add4ae1d4f59d91fb = $(`&lt;div id=&quot;html_a169af660061893add4ae1d4f59d91fb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;Affinity Dispensary&lt;/strong&gt;&lt;br&gt;     7739 E Colfax Ave&lt;br&gt;     Denver, CO 80220&lt;br&gt;     Type: Undisclosed     &lt;/div&gt;`)[0];
#                 popup_e6abeb6984331bf2e239567cf0fd1c6d.setContent(html_a169af660061893add4ae1d4f59d91fb);
#
#
#
#         marker_3ee9a68a9a48b242cf145dd2b77309de.bindPopup(popup_e6abeb6984331bf2e239567cf0fd1c6d)
#         ;

# %% [markdown]
# ## Step 4: Implement Search Functionality

# %%
# Example: Search for dispensaries in a specific city
city_search = "Denver"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[39.5501, -105.7821], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Name']}</strong><br>
    {row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip']}<br>
    Type: {row['Type']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_dispensaries_map_denver.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a4fba7486b6d74164306303a611f0c60 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a4fba7486b6d74164306303a611f0c60&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a4fba7486b6d74164306303a611f0c60 = L.map(
#                 &quot;map_a4fba7486b6d74164306303a611f0c60&quot;,
#                 {
#                     center: [39.5501, -105.7821],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_50ce6ff1d810c6370a9eed0fd11a39d5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_50ce6ff1d810c6370a9eed0fd11a39d5.addTo(map_a4fba7486b6d74164306303a611f0c60);
#
#
#             var marker_36d337965be4b41419dd69a7f87e56d2 = L.marker(
#                 [39.7402361, -104.8982617],
#                 {}
#             ).addTo(map_a4fba7486b6d74164306303a611f0c60);
#
#
#             var icon_6047e4dcbe12d246a96c148120f6e514 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_36d337965be4b41419dd69a7f87e56d2.setIcon(icon_6047e4dcbe12d246a96c148120f6e514);
#
#
#         var popup_55311e029ec940b9bdef04b709af7fc9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9d0ddb43212069f6fa803d6ee1f9fdf2 = $(`&lt;div id=&quot;html_9d0ddb43212069f6fa803d6ee1f9fdf2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;Affinity Dispensary&lt;/strong&gt;&lt;br&gt;     7739 E Colfax Ave&lt;br&gt;     Denver, CO 80220&lt;br&gt;     Type: Undisclosed     &lt;/div&gt;`)[0];
#                 popup_55311e029ec940b9bdef04b709af7fc9.setContent(html_9d0ddb43212069f6fa803d6ee1f9fdf2);
#
#
#
#         marker_36d337965be4b41419dd69a7f87e56d2.bindPopup(popup_55311e029ec940b9bdef04b709af7fc9)
#         ;
#
#
#
#
#             var marker_dffb427138e2479fcb4b49b0b5d83cfd = L.marker(
#                 [39.6783736, -104.9087922],
#                 {}
#             ).addTo(map_a4fba7486b6d74164306303a611f0c60);
#
#
#             var icon_66881afa95a4eea5d6555a6ac3b92673 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_dffb427138e2479fcb4b49b0b5d83cfd.setIcon(icon_66881afa95a4eea5d6555a6ac3b92673);
#
#
#         var popup_ca24272a1db4163efb3329c9a45ea5ad = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_792863e1375ae661bcc394ba2a0be682 = $(`&lt;div id=&quot;html_792863e1375ae661bcc394ba2a0be682&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;Altitude the Dispensary&lt;/strong&gt;&lt;br&gt;     6858 E Evans Ave&lt;br&gt;     Denver, CO 80224&lt;br&gt;     Type: Undisclosed     &lt;/div&gt;`)[0];
#                 popup_ca24272a1db4163efb3329c9a45ea5ad.setContent(html_792863e1375ae661bcc394ba2a0be682);
#
#
#
#         marker_dffb427138e2479fcb4b49b0b5d83cfd.bindPopup(popup_ca24272a1db4163efb3329c9a45ea5ad)
#         ;
#
#
#
#
#             var marker_291e3973732847fd23ae6ea93dc67579 = L.marker(
#                 [39.675782, -104.987681],
#                 {}
#             ).addTo(map_a4fba7486b6d74164306303a611f0c60);
#
#
#             var icon_7e66928692eaeb908087ff17bb533f72 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_291e3973732847fd23ae6ea93dc67579.setIcon(icon_7e66928692eaeb908087ff17bb533f72);
#
#
#         var popup_8d689b6b40f8725df710da8826feb839 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0fceef6db5706ebde2c1d660f58568a2 = $(`&lt;div id=&quot;html_0fceef6db5706ebde2c1d660f58568a2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;Apothecary Farms&lt;/strong&gt;&lt;br&gt;     2251 S Broadway&lt;br&gt;     Denver, CO 80210&lt;br&gt;     Type: Undisclosed     &lt;/div&gt;`)[0];
#                 popup_8d689b6b40f8725df710da8826feb839.setContent(html_0fceef6db5706ebde2c1d660f58568a2);
#
#
#
#         marker_291e3973732847fd23ae6ea93dc67579.bindPopup(popup_8d689b6b40f8725df710da8826feb839)
#         ;
#
#
#
#
#             var ma

# %%
# Example: Search for dispensaries in a specific city
city_search = "Colorado Springs"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[38.8591, -104.8135], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Name']}</strong><br>
    {row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip']}<br>
    Type: {row['Type']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_dispensaries_map_colorado_springs.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_de48c3612c6142effd76cdef5138d8d1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_de48c3612c6142effd76cdef5138d8d1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_de48c3612c6142effd76cdef5138d8d1 = L.map(
#                 &quot;map_de48c3612c6142effd76cdef5138d8d1&quot;,
#                 {
#                     center: [38.8591, -104.8135],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_490d2cb0deb0ad4e799570ce0a321527 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_490d2cb0deb0ad4e799570ce0a321527.addTo(map_de48c3612c6142effd76cdef5138d8d1);
#
#
#             var marker_3749c3b1e3e30767f41a6e63ea127eb9 = L.marker(
#                 [38.8880004, -104.8191087],
#                 {}
#             ).addTo(map_de48c3612c6142effd76cdef5138d8d1);
#
#
#             var icon_f4dda8b48a36aeded4143d0cf6b03531 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3749c3b1e3e30767f41a6e63ea127eb9.setIcon(icon_f4dda8b48a36aeded4143d0cf6b03531);
#
#
#         var popup_47ae4eefffd243f406ea438ac51dcced = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_30bf44c7eba34c84191ad9fcc60bca76 = $(`&lt;div id=&quot;html_30bf44c7eba34c84191ad9fcc60bca76&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;Altitude Organic Medicine&lt;/strong&gt;&lt;br&gt;     3840 N Nevada Ave&lt;br&gt;     Colorado Springs, CO 80907&lt;br&gt;     Type: Medical     &lt;/div&gt;`)[0];
#                 popup_47ae4eefffd243f406ea438ac51dcced.setContent(html_30bf44c7eba34c84191ad9fcc60bca76);
#
#
#
#         marker_3749c3b1e3e30767f41a6e63ea127eb9.bindPopup(popup_47ae4eefffd243f406ea438ac51dcced)
#         ;
#
#
#
#
#             var marker_9dc1575532c7ced017768db13949ad12 = L.marker(
#                 [38.8376981, -104.7844841],
#                 {}
#             ).addTo(map_de48c3612c6142effd76cdef5138d8d1);
#
#
#             var icon_f8d83efe3177270e9659198da370cfa5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9dc1575532c7ced017768db13949ad12.setIcon(icon_f8d83efe3177270e9659198da370cfa5);
#
#
#         var popup_c471817e17d6d0617c69acb6f61ad751 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_838c0dd645cd5cacc85a230ead3ab07c = $(`&lt;div id=&quot;html_838c0dd645cd5cacc85a230ead3ab07c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;Altitude Organic Medicine&lt;/strong&gt;&lt;br&gt;     2354 E Platte Ave&lt;br&gt;     Colorado Springs, CO 80909&lt;br&gt;     Type: Medical     &lt;/div&gt;`)[0];
#                 popup_c471817e17d6d0617c69acb6f61ad751.setContent(html_838c0dd645cd5cacc85a230ead3ab07c);
#
#
#
#         marker_9dc1575532c7ced017768db13949ad12.bindPopup(popup_c471817e17d6d0617c69acb6f61ad751)
#         ;
#
#
#
#
#             var marker_076da15455fc4014aa18d964d9bb0943 = L.marker(
#                 [38.8264775, -104.8237992],
#                 {}
#             ).addTo(map_de48c3612c6142effd76cdef5138d8d1);
#
#
#             var icon_a876ce8657af5ccbfa1adf2aca9bf337 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_076da15455fc4014aa18d964d9bb0943.setIcon(icon_a876ce8657af5ccbfa1adf2aca9bf337);
#
#
#         var popup_150435f01b5caffdc7d38c562bd728ce = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cadbc166b94511fe8e9455ff2912de41 = $(`&lt;div id=&quot;html_cadbc166b94511fe8e9455ff2912de41&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;Altitude Organic Medicine&lt;/strong&gt;&lt;br&gt;     523 S Tejon St&lt;br&gt;     Colorado Springs, CO 80903&lt;br&gt;     Type: Undisclosed     &lt;/div&gt;`)[0];
#                 popup_150435f01b5caffdc7d38c562bd728ce.setContent(html_cadbc166b94511fe8e9455ff2912de41);
#
#
#
#         marker_076da15455fc4014aa18d964d9bb0943.bindPopup(popup_150435f01b5caffdc7d38c562bd728ce)

# %%
# Example: Search for dispensaries in a specific city
city_search = "Aurora"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[39.7108, -104.8125], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Name']}</strong><br>
    {row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip']}<br>
    Type: {row['Type']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_dispensaries_map_aurora.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_94c12be44745f1228a79ebc715dd5049 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_94c12be44745f1228a79ebc715dd5049&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_94c12be44745f1228a79ebc715dd5049 = L.map(
#                 &quot;map_94c12be44745f1228a79ebc715dd5049&quot;,
#                 {
#                     center: [39.7108, -104.8125],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_980970f1cf1bce7797c7eade94b7efb1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_980970f1cf1bce7797c7eade94b7efb1.addTo(map_94c12be44745f1228a79ebc715dd5049);
#
#
#             var marker_61521fe5e599cdb4aba3cd2146a976d5 = L.marker(
#                 [39.6670498, -104.8598611],
#                 {}
#             ).addTo(map_94c12be44745f1228a79ebc715dd5049);
#
#
#             var icon_c75174d792644bcb6e2bcc0b747b0472 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_61521fe5e599cdb4aba3cd2146a976d5.setIcon(icon_c75174d792644bcb6e2bcc0b747b0472);
#
#
#         var popup_2b45cbc9c9adc2b584c2f8d9ada77b32 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8731a8028610cd7708934b1db4d1bc54 = $(`&lt;div id=&quot;html_8731a8028610cd7708934b1db4d1bc54&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;Colorado Harvest Company&lt;/strong&gt;&lt;br&gt;     11002 E Yale Ave&lt;br&gt;     Aurora, CO 80014&lt;br&gt;     Type: Recreational     &lt;/div&gt;`)[0];
#                 popup_2b45cbc9c9adc2b584c2f8d9ada77b32.setContent(html_8731a8028610cd7708934b1db4d1bc54);
#
#
#
#         marker_61521fe5e599cdb4aba3cd2146a976d5.bindPopup(popup_2b45cbc9c9adc2b584c2f8d9ada77b32)
#         ;
#
#
#
#
#             var marker_ea0674004edbe3e879f81a667225c5c5 = L.marker(
#                 [39.6373002, -104.7920785],
#                 {}
#             ).addTo(map_94c12be44745f1228a79ebc715dd5049);
#
#
#             var icon_04665046e71cf856e254a017c584f1c0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ea0674004edbe3e879f81a667225c5c5.setIcon(icon_04665046e71cf856e254a017c584f1c0);
#
#
#         var popup_0ed52210d8cead85777fbacc060dc8c5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5c210d9427b294de8e1c8a841997cd4f = $(`&lt;div id=&quot;html_5c210d9427b294de8e1c8a841997cd4f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;Euflora&lt;/strong&gt;&lt;br&gt;     4343 S Buckley Road&lt;br&gt;     Aurora, CO 80013&lt;br&gt;     Type: Undisclosed     &lt;/div&gt;`)[0];
#                 popup_0ed52210d8cead85777fbacc060dc8c5.setContent(html_5c210d9427b294de8e1c8a841997cd4f);
#
#
#
#         marker_ea0674004edbe3e879f81a667225c5c5.bindPopup(popup_0ed52210d8cead85777fbacc060dc8c5)
#         ;
#
#
#
#
#             var marker_e24f230aff61d03cef12d1970eca35e5 = L.marker(
#                 [39.6025572, -104.7156415],
#                 {}
#             ).addTo(map_94c12be44745f1228a79ebc715dd5049);
#
#
#             var icon_dd5742027cf6944f59fe6feb049957c2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e24f230aff61d03cef12d1970eca35e5.setIcon(icon_dd5742027cf6944f59fe6feb049957c2);
#
#
#         var popup_ef0f737111fa1ce96d49831a680a2722 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1c385c80e6d51dbd3f51392debfe4869 = $(`&lt;div id=&quot;html_1c385c80e6d51dbd3f51392debfe4869&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;Euflora&lt;/strong&gt;&lt;br&gt;     6260 S Gun Club Road&lt;br&gt;     Aurora, CO 80016&lt;br&gt;     Type: Undisclosed     &lt;/div&gt;`)[0];
#                 popup_ef0f737111fa1ce96d49831a680a2722.setContent(html_1c385c80e6d51dbd3f51392debfe4869);
#
#
#
#         marker_e24f230aff61d03cef12d1970eca35e5.bindPopup(popup_ef0f737111fa1ce96d49831a680a2722)
#         ;
#
#
#
#
#             var marker_43795

# %%
# Example: Search for dispensaries in a specific city
city_search = "Fort Collins"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[40.5853, -105.0844], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Name']}</strong><br>
    {row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip']}<br>
    Type: {row['Type']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_dispensaries_map_fort_collins.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d3a45bf451ce1346492573c1d49bebd6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d3a45bf451ce1346492573c1d49bebd6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d3a45bf451ce1346492573c1d49bebd6 = L.map(
#                 &quot;map_d3a45bf451ce1346492573c1d49bebd6&quot;,
#                 {
#                     center: [40.5853, -105.0844],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5ed9824ab4efb7b96f55cc25572b01ff = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_5ed9824ab4efb7b96f55cc25572b01ff.addTo(map_d3a45bf451ce1346492573c1d49bebd6);
#
#
#             var marker_d35e9786ec4d0c1b9be2e3a6fb0995bc = L.marker(
#                 [40.5738399, -105.0473852],
#                 {}
#             ).addTo(map_d3a45bf451ce1346492573c1d49bebd6);
#
#
#             var icon_94a9b1a530e041468a2856a89df02cee = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d35e9786ec4d0c1b9be2e3a6fb0995bc.setIcon(icon_94a9b1a530e041468a2856a89df02cee);
#
#
#         var popup_3257928ae65cbab083e0bc3f0b73458c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_34053968280ce2fea970bfca825313a8 = $(`&lt;div id=&quot;html_34053968280ce2fea970bfca825313a8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;Ace’s Place&lt;/strong&gt;&lt;br&gt;     1101 Academy Ct Unit 4&lt;br&gt;     Fort Collins, CO 80524&lt;br&gt;     Type: Undisclosed     &lt;/div&gt;`)[0];
#                 popup_3257928ae65cbab083e0bc3f0b73458c.setContent(html_34053968280ce2fea970bfca825313a8);
#
#
#
#         marker_d35e9786ec4d0c1b9be2e3a6fb0995bc.bindPopup(popup_3257928ae65cbab083e0bc3f0b73458c)
#         ;
#
#
#
#
#             var marker_39a13b2ad040ebb926e206a5d9d32dac = L.marker(
#                 [40.5779514, -105.0035754],
#                 {}
#             ).addTo(map_d3a45bf451ce1346492573c1d49bebd6);
#
#
#             var icon_ff5bf329a8539fa1ab26c71b0f81de0d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_39a13b2ad040ebb926e206a5d9d32dac.setIcon(icon_ff5bf329a8539fa1ab26c71b0f81de0d);
#
#
#         var popup_97f7cab7c6d5ff8ce61324dd917b8a43 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b2393ef63be06d4e48f162888f15293b = $(`&lt;div id=&quot;html_b2393ef63be06d4e48f162888f15293b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;Choice Organics&lt;/strong&gt;&lt;br&gt;     813 Smithfield Dr&lt;br&gt;     Fort Collins, CO 80524&lt;br&gt;     Type: Undisclosed     &lt;/div&gt;`)[0];
#                 popup_97f7cab7c6d5ff8ce61324dd917b8a43.setContent(html_b2393ef63be06d4e48f162888f15293b);
#
#
#
#         marker_39a13b2ad040ebb926e206a5d9d32dac.bindPopup(popup_97f7cab7c6d5ff8ce61324dd917b8a43)
#         ;
#
#
#
#
#             var marker_2d9ea4704a0d8e257269cadb37c5aa4e = L.marker(
#                 [40.5763751, -105.0767149],
#                 {}
#             ).addTo(map_d3a45bf451ce1346492573c1d49bebd6);
#
#
#             var icon_640468f9754aa40bafb6815b040a0844 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2d9ea4704a0d8e257269cadb37c5aa4e.setIcon(icon_640468f9754aa40bafb6815b040a0844);
#
#
#         var popup_ac58fe6c7a143758dcd96fcb40ef32e4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7be952690e208b8703aa3f3b457cd142 = $(`&lt;div id=&quot;html_7be952690e208b8703aa3f3b457cd142&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;Elite Organics&lt;/strong&gt;&lt;br&gt;     804 S College Ave Unit C&lt;br&gt;     Fort Collins, CO 80524&lt;br&gt;     Type: Undisclosed     &lt;/div&gt;`)[0];
#                 popup_ac58fe6c7a143758dcd96fcb40ef32e4.setContent(html_7be952690e208b8703aa3f3b457cd142);
#
#
#
#         marker_2d9ea4704a0d8e257269cadb37c5aa4e.bindPopup(popup_ac58fe6c7a143758dcd96fcb40ef32e4)
#         ;

# %%
# Example: Search for dispensaries in a specific city
city_search = "Lakewood"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[39.7109, -105.0815], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Name']}</strong><br>
    {row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip']}<br>
    Type: {row['Type']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_dispensaries_map_lakewood.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fe14fea51b3b586f94ef006a4af59105 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fe14fea51b3b586f94ef006a4af59105&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fe14fea51b3b586f94ef006a4af59105 = L.map(
#                 &quot;map_fe14fea51b3b586f94ef006a4af59105&quot;,
#                 {
#                     center: [39.7109, -105.0815],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cb3700589cc1bde10bacdeff2b115cdf = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_cb3700589cc1bde10bacdeff2b115cdf.addTo(map_fe14fea51b3b586f94ef006a4af59105);
#
#
#             var marker_bd6383a590fc17f70e00b4bc2f50567c = L.marker(
#                 [39.7400564, -105.1323528],
#                 {}
#             ).addTo(map_fe14fea51b3b586f94ef006a4af59105);
#
#
#             var icon_1dbc8c40cf345f4ae97d8b8d5c0f1a6d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_bd6383a590fc17f70e00b4bc2f50567c.setIcon(icon_1dbc8c40cf345f4ae97d8b8d5c0f1a6d);
#
#
#         var popup_b3f3b921dabd896b74919d80f4ec7fc6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d2181cfbe84079e081b510b5686d1969 = $(`&lt;div id=&quot;html_d2181cfbe84079e081b510b5686d1969&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;Ajoya&lt;/strong&gt;&lt;br&gt;     11950 W Colfax Ave&lt;br&gt;     Lakewood, CO 80215&lt;br&gt;     Type: Undisclosed     &lt;/div&gt;`)[0];
#                 popup_b3f3b921dabd896b74919d80f4ec7fc6.setContent(html_d2181cfbe84079e081b510b5686d1969);
#
#
#
#         marker_bd6383a590fc17f70e00b4bc2f50567c.bindPopup(popup_b3f3b921dabd896b74919d80f4ec7fc6)
#         ;
#
#
#
#
#             var marker_c760d6f68934ac893083cad6d11ba75c = L.marker(
#                 [39.7106571, -105.1181927],
#                 {}
#             ).addTo(map_fe14fea51b3b586f94ef006a4af59105);
#
#
#             var icon_fb063ddfb456aa532caadc955d4a065c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c760d6f68934ac893083cad6d11ba75c.setIcon(icon_fb063ddfb456aa532caadc955d4a065c);
#
#
#         var popup_66fdf2b210a1df111afc1391c3fd042a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fb48c9b437cc0021137e8818325439df = $(`&lt;div id=&quot;html_fb48c9b437cc0021137e8818325439df&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;Ascend Cannabis Company&lt;/strong&gt;&lt;br&gt;     10712 W Alameda Ave&lt;br&gt;     Lakewood, CO 80226&lt;br&gt;     Type: Undisclosed     &lt;/div&gt;`)[0];
#                 popup_66fdf2b210a1df111afc1391c3fd042a.setContent(html_fb48c9b437cc0021137e8818325439df);
#
#
#
#         marker_c760d6f68934ac893083cad6d11ba75c.bindPopup(popup_66fdf2b210a1df111afc1391c3fd042a)
#         ;
#
#
#
#
#             var marker_51b2743c8695d95f4da48cdafa7a987d = L.marker(
#                 [39.6965991, -105.0700452],
#                 {}
#             ).addTo(map_fe14fea51b3b586f94ef006a4af59105);
#
#
#             var icon_d4947c372f89a28919129e81e69a955d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_51b2743c8695d95f4da48cdafa7a987d.setIcon(icon_d4947c372f89a28919129e81e69a955d);
#
#
#         var popup_2b479e48253ea6c99bf65389c61737c5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a018a4efbc60b1477725dd561aed65df = $(`&lt;div id=&quot;html_a018a4efbc60b1477725dd561aed65df&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;Cross Genetics&lt;/strong&gt;&lt;br&gt;     6745 W Mississippi Ave&lt;br&gt;     Lakewood, CO 80226&lt;br&gt;     Type: Medical     &lt;/div&gt;`)[0];
#                 popup_2b479e48253ea6c99bf65389c61737c5.setContent(html_a018a4efbc60b1477725dd561aed65df);
#
#
#
#         marker_51b2743c8695d95f4da48cdafa7a987d.bindPopup(popup_2b479e48253ea6c99bf65389c61737c5)
#         ;
#
#
#
#
#             var mar

# %%
# Example: Search for dispensaries in a specific city
city_search = "Arvada"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[39.8028, -105.0875], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Name']}</strong><br>
    {row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip']}<br>
    Type: {row['Type']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_dispensaries_map_arvada.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fc54f025c7c0dbcc1d5565f9075b4e5b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fc54f025c7c0dbcc1d5565f9075b4e5b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fc54f025c7c0dbcc1d5565f9075b4e5b = L.map(
#                 &quot;map_fc54f025c7c0dbcc1d5565f9075b4e5b&quot;,
#                 {
#                     center: [39.8028, -105.0875],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_44784ab7a391c18050ae0b0cba03ef69 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_44784ab7a391c18050ae0b0cba03ef69.addTo(map_fc54f025c7c0dbcc1d5565f9075b4e5b);
#
#
#             var marker_7f8c7aaebe9a2bbce50dbaa1fe75b9eb = L.marker(
#                 [39.799578, -105.0531965],
#                 {}
#             ).addTo(map_fc54f025c7c0dbcc1d5565f9075b4e5b);
#
#
#             var icon_f84817bdc40e06e9064ae310aa2d1f0c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7f8c7aaebe9a2bbce50dbaa1fe75b9eb.setIcon(icon_f84817bdc40e06e9064ae310aa2d1f0c);
#
#
#         var popup_a07db3eff9615ec658824938ce458768 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ce3a80de891df94ea3de32250555f031 = $(`&lt;div id=&quot;html_ce3a80de891df94ea3de32250555f031&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;Berkeley Dispensary&lt;/strong&gt;&lt;br&gt;     5398 Sheridan Blvd&lt;br&gt;     Arvada, CO 80002&lt;br&gt;     Type: Undisclosed     &lt;/div&gt;`)[0];
#                 popup_a07db3eff9615ec658824938ce458768.setContent(html_ce3a80de891df94ea3de32250555f031);
#
#
#
#         marker_7f8c7aaebe9a2bbce50dbaa1fe75b9eb.bindPopup(popup_a07db3eff9615ec658824938ce458768)
#         ;
#
#
#
#
#             var marker_63e7f1d9fcc064a5972ea9cf0177945c = L.marker(
#                 [39.799578, -105.0531965],
#                 {}
#             ).addTo(map_fc54f025c7c0dbcc1d5565f9075b4e5b);
#
#
#             var icon_8c9300d43c859fafc97b14e54465b9f9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_63e7f1d9fcc064a5972ea9cf0177945c.setIcon(icon_8c9300d43c859fafc97b14e54465b9f9);
#
#
#         var popup_a199238d83161c1226fcfe9b5336b3ff = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_74dbd50d9ebad4ca7355d2db6a588f30 = $(`&lt;div id=&quot;html_74dbd50d9ebad4ca7355d2db6a588f30&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;Yuma Way Cannabis Co&lt;/strong&gt;&lt;br&gt;     5389 Sheridan Boulevard&lt;br&gt;     Arvada, CO 80012&lt;br&gt;     Type: Recreational     &lt;/div&gt;`)[0];
#                 popup_a199238d83161c1226fcfe9b5336b3ff.setContent(html_74dbd50d9ebad4ca7355d2db6a588f30);
#
#
#
#         marker_63e7f1d9fcc064a5972ea9cf0177945c.bindPopup(popup_a199238d83161c1226fcfe9b5336b3ff)
#         ;
#
#
#
#
#             tile_layer_44784ab7a391c18050ae0b0cba03ef69.addTo(map_fc54f025c7c0dbcc1d5565f9075b4e5b);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Example: Search for dispensaries in a specific city
city_search = "Greeley"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[40.4233, -104.7112], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Name']}</strong><br>
    {row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip']}<br>
    Type: {row['Type']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_dispensaries_map_greeley.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b72240e58b351bdf5e40fa6f7597ccff {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b72240e58b351bdf5e40fa6f7597ccff&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b72240e58b351bdf5e40fa6f7597ccff = L.map(
#                 &quot;map_b72240e58b351bdf5e40fa6f7597ccff&quot;,
#                 {
#                     center: [40.4233, -104.7112],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f4a02622039e9035de4401a4d9afc722 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f4a02622039e9035de4401a4d9afc722.addTo(map_b72240e58b351bdf5e40fa6f7597ccff);
#
#
#             var marker_a242ff17c604985bc41e41be411fb86f = L.marker(
#                 [40.396977, -104.687597],
#                 {}
#             ).addTo(map_b72240e58b351bdf5e40fa6f7597ccff);
#
#
#             var icon_31fb431fbbf6839f2d80b0659039cb46 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a242ff17c604985bc41e41be411fb86f.setIcon(icon_31fb431fbbf6839f2d80b0659039cb46);
#
#
#         var popup_bbc349235e6e4d3f1ac41eebd43316b7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e6d6438a8ee16713b8daa9b2cf01db93 = $(`&lt;div id=&quot;html_e6d6438a8ee16713b8daa9b2cf01db93&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;High Plains Strainz&lt;/strong&gt;&lt;br&gt;     2506 Sixth Ave&lt;br&gt;     Greeley, CO 80631&lt;br&gt;     Type: Undisclosed     &lt;/div&gt;`)[0];
#                 popup_bbc349235e6e4d3f1ac41eebd43316b7.setContent(html_e6d6438a8ee16713b8daa9b2cf01db93);
#
#
#
#         marker_a242ff17c604985bc41e41be411fb86f.bindPopup(popup_bbc349235e6e4d3f1ac41eebd43316b7)
#         ;
#
#
#
#
#             var marker_737ae2be789037bc7be9163f9489eb5c = L.marker(
#                 [40.3942101, -104.6630567],
#                 {}
#             ).addTo(map_b72240e58b351bdf5e40fa6f7597ccff);
#
#
#             var icon_0cc05628c67b76e663310aab27dac248 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_737ae2be789037bc7be9163f9489eb5c.setIcon(icon_0cc05628c67b76e663310aab27dac248);
#
#
#         var popup_fc72b4f01799d42e32aa5e4cfc27dc95 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9cd408c0e847c6954a3fb1ecfe402e48 = $(`&lt;div id=&quot;html_9cd408c0e847c6954a3fb1ecfe402e48&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;Nature’s Herbs and Wellness&lt;/strong&gt;&lt;br&gt;     522 27th St&lt;br&gt;     Greeley, CO 80631&lt;br&gt;     Type: Undisclosed     &lt;/div&gt;`)[0];
#                 popup_fc72b4f01799d42e32aa5e4cfc27dc95.setContent(html_9cd408c0e847c6954a3fb1ecfe402e48);
#
#
#
#         marker_737ae2be789037bc7be9163f9489eb5c.bindPopup(popup_fc72b4f01799d42e32aa5e4cfc27dc95)
#         ;
#
#
#
#
#             var marker_59a5b9ba844aa9ba181382d8b4a74a08 = L.marker(
#                 [40.396856, -104.689776],
#                 {}
#             ).addTo(map_b72240e58b351bdf5e40fa6f7597ccff);
#
#
#             var icon_383bc6bfe2ab0aa88a82244b04ceec60 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_59a5b9ba844aa9ba181382d8b4a74a08.setIcon(icon_383bc6bfe2ab0aa88a82244b04ceec60);
#
#
#         var popup_92398415e5122b17217dddb6bb05e16f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e7e450a1b361fd624faf2438a7aa89fa = $(`&lt;div id=&quot;html_e7e450a1b361fd624faf2438a7aa89fa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;Smokey’s 420 House&lt;/strong&gt;&lt;br&gt;     2515 Seventh Ave&lt;br&gt;     Greeley, CO 80631&lt;br&gt;     Type: Undisclosed     &lt;/div&gt;`)[0];
#                 popup_92398415e5122b17217dddb6bb05e16f.setContent(html_e7e450a1b361fd624faf2438a7aa89fa);
#
#
#
#         marker_59a5b9ba844aa9ba181382d8b4a74a08.bindPopup(popup_92398415e5122b17217dddb6bb05e16f)
#         ;
#
#
#
#
#             tile_l

# %%
# Example: Search for dispensaries in a specific city
city_search = "Pueblo"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[38.2765, -104.6046], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Name']}</strong><br>
    {row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip']}<br>
    Type: {row['Type']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_dispensaries_map_pueblo.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_34691e00a3377b40396e615b72e1034c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_34691e00a3377b40396e615b72e1034c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_34691e00a3377b40396e615b72e1034c = L.map(
#                 &quot;map_34691e00a3377b40396e615b72e1034c&quot;,
#                 {
#                     center: [38.2765, -104.6046],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_65fbf581dd86887774c707939c726024 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_65fbf581dd86887774c707939c726024.addTo(map_34691e00a3377b40396e615b72e1034c);
#
#
#             var marker_8639e0de811aa837ced57572f1eec549 = L.marker(
#                 [38.2499983, -104.6012742],
#                 {}
#             ).addTo(map_34691e00a3377b40396e615b72e1034c);
#
#
#             var icon_84ca567fda78ee644e8298e4e64b42c3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8639e0de811aa837ced57572f1eec549.setIcon(icon_84ca567fda78ee644e8298e4e64b42c3);
#
#
#         var popup_0d5cf6772b3a5cbeee5a3eef63ba3395 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_86015e25687bf89693ddd5b1844b8e41 = $(`&lt;div id=&quot;html_86015e25687bf89693ddd5b1844b8e41&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;Apothecary Farms&lt;/strong&gt;&lt;br&gt;     1917 Santa Fe Dr&lt;br&gt;     Pueblo, CO 81006&lt;br&gt;     Type: Undisclosed     &lt;/div&gt;`)[0];
#                 popup_0d5cf6772b3a5cbeee5a3eef63ba3395.setContent(html_86015e25687bf89693ddd5b1844b8e41);
#
#
#
#         marker_8639e0de811aa837ced57572f1eec549.bindPopup(popup_0d5cf6772b3a5cbeee5a3eef63ba3395)
#         ;
#
#
#
#
#             var marker_2d5949db8dca6fa9482961344eb5093b = L.marker(
#                 [38.2188076, -104.6415403],
#                 {}
#             ).addTo(map_34691e00a3377b40396e615b72e1034c);
#
#
#             var icon_bc5b475b44e49a0af0bf3831f6ca6d41 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2d5949db8dca6fa9482961344eb5093b.setIcon(icon_bc5b475b44e49a0af0bf3831f6ca6d41);
#
#
#         var popup_2e073e65e5fbb386f55d0a10c7a22c38 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_46487381a2e9ea626efdf9789a8913d9 = $(`&lt;div id=&quot;html_46487381a2e9ea626efdf9789a8913d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;Canna Cabinet&lt;/strong&gt;&lt;br&gt;     2630 W Pueblo Blvd Unit E&lt;br&gt;     Pueblo, CO 81004&lt;br&gt;     Type: Undisclosed     &lt;/div&gt;`)[0];
#                 popup_2e073e65e5fbb386f55d0a10c7a22c38.setContent(html_46487381a2e9ea626efdf9789a8913d9);
#
#
#
#         marker_2d5949db8dca6fa9482961344eb5093b.bindPopup(popup_2e073e65e5fbb386f55d0a10c7a22c38)
#         ;
#
#
#
#
#             var marker_6b49c39d5725285a361e04560291d9d1 = L.marker(
#                 [38.3380009, -104.6201045],
#                 {}
#             ).addTo(map_34691e00a3377b40396e615b72e1034c);
#
#
#             var icon_b634dbd6be9a6e8a0003875e35b8c1cc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6b49c39d5725285a361e04560291d9d1.setIcon(icon_b634dbd6be9a6e8a0003875e35b8c1cc);
#
#
#         var popup_994049c4663f36af7525dd43b3ae59fc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_793a657772e55267addc2fad50c41a9d = $(`&lt;div id=&quot;html_793a657772e55267addc2fad50c41a9d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;The Cannabis Depot&lt;/strong&gt;&lt;br&gt;     2440 N Interstate 25&lt;br&gt;     Pueblo, CO 81008&lt;br&gt;     Type: Recreational     &lt;/div&gt;`)[0];
#                 popup_994049c4663f36af7525dd43b3ae59fc.setContent(html_793a657772e55267addc2fad50c41a9d);
#
#
#
#         marker_6b49c39d5725285a361e04560291d9d1.bindPopup(popup_994049c4663f36af7525dd43b3ae59fc)
#         ;
#
#
#
#
#             v

# %%
# Example: Search for dispensaries in a specific city
city_search = "Boulder"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[40.0150, -105.2705], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Name']}</strong><br>
    {row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip']}<br>
    Type: {row['Type']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_dispensaries_map_boulder.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7dbc30c6ab5b719ae282cf09e15a0e86 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7dbc30c6ab5b719ae282cf09e15a0e86&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7dbc30c6ab5b719ae282cf09e15a0e86 = L.map(
#                 &quot;map_7dbc30c6ab5b719ae282cf09e15a0e86&quot;,
#                 {
#                     center: [40.015, -105.2705],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_06d14e25f0cd281066f37964b26e140b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_06d14e25f0cd281066f37964b26e140b.addTo(map_7dbc30c6ab5b719ae282cf09e15a0e86);
#
#
#             var marker_4ac9b0805962bd164328e435fe41f348 = L.marker(
#                 [40.0141938, -105.227272],
#                 {}
#             ).addTo(map_7dbc30c6ab5b719ae282cf09e15a0e86);
#
#
#             var icon_33595b11d33070a60073d63c910cf222 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4ac9b0805962bd164328e435fe41f348.setIcon(icon_33595b11d33070a60073d63c910cf222);
#
#
#         var popup_b0b4b28bcec79a30b53bd10fabe87103 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b80010330a789e8d72365ef8d09b4308 = $(`&lt;div id=&quot;html_b80010330a789e8d72365ef8d09b4308&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;Boulder Wellness Center&lt;/strong&gt;&lt;br&gt;     5420 Arapahoe Ave Unit F&lt;br&gt;     Boulder, CO 80303&lt;br&gt;     Type: Undisclosed     &lt;/div&gt;`)[0];
#                 popup_b0b4b28bcec79a30b53bd10fabe87103.setContent(html_b80010330a789e8d72365ef8d09b4308);
#
#
#
#         marker_4ac9b0805962bd164328e435fe41f348.bindPopup(popup_b0b4b28bcec79a30b53bd10fabe87103)
#         ;
#
#
#
#
#             var marker_c05b16040ddbc2543011d259e4b41c18 = L.marker(
#                 [40.0174738, -105.2538668],
#                 {}
#             ).addTo(map_7dbc30c6ab5b719ae282cf09e15a0e86);
#
#
#             var icon_36bc49aa05dc3842e782c49656a85691 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c05b16040ddbc2543011d259e4b41c18.setIcon(icon_36bc49aa05dc3842e782c49656a85691);
#
#
#         var popup_89947d371391e36afde77bf814a993e6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0b57a298f09c906210c5b0d6ffad8fa4 = $(`&lt;div id=&quot;html_0b57a298f09c906210c5b0d6ffad8fa4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;Drift&lt;/strong&gt;&lt;br&gt;     1750 30th St Unit 12&lt;br&gt;     Boulder, CO 80301&lt;br&gt;     Type: Undisclosed     &lt;/div&gt;`)[0];
#                 popup_89947d371391e36afde77bf814a993e6.setContent(html_0b57a298f09c906210c5b0d6ffad8fa4);
#
#
#
#         marker_c05b16040ddbc2543011d259e4b41c18.bindPopup(popup_89947d371391e36afde77bf814a993e6)
#         ;
#
#
#
#
#             var marker_19986a0f06b3876b4f1495ba2568206d = L.marker(
#                 [39.9856087, -105.2294495],
#                 {}
#             ).addTo(map_7dbc30c6ab5b719ae282cf09e15a0e86);
#
#
#             var icon_aad563aa7f6c73c6fc7dbff7345be4b7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_19986a0f06b3876b4f1495ba2568206d.setIcon(icon_aad563aa7f6c73c6fc7dbff7345be4b7);
#
#
#         var popup_2955d128f1885ed19ae49e0a05e247b7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a7820e9899fe54f894ba21d52e3fc5aa = $(`&lt;div id=&quot;html_a7820e9899fe54f894ba21d52e3fc5aa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;Drift&lt;/strong&gt;&lt;br&gt;     5190 S Boulder Rd&lt;br&gt;     Boulder, CO 80303&lt;br&gt;     Type: Undisclosed     &lt;/div&gt;`)[0];
#                 popup_2955d128f1885ed19ae49e0a05e247b7.setContent(html_a7820e9899fe54f894ba21d52e3fc5aa);
#
#
#
#         marker_19986a0f06b3876b4f1495ba2568206d.bindPopup(popup_2955d128f1885ed19ae49e0a05e247b7)
#         ;
#
#
#
#
#             var marker_9bec

# %%
# Example: Search for dispensaries in a specific city
city_search = "Durango"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[39.0714, -108.5497], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Name']}</strong><br>
    {row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip']}<br>
    Type: {row['Type']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_dispensaries_map_durango.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e668f36e132c798680c159e01ad6792e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e668f36e132c798680c159e01ad6792e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e668f36e132c798680c159e01ad6792e = L.map(
#                 &quot;map_e668f36e132c798680c159e01ad6792e&quot;,
#                 {
#                     center: [39.0714, -108.5497],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fc44bdc66d469c099b675b458e81e0be = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_fc44bdc66d469c099b675b458e81e0be.addTo(map_e668f36e132c798680c159e01ad6792e);
#
#
#             var marker_84cf64e46745130a80e5e4c846696e23 = L.marker(
#                 [37.3219931, -107.8517289],
#                 {}
#             ).addTo(map_e668f36e132c798680c159e01ad6792e);
#
#
#             var icon_a43ef60e94a3cb922f01ede79691ba59 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_84cf64e46745130a80e5e4c846696e23.setIcon(icon_a43ef60e94a3cb922f01ede79691ba59);
#
#
#         var popup_c9f55914a13cfb42a13e0dd6ecb15139 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d6f8f92bef63f61ae346aa8d3980a464 = $(`&lt;div id=&quot;html_d6f8f92bef63f61ae346aa8d3980a464&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;Acme Healing Center&lt;/strong&gt;&lt;br&gt;     1644 County Road 203&lt;br&gt;     Durango, CO 81301&lt;br&gt;     Type: Undisclosed     &lt;/div&gt;`)[0];
#                 popup_c9f55914a13cfb42a13e0dd6ecb15139.setContent(html_d6f8f92bef63f61ae346aa8d3980a464);
#
#
#
#         marker_84cf64e46745130a80e5e4c846696e23.bindPopup(popup_c9f55914a13cfb42a13e0dd6ecb15139)
#         ;
#
#
#
#
#             var marker_91c2594dd8c3b7d75527c5e0b43baa61 = L.marker(
#                 [37.264992, -107.879],
#                 {}
#             ).addTo(map_e668f36e132c798680c159e01ad6792e);
#
#
#             var icon_43285f60142330e8d58e9343d51fe346 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_91c2594dd8c3b7d75527c5e0b43baa61.setIcon(icon_43285f60142330e8d58e9343d51fe346);
#
#
#         var popup_560b03e9f57c40bbc81a85581478cfa0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a7feceb8c44f564349a8424254afed7e = $(`&lt;div id=&quot;html_a7feceb8c44f564349a8424254afed7e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;Colorado Grow Company&lt;/strong&gt;&lt;br&gt;     965 1/2 Main Ave&lt;br&gt;     Durango, CO 81301&lt;br&gt;     Type: Undisclosed     &lt;/div&gt;`)[0];
#                 popup_560b03e9f57c40bbc81a85581478cfa0.setContent(html_a7feceb8c44f564349a8424254afed7e);
#
#
#
#         marker_91c2594dd8c3b7d75527c5e0b43baa61.bindPopup(popup_560b03e9f57c40bbc81a85581478cfa0)
#         ;
#
#
#
#
#             var marker_2951932278e8496eaaa12f6272572236 = L.marker(
#                 [37.318364, -107.880367],
#                 {}
#             ).addTo(map_e668f36e132c798680c159e01ad6792e);
#
#
#             var icon_91a7d8018765e0dcb8c7754d6e6372cf = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2951932278e8496eaaa12f6272572236.setIcon(icon_91a7d8018765e0dcb8c7754d6e6372cf);
#
#
#         var popup_f1f72e8d3bbafb520806ec09c5c7792d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_da082440c20a955d29a5ffaab52703b0 = $(`&lt;div id=&quot;html_da082440c20a955d29a5ffaab52703b0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;Durango Cannabis Company&lt;/strong&gt;&lt;br&gt;     28753 US160&lt;br&gt;     Durango, CO 81301&lt;br&gt;     Type: Recreational     &lt;/div&gt;`)[0];
#                 popup_f1f72e8d3bbafb520806ec09c5c7792d.setContent(html_da082440c20a955d29a5ffaab52703b0);
#
#
#
#         marker_2951932278e8496eaaa12f6272572236.bindPopup(popup_f1f72e8d3bbafb520806ec09c5c7792d)
#         ;
#
#
#
#
#             va

# %% [markdown]
# ## Step 5: Export Cleaned Data to CSV

# %%
# Export the cleaned DataFrame to a CSV file
df.to_csv("cleaned_colorado_dispensaries_v2.csv", index=False)

# Confirm the export
print("Data exported to colorado_dispensaries_v2.csv")
# Out:
# Data exported to cleaned_dispensaries_v2.csv
