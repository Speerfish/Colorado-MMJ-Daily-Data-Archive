# %% [markdown]
# # Jupyter Notebook: Parsing CSV file and Visualizing Data

# %% [markdown]
# In this notebook, we will load a CSV file, convert it to a pandas DataFrame, and then create multiple county specific map visualizations using folium.

# %%
pip install pandas folium
# Out:
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (2.2.3)
# Requirement already satisfied: folium in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (0.17.0)
# Requirement already satisfied: numpy>=1.23.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/ceraven/Library/Python/3.11/lib/python/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas) (2024.2)
# Requirement already satisfied: branca>=0.6.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from folium) (0.8.0)
# Requirement already satisfied: jinja2>=2.9 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from folium) (3.1.4)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from folium) (2024.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jinja2>=2.9->folium) (2.1.5)
# Requirement already satisfied: six>=1.5 in /Users/ceraven/Library/Python/3.11/lib/python/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->folium) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->folium) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->folium) (2024.8.30)
#
# [notice] A new release of pip available: 22.3.1 -> 24.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import necessary libraries
import pandas as pd
import folium

# %% [markdown]
# ## Step 1: Load CSV File

# %%
# Load the CSV file into a DataFrame
file_path = "colorado_hemp.csv"

df = pd.read_csv(file_path)

# Optional: Display the first few rows to check if the file is loaded correctly
df.head(15)
# Out:
#                                             Name    County State  \
# 0                                        6ixhemp   Douglas    CO
# 1   Affordable housing hemp fiber and composites   Boulder    CO
# 2                   Agriculture Policy Solutions   Larimer    CO
# 3                                 Antedotum Inc.    Pitkin    CO
# 4                             Apex Herbology LLC    Denver    CO
# 5                                     BoCo Farms   Boulder    CO
# 6                             Cabaniss Group LLC   Fremont    CO
# 7                                Cloud CO. Farms   Alamosa    CO
# 8                         Colorado Hemp Genetics   El Paso    CO
# 9            Colorado Hemp Procesing Cooporative    Denver    CO
# 10                             Dama Distributing     Adams    CO
# 11                                      Delta AG     Delta    CO
# 12                               DRAM Apothecary   Boulder    CO
# 13                             element6 Dynamics   Boulder    CO
# 14                     Enviro Textiles/Machinery  Garfield    CO
#
#                  Industry            Category  \
# 0   Industrial Processing       Decortication
# 1            Construction               Other
# 2      Genetics & Testing         Lab Testing
# 3   Industrial Processing  Other End Products
# 4      Genetics & Testing         Lab Testing
# 5      Genetics & Testing  Seeds and Genetics
# 6   Industrial Processing      CBD Extraction
# 7      Genetics & Testing  Seeds and Genetics
# 8      Genetics & Testing  Seeds and Genetics
# 9   Industrial Processing      CBD Extraction
# 10  Equipment & Packaging           Packaging
# 11  Industrial Processing       Decortication
# 12           Food & Drink            Beverage
# 13     Genetics & Testing  Seeds and Genetics
# 14  Industrial Processing       Decortication
#
#                             Website   Latitude  Longitude
# 0      https://6ixhemp.org/contact/  39.348300  -104.9202
# 1                    GAPhousing.com  40.088000  -105.3448
# 2         www.agpolicysolutions.com  40.629100  -105.4465
# 3                www.antedotum.comm  39.190000  -106.8100
# 4                 apexherbology.com  39.764400  -104.9549
# 5                               NaN  40.088111  -105.3448
# 6                 CabanissGroup.com  38.484200  -105.4521
# 7             www.cloudcofarms.comm  37.546600  -105.7781
# 8       https://cohempgenetics.com/  38.829600  -104.5628
# 9                https://cohpc.org/  39.764411  -104.9549
# 10             Damadistributing.com  39.870100  -104.1631
# 11             https://deltaag.com/  38.941900  -107.8040
# 12  https://www.dramapothecary.com/  40.088222  -105.3448
# 13     https://element6dynamics.com  40.088333  -105.3448
# 14  https://www.envirotextiles.com/  39.718400  -107.5261

# %% [markdown]
# ## Step 2: Clean and Prepare the Data

# %%
# Check column names and data types
df.info()

# Clean any missing latitude or longitude data
df.dropna(subset=['Longitude', 'Latitude'], inplace=True)

# Optional: Check for missing values in other important columns
df.isnull().sum()

# Optional: Display the first few rows of cleaned data
df.head(15)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       59 non-null     object
#  1   County     59 non-null     object
#  2   State      59 non-null     object
#  3   Industry   59 non-null     object
#  4   Category   59 non-null     object
#  5   Website    58 non-null     object
#  6   Latitude   59 non-null     float64
#  7   Longitude  59 non-null     float64
# dtypes: float64(2), object(6)
# memory usage: 3.8+ KB
#                                             Name    County State  \
# 0                                        6ixhemp   Douglas    CO
# 1   Affordable housing hemp fiber and composites   Boulder    CO
# 2                   Agriculture Policy Solutions   Larimer    CO
# 3                                 Antedotum Inc.    Pitkin    CO
# 4                             Apex Herbology LLC    Denver    CO
# 5                                     BoCo Farms   Boulder    CO
# 6                             Cabaniss Group LLC   Fremont    CO
# 7                                Cloud CO. Farms   Alamosa    CO
# 8                         Colorado Hemp Genetics   El Paso    CO
# 9            Colorado Hemp Procesing Cooporative    Denver    CO
# 10                             Dama Distributing     Adams    CO
# 11                                      Delta AG     Delta    CO
# 12                               DRAM Apothecary   Boulder    CO
# 13                             element6 Dynamics   Boulder    CO
# 14                     Enviro Textiles/Machinery  Garfield    CO
#
#                  Industry            Category  \
# 0   Industrial Processing       Decortication
# 1            Construction               Other
# 2      Genetics & Testing         Lab Testing
# 3   Industrial Processing  Other End Products
# 4      Genetics & Testing         Lab Testing
# 5      Genetics & Testing  Seeds and Genetics
# 6   Industrial Processing      CBD Extraction
# 7      Genetics & Testing  Seeds and Genetics
# 8      Genetics & Testing  Seeds and Genetics
# 9   Industrial Processing      CBD Extraction
# 10  Equipment & Packaging           Packaging
# 11  Industrial Processing       Decortication
# 12           Food & Drink            Beverage
# 13     Genetics & Testing  Seeds and Genetics
# 14  Industrial Processing       Decortication
#
#                             Website   Latitude  Longitude
# 0      https://6ixhemp.org/contact/  39.348300  -104.9202
# 1                    GAPhousing.com  40.088000  -105.3448
# 2         www.agpolicysolutions.com  40.629100  -105.4465
# 3                www.antedotum.comm  39.190000  -106.8100
# 4                 apexherbology.com  39.764400  -104.9549
# 5                               NaN  40.088111  -105.3448
# 6                 CabanissGroup.com  38.484200  -105.4521
# 7             www.cloudcofarms.comm  37.546600  -105.7781
# 8       https://cohempgenetics.com/  38.829600  -104.5628
# 9                https://cohpc.org/  39.764411  -104.9549
# 10             Damadistributing.com  39.870100  -104.1631
# 11             https://deltaag.com/  38.941900  -107.8040
# 12  https://www.dramapothecary.com/  40.088222  -105.3448
# 13     https://element6dynamics.com  40.088333  -105.3448
# 14  https://www.envirotextiles.com/  39.718400  -107.5261

# %% [markdown]
# ## Step 3: Create a Searchable Map

# %%
# Initialize the map centered around Colorado
m = folium.Map(location=[39.5501, -105.7821], zoom_start=7)

# Add markers to the map for each hemp industry location
for idx, row in df.iterrows():
    popup_text = f"""
    <strong>{row['Name']}</strong><br>
    {row['County']} County, {row['State']}<br>
    Industry: {row['Industry']}<br>
    Category: {row['Category']}<br>
    Website: <a href="{row['Website']}">{row['Name']}</a><br>
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text,
    ).add_to(m)

# Save the map as an HTML file
m.save("colorado_hemp_industry_map.html")

# Display the map in the notebook
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f2d5ccfb9ce466038232665852fc0b66 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f2d5ccfb9ce466038232665852fc0b66&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f2d5ccfb9ce466038232665852fc0b66 = L.map(
#                 &quot;map_f2d5ccfb9ce466038232665852fc0b66&quot;,
#                 {
#                     center: [39.5501, -105.7821],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_522c4136132d45d5da4b7d00aac74048 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_522c4136132d45d5da4b7d00aac74048.addTo(map_f2d5ccfb9ce466038232665852fc0b66);
#
#
#             var marker_70d36334dade85bedbafa5eefcec6eba = L.marker(
#                 [39.3483, -104.9202],
#                 {}
#             ).addTo(map_f2d5ccfb9ce466038232665852fc0b66);
#
#
#         var popup_7da0f78b02dc338709604707688217ae = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_06e4adc8eab0e4f04aefef7ef940e43b = $(`&lt;div id=&quot;html_06e4adc8eab0e4f04aefef7ef940e43b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;6ixhemp&lt;/strong&gt;&lt;br&gt;     Douglas County, CO&lt;br&gt;     Industry: Industrial Processing&lt;br&gt;     Category: Decortication&lt;br&gt;     Website: &lt;a href=&quot;https://6ixhemp.org/contact/&quot;&gt;6ixhemp&lt;/a&gt;&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_7da0f78b02dc338709604707688217ae.setContent(html_06e4adc8eab0e4f04aefef7ef940e43b);
#
#
#
#         marker_70d36334dade85bedbafa5eefcec6eba.bindPopup(popup_7da0f78b02dc338709604707688217ae)
#         ;
#
#
#
#
#             var marker_65179fe61724cc7b41c4feb3c5600277 = L.marker(
#                 [40.088, -105.3448],
#                 {}
#             ).addTo(map_f2d5ccfb9ce466038232665852fc0b66);
#
#
#         var popup_96b6a27756b7e5a39e13b970935557db = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2f26bd5a90ac2b201f1b3659957ba756 = $(`&lt;div id=&quot;html_2f26bd5a90ac2b201f1b3659957ba756&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;Affordable housing hemp fiber and composites&lt;/strong&gt;&lt;br&gt;     Boulder County, CO&lt;br&gt;     Industry: Construction&lt;br&gt;     Category: Other&lt;br&gt;     Website: &lt;a href=&quot;GAPhousing.com&quot;&gt;Affordable housing hemp fiber and composites&lt;/a&gt;&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_96b6a27756b7e5a39e13b970935557db.setContent(html_2f26bd5a90ac2b201f1b3659957ba756);
#
#
#
#         marker_65179fe61724cc7b41c4feb3c5600277.bindPopup(popup_96b6a27756b7e5a39e13b970935557db)
#         ;
#
#
#
#
#             var marker_ca7732c25417c7a131678533b08be207 = L.marker(
#                 [40.6291, -105.4465],
#                 {}
#             ).addTo(map_f2d5ccfb9ce466038232665852fc0b66);
#
#
#         var popup_07e5062b2f9400bbe695e14ab49e719e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bf16f72fdd393fb27f5081f76f02ece0 = $(`&lt;div id=&quot;html_bf16f72fdd393fb27f5081f76f02ece0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;Agriculture Policy Solutions&lt;/strong&gt;&lt;br&gt;     Larimer County, CO&lt;br&gt;     Industry: Genetics &amp; Testing&lt;br&gt;     Category: Lab Testing&lt;br&gt;     Website: &lt;a href=&quot;www.agpolicysolutions.com&quot;&gt;Agriculture Policy Solutions&lt;/a&gt;&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_07e5062b2f9400bbe695e14ab49e719e.setContent(html_bf16f72fdd393fb27f5081f76f02ece0);
#
#
#
#         marker_ca7732c25417c7a131678533b08be207.bindPopup(popup_07e5062b2f9400bbe695e14ab49e719e)
#         ;
#
#
#
#
#             var marker_3361a0010df69ce1b0d32229f35828e5 = L.marker(
#                 [39.19, -106.81],
#                 {}
#             ).addTo(map_f2d5ccfb9ce466038232665852fc0b66);
#
#
#         var popup_c0e7fe19549ac2e4299b7c2f61f6e4b7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_75535753b7c00ba372e6851edd05d99d = $(`&lt;div id=&quot;html_75535753b7c00ba372e6851edd05d99d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;Antedotum Inc.&lt;/strong&gt;&lt;br&gt;     Pitkin County, CO&lt;br&gt;     Industry: Industrial Processing&lt;br&gt;     Category: Other End Products&lt;br&gt;     Website: &lt;a href=&quot;www.antedotum.comm&quot;&gt;Antedotum Inc.&lt;/a&gt;&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_c0e7fe19549ac2e4299b7c2f61f6e4b7.setContent(html_75535753b7c00ba372e6851edd05d99d);

# %% [markdown]
# ## Step 4: Implement Search Functionality

# %%
# Example: Search for hemp industry in a specific county
county_search = "Denver"  # Replace with user input

# Filter the DataFrame based on the county
filtered_df = df[df['County'].str.contains(county_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[39.5501, -105.7821], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Name']}</strong><br>
    {row['County']} County, {row['State']}<br>
    Industry: {row['Industry']}<br>
    Category: {row['Category']}<br>
    Website: <a href="{row['Website']}">{row['Name']}</a><br>
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text,
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_hemp_industry_map_denver_county.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d9e7a7c7a522a9d7ea5acf393dd6b61a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d9e7a7c7a522a9d7ea5acf393dd6b61a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d9e7a7c7a522a9d7ea5acf393dd6b61a = L.map(
#                 &quot;map_d9e7a7c7a522a9d7ea5acf393dd6b61a&quot;,
#                 {
#                     center: [39.5501, -105.7821],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8159ec39b2bfa2c5be59c60a627e64cf = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_8159ec39b2bfa2c5be59c60a627e64cf.addTo(map_d9e7a7c7a522a9d7ea5acf393dd6b61a);
#
#
#             var marker_2582d2be585dc158db2e1c646b0de0e4 = L.marker(
#                 [39.7644, -104.9549],
#                 {}
#             ).addTo(map_d9e7a7c7a522a9d7ea5acf393dd6b61a);
#
#
#         var popup_ce37eb3d7c66f095efcc68b995417f99 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_011f012384f89cab54fe999622efd377 = $(`&lt;div id=&quot;html_011f012384f89cab54fe999622efd377&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;Apex Herbology LLC&lt;/strong&gt;&lt;br&gt;     Denver County, CO&lt;br&gt;     Industry: Genetics &amp; Testing&lt;br&gt;     Category: Lab Testing&lt;br&gt;     Website: &lt;a href=&quot;apexherbology.com&quot;&gt;Apex Herbology LLC&lt;/a&gt;&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_ce37eb3d7c66f095efcc68b995417f99.setContent(html_011f012384f89cab54fe999622efd377);
#
#
#
#         marker_2582d2be585dc158db2e1c646b0de0e4.bindPopup(popup_ce37eb3d7c66f095efcc68b995417f99)
#         ;
#
#
#
#
#             var marker_e828eae2aac2d62d06729fd139510647 = L.marker(
#                 [39.7644111, -104.9549],
#                 {}
#             ).addTo(map_d9e7a7c7a522a9d7ea5acf393dd6b61a);
#
#
#         var popup_162738ffd8413f58bd828d51aeb0d7a1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d45ead251e38a84e2ff6ed1465d5fcc0 = $(`&lt;div id=&quot;html_d45ead251e38a84e2ff6ed1465d5fcc0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;Colorado Hemp Procesing Cooporative&lt;/strong&gt;&lt;br&gt;     Denver County, CO&lt;br&gt;     Industry: Industrial Processing&lt;br&gt;     Category: CBD Extraction&lt;br&gt;     Website: &lt;a href=&quot;https://cohpc.org/&quot;&gt;Colorado Hemp Procesing Cooporative&lt;/a&gt;&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_162738ffd8413f58bd828d51aeb0d7a1.setContent(html_d45ead251e38a84e2ff6ed1465d5fcc0);
#
#
#
#         marker_e828eae2aac2d62d06729fd139510647.bindPopup(popup_162738ffd8413f58bd828d51aeb0d7a1)
#         ;
#
#
#
#
#             var marker_ebba2e8f1b496e31aa58142f4f88fac5 = L.marker(
#                 [39.7644222, -104.9549],
#                 {}
#             ).addTo(map_d9e7a7c7a522a9d7ea5acf393dd6b61a);
#
#
#         var popup_8444beca4fdd52164d60a1ca865fda4f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6bad587ba5330d5c540aabec408e2bf7 = $(`&lt;div id=&quot;html_6bad587ba5330d5c540aabec408e2bf7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;FarmMax&lt;/strong&gt;&lt;br&gt;     Denver County, CO&lt;br&gt;     Industry: Industrial Processing&lt;br&gt;     Category: Decortication&lt;br&gt;     Website: &lt;a href=&quot;www.farmmax.us&quot;&gt;FarmMax&lt;/a&gt;&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_8444beca4fdd52164d60a1ca865fda4f.setContent(html_6bad587ba5330d5c540aabec408e2bf7);
#
#
#
#         marker_ebba2e8f1b496e31aa58142f4f88fac5.bindPopup(popup_8444beca4fdd52164d60a1ca865fda4f)
#         ;
#
#
#
#
#             var marker_48f949cc55939d008b34e532f6dd61c6 = L.marker(
#                 [39.7644333, -104.9549],
#                 {}
#             ).addTo(map_d9e7a7c7a522a9d7ea5acf393dd6b61a);
#
#
#         var popup_994d712a48d9db510674fad57a5c61c5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_212c0295dbe52716c43c29a62c14830f = $(`&lt;div id=&quot;html_212c0295dbe52716c43c29a62c14830f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;Healthy Hemp Homes&lt;/strong&gt;&lt;br&gt;     Denver County, CO&lt;br&gt;     Industry: Construction&lt;br&gt;     Category: Insulation&lt;br&gt;     Website: &lt;a href=&quot;https://www.healthyhemphomes.org/&quot;&gt;Healthy Hemp Homes&lt;/a&gt;&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_994d712a48d9db510674fad57a5c61c5.setContent(html_212c0295dbe52716c43c29a62c14830f);
#
#
#
#         marker_48f949cc55939d

# %%
# Example: Search for hemp industry in a specific county
county_search = "El Paso"  # Replace with user input

# Filter the DataFrame based on the county
filtered_df = df[df['County'].str.contains(county_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[38.8591, -104.8135], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Name']}</strong><br>
    {row['County']} County, {row['State']}<br>
    Industry: {row['Industry']}<br>
    Category: {row['Category']}<br>
    Website: <a href="{row['Website']}">{row['Name']}</a><br>
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text,
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_hemp_industry_map_el_paso_county.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4996b9a8e6b1bc2e2d33fd6ed5d5bc38 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4996b9a8e6b1bc2e2d33fd6ed5d5bc38&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4996b9a8e6b1bc2e2d33fd6ed5d5bc38 = L.map(
#                 &quot;map_4996b9a8e6b1bc2e2d33fd6ed5d5bc38&quot;,
#                 {
#                     center: [38.8591, -104.8135],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_87c60733ed2e7ca85256a921ab447260 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_87c60733ed2e7ca85256a921ab447260.addTo(map_4996b9a8e6b1bc2e2d33fd6ed5d5bc38);
#
#
#             var marker_10983b5c002cf22cdadc94c4da7d600a = L.marker(
#                 [38.8296, -104.5628],
#                 {}
#             ).addTo(map_4996b9a8e6b1bc2e2d33fd6ed5d5bc38);
#
#
#         var popup_fa8d1c8865ea8c8a37a76318365a7658 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_99ee9b25df15a200f44df9f90b313d37 = $(`&lt;div id=&quot;html_99ee9b25df15a200f44df9f90b313d37&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;Colorado Hemp Genetics&lt;/strong&gt;&lt;br&gt;     El Paso County, CO&lt;br&gt;     Industry: Genetics &amp; Testing&lt;br&gt;     Category: Seeds and Genetics&lt;br&gt;     Website: &lt;a href=&quot;https://cohempgenetics.com/&quot;&gt;Colorado Hemp Genetics&lt;/a&gt;&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_fa8d1c8865ea8c8a37a76318365a7658.setContent(html_99ee9b25df15a200f44df9f90b313d37);
#
#
#
#         marker_10983b5c002cf22cdadc94c4da7d600a.bindPopup(popup_fa8d1c8865ea8c8a37a76318365a7658)
#         ;
#
#
#
#
#             var marker_fcf6c40bb6bdab8fffcaeb0e55e2936b = L.marker(
#                 [38.8296111, -104.5628],
#                 {}
#             ).addTo(map_4996b9a8e6b1bc2e2d33fd6ed5d5bc38);
#
#
#         var popup_6a55f769650fadad6351e7d5e2bdee16 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8a74caed8b812f1e5013d89f25970a85 = $(`&lt;div id=&quot;html_8a74caed8b812f1e5013d89f25970a85&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;NanoLabs CBD&lt;/strong&gt;&lt;br&gt;     El Paso County, CO&lt;br&gt;     Industry: Industrial Processing&lt;br&gt;     Category: Other End Products&lt;br&gt;     Website: &lt;a href=&quot;www.nanolabshemp.com&quot;&gt;NanoLabs CBD&lt;/a&gt;&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_6a55f769650fadad6351e7d5e2bdee16.setContent(html_8a74caed8b812f1e5013d89f25970a85);
#
#
#
#         marker_fcf6c40bb6bdab8fffcaeb0e55e2936b.bindPopup(popup_6a55f769650fadad6351e7d5e2bdee16)
#         ;
#
#
#
#
#             var marker_0d7e8fd1b9dfd0980e64b73f531dc9f4 = L.marker(
#                 [38.8296222, -104.5628],
#                 {}
#             ).addTo(map_4996b9a8e6b1bc2e2d33fd6ed5d5bc38);
#
#
#         var popup_5d60efd623318e63b5fde31965e86332 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_607a362be5892df50ff5c0b022c2b6e3 = $(`&lt;div id=&quot;html_607a362be5892df50ff5c0b022c2b6e3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;Noble Soul Farm&lt;/strong&gt;&lt;br&gt;     El Paso County, CO&lt;br&gt;     Industry: Industrial Processing&lt;br&gt;     Category: Decortication&lt;br&gt;     Website: &lt;a href=&quot;https://noblesoulfarm.com/&quot;&gt;Noble Soul Farm&lt;/a&gt;&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_5d60efd623318e63b5fde31965e86332.setContent(html_607a362be5892df50ff5c0b022c2b6e3);
#
#
#
#         marker_0d7e8fd1b9dfd0980e64b73f531dc9f4.bindPopup(popup_5d60efd623318e63b5fde31965e86332)
#         ;
#
#
#
#
#             tile_layer_87c60733ed2e7ca85256a921ab447260.addTo(map_4996b9a8e6b1bc2e2d33fd6ed5d5bc38);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Example: Search for hemp industry in a specific county
county_search = "Arapahoe"  # Replace with user input

# Filter the DataFrame based on the county
filtered_df = df[df['County'].str.contains(county_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[39.7108, -104.8125], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Name']}</strong><br>
    {row['County']} County, {row['State']}<br>
    Industry: {row['Industry']}<br>
    Category: {row['Category']}<br>
    Website: <a href="{row['Website']}">{row['Name']}</a><br>
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text,
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_hemp_industry_map_arapahoe_county.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_df47a5a7e8c40f6313208b9be172fe29 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_df47a5a7e8c40f6313208b9be172fe29&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_df47a5a7e8c40f6313208b9be172fe29 = L.map(
#                 &quot;map_df47a5a7e8c40f6313208b9be172fe29&quot;,
#                 {
#                     center: [39.7108, -104.8125],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_34306d45c718a4c65cd33460102772a6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_34306d45c718a4c65cd33460102772a6.addTo(map_df47a5a7e8c40f6313208b9be172fe29);
#
#
#             var marker_f9625340b60be63947e1da9332eb1d51 = L.marker(
#                 [39.6519, -104.2834],
#                 {}
#             ).addTo(map_df47a5a7e8c40f6313208b9be172fe29);
#
#
#         var popup_66e7021abd2cf5d62adc4e23c7b3b559 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_346e54c399f49158b199e8cab6b635ab = $(`&lt;div id=&quot;html_346e54c399f49158b199e8cab6b635ab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;Nepra Foods&lt;/strong&gt;&lt;br&gt;     Arapahoe County, CO&lt;br&gt;     Industry: Food &amp; Drink&lt;br&gt;     Category: Food&lt;br&gt;     Website: &lt;a href=&quot;https://neprafoods.com/&quot;&gt;Nepra Foods&lt;/a&gt;&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_66e7021abd2cf5d62adc4e23c7b3b559.setContent(html_346e54c399f49158b199e8cab6b635ab);
#
#
#
#         marker_f9625340b60be63947e1da9332eb1d51.bindPopup(popup_66e7021abd2cf5d62adc4e23c7b3b559)
#         ;
#
#
#
#
#             tile_layer_34306d45c718a4c65cd33460102772a6.addTo(map_df47a5a7e8c40f6313208b9be172fe29);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Example: Search for hemp industry in a specific county
county_search = "Larimer"  # Replace with user input

# Filter the DataFrame based on the county
filtered_df = df[df['County'].str.contains(county_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[40.5853, -105.0844], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Name']}</strong><br>
    {row['County']} County, {row['State']}<br>
    Industry: {row['Industry']}<br>
    Category: {row['Category']}<br>
    Website: <a href="{row['Website']}">{row['Name']}</a><br>
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text,
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_hemp_industry_map_larimer_county.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9b83ecf9adac157e7e28d1aaf5a65f74 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9b83ecf9adac157e7e28d1aaf5a65f74&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9b83ecf9adac157e7e28d1aaf5a65f74 = L.map(
#                 &quot;map_9b83ecf9adac157e7e28d1aaf5a65f74&quot;,
#                 {
#                     center: [40.5853, -105.0844],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_641ea7d992e73218cc159bbbee5d75fb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_641ea7d992e73218cc159bbbee5d75fb.addTo(map_9b83ecf9adac157e7e28d1aaf5a65f74);
#
#
#             var marker_385950d38cc155a4f97f7381839be409 = L.marker(
#                 [40.6291, -105.4465],
#                 {}
#             ).addTo(map_9b83ecf9adac157e7e28d1aaf5a65f74);
#
#
#         var popup_eed9fe240d61584e628d724871ba27e0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_01a533bcbb62083d65775171bcdbd867 = $(`&lt;div id=&quot;html_01a533bcbb62083d65775171bcdbd867&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;Agriculture Policy Solutions&lt;/strong&gt;&lt;br&gt;     Larimer County, CO&lt;br&gt;     Industry: Genetics &amp; Testing&lt;br&gt;     Category: Lab Testing&lt;br&gt;     Website: &lt;a href=&quot;www.agpolicysolutions.com&quot;&gt;Agriculture Policy Solutions&lt;/a&gt;&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_eed9fe240d61584e628d724871ba27e0.setContent(html_01a533bcbb62083d65775171bcdbd867);
#
#
#
#         marker_385950d38cc155a4f97f7381839be409.bindPopup(popup_eed9fe240d61584e628d724871ba27e0)
#         ;
#
#
#
#
#             var marker_f594f628c788b8593901de177904d407 = L.marker(
#                 [40.6291111, -105.4465],
#                 {}
#             ).addTo(map_9b83ecf9adac157e7e28d1aaf5a65f74);
#
#
#         var popup_96f809c7e493d76abd44b8a381ff0b12 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8852a7adfac49eb4d3879f620c23bcdb = $(`&lt;div id=&quot;html_8852a7adfac49eb4d3879f620c23bcdb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;Fat Pig Society&lt;/strong&gt;&lt;br&gt;     Larimer County, CO&lt;br&gt;     Industry: Industrial Processing&lt;br&gt;     Category: CBD Extraction&lt;br&gt;     Website: &lt;a href=&quot;https://fatpigsociety.com/&quot;&gt;Fat Pig Society&lt;/a&gt;&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_96f809c7e493d76abd44b8a381ff0b12.setContent(html_8852a7adfac49eb4d3879f620c23bcdb);
#
#
#
#         marker_f594f628c788b8593901de177904d407.bindPopup(popup_96f809c7e493d76abd44b8a381ff0b12)
#         ;
#
#
#
#
#             var marker_1781aa852e60ea57fe06bf241248c68e = L.marker(
#                 [40.6291222, -105.4465],
#                 {}
#             ).addTo(map_9b83ecf9adac157e7e28d1aaf5a65f74);
#
#
#         var popup_541beed9cb9d435d20c02811817c56f0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f46e783613d97d4e38f0ba46286ae03b = $(`&lt;div id=&quot;html_f46e783613d97d4e38f0ba46286ae03b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;Globex Extraction Services&lt;/strong&gt;&lt;br&gt;     Larimer County, CO&lt;br&gt;     Industry: Industrial Processing&lt;br&gt;     Category: CBD Extraction&lt;br&gt;     Website: &lt;a href=&quot;https://globexextraction.com/&quot;&gt;Globex Extraction Services&lt;/a&gt;&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_541beed9cb9d435d20c02811817c56f0.setContent(html_f46e783613d97d4e38f0ba46286ae03b);
#
#
#
#         marker_1781aa852e60ea57fe06bf241248c68e.bindPopup(popup_541beed9cb9d435d20c02811817c56f0)
#         ;
#
#
#
#
#             var marker_ba2e2e79c86feb5336bec0101ee383b0 = L.marker(
#                 [40.6291333, -105.4465],
#                 {}
#             ).addTo(map_9b83ecf9adac157e7e28d1aaf5a65f74);
#
#
#         var popup_0c16417237392cbcd35ff4dec714f4f1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3e3fa6171c876e86f5ba42777e376e08 = $(`&lt;div id=&quot;html_3e3fa6171c876e86f5ba42777e376e08&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;New West Genetics&lt;/strong&gt;&lt;br&gt;     Larimer County, CO&lt;br&gt;     Industry: Genetics &amp; Testing&lt;br&gt;     Category: Seeds and Genetics&lt;br&gt;     Website: &lt;a href=&quot;https://newwestgenetics.com/&quot;&gt;New West Genetics&lt;/a&gt;&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_0c16417237392cbcd35ff4dec714f4f1.setContent(html_3e3fa6171c876e86f5ba42

# %%
# Example: Search for hemp industry in a specific county
county_search = "Jefferson"  # Replace with user input

# Filter the DataFrame based on the county
filtered_df = df[df['County'].str.contains(county_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[39.7109, -105.0815], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Name']}</strong><br>
    {row['County']} County, {row['State']}<br>
    Industry: {row['Industry']}<br>
    Category: {row['Category']}<br>
    Website: <a href="{row['Website']}">{row['Name']}</a><br>
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text,
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_hemp_industry_map_jefferson_county.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a531245e261ffe70704a2ab53c11d715 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a531245e261ffe70704a2ab53c11d715&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a531245e261ffe70704a2ab53c11d715 = L.map(
#                 &quot;map_a531245e261ffe70704a2ab53c11d715&quot;,
#                 {
#                     center: [39.7109, -105.0815],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0df46c3a6d6ffa1ffd34ce65adf83fe5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_0df46c3a6d6ffa1ffd34ce65adf83fe5.addTo(map_a531245e261ffe70704a2ab53c11d715);
#
#
#             var marker_e2d8bf5732511d5d15fa9e4cc0e1c055 = L.marker(
#                 [39.5234, -105.2388],
#                 {}
#             ).addTo(map_a531245e261ffe70704a2ab53c11d715);
#
#
#         var popup_96d2cb17a4c7eb9224c6763fc0ea926a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d0b3bac05d69bace0a75c09a396368bd = $(`&lt;div id=&quot;html_d0b3bac05d69bace0a75c09a396368bd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;Gobi Labs&lt;/strong&gt;&lt;br&gt;     Jefferson County, CO&lt;br&gt;     Industry: Genetics &amp; Testing&lt;br&gt;     Category: Lab Testing&lt;br&gt;     Website: &lt;a href=&quot;https://gobilabs.com/&quot;&gt;Gobi Labs&lt;/a&gt;&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_96d2cb17a4c7eb9224c6763fc0ea926a.setContent(html_d0b3bac05d69bace0a75c09a396368bd);
#
#
#
#         marker_e2d8bf5732511d5d15fa9e4cc0e1c055.bindPopup(popup_96d2cb17a4c7eb9224c6763fc0ea926a)
#         ;
#
#
#
#
#             tile_layer_0df46c3a6d6ffa1ffd34ce65adf83fe5.addTo(map_a531245e261ffe70704a2ab53c11d715);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Example: Search for hemp industry in a specific county
county_search = "Rio Grande"  # Replace with user input

# Filter the DataFrame based on the county
filtered_df = df[df['County'].str.contains(county_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[40.4233, -104.7112], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Name']}</strong><br>
    {row['County']} County, {row['State']}<br>
    Industry: {row['Industry']}<br>
    Category: {row['Category']}<br>
    Website: <a href="{row['Website']}">{row['Name']}</a><br>
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text,
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_hemp_industry_map_rio_grande_county.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_be86013dd7c1c0c85276d981f3b8c097 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_be86013dd7c1c0c85276d981f3b8c097&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_be86013dd7c1c0c85276d981f3b8c097 = L.map(
#                 &quot;map_be86013dd7c1c0c85276d981f3b8c097&quot;,
#                 {
#                     center: [40.4233, -104.7112],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d186e9f7fcf95a4105631b98e2627cc4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d186e9f7fcf95a4105631b98e2627cc4.addTo(map_be86013dd7c1c0c85276d981f3b8c097);
#
#
#             var marker_39786fbed5018db5db393156c2dfcf2e = L.marker(
#                 [37.6147, -106.3753],
#                 {}
#             ).addTo(map_be86013dd7c1c0c85276d981f3b8c097);
#
#
#         var popup_d1062323a82ba50331821b120ee8a71c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1bd5cc1b6746bd349185403ffe7474bc = $(`&lt;div id=&quot;html_1bd5cc1b6746bd349185403ffe7474bc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;Formation Ag&lt;/strong&gt;&lt;br&gt;     Rio Grande County, CO&lt;br&gt;     Industry: Industrial Processing&lt;br&gt;     Category: Decortication&lt;br&gt;     Website: &lt;a href=&quot;https://formation-ag.com/&quot;&gt;Formation Ag&lt;/a&gt;&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_d1062323a82ba50331821b120ee8a71c.setContent(html_1bd5cc1b6746bd349185403ffe7474bc);
#
#
#
#         marker_39786fbed5018db5db393156c2dfcf2e.bindPopup(popup_d1062323a82ba50331821b120ee8a71c)
#         ;
#
#
#
#
#             var marker_fd6a16941b5bee3952674ed13f88b659 = L.marker(
#                 [37.6147111, -106.3753],
#                 {}
#             ).addTo(map_be86013dd7c1c0c85276d981f3b8c097);
#
#
#         var popup_75e87775755f4c250d75fa7989551c53 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d91c4af80d379a51d3f862ad847eebf5 = $(`&lt;div id=&quot;html_d91c4af80d379a51d3f862ad847eebf5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;Global Fiber Processing Monte Vista&lt;/strong&gt;&lt;br&gt;     Rio Grande County, CO&lt;br&gt;     Industry: Industrial Processing&lt;br&gt;     Category: Decortication&lt;br&gt;     Website: &lt;a href=&quot;https://www.globalfiberprocessing.com&quot;&gt;Global Fiber Processing Monte Vista&lt;/a&gt;&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_75e87775755f4c250d75fa7989551c53.setContent(html_d91c4af80d379a51d3f862ad847eebf5);
#
#
#
#         marker_fd6a16941b5bee3952674ed13f88b659.bindPopup(popup_75e87775755f4c250d75fa7989551c53)
#         ;
#
#
#
#
#             var marker_5c1986903e44a60ca8fb1d00e6c270d5 = L.marker(
#                 [37.6147222, -106.3753],
#                 {}
#             ).addTo(map_be86013dd7c1c0c85276d981f3b8c097);
#
#
#         var popup_3e54514c38c7439956bf6836f43f80c1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cc16c95ac892356c5622ffde5e8f9d53 = $(`&lt;div id=&quot;html_cc16c95ac892356c5622ffde5e8f9d53&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;SLV Hemp&lt;/strong&gt;&lt;br&gt;     Rio Grande County, CO&lt;br&gt;     Industry: Industrial Processing&lt;br&gt;     Category: Decortication&lt;br&gt;     Website: &lt;a href=&quot;https://slvhemp.com/&quot;&gt;SLV Hemp&lt;/a&gt;&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_3e54514c38c7439956bf6836f43f80c1.setContent(html_cc16c95ac892356c5622ffde5e8f9d53);
#
#
#
#         marker_5c1986903e44a60ca8fb1d00e6c270d5.bindPopup(popup_3e54514c38c7439956bf6836f43f80c1)
#         ;
#
#
#
#
#             var marker_e74f2ec60ece07490ab4c24292f05457 = L.marker(
#                 [37.6147333, -106.3753],
#                 {}
#             ).addTo(map_be86013dd7c1c0c85276d981f3b8c097);
#
#
#         var popup_ead35a6079e5315390ff56e8e813c918 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bd08b51b5f9b2dacbaf59a0243ee0daf = $(`&lt;div id=&quot;html_bd08b51b5f9b2dacbaf59a0243ee0daf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;Wright-Oakes LLC&lt;/strong&gt;&lt;br&gt;     Rio Grande County, CO&lt;br&gt;     Industry: Food &amp; Drink&lt;br&gt;     Category: Food&lt;br&gt;     Website: &lt;a href=&quot;https://himtp.com/&quot;&gt;Wright-Oakes LLC&lt;/a&gt;&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_ead35a6079e5315390ff56e8e813c918.setContent(html_bd08b51b5f9b2dacbaf59a0243ee0daf);
#
#
#
#         mar

# %%
# Example: Search for hemp industry in a specific county
county_search = "Pueblo"  # Replace with user input

# Filter the DataFrame based on the county
filtered_df = df[df['County'].str.contains(county_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[38.2765, -104.6046], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Name']}</strong><br>
    {row['County']} County, {row['State']}<br>
    Industry: {row['Industry']}<br>
    Category: {row['Category']}<br>
    Website: <a href="{row['Website']}">{row['Name']}</a><br>
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text,
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_hemp_industry_map_pueblo_county.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6d810aca78bada177ca1e134b6bb9951 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6d810aca78bada177ca1e134b6bb9951&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6d810aca78bada177ca1e134b6bb9951 = L.map(
#                 &quot;map_6d810aca78bada177ca1e134b6bb9951&quot;,
#                 {
#                     center: [38.2765, -104.6046],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3c86c98a2025236cfa0afddd2e698237 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_3c86c98a2025236cfa0afddd2e698237.addTo(map_6d810aca78bada177ca1e134b6bb9951);
#
#
#             var marker_4a7c3977a330e8013a747927e1cfcf2a = L.marker(
#                 [38.1295, -104.5533],
#                 {}
#             ).addTo(map_6d810aca78bada177ca1e134b6bb9951);
#
#
#         var popup_3af19bdf747246d849ff8447969e2e63 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2d5979dac7964647e4d6dc7236baf280 = $(`&lt;div id=&quot;html_2d5979dac7964647e4d6dc7236baf280&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;HFF LLC&lt;/strong&gt;&lt;br&gt;     Pueblo County, CO&lt;br&gt;     Industry: Industrial Processing&lt;br&gt;     Category: CBD Extraction&lt;br&gt;     Website: &lt;a href=&quot;Hempfieldsfarm.com&quot;&gt;HFF LLC&lt;/a&gt;&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_3af19bdf747246d849ff8447969e2e63.setContent(html_2d5979dac7964647e4d6dc7236baf280);
#
#
#
#         marker_4a7c3977a330e8013a747927e1cfcf2a.bindPopup(popup_3af19bdf747246d849ff8447969e2e63)
#         ;
#
#
#
#
#             tile_layer_3c86c98a2025236cfa0afddd2e698237.addTo(map_6d810aca78bada177ca1e134b6bb9951);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Example: Search for hemp industry in a specific county
county_search = "Boulder"  # Replace with user input

# Filter the DataFrame based on the county
filtered_df = df[df['County'].str.contains(county_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[40.0150, -105.2705], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Name']}</strong><br>
    {row['County']} County, {row['State']}<br>
    Industry: {row['Industry']}<br>
    Category: {row['Category']}<br>
    Website: <a href="{row['Website']}">{row['Name']}</a><br>
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text,
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_hemp_industry_map_boulder_county.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_25cd860406905b14c9489695cafe31a4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_25cd860406905b14c9489695cafe31a4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_25cd860406905b14c9489695cafe31a4 = L.map(
#                 &quot;map_25cd860406905b14c9489695cafe31a4&quot;,
#                 {
#                     center: [40.015, -105.2705],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bd1f65914f42f3df9e61a6d0090a39e4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_bd1f65914f42f3df9e61a6d0090a39e4.addTo(map_25cd860406905b14c9489695cafe31a4);
#
#
#             var marker_1046f9d9290f18a8fa0393c9c817c685 = L.marker(
#                 [40.088, -105.3448],
#                 {}
#             ).addTo(map_25cd860406905b14c9489695cafe31a4);
#
#
#         var popup_33851c7b1f118259267d26a1f7fae5ea = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3989b3b83cf6bee5b1e6971694573437 = $(`&lt;div id=&quot;html_3989b3b83cf6bee5b1e6971694573437&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;Affordable housing hemp fiber and composites&lt;/strong&gt;&lt;br&gt;     Boulder County, CO&lt;br&gt;     Industry: Construction&lt;br&gt;     Category: Other&lt;br&gt;     Website: &lt;a href=&quot;GAPhousing.com&quot;&gt;Affordable housing hemp fiber and composites&lt;/a&gt;&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_33851c7b1f118259267d26a1f7fae5ea.setContent(html_3989b3b83cf6bee5b1e6971694573437);
#
#
#
#         marker_1046f9d9290f18a8fa0393c9c817c685.bindPopup(popup_33851c7b1f118259267d26a1f7fae5ea)
#         ;
#
#
#
#
#             var marker_1ee70ad3d02df49444efd0e341d07982 = L.marker(
#                 [40.0881111, -105.3448],
#                 {}
#             ).addTo(map_25cd860406905b14c9489695cafe31a4);
#
#
#         var popup_be2df91e6e648eddfa37c53bb5a65855 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ce70a8179be5a23f8d841e2fdc8d0408 = $(`&lt;div id=&quot;html_ce70a8179be5a23f8d841e2fdc8d0408&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;BoCo Farms&lt;/strong&gt;&lt;br&gt;     Boulder County, CO&lt;br&gt;     Industry: Genetics &amp; Testing&lt;br&gt;     Category: Seeds and Genetics&lt;br&gt;     Website: &lt;a href=&quot;nan&quot;&gt;BoCo Farms&lt;/a&gt;&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_be2df91e6e648eddfa37c53bb5a65855.setContent(html_ce70a8179be5a23f8d841e2fdc8d0408);
#
#
#
#         marker_1ee70ad3d02df49444efd0e341d07982.bindPopup(popup_be2df91e6e648eddfa37c53bb5a65855)
#         ;
#
#
#
#
#             var marker_6581ef54cac04b0ecca734c55dcc95f2 = L.marker(
#                 [40.0882222, -105.3448],
#                 {}
#             ).addTo(map_25cd860406905b14c9489695cafe31a4);
#
#
#         var popup_b20c7b8f12daeb4d426c0cbf8c44ddfa = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3041d456a2a3db77c1c39ddfba461739 = $(`&lt;div id=&quot;html_3041d456a2a3db77c1c39ddfba461739&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;DRAM Apothecary&lt;/strong&gt;&lt;br&gt;     Boulder County, CO&lt;br&gt;     Industry: Food &amp; Drink&lt;br&gt;     Category: Beverage&lt;br&gt;     Website: &lt;a href=&quot;https://www.dramapothecary.com/&quot;&gt;DRAM Apothecary&lt;/a&gt;&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_b20c7b8f12daeb4d426c0cbf8c44ddfa.setContent(html_3041d456a2a3db77c1c39ddfba461739);
#
#
#
#         marker_6581ef54cac04b0ecca734c55dcc95f2.bindPopup(popup_b20c7b8f12daeb4d426c0cbf8c44ddfa)
#         ;
#
#
#
#
#             var marker_ad6968e00f2524e49136baf8231172f8 = L.marker(
#                 [40.0883333, -105.3448],
#                 {}
#             ).addTo(map_25cd860406905b14c9489695cafe31a4);
#
#
#         var popup_a5a73765f958b062c496e5aaed9cf031 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_933ed3b4f612d4a0560bf150e3421ea9 = $(`&lt;div id=&quot;html_933ed3b4f612d4a0560bf150e3421ea9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;element6 Dynamics&lt;/strong&gt;&lt;br&gt;     Boulder County, CO&lt;br&gt;     Industry: Genetics &amp; Testing&lt;br&gt;     Category: Seeds and Genetics&lt;br&gt;     Website: &lt;a href=&quot;https://element6dynamics.com&quot;&gt;element6 Dynamics&lt;/a&gt;&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_a5a73765f958b062c496e5aaed9cf031.setContent(html_933ed3b4f612d4a0560bf150e3421ea9);
#
#
#
#         marker_ad696

# %%
# Example: Search for hemp industry in a specific county
county_search = "Delta"  # Replace with user input

# Filter the DataFrame based on the county
filtered_df = df[df['County'].str.contains(county_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[39.0714, -108.5497], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Name']}</strong><br>
    {row['County']} County, {row['State']}<br>
    Industry: {row['Industry']}<br>
    Category: {row['Category']}<br>
    Website: <a href="{row['Website']}">{row['Name']}</a><br>
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text,
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_hemp_industry_map_delta_county.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0f3db66902033d9248d7d65263984c49 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0f3db66902033d9248d7d65263984c49&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0f3db66902033d9248d7d65263984c49 = L.map(
#                 &quot;map_0f3db66902033d9248d7d65263984c49&quot;,
#                 {
#                     center: [39.0714, -108.5497],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c2797532f91a05835711dd027e8a0f9f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c2797532f91a05835711dd027e8a0f9f.addTo(map_0f3db66902033d9248d7d65263984c49);
#
#
#             var marker_15113f6362b9c431abbbeef1b5141608 = L.marker(
#                 [38.9419, -107.804],
#                 {}
#             ).addTo(map_0f3db66902033d9248d7d65263984c49);
#
#
#         var popup_642e78e534c12d8ae056a66de2399b32 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_471ee9de05b4bd9ef383a687223d9f8a = $(`&lt;div id=&quot;html_471ee9de05b4bd9ef383a687223d9f8a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;Delta AG&lt;/strong&gt;&lt;br&gt;     Delta County, CO&lt;br&gt;     Industry: Industrial Processing&lt;br&gt;     Category: Decortication&lt;br&gt;     Website: &lt;a href=&quot;https://deltaag.com/&quot;&gt;Delta AG&lt;/a&gt;&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_642e78e534c12d8ae056a66de2399b32.setContent(html_471ee9de05b4bd9ef383a687223d9f8a);
#
#
#
#         marker_15113f6362b9c431abbbeef1b5141608.bindPopup(popup_642e78e534c12d8ae056a66de2399b32)
#         ;
#
#
#
#
#             var marker_136eec41040ea45eee660b0aa3bd226f = L.marker(
#                 [38.9419111, -107.804],
#                 {}
#             ).addTo(map_0f3db66902033d9248d7d65263984c49);
#
#
#         var popup_06ebeb50cd89619e0b7b21e0fdfb5d65 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b3f4c9bf3f7d5109d7651370ec679ff4 = $(`&lt;div id=&quot;html_b3f4c9bf3f7d5109d7651370ec679ff4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;Fields of Glory Organic Farm&lt;/strong&gt;&lt;br&gt;     Delta County, CO&lt;br&gt;     Industry: Industrial Processing&lt;br&gt;     Category: Decortication&lt;br&gt;     Website: &lt;a href=&quot;FieldsofGlory.org&quot;&gt;Fields of Glory Organic Farm&lt;/a&gt;&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_06ebeb50cd89619e0b7b21e0fdfb5d65.setContent(html_b3f4c9bf3f7d5109d7651370ec679ff4);
#
#
#
#         marker_136eec41040ea45eee660b0aa3bd226f.bindPopup(popup_06ebeb50cd89619e0b7b21e0fdfb5d65)
#         ;
#
#
#
#
#             tile_layer_c2797532f91a05835711dd027e8a0f9f.addTo(map_0f3db66902033d9248d7d65263984c49);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Step 5: Export Cleaned Data to CSV

# %%
# Export the cleaned DataFrame to a CSV file
df.to_csv("cleaned_colorado_hemp_industry_v2.csv", index=False)

# Confirm the export
print("Data exported to cleaned_colorado_hemp_industry_v2.csv")
# Out:
# Data exported to cleaned_colorado_hemp_industry_v2.csv
