# %% [markdown]
# # Jupyter Notebook: Parsing CSV file and Visualizing Data

# %% [markdown]
# In this notebook, we will load a CSV file, convert it to a pandas DataFrame, and then create a map visualizations using folium.

# %%
pip install pandas folium
# Out:
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (2.2.3)
# Requirement already satisfied: folium in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (0.17.0)
# Requirement already satisfied: numpy>=1.23.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/ceraven/Library/Python/3.11/lib/python/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas) (2024.2)
# Requirement already satisfied: branca>=0.6.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from folium) (0.8.0)
# Requirement already satisfied: jinja2>=2.9 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from folium) (3.1.4)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from folium) (2024.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jinja2>=2.9->folium) (2.1.5)
# Requirement already satisfied: six>=1.5 in /Users/ceraven/Library/Python/3.11/lib/python/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->folium) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->folium) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->folium) (2024.8.30)
#
# [notice] A new release of pip available: 22.3.1 -> 24.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import necessary libraries
import pandas as pd
import folium

# %% [markdown]
# ## Step 1: Load CSV File

# %%
# Load the CSV file into a DataFrame
file_path = "colorado_testing_facilities_full_list.csv"

df = pd.read_csv(file_path)

# Optional: Display the first few rows to check if the file is loaded correctly
df.head(15)
# Out:
#    License Number                        Facility Name  \
# 0       405-00004          AGRICOR LABORATORIES DE LLC
# 1       405-00002                 AGRISCIENCE LABS INC
# 2       405-00011                   BONA FIDES MEDICAL
# 3       405-00006                  GOBI ANALYTICAL INC
# 4       405-00003   NORDIC ANALYTICAL LABORATORIES LLC
# 5       405-00019  NORDIC ANALYTICAL LABORATORIES LLC
# 6       405-00008                     PHYTATECH CO LLC
# 7      405R-00009          AGRICOR LABORATORIES DE LLC
# 8      405R-00005                 AGRISCIENCE LABS INC
# 9      405R-00010            BONA FIDES LABORATORY INC
# 10     405R-00007                  GOBI ANALYTICAL INC
# 11     405R-00020   NORDIC ANALYTICAL LABORATORIES LLC
# 12     405R-00035   NORDIC ANALYTICAL LABORATORIES LLC
# 13     405R-00011                     PHYTATECH CO LLC
#
#                            DBA                         Street         City  \
# 0                      SC Labs    1301 S Jason Street, Unit K       Denver
# 1                          NaN        2120 South Birch Street       Denver
# 2   Bona Fides Laboratory Inc.  4910 North Fox Street, Unit E       Denver
# 3                    GOBI LABS         3924 Youngfield Street  Wheat Ridge
# 4                          NaN        3960 North Grape Street       Denver
# 5                          NaN      417 East Northern Avenue        Pueblo
# 6                  Kaycha Labs    879 North Federal Boulevard       Denver
# 7                      SC Labs    1301 S Jason Street, Unit K       Denver
# 8                          NaN        2120 South Birch Street       Denver
# 9                          NaN  4910 North Fox Street, Unit E       Denver
# 10                   Gobi Labs         3924 Youngfield Street  Wheat Ridge
# 11                         NaN        3960 North Grape Street       Denver
# 12                         NaN       417 East Northern Avenue       Pueblo
# 13                 Kaycha Labs    879 North Federal Boulevard       Denver
#
#    State  Zip Code   Latitude   Longitude
# 0     CO   80223.0  39.770206 -105.020537
# 1     CO   80222.0  39.678008 -104.936220
# 2     CO   80216.0  39.786409 -104.993794
# 3     CO   80033.0  39.769108 -105.142375
# 4     CO   80207.0  39.772205 -104.924540
# 5     CO   81006.0  38.244036 -104.611101
# 6     CO   80204.0  39.730820 -105.025232
# 7     CO   80223.0  39.770206 -105.020537
# 8     CO   80222.0  39.678008 -104.936220
# 9     CO   80216.0  39.786409 -104.993794
# 10    CO   80033.0  39.769108 -105.142375
# 11    CO   80207.0  39.772205 -104.924540
# 12    CO   81006.0  38.244036 -104.611101
# 13    CO   80204.0  39.730820 -105.025232

# %% [markdown]
# ## Step 2: Clean and Prepare the Data

# %%
# Check column names and data types
df.info()

# Clean any missing latitude or longitude data
df.dropna(subset=['Longitude', 'Latitude'], inplace=True)

# Optional: Check for missing values in other important columns
df.isnull().sum()

# Optional: Display the first few rows of cleaned data
df.head(15)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   License Number  14 non-null     object
#  1   Facility Name   14 non-null     object
#  2   DBA             7 non-null      object
#  3   Street          14 non-null     object
#  4   City            14 non-null     object
#  5   State           14 non-null     object
#  6   Zip Code        14 non-null     float64
#  7   Latitude        14 non-null     float64
#  8   Longitude       14 non-null     float64
# dtypes: float64(3), object(6)
# memory usage: 1.1+ KB
#    License Number                        Facility Name  \
# 0       405-00004          AGRICOR LABORATORIES DE LLC
# 1       405-00002                 AGRISCIENCE LABS INC
# 2       405-00011                   BONA FIDES MEDICAL
# 3       405-00006                  GOBI ANALYTICAL INC
# 4       405-00003   NORDIC ANALYTICAL LABORATORIES LLC
# 5       405-00019  NORDIC ANALYTICAL LABORATORIES LLC
# 6       405-00008                     PHYTATECH CO LLC
# 7      405R-00009          AGRICOR LABORATORIES DE LLC
# 8      405R-00005                 AGRISCIENCE LABS INC
# 9      405R-00010            BONA FIDES LABORATORY INC
# 10     405R-00007                  GOBI ANALYTICAL INC
# 11     405R-00020   NORDIC ANALYTICAL LABORATORIES LLC
# 12     405R-00035   NORDIC ANALYTICAL LABORATORIES LLC
# 13     405R-00011                     PHYTATECH CO LLC
#
#                            DBA                         Street         City  \
# 0                      SC Labs    1301 S Jason Street, Unit K       Denver
# 1                          NaN        2120 South Birch Street       Denver
# 2   Bona Fides Laboratory Inc.  4910 North Fox Street, Unit E       Denver
# 3                    GOBI LABS         3924 Youngfield Street  Wheat Ridge
# 4                          NaN        3960 North Grape Street       Denver
# 5                          NaN      417 East Northern Avenue        Pueblo
# 6                  Kaycha Labs    879 North Federal Boulevard       Denver
# 7                      SC Labs    1301 S Jason Street, Unit K       Denver
# 8                          NaN        2120 South Birch Street       Denver
# 9                          NaN  4910 North Fox Street, Unit E       Denver
# 10                   Gobi Labs         3924 Youngfield Street  Wheat Ridge
# 11                         NaN        3960 North Grape Street       Denver
# 12                         NaN       417 East Northern Avenue       Pueblo
# 13                 Kaycha Labs    879 North Federal Boulevard       Denver
#
#    State  Zip Code   Latitude   Longitude
# 0     CO   80223.0  39.770206 -105.020537
# 1     CO   80222.0  39.678008 -104.936220
# 2     CO   80216.0  39.786409 -104.993794
# 3     CO   80033.0  39.769108 -105.142375
# 4     CO   80207.0  39.772205 -104.924540
# 5     CO   81006.0  38.244036 -104.611101
# 6     CO   80204.0  39.730820 -105.025232
# 7     CO   80223.0  39.770206 -105.020537
# 8     CO   80222.0  39.678008 -104.936220
# 9     CO   80216.0  39.786409 -104.993794
# 10    CO   80033.0  39.769108 -105.142375
# 11    CO   80207.0  39.772205 -104.924540
# 12    CO   81006.0  38.244036 -104.611101
# 13    CO   80204.0  39.730820 -105.025232

# %% [markdown]
# ## Step 3: Create a Searchable Map

# %%
# Initialize the map centered around Colorado
m = folium.Map(location=[39.5501, -105.7821], zoom_start=7)

# Add markers to the map for each food pantry
for idx, row in df.iterrows():
    popup_text = f"""
    <strong>{row['Facility Name']}</strong><br>
    <strong>{row['DBA']}</strong><br>
    {row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip Code']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m)

# Save the map as an HTML file
m.save("colorado_testing_facilities_full_list_map.html")

# Display the map in the notebook
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_abf7d37a9b449d528839809a6d37fec1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_abf7d37a9b449d528839809a6d37fec1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_abf7d37a9b449d528839809a6d37fec1 = L.map(
#                 &quot;map_abf7d37a9b449d528839809a6d37fec1&quot;,
#                 {
#                     center: [39.5501, -105.7821],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_43cacd20f26143271e10101d503f1195 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_43cacd20f26143271e10101d503f1195.addTo(map_abf7d37a9b449d528839809a6d37fec1);
#
#
#             var marker_a4f0cd84e29f86513a7c051bcdd00834 = L.marker(
#                 [39.770206, -105.020537],
#                 {}
#             ).addTo(map_abf7d37a9b449d528839809a6d37fec1);
#
#
#             var icon_e846c58f9f15d858d558af051e42f6e6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a4f0cd84e29f86513a7c051bcdd00834.setIcon(icon_e846c58f9f15d858d558af051e42f6e6);
#
#
#         var popup_e74494878d7e9b6657781afc750558e1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a366c7c29f1e3dda8f8e982a597b6fa4 = $(`&lt;div id=&quot;html_a366c7c29f1e3dda8f8e982a597b6fa4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;AGRICOR LABORATORIES DE LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;SC Labs&lt;/strong&gt;&lt;br&gt;     1301 S Jason Street, Unit K&lt;br&gt;     Denver, CO 80223.0     &lt;/div&gt;`)[0];
#                 popup_e74494878d7e9b6657781afc750558e1.setContent(html_a366c7c29f1e3dda8f8e982a597b6fa4);
#
#
#
#         marker_a4f0cd84e29f86513a7c051bcdd00834.bindPopup(popup_e74494878d7e9b6657781afc750558e1)
#         ;
#
#
#
#
#             var marker_4633bcb0453f242fe683030daa307414 = L.marker(
#                 [39.6780084, -104.9362201],
#                 {}
#             ).addTo(map_abf7d37a9b449d528839809a6d37fec1);
#
#
#             var icon_1f92b0f5c1219da5e18ebdcf10bf2b2e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4633bcb0453f242fe683030daa307414.setIcon(icon_1f92b0f5c1219da5e18ebdcf10bf2b2e);
#
#
#         var popup_c8ead9a93029ca2d5f36c9774f8531be = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2a241e9e6a10113e347a7a968c3aba28 = $(`&lt;div id=&quot;html_2a241e9e6a10113e347a7a968c3aba28&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;AGRISCIENCE LABS INC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;nan&lt;/strong&gt;&lt;br&gt;     2120 South Birch Street&lt;br&gt;     Denver, CO 80222.0     &lt;/div&gt;`)[0];
#                 popup_c8ead9a93029ca2d5f36c9774f8531be.setContent(html_2a241e9e6a10113e347a7a968c3aba28);
#
#
#
#         marker_4633bcb0453f242fe683030daa307414.bindPopup(popup_c8ead9a93029ca2d5f36c9774f8531be)
#         ;
#
#
#
#
#             var marker_25b36898f4cc6f0b7c8c3199528877bd = L.marker(
#                 [39.786409, -104.993794],
#                 {}
#             ).addTo(map_abf7d37a9b449d528839809a6d37fec1);
#
#
#             var icon_22b84ca9355ce61a0e345f65e7d05a7a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_25b36898f4cc6f0b7c8c3199528877bd.setIcon(icon_22b84ca9355ce61a0e345f65e7d05a7a);
#
#
#         var popup_2038bdc080d69fa59db45ea797fbba8f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_74cb6177eaf46885ae28c6fc5ec6deb8 = $(`&lt;div id=&quot;html_74cb6177eaf46885ae28c6fc5ec6deb8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;BONA FIDES MEDICAL&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Bona Fides Laboratory Inc.&lt;/strong&gt;&lt;br&gt;     4910 North Fox Street, Unit E&lt;br&gt;     Denver, CO 80216.0     &lt;/div&gt;`)[0];
#                 popup_2038bdc080d69fa59db45ea797fbba8f.setContent(html_74cb6177eaf46885ae28c6fc5ec6deb8);
#
#
#
#         marker_25b36898f4cc6f0b7

# %% [markdown]
# ## Step 4: Implement Search Functionality

# %%
# Example: Search for testing facilities in a specific city
city_search = "Denver"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[39.5501, -105.7821], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Facility Name']}</strong><br>
    <strong>{row['DBA']}</strong><br>
    {row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip Code']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_testing_facilities_map_denver.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c5b14009525fa607acb8836a887527c0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c5b14009525fa607acb8836a887527c0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c5b14009525fa607acb8836a887527c0 = L.map(
#                 &quot;map_c5b14009525fa607acb8836a887527c0&quot;,
#                 {
#                     center: [39.5501, -105.7821],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d35571ff1ac41a4431337b1760264830 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d35571ff1ac41a4431337b1760264830.addTo(map_c5b14009525fa607acb8836a887527c0);
#
#
#             var marker_97a02fd9542b3c8942bdc36c01421dea = L.marker(
#                 [39.770206, -105.020537],
#                 {}
#             ).addTo(map_c5b14009525fa607acb8836a887527c0);
#
#
#             var icon_786a3deeb6b818b3e161a7324acab61c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_97a02fd9542b3c8942bdc36c01421dea.setIcon(icon_786a3deeb6b818b3e161a7324acab61c);
#
#
#         var popup_58de1ed100d97ad20143205f6fb22377 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f70eb1fc607bcb46aab46fc909c2ce60 = $(`&lt;div id=&quot;html_f70eb1fc607bcb46aab46fc909c2ce60&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;AGRICOR LABORATORIES DE LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;SC Labs&lt;/strong&gt;&lt;br&gt;     1301 S Jason Street, Unit K&lt;br&gt;     Denver, CO 80223.0     &lt;/div&gt;`)[0];
#                 popup_58de1ed100d97ad20143205f6fb22377.setContent(html_f70eb1fc607bcb46aab46fc909c2ce60);
#
#
#
#         marker_97a02fd9542b3c8942bdc36c01421dea.bindPopup(popup_58de1ed100d97ad20143205f6fb22377)
#         ;
#
#
#
#
#             var marker_ee003a162331cdf98efc04fc5bf5ac37 = L.marker(
#                 [39.6780084, -104.9362201],
#                 {}
#             ).addTo(map_c5b14009525fa607acb8836a887527c0);
#
#
#             var icon_ec213d1f1dac179236659106d9005363 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ee003a162331cdf98efc04fc5bf5ac37.setIcon(icon_ec213d1f1dac179236659106d9005363);
#
#
#         var popup_5fb734b329aff7cbacd7496daaf9e999 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0de82280f4da18a88f7cb137e86a4f49 = $(`&lt;div id=&quot;html_0de82280f4da18a88f7cb137e86a4f49&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;AGRISCIENCE LABS INC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;nan&lt;/strong&gt;&lt;br&gt;     2120 South Birch Street&lt;br&gt;     Denver, CO 80222.0     &lt;/div&gt;`)[0];
#                 popup_5fb734b329aff7cbacd7496daaf9e999.setContent(html_0de82280f4da18a88f7cb137e86a4f49);
#
#
#
#         marker_ee003a162331cdf98efc04fc5bf5ac37.bindPopup(popup_5fb734b329aff7cbacd7496daaf9e999)
#         ;
#
#
#
#
#             var marker_3db85aa297bb6c7b188861b827efe99b = L.marker(
#                 [39.786409, -104.993794],
#                 {}
#             ).addTo(map_c5b14009525fa607acb8836a887527c0);
#
#
#             var icon_a6ee4abd4b7a5e30e32f3fd17beca6c2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3db85aa297bb6c7b188861b827efe99b.setIcon(icon_a6ee4abd4b7a5e30e32f3fd17beca6c2);
#
#
#         var popup_c076cf0115359112dac1d28a6daae902 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8539a0dccb06cf1a68e3a24a2801d2c7 = $(`&lt;div id=&quot;html_8539a0dccb06cf1a68e3a24a2801d2c7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;BONA FIDES MEDICAL&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;Bona Fides Laboratory Inc.&lt;/strong&gt;&lt;br&gt;     4910 North Fox Street, Unit E&lt;br&gt;     Denver, CO 80216.0     &lt;/div&gt;`)[0];
#                 popup_c076cf0115359112dac1d28a6daae902.setContent(html_8539a0dccb06cf1a68e3a24a2801d2c7);
#
#
#
#         marker_3db85aa297bb6c7b1

# %%
# Example: Search for testing facilities in a specific city
city_search = "Pueblo"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[38.2765, -104.6046], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Facility Name']}</strong><br>
    <strong>{row['DBA']}</strong><br>
    {row['Street']}<br>
    {row['City']}, {row['State']} {row['Zip Code']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text, icon=folium.Icon(icon="cloud",color="green")
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_testing_facilities_map_pueblo.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a46c3c3f98e8b5d54de626d310c86e83 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a46c3c3f98e8b5d54de626d310c86e83&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a46c3c3f98e8b5d54de626d310c86e83 = L.map(
#                 &quot;map_a46c3c3f98e8b5d54de626d310c86e83&quot;,
#                 {
#                     center: [38.2765, -104.6046],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f72cc55dcbfa25105ead286bd753a998 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f72cc55dcbfa25105ead286bd753a998.addTo(map_a46c3c3f98e8b5d54de626d310c86e83);
#
#
#             var marker_599d1e289ed4462f0680828ec8c6b385 = L.marker(
#                 [38.2440356, -104.611101],
#                 {}
#             ).addTo(map_a46c3c3f98e8b5d54de626d310c86e83);
#
#
#             var icon_5803703b31569f5cbc03daafdf970bfc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_599d1e289ed4462f0680828ec8c6b385.setIcon(icon_5803703b31569f5cbc03daafdf970bfc);
#
#
#         var popup_5a2d767528b69a724037239da1c6daa7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_469c88bb271a9f39d847c771116e5866 = $(`&lt;div id=&quot;html_469c88bb271a9f39d847c771116e5866&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;NORDIC ANALYTICAL LABORATORIES LLC &lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;nan&lt;/strong&gt;&lt;br&gt;     417 East Northern Avenue &lt;br&gt;     Pueblo, CO 81006.0     &lt;/div&gt;`)[0];
#                 popup_5a2d767528b69a724037239da1c6daa7.setContent(html_469c88bb271a9f39d847c771116e5866);
#
#
#
#         marker_599d1e289ed4462f0680828ec8c6b385.bindPopup(popup_5a2d767528b69a724037239da1c6daa7)
#         ;
#
#
#
#
#             var marker_5eb257189438ad6dd56abe3b45fb34d5 = L.marker(
#                 [38.2440356, -104.611101],
#                 {}
#             ).addTo(map_a46c3c3f98e8b5d54de626d310c86e83);
#
#
#             var icon_756f05a60dd169ed942de1bb823ad090 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5eb257189438ad6dd56abe3b45fb34d5.setIcon(icon_756f05a60dd169ed942de1bb823ad090);
#
#
#         var popup_3aad58c9d98bd06b9e96683639bee96b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_585a2140d651704fb10f581f6f8ecc9b = $(`&lt;div id=&quot;html_585a2140d651704fb10f581f6f8ecc9b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;NORDIC ANALYTICAL LABORATORIES LLC&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;nan&lt;/strong&gt;&lt;br&gt;     417 East Northern Avenue&lt;br&gt;     Pueblo, CO 81006.0     &lt;/div&gt;`)[0];
#                 popup_3aad58c9d98bd06b9e96683639bee96b.setContent(html_585a2140d651704fb10f581f6f8ecc9b);
#
#
#
#         marker_5eb257189438ad6dd56abe3b45fb34d5.bindPopup(popup_3aad58c9d98bd06b9e96683639bee96b)
#         ;
#
#
#
#
#             tile_layer_f72cc55dcbfa25105ead286bd753a998.addTo(map_a46c3c3f98e8b5d54de626d310c86e83);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Step 5: Export Cleaned Data to CSV

# %%
# Export the cleaned DataFrame to a CSV file
df.to_csv("cleaned_colorado_testing_facilities_full_list_v2.csv", index=False)

# Confirm the export
print("Data exported to colorado_testing_facilities_full_list_v2.csv")
# Out:
# Data exported to colorado_testing_facilities_full_list_v2.csv
